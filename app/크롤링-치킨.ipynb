# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 카페[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[9]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 25:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 카페 데이터(이미지) 수집
soup = BeautifulSoup(html, 'lxml')
img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
count = 1
for i in img:
    img_url = i.get_text("url", strip=True)
    img_url_parse = img_url[4:-1]
    try:
        urllib.request.urlretrieve(img_url_parse, f'{count}.chicken_food_img.jpg')
    except:
        pass
    count += 1

# 일식 데이터(식당명) 수집
japan_store_list = []
japan_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in japan_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(japan_store_list):
    print(i, name)


    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 8:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='치킨',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=1),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
        print('음식 카테고리 성공')
        print('=========================================')
        
        store_category_foods = menu.select(".row-menu")

        for food in store_category_foods:
            food_menu = food.select_one(".col-menu > strong").get_text(strip=True)
            print(food_menu)
            print('음식메뉴 성공')
            print('===============')
            food_info = food.select_one(".col-menu > span").get_text(strip=True)
            print(food_info)
            print('음식정보 성공')
            print('===============')
            food_money = food.select_one("span.calculate-price").get_text(strip=True)
            food_moneys = food_money.replace(",", "")
            print(food_moneys)
            print('금액 성공')
            print('===============')
            
            Food.objects.create(
            category=food_category,
            name=food_menu,
            price=food_moneys,
            food_info=food_info,
            )

        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:83: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하1층
# 주소 뽑기 성공
# =========================================
#
# 종선이네 삼대가족의 노하우가 만난 닭강정 맛집
# Chicken & Soul Food from Incheon
#
# 종선이네는 80년대의 인천 신포시장 엄마네 닭집의 추억과
# 종가집에서 대대로 내려오는 우리의 전통 할머니네 장과 쌈으로
# 한국인이 가장 좋아하는 닭강정을 요리하는 곳 입니다.
#
# 강남구 논현점 매장에 이어, 역삼점을 오픈하였습니다.
# #종선이네 #닭치고 쌈싸먹어 #닭강정 맛집
#
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 누룽지,볶은현미: 국내산
# 고춧가루: 중국산
# 베이컨 :수입산
# 닭고기 : 국내산,브라질산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [종선이네 전통장]
# 음식 카테고리 성공
# =========================================
# [종선이네 신포시장]
# 음식 카테고리 성공
# =========================================
# [류셰프 X 종선이네]
# 음식 카테고리 성공
# =========================================
# [반마리]
# 음식 카테고리 성공
# =========================================
# [찜닭갈비]
# 음식 카테고리 성공
# =========================================
# [분식 & 사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [음료수]
# 음식 카테고리 성공
# =========================================
# [종선이네 전통장]
# 음식 카테고리 성공
# =========================================
# 유자 된장 닭강정
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 숙성 간장 닭강정
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 장독대 고추장 닭강정
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 마늘 쌈장 닭강정
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 사천식 중화풍 닭강정
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# [종선이네 신포시장]
# 음식 카테고리 성공
# =========================================
# 고추깻잎 순살치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 검은깨 순살치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# [류셰프 X 종선이네]
# 음식 카테고리 성공
# =========================================
# 레몬크림 닭강정
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 깐풍소스 순살치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 블랙페퍼 닭강정
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [반마리]
# 음식 카테고리 성공
# =========================================
# 유자된장 닭강정 반마리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 숙성간장 닭강정 반마리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 장독대고추장 닭강정 반마리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 마늘쌈장 닭강정 반마리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 사천식 중화풍 닭강정 반마리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 레몬크림닭강정 반마리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 깐풍소스 닭강정 반마리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 블랙페퍼 닭강정 반마리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 고추깻잎순살치킨 반마리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 검은깨 순살치킨 반마리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# [찜닭갈비]
# 음식 카테고리 성공
# =========================================
# 마늘간장 찜닭갈비
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 볶음 짜장 찜닭갈비
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 허니고추장 찜닭갈비
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 불닭 찜닭갈비
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# [분식 & 사이드메뉴]
# 음식 카테고리 성공
# =========================================
# 빨간 치볶이
# 음식메뉴 성공
# ===============
# 고추장 떡볶이 + 순살치킨
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 모듬튀김
# 음식메뉴 성공
# ===============
# 오징어, 김말이, 만두, 야채, 게맛살
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 여수식 갓짱아찌 파스타
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 감자튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 씨앗호떡
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 타꼬야끼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 모듬 고로케
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 매콤 비빔당면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# [음료수]
# 음식 카테고리 성공
# =========================================
# 코카콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 대만식 블랙티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 대만식 블랙밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# 대만식 타로밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:217: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 강남구 역삼동 668-9 지하1층
# 주소 뽑기 성공
# =========================================
# 치킨과 피자 전문점 '치킨먹고팔자피자'입니다.
#
# 가게 소개 뽑기 성공
# =========================================
# 닭고기 	국내산,브라질산돼지고기	호주산 미국산 아일랜드산 스페인산 독일산 미국산소고기	호주산 미국산생새우	베트남산햄	스페인산 미국산 벨기에산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [피자메뉴]
# 음식 카테고리 성공
# =========================================
# [치킨메뉴]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# 세트1
# 음식메뉴 성공
# ===============
# (슈퍼콤비네이션/페페로니 가득피자/체다치즈피자)택1 + 치킨+ 콜라
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 세트2
# 음식메뉴 성공
# ===============
# (베이컨 포테이토피자/스트링치즈 고구마피자/클래식 고구마 피자치즈 후라이피자/하와이안피자/생모짜렐라 피자/소불고기피자크리미어니언 피자) 택1 + 치킨+ 콜라
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 세트3
# 음식메뉴 성공
# ===============
# (바베큐더블소세지 피자/쉬림프 핫치킨피자/트리플바베큐피자갈릭앤갈릭피자/통새우 불고기 피자/베이컨콰드로피자)택1 + 치킨+ 콜라
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# [피자메뉴]
# 음식 카테고리 성공
# =========================================
# 슈퍼콤비네이션
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# 페페로니 가득피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# 체다치즈피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# 베이컨 포테이토피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 스트링치즈 고구마피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 클래식 고구마 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 치즈 후라이 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# 하와이안피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# 프리미엄 소불고기피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# 크리미어니언피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 생모짜렐라피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# 바베큐더블소세지 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 쉬림프 핫치킨피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 트리플 바베큐피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 갈릭앤갈릭피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 통새우 불고기 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 베이컨콰드로피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 엑스트라쿼터피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20900
# 금액 성공
# ===============
# [치킨메뉴]
# 음식 카테고리 성공
# =========================================
# 후라이드 치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 양념치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 허니갈릭
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 허브간장 치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 핫양념치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 볼케이노 치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 강남구 역삼동 730-5 1층
# 주소 뽑기 성공
# =========================================
#
# 치킨이 누나홀닭을 만나면 요리가 된다!
# 맛있는 치킨 요리가 시작되는 곳!
# 프리미엄 웰빙 오븐 치킨 전문점, 누구나 홀딱 반한 누나홀닭~!
#
#
# 가게 소개 뽑기 성공
# =========================================
# 닭고기 : 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [오븐치킨]
# 음식 카테고리 성공
# =========================================
# [오븐순살치킨]
# 음식 카테고리 성공
# =========================================
# [쌈닭]
# 음식 카테고리 성공
# =========================================
# [풍미메뉴]
# 음식 카테고리 성공
# =========================================
# [미니메뉴]
# 음식 카테고리 성공
# =========================================
# [실속세트메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [오븐치킨]
# 음식 카테고리 성공
# =========================================
# 닭들애나쵸
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공사랑에 빠진 베이크치킨과 바삭한 나쵸! 그 위에 뿌려진 치즈갈릭소스와 닭들애(愛) 나쵸소스의 더블 MIX
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 바사칸닭
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공바삭함 속에 감춰진 풍부한 맛! 마성의 베이크 치킨
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# 땡초치킨
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공정신이 번쩍 나는 매콤 고추의 중독적인 맛!!
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 간장치킨
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공마늘과 간장의 적절한 조화!!짜지않고 담백한 누나홀닭만의 간장 치킨!!
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 양념치킨
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공토마토와 칠리소스로 맛을 낸 한국형 양념 치킨!!!
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 촉촉칸닭
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공기름 Down 육즙 UP!촉촉하고 담백한 오리지널 로스트 치킨!!
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# [오븐순살치킨]
# 음식 카테고리 성공
# =========================================
# 닭들애나쵸순살
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공사랑에 빠진 베이크치킨과 바삭한 나쵸! 그 위에 뿌려진 치즈갈릭소스와 닭들애(愛) 나쵸소스의 더블 MIX
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 바사칸순살
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공바삭함 속에 감춰진 풍부한 맛! 마성의 베이크 치킨
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 땡초순살
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공정신이 번쩍 나는 매콤 고추의 중독적인 맛!!
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 간장순살
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공마늘과 간장의 적절한 조화!!짜지않고 담백한 누나홀닭만의 간장 치킨!!
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 양념순살
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공토마토와 칠리소스로 맛을 낸 한국형 양념 치킨!!!
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 촉촉칸순살
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공기름 Down 육즙 UP!촉촉하고 담백한 오리지널 로스트 치킨!!
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# [쌈닭]
# 음식 카테고리 성공
# =========================================
# 후레쉬쌈닭
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공로스트 치킨순살을 상큼한 야채와 무쌈에 싸먹는 후레쉬한 웰빙쌈!!
# 음식정보 성공
# ===============
# 19900
# 금액 성공
# ===============
# 쌈닭화이타
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공매콤한 볶은 야채, 감자, 로스트 치킨순살을 또띠아에 싸먹는 멕시칸 Style 쌈!
# 음식정보 성공
# ===============
# 19900
# 금액 성공
# ===============
# 파닥파닭
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공그라나파다노 치즈로 토핑된 파채와 로스트 치킨순살을 싸먹는 쌈닭메뉴!
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# [풍미메뉴]
# 음식 카테고리 성공
# =========================================
# 시실리안치킨퀘사디아
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공오븐에서 수제로 구워 낸 시실리안 스타일의 치즈 듬뿍 치킨 퀘사디아
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 쫄뱅이
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공쫄쫄쫄 쫄면과 골뱅이의 만남!
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# [미니메뉴]
# 음식 카테고리 성공
# =========================================
# 살사나쵸
# 음식메뉴 성공
# ===============
# 멕시칸 나쵸를 살사소스와 함께 가볍게 즐길 수 있는 메뉴
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 헐~ 3줄소시지
# 음식메뉴 성공
# ===============
# 소시지는 조금만 먹고 싶은데...수제소시지 2줄과 감자로 가볍게 즐기세요!!
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 러블리샐러드
# 음식메뉴 성공
# ===============
# 실속형 하우스 샐러드!
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 오다리튀김
# 음식메뉴 성공
# ===============
# 탱탱한 오징어다리를 바삭하게 튀긴 중독적인 맛!
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 미안한 포테이토 ( 치킨 주문시에만 가능 )
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 국물떡볶이 ( 치킨 주문시에만 가능 )
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# [실속세트메뉴]
# 음식 카테고리 성공
# =========================================
# 세트 1
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공바사칸닭 + 러블리샐러드
# 음식정보 성공
# ===============
# 24900
# 금액 성공
# ===============
# 세트 2
# 음식메뉴 성공
# ===============
# 콜라(245ml)제공바사칸닭 + 쫄뱅이
# 음식정보 성공
# ===============
# 30900
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다(500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 콜라 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 사이다 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 순살변경
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 강남구 역삼동 672-30 2층
# 주소 뽑기 성공
# =========================================
#
# 귀한 맛집일수록 꼭꼭 숨어있다?역삼동 골목길에 위치해 있지만 이미 알만한 사람들은 다~~아는유명한 역삼동 맛집 호또치킨!!!그 치킨이 푸드플라이에 드디어 상륙하다!매일매일 주문과 동시에 그자리에서 튀겨내는 신선한 닭의 맛!이젠 호또치킨의 중독성 강한맛을 저희 푸드플라이와 함께 즐겨요~
#
#
# 가게 소개 뽑기 성공
# =========================================
# 뼈있는닭 : 국내산뼈없는닭(순살) : 수입산(브라질산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [치킨메뉴 A (Chicken Menu A)]
# 음식 카테고리 성공
# =========================================
# [치킨메뉴 B (Chicken Menu B)]
# 음식 카테고리 성공
# =========================================
# [스페셜 (Special)]
# 음식 카테고리 성공
# =========================================
# [사이드 (Side Menu)]
# 음식 카테고리 성공
# =========================================
# [음료 (Drinks)]
# 음식 카테고리 성공
# =========================================
# [반/반 (Half and Half)]
# 음식 카테고리 성공
# =========================================
# [치킨메뉴 A (Chicken Menu A)]
# 음식 카테고리 성공
# =========================================
# 오리지널
# 음식메뉴 성공
# ===============
# 가장 기본적인 오리지널 치킨의 맛을 호또와 함께 느껴보세요.
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 통후추치킨
# 음식메뉴 성공
# ===============
# 호또치킨의 가장 대표적 인기메뉴 통후추치킨. 통후추와 치킨의 환상적인만남! 한번 맛보면 계속 중독되는 그 맛을 느껴보세요.
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 카레치킨
# 음식메뉴 성공
# ===============
# 바삭한 치킨에 카레가 더해져 더욱 매력적인 맛 카레치킨.
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 핫크리스피
# 음식메뉴 성공
# ===============
# 호또치킨만의 특제소스로 한층더 맛있어진 핫크리스피 치킨.
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# [치킨메뉴 B (Chicken Menu B)]
# 음식 카테고리 성공
# =========================================
# 어니언치킨
# 음식메뉴 성공
# ===============
# 양파의향이 코를자극하고 치킨의 담백함이 입을 자극하는 새로운맛.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 간장치킨
# 음식메뉴 성공
# ===============
# 간장소스를 입어 더욱 맛있는 호또의 간장치킨.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 양념치킨
# 음식메뉴 성공
# ===============
# 자체개발한 호또의 특제소스로 만들어진 양념치킨 호또치킨의 인기메뉴중 한가지 입니다.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# [스페셜 (Special)]
# 음식 카테고리 성공
# =========================================
# 부추골뱅이
# 음식메뉴 성공
# ===============
# 신선한 골뱅이를 부추와함께 드시는 스페셜 메뉴.
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# [사이드 (Side Menu)]
# 음식 카테고리 성공
# =========================================
# 감자말이새우(10개)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 새우튀김(10개)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 치즈스틱+고구마치즈스틱
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 오징어링+김말이튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 감자+고구마튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 해시브라운
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 감자튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 고구마튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 소스 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# [음료 (Drinks)]
# 음식 카테고리 성공
# =========================================
# 코카콜라 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 코카콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 웰치스 포도 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 웰치스 딸기 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# [반/반 (Half and Half)]
# 음식 카테고리 성공
# =========================================
# 어니언+간장
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 어니언+양념
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 간장+어니언
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 간장+양념
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 양념+어니언
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 양념+간장
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 오리지널+어니언
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 오리지널+간장
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 카레+어니언
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 카레+간장
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 카레+양념
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 통후추+어니언
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 통후추+간장
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 통후추+양념
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 오리지널+통후추
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 오리지널+카레
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 통후추+오리지널
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 통후추+카레
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 카레+오리지널
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 카레+통후추
# 음식메뉴 성공
# ===============
# 순살은 불가합니다 양해 부탁드립니다.
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 오리지널+양념
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 서초구 서초동 1309-6
# 주소 뽑기 성공
# =========================================
# 생생정보통등 매스컴에서 극찬한 줄서서 먹는 통닭집 '이수 통닭'입니다.저희 '가마솥닭'이 맛있는 이유1. 신선한 국내산 냉장닭을 씁니다.2. 직접 손질하여 한번 더 세척합니다.3. 염장(염지) 하지 않습니다.4. 주문시 생닭을 즉시 조리 합니다.5. 조리시 사용되는 가마솥을 매일 손질/세척 합니다.6. 기름 정제기를 쓰지않고 매일 매일 새기름으로 교체합니다.
#
# 가게 소개 뽑기 성공
# =========================================
# 냉장닭 : 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [가마솥치킨  (1마리)]
# 음식 카테고리 성공
# =========================================
# [골뱅이세트]
# 음식 카테고리 성공
# =========================================
# [기타메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [가마솥치킨  (1마리)]
# 음식 카테고리 성공
# =========================================
# 가마솥 옛날 통닭 (1마리)
# 음식메뉴 성공
# ===============
# 매일 깨끗한 기름으로 바로 튀겨내는 이수통닭의 대표메뉴 가마솥 누드 통닭!
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 후라이드 치킨 (1마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 양념 치킨 (1마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 깐풍 치킨 (1마리)
# 음식메뉴 성공
# ===============
# 이수통닭의 인기메뉴!
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 통후추 치킨 (1마리)
# 음식메뉴 성공
# ===============
# 통후추와 바삭하게 튀겨낸 매력적인 맛 통후추치킨!
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 반반 치킨 (1마리)
# 음식메뉴 성공
# ===============
# 양념치킨 + 후라이드치킨
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 통후추 반반 치킨 (1마리)
# 음식메뉴 성공
# ===============
# 통후추 치킨 + 후라이드 치킨
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 깐풍 반반 치킨 (1마리)
# 음식메뉴 성공
# ===============
# 깐풍 치킨 + 후라이드 치킨
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 깐풍 반 + 통후추 반
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 깐풍 반 + 양념 반
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 통후추 반 + 양념 반
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 후라이드 치킨 (반마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 양념 치킨 (반마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 깐풍 치킨 (반마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 통후추 치킨 (반마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 모래집 튀김 (1마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 깐풍 모래집 튀김 (1마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 모래집 튀김 (반마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# [골뱅이세트]
# 음식 카테고리 성공
# =========================================
# 가마솥 옛날 통닭 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 후라이드 치킨 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 양념 치킨 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 깐풍 치킨 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 통후추 치킨 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 치킨 반마리 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 양념 반마리 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 깐풍 반마리 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 통후추 반마리 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 모래집 튀김 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 반반 치킨 & 골뱅이
# 음식메뉴 성공
# ===============
# 양념치킨 + 후라이드치킨
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 깐풍 반반 & 골뱅이
# 음식메뉴 성공
# ===============
# 깐풍 치킨 + 후라이드 치킨
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 통후추 반반 & 골뱅이
# 음식메뉴 성공
# ===============
# 통후추 치킨 + 후라이드 치킨
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 깐풍 반 + 통후추 반 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 양념 반 + 통후추 반 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 양념 반 + 깐풍 반 & 골뱅이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# [기타메뉴]
# 음식 카테고리 성공
# =========================================
# 동표 을지로 골뱅이(소면)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 먹태
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 노가리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 한치
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 마른 오징어
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 양념 소스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# 겨자 소스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 파인애플 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---6번 식당파싱 시작 ---
# 서울 서초구 서초동 1665-7
# 주소 뽑기 성공
# =========================================
#
# 가마로강정은 주문과 동시에 착한재료를 이용하여 튀겨냅니다.가마솥을 이용한 튀김기법 (열전도율이 높은 가마솥에서 튀겨내어 더욱 바삭합니다.)소화율이 뛰어난 쌀가루반죽 (밀가루반죽에 비해 낮은열량과 쌀가루를 이용하여 차별화된 바삭한 식감)옥수수100% (가마로강정만의 전용유 사용)(강정 주문시 무, 음료수는 포함되지 않습니다.)
#
#
# 가게 소개 뽑기 성공
# =========================================
# 순살강정, 순살치킨 : 미국산,브라질산후라이드치킨: 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15500
# 최소 금액 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [사이드 메뉴]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# 땡초+달콤 반반 세트
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 땡초+매콤 반반 세트
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 땡초세트 (대)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# 반반 세트 (매콤 + 달콤)
# 음식메뉴 성공
# ===============
# 반반 닭강정 + 무 + 음료 택1
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 달콤 세트
# 음식메뉴 성공
# ===============
# 달콤 닭강정(대) + 무 + 음료 택1
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 매콤 세트
# 음식메뉴 성공
# ===============
# 매콤 닭강정(대) + 무 + 음료 택1
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 후라이드 세트
# 음식메뉴 성공
# ===============
# 후라이드 한마리 + 무 + 음료 택1
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 마늘간장순살치킨
# 음식메뉴 성공
# ===============
# 무 + 음료 택1
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# 칠리새우순살치킨
# 음식메뉴 성공
# ===============
# 무 + 음료 택1
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# [사이드 메뉴]
# 음식 카테고리 성공
# =========================================
# 콜라 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 마운틴듀 (400ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 치즈갈릭소스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 각 무
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# 칠리살사소스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 서울 강남구 역삼동 696-40
# 주소 뽑기 성공
# =========================================
#
# 오랜 친구처럼 변함없는 맛!깐부치킨은 다년간의 깐부연구소 개발, 투자를 통해 오랜 시간 치킨의 맛이 변하지 않도록 연구하였습니다.
# 손님께서 언제나 부담 없이 편안하게 그리고 맛있게 드실 수 있도록 온 힘을 다하겠습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 닭고기 : 국내산감자 : 미국산샐러드 : 국내산(야채믹스) 드레싱 : 외국산(아르헨티나, 미국, 베트남등)소세지 : 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [치킨 메뉴 (Chicken Menu)]
# 음식 카테고리 성공
# =========================================
# [사이드 메뉴 (Side Menu)]
# 음식 카테고리 성공
# =========================================
# [세트 메뉴 (Set Menu)]
# 음식 카테고리 성공
# =========================================
# [기타]
# 음식 카테고리 성공
# =========================================
# [치킨 메뉴 (Chicken Menu)]
# 음식 카테고리 성공
# =========================================
# 마늘 전기구이
# 음식메뉴 성공
# ===============
# 아삭하고 은은한 마늘향이 치킨 곳곳에 스며들어 먹어도 질리지 않는 웰빙치킨입니다.
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 전기구이 치킨
# 음식메뉴 성공
# ===============
# 50,60년대 향수를 불러일으키는 옛날 맛 그대로~ 남녀노소 누구나 좋아하는 기름기 적고 맛은담백한 깐부의 추천메뉴!
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 후라이드 치킨
# 음식메뉴 성공
# ===============
# 깐부만의 특별 염지 가공법으로 속살이 부드럽고 연하며, 바삭함이 오래가는 고소한 맛에 반하게 되는 메뉴입니다.
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 크리스피 치킨
# 음식메뉴 성공
# ===============
# 깐부만의 특별 염지 가공한 닭에 특별한 튀김옷을 입혀 속살은 부드럽고 겉은 바삭한 특별한 치킨!
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 순살 크리스피
# 음식메뉴 성공
# ===============
# 고단백 저지방의 순살과 코울슬로 + 웨지포테이토가 같이 나옵니다.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 깐부 불사조(순살)
# 음식메뉴 성공
# ===============
# 잊혀졌던 매운맛이 돌아왔다~ 불 사 조. 코울슬로 + 어니언포테이토가 같이 나옵니다
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 양념치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 순살스윗치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 순살파닭
# 음식메뉴 성공
# ===============
# 깐부만의 특별한 소스와 파를 곁들여 영양가 만점의 치킨.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고추 후라이드 치킨
# 음식메뉴 성공
# ===============
# 깐부만의 특별 염지 가공법과 파우더에 청양고추를 가미한 매콤한 맛의 후라이드 치킨입니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 순살고추간장치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 마늘간장치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 반반치킨 (후라이드 + 양념)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 오리지날 윙 & 봉 크런치 (20pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 마늘간장 윙 & 봉 크런치 (20pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 불사조 윙 & 봉 크런치 (20pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 깐부유린치킨 (안심살)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# [사이드 메뉴 (Side Menu)]
# 음식 카테고리 성공
# =========================================
# 깐부 골뱅이
# 음식메뉴 성공
# ===============
# 신선한 골뱅이가 깐부에 떴다! 골뱅이와 쌉싸름한 파에 깐부만의 매콤,새콤,달콤한 양념으로 맛을 낸 깐부 골뱅이! 쫄면사리에 비벼먹는 깐부만의 특별한 골뱅이 무침!
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 깐부소세지
# 음식메뉴 성공
# ===============
# 유럽식 전통 수제 소세지. (어니언포테이토 포함.)
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 웨지 포테이토
# 음식메뉴 성공
# ===============
# 허브가 쏙쏙 들어가 더욱 담백하고 고소한 웨지 포테이토입니다.
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 스파이시포테이토
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 케이준치킨샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 코울슬러
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 파샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 마늘토핑
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 코카콜라 (1.25리터)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# [세트 메뉴 (Set Menu)]
# 음식 카테고리 성공
# =========================================
# A set
# 음식메뉴 성공
# ===============
# 전기구이 + 골뱅이 + 웨지포테이토로 구성된 메뉴 입니다.
# 음식정보 성공
# ===============
# 42000
# 금액 성공
# ===============
# B set
# 음식메뉴 성공
# ===============
# 후라이드 + 골뱅이 + 웨지포테이토로 구성된 메뉴 입니다.
# 음식정보 성공
# ===============
# 44000
# 금액 성공
# ===============
# C set
# 음식메뉴 성공
# ===============
# 크리스피 + 골뱅이 + 웨지포테이토로 구성된 메뉴 입니다.
# 음식정보 성공
# ===============
# 45000
# 금액 성공
# ===============
# D set
# 음식메뉴 성공
# ===============
# 마늘전기구이 + 골뱅이 + 웨지포테이토로 구성된 메뉴 입니다.
# 음식정보 성공
# ===============
# 44000
# 금액 성공
# ===============
# E set
# 음식메뉴 성공
# ===============
# 고추 후라이드 + 골뱅이 + 웨지포테이토로 구성된 메뉴 입니다.
# 음식정보 성공
# ===============
# 47000
# 금액 성공
# ===============
# [기타]
# 음식 카테고리 성공
# =========================================
# 무 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# 소스 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 300
# 금액 성공
# ===============
# ===========끝===========
# ---8번 식당파싱 시작 ---
# 서울 강남구 논현동 209 1층 105/106호
# 주소 뽑기 성공
# =========================================
#
# 오랜 친구처럼 변함없는 맛!깐부치킨은 다년간의 깐부연구소 개발, 투자를 통해 오랜 시간 치킨의
# 맛이 변하지 않도록 연구하였습니다.
# 손님께서 언제나 부담 없이 편안하게 그리고 맛있게 드실 수 있도록 온 힘을 다하겠습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 닭고기 : 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [치킨 메뉴 (Chicken Menu)]
# 음식 카테고리 성공
# =========================================
# [사이드 메뉴 (Side Menu)]
# 음식 카테고리 성공
# =========================================
# [세트 메뉴 (Set Menu)]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [치킨 메뉴 (Chicken Menu)]
# 음식 카테고리 성공
# =========================================
# 순살 크리스피
# 음식메뉴 성공
# ===============
# 고단백 저지방의 순살과 웨지포테이토가 같이 나옵니다.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 깐부 불사조
# 음식메뉴 성공
# ===============
# 잊혀졌던 매운맛이 돌아왔다~ 불 사 조.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 마늘 전기구이
# 음식메뉴 성공
# ===============
# 아삭하고 은은한 마늘향이 치킨 곳곳에 스며들어 먹어도 질리지 않는 웰빙치킨입니다.
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 전기구이 치킨
# 음식메뉴 성공
# ===============
# 50,60년대 향수를 불러일으키는 옛날 맛 그대로~ 남녀노소 누구나 좋아하는 기름기 적고 맛은담백한 깐부의 추천메뉴!
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 후라이드 치킨
# 음식메뉴 성공
# ===============
# 깐부만의 특별 염지 가공법으로 속살이 부드럽고 연하며, 바삭함이 오래가는 고소한 맛에 반하게 되는 메뉴입니다.
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 양념반 + 후라이드반
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 양념치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 크리스피 치킨
# 음식메뉴 성공
# ===============
# 깐부만의 특별 염지 가공한 닭에 특별한 튀김옷을 입혀 속살은 부드럽고 겉은 바삭한 특별한 치킨!
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 크리스피반 + 양념반
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 크리스피 치킨 (양념)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 고추 후라이드 치킨
# 음식메뉴 성공
# ===============
# 깐부만의 특별 염지 가공법과 파우더에 청양고추를 가미한 매콤한 맛의 후라이드 치킨입니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 순살파닭
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고추간장치킨(순살)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 순살스윗치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 윙&봉
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 마늘간장치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 윙 & 봉 크런치
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 마늘간장 윙 & 봉 크런치
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 불사조 윙 & 봉 크런치
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 바삭한 식스팩
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# [사이드 메뉴 (Side Menu)]
# 음식 카테고리 성공
# =========================================
# 깐부 골뱅이
# 음식메뉴 성공
# ===============
# 신선한 골뱅이가 깐부에 떴다! 골뱅이와 쌉싸름한 파에 깐부만의 매콤,새콤,달콤한 양념으로 맛을 낸 깐부 골뱅이! 쫄면사리에 비벼먹는 깐부만의 특별한 골뱅이 무침!
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 깐부 불닭발
# 음식메뉴 성공
# ===============
# 화끈한 여성들에게 더더욱 인기 만점인 메뉴! 콜라겐이 듬뿍,입안이 얼얼! 불닭발과 함께 스트레스를 날려버리자!
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 깐부소세지
# 음식메뉴 성공
# ===============
# 유럽식 전통 수제 소세지.
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 오돌뼈&주먹밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 한치
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 노가리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 스파이시포테이토
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 웨지 포테이토
# 음식메뉴 성공
# ===============
# 허브가 쏙쏙 들어가 더욱 담백하고 고소한 웨지 포테이토입니다.
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# [세트 메뉴 (Set Menu)]
# 음식 카테고리 성공
# =========================================
# A set
# 음식메뉴 성공
# ===============
# 전기구이 + 골뱅이 + 웨지포테이토
# 음식정보 성공
# ===============
# 41000
# 금액 성공
# ===============
# B set
# 음식메뉴 성공
# ===============
# 후라이드 + 골뱅이 + 웨지포테이토
# 음식정보 성공
# ===============
# 43000
# 금액 성공
# ===============
# C set
# 음식메뉴 성공
# ===============
# 크리스피 + 골뱅이 + 웨지포테이토
# 음식정보 성공
# ===============
# 44000
# 금액 성공
# ===============
# D set
# 음식메뉴 성공
# ===============
# 마늘전기구이 + 골뱅이 + 웨지포테이토
# 음식정보 성공
# ===============
# 43000
# 금액 성공
# ===============
# E set
# 음식메뉴 성공
# ===============
# 고추 후라이드 + 골뱅이 + 웨지포테이토
# 음식정보 성공
# ===============
# 46000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (1.5L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---9번 식당파싱 시작 ---
# 서울 강남구 신사동 517-15 2층
# 주소 뽑기 성공
# =========================================
#
# 안녕하세요 가로수길에위치한 순수하게 맛있는 순수치킨입니다.
# 국내산 신선육으로 깔끔하고 맛있게 튀겨내는 핫한 치킨! 오늘 순수하시고 행복하세요!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 닭(신선육) : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [메인 메뉴]
# 음식 카테고리 성공
# =========================================
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [메인 메뉴]
# 음식 카테고리 성공
# =========================================
# 순수치킨 (후라이드)
# 음식메뉴 성공
# ===============
# 순수치킨만의 바삭하고 고소한 후라이드 치킨
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 사과양념치킨
# 음식메뉴 성공
# ===============
# 오리지널 양념치킨이 사과를 품어 신선한 향이 듬뿍
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 벌꿀간장치킨
# 음식메뉴 성공
# ===============
# 달콤 짭조름한 순수만의 특제 간장소스, 벌꿀을 넣어 고급스런 맛
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 마늘치킨
# 음식메뉴 성공
# ===============
# 마늘을 듬뿍 넣어 알싸함이 일품, 신선하고 건강한 맛
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고마치킨
# 음식메뉴 성공
# ===============
# 고추와 마늘이 만나 고마치킨! 매콤새콤달콤함이 어우러져 풍미작렬
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고추치킨
# 음식메뉴 성공
# ===============
# 맛있고 화끈하게 매운 맛이 그리울 땐 고추치킨,매움 레벨 100!
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 반반치킨
# 음식메뉴 성공
# ===============
# 순수치킨(후라이드)반 + 양념(5종 중 택1)반
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 반반치킨 2
# 음식메뉴 성공
# ===============
# 양념치킨 메뉴 5종 중 택2
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# 호로록떡볶이
# 음식메뉴 성공
# ===============
# 매콤달콤한 순수의 특제 떡볶이, 떡볶이 전문점보다 맛잇다는 호평이 가득
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 바삭이쥐포
# 음식메뉴 성공
# ===============
# 바삭한 쥐포로 치맥에 감초 역할!
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 감자칩
# 음식메뉴 성공
# ===============
# 신선한 슬라이스 감자 후라이
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 콜라 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# ===========끝===========
# ---10번 식당파싱 시작 ---
# 10번 오류
# 서울 강남구 신사동 517-15 2층
# 주소 뽑기 성공
# =========================================
#
# 안녕하세요 가로수길에위치한 순수하게 맛있는 순수치킨입니다.
# 국내산 신선육으로 깔끔하고 맛있게 튀겨내는 핫한 치킨! 오늘 순수하시고 행복하세요!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 닭(신선육) : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [메인 메뉴]
# 음식 카테고리 성공
# =========================================
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [메인 메뉴]
# 음식 카테고리 성공
# =========================================
# 순수치킨 (후라이드)
# 음식메뉴 성공
# ===============
# 순수치킨만의 바삭하고 고소한 후라이드 치킨
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 사과양념치킨
# 음식메뉴 성공
# ===============
# 오리지널 양념치킨이 사과를 품어 신선한 향이 듬뿍
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 벌꿀간장치킨
# 음식메뉴 성공
# ===============
# 달콤 짭조름한 순수만의 특제 간장소스, 벌꿀을 넣어 고급스런 맛
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 마늘치킨
# 음식메뉴 성공
# ===============
# 마늘을 듬뿍 넣어 알싸함이 일품, 신선하고 건강한 맛
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고마치킨
# 음식메뉴 성공
# ===============
# 고추와 마늘이 만나 고마치킨! 매콤새콤달콤함이 어우러져 풍미작렬
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고추치킨
# 음식메뉴 성공
# ===============
# 맛있고 화끈하게 매운 맛이 그리울 땐 고추치킨,매움 레벨 100!
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 반반치킨
# 음식메뉴 성공
# ===============
# 순수치킨(후라이드)반 + 양념(5종 중 택1)반
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 반반치킨 2
# 음식메뉴 성공
# ===============
# 양념치킨 메뉴 5종 중 택2
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# 호로록떡볶이
# 음식메뉴 성공
# ===============
# 매콤달콤한 순수의 특제 떡볶이, 떡볶이 전문점보다 맛잇다는 호평이 가득
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 바삭이쥐포
# 음식메뉴 성공
# ===============
# 바삭한 쥐포로 치맥에 감초 역할!
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 감자칩
# 음식메뉴 성공
# ===============
# 신선한 슬라이스 감자 후라이
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 콜라 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# ===========끝===========
# ---10번 식당파싱 시작 ---
# 10번 오류
# 서울 강남구 신사동 517-15 2층
# 주소 뽑기 성공
# =========================================
#
# 안녕하세요 가로수길에위치한 순수하게 맛있는 순수치킨입니다.
# 국내산 신선육으로 깔끔하고 맛있게 튀겨내는 핫한 치킨! 오늘 순수하시고 행복하세요!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 닭(신선육) : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [메인 메뉴]
# 음식 카테고리 성공
# =========================================
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [메인 메뉴]
# 음식 카테고리 성공
# =========================================
# 순수치킨 (후라이드)
# 음식메뉴 성공
# ===============
# 순수치킨만의 바삭하고 고소한 후라이드 치킨
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 사과양념치킨
# 음식메뉴 성공
# ===============
# 오리지널 양념치킨이 사과를 품어 신선한 향이 듬뿍
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 벌꿀간장치킨
# 음식메뉴 성공
# ===============
# 달콤 짭조름한 순수만의 특제 간장소스, 벌꿀을 넣어 고급스런 맛
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 마늘치킨
# 음식메뉴 성공
# ===============
# 마늘을 듬뿍 넣어 알싸함이 일품, 신선하고 건강한 맛
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고마치킨
# 음식메뉴 성공
# ===============
# 고추와 마늘이 만나 고마치킨! 매콤새콤달콤함이 어우러져 풍미작렬
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고추치킨
# 음식메뉴 성공
# ===============
# 맛있고 화끈하게 매운 맛이 그리울 땐 고추치킨,매움 레벨 100!
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 반반치킨
# 음식메뉴 성공
# ===============
# 순수치킨(후라이드)반 + 양념(5종 중 택1)반
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 반반치킨 2
# 음식메뉴 성공
# ===============
# 양념치킨 메뉴 5종 중 택2
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# 호로록떡볶이
# 음식메뉴 성공
# ===============
# 매콤달콤한 순수의 특제 떡볶이, 떡볶이 전문점보다 맛잇다는 호평이 가득
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 바삭이쥐포
# 음식메뉴 성공
# ===============
# 바삭한 쥐포로 치맥에 감초 역할!
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 감자칩
# 음식메뉴 성공
# ===============
# 신선한 슬라이스 감자 후라이
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 콜라 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# ===========끝===========
# ---10번 식당파싱 시작 ---
# 10번 오류
# 서울 강남구 신사동 517-15 2층
# 주소 뽑기 성공
# =========================================
#
# 안녕하세요 가로수길에위치한 순수하게 맛있는 순수치킨입니다.
# 국내산 신선육으로 깔끔하고 맛있게 튀겨내는 핫한 치킨! 오늘 순수하시고 행복하세요!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 닭(신선육) : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [메인 메뉴]
# 음식 카테고리 성공
# =========================================
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [메인 메뉴]
# 음식 카테고리 성공
# =========================================
# 순수치킨 (후라이드)
# 음식메뉴 성공
# ===============
# 순수치킨만의 바삭하고 고소한 후라이드 치킨
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 사과양념치킨
# 음식메뉴 성공
# ===============
# 오리지널 양념치킨이 사과를 품어 신선한 향이 듬뿍
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 벌꿀간장치킨
# 음식메뉴 성공
# ===============
# 달콤 짭조름한 순수만의 특제 간장소스, 벌꿀을 넣어 고급스런 맛
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 마늘치킨
# 음식메뉴 성공
# ===============
# 마늘을 듬뿍 넣어 알싸함이 일품, 신선하고 건강한 맛
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고마치킨
# 음식메뉴 성공
# ===============
# 고추와 마늘이 만나 고마치킨! 매콤새콤달콤함이 어우러져 풍미작렬
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고추치킨
# 음식메뉴 성공
# ===============
# 맛있고 화끈하게 매운 맛이 그리울 땐 고추치킨,매움 레벨 100!
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 반반치킨
# 음식메뉴 성공
# ===============
# 순수치킨(후라이드)반 + 양념(5종 중 택1)반
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 반반치킨 2
# 음식메뉴 성공
# ===============
# 양념치킨 메뉴 5종 중 택2
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# 호로록떡볶이
# 음식메뉴 성공
# ===============
# 매콤달콤한 순수의 특제 떡볶이, 떡볶이 전문점보다 맛잇다는 호평이 가득
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 바삭이쥐포
# 음식메뉴 성공
# ===============
# 바삭한 쥐포로 치맥에 감초 역할!
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 감자칩
# 음식메뉴 성공
# ===============
# 신선한 슬라이스 감자 후라이
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 콜라 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# ===========끝===========
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-de9f4d3b34c3> in <module>
#     226
#     227
# --> 228     driver.back()
#     229     driver.implicitly_wait(12)
#     230
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in back(self)
#     811             driver.back()
#     812         """
# --> 813         self.execute(Command.GO_BACK)
#     814
#     815     def forward(self):
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     321             response = conn.urlopen(method, url, **kw)
#     322         else:
# --> 323             response = conn.urlopen(method, u.request_uri, **kw)
#     324
#     325         redirect_location = redirect and response.get_redirect_location()
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
