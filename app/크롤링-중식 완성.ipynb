# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 카페[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[10]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 25:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 카페 데이터(이미지) 수집
soup = BeautifulSoup(html, 'lxml')
img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
count = 1
for i in img:
    img_url = i.get_text("url", strip=True)
    img_url_parse = img_url[4:-1]
    try:
        urllib.request.urlretrieve(img_url_parse, f'{count}.china_food_img.jpg')
    except:
        pass
    count += 1

# 일식 데이터(식당명) 수집
japan_store_list = []
japan_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in japan_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(japan_store_list):
    print(i, name)


    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 8:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='중식',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=1),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
        print('음식 카테고리 성공')
        print('=========================================')
        
        store_category_foods = menu.select(".row-menu")

        for food in store_category_foods:
            food_menu = food.select_one(".col-menu > strong").get_text(strip=True)
            print(food_menu)
            print('음식메뉴 성공')
            print('===============')
            food_info = food.select_one(".col-menu > span").get_text(strip=True)
            print(food_info)
            print('음식정보 성공')
            print('===============')
            food_money = food.select_one("span.calculate-price").get_text(strip=True)
            food_moneys = food_money.replace(",", "")
            print(food_moneys)
            print('금액 성공')
            print('===============')
            
            Food.objects.create(
            category=food_category,
            name=food_menu,
            price=food_moneys,
            food_info=food_info,
            )

        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:83: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하 1층
# 주소 뽑기 성공
# =========================================
#
# oncept : 여유롭고 우아하게 즐기는 중국식 브런치, 가정식 요리 전문점
# Keyword : 깨끗함, 여유로움, 우아함, 새로운 스타일의 중식 브런치
#
# 쿵푸키친은.. 호텔 Chef 가 직접 만드는 담백하고 우아한 맛의
# 중국식 브런치 메뉴를 전문으로 하는 곳입니다.
# 중식 전문 Chef 와 양식 전문 Chef 가 만나, 이제껏 배달로 즐기지 못했던
# 재미있고 다양한 스타일의 메뉴를 선보입니다.
#
# 이제껏 만나보지 못했던 깨끗하고, 여유롭고, 고급스럽고 담백한 맛의
# 새로운 중식요리를 집에서 만나보세요.
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# 육즙 탕수육, 어향가지튀김, 차슈 바오번, 통삼겹 짜장, 간짜장, 돈육 볶음면 (돼지고기 : 국내산, 캐나다산) / 차돌 짬뽕 (소고기 : 미국산) / 깐풍기 : 브라질산  / 칠리 새우, 레몬 새우, 깐풍 새우 (새우 :  태국산) / 쌀(국내산) /고추 가루(중국산) / 김치 (중국산) / 두부(중국산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [브런치 스페셜 (Brunch Special)]
# 음식 카테고리 성공
# =========================================
# [딤섬 (Dimsum)]
# 음식 카테고리 성공
# =========================================
# [고기류 (Meat)]
# 음식 카테고리 성공
# =========================================
# [해산물류 (Seafood)]
# 음식 카테고리 성공
# =========================================
# [바다와 육지]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [밥류 (Rice)]
# 음식 카테고리 성공
# =========================================
# [면류 (Noodle with Soup)]
# 음식 카테고리 성공
# =========================================
# [면류 (Fried Noodle)]
# 음식 카테고리 성공
# =========================================
# [나홀로스페셜]
# 음식 카테고리 성공
# =========================================
# [쿵푸키친 X 종선이네 Collaboration]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [브런치 스페셜 (Brunch Special)]
# 음식 카테고리 성공
# =========================================
# 대만식 꽃빵과 연유
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 부추 & 토마토 스크램블 에그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 중화풍 감바스 알 아히요 (with 꽃빵)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 청경채 볶음
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 매콤 토마토 해장짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 해산물 크림짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# [딤섬 (Dimsum)]
# 음식 카테고리 성공
# =========================================
# 하가우 (새우 딤섬) (6개)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 어혈교 (새우부추 딤섬) (6개)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 쇼마이 (새우관자 딤섬) (6개)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 모듬딤섬 (6개)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 군만두
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# [고기류 (Meat)]
# 음식 카테고리 성공
# =========================================
# 육즙 탕수육
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 매콤칠리 탕수육
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 사천식 깐풍기
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# [해산물류 (Seafood)]
# 음식 카테고리 성공
# =========================================
# 사천식 칠리새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 레몬크림 새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 깐풍 새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [바다와 육지]
# 음식 카테고리 성공
# =========================================
# 칠리 새우 닭
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 깐풍 새우 닭
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 레몬크림 새우 닭
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# 브런치 스페셜
# 음식메뉴 성공
# ===============
# 중화풍 감바스 알 아히요 (with 꽃빵) + 모둠딤섬 + 미니 육즙 탕수육 + 1988 옛날식 간짜장 + 북경식 돈육 볶음밥
# 음식정보 성공
# ===============
# 31000
# 금액 성공
# ===============
# 쿵푸 스페셜
# 음식메뉴 성공
# ===============
# 육즙 탕수육(M) + 군만두 + 삼겹 짜장 + 차돌 짬뽕
# 음식정보 성공
# ===============
# 31000
# 금액 성공
# ===============
# 나홀로 스페셜
# 음식메뉴 성공
# ===============
# 미니 육즙 탕수육 + 1988 짬뽕 또는 1988 옛날짜장 중 택 1 + 모둠딤섬
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 둘이서 스페셜 세트
# 음식메뉴 성공
# ===============
# 깐풍기(소) + 1988 옛날짜장 + 1988 육짬뽕
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# [밥류 (Rice)]
# 음식 카테고리 성공
# =========================================
# 마파두부덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 북경식 돈육 볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 굴소스로 볶아낸 새우볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 쿵푸 볶음밥 (야채 볶음밥)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 중화잡채밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 게살 볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# [면류 (Noodle with Soup)]
# 음식 카테고리 성공
# =========================================
# 1988 옛날 육짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 1988 짬뽕밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 매운 불짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 차돌 짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# (시즌 특선) 굴짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 해물 백짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 해물 홍짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 마라 순두부탕면 (쌀국수)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# [면류 (Fried Noodle)]
# 음식 카테고리 성공
# =========================================
# 1988 옛날 간짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 청양고추 간짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 통삼겹 짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 북경식 돈육 볶음면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# [나홀로스페셜]
# 음식 카테고리 성공
# =========================================
# 나홀로 스페셜
# 음식메뉴 성공
# ===============
# 미니 육즙 탕수육+1988 짬뽕 또는 1988 간짜장 중 택1 + 모둠딤섬
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# [쿵푸키친 X 종선이네 Collaboration]
# 음식 카테고리 성공
# =========================================
# 간장 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 쌈장 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 장독대 고추장 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 블랙페퍼 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 레몬크림 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 코카콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 칠성사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 대만식 블랙티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 대만식 블랙밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# 대만식 타로 밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:217: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 강남구 역삼동 814-6 3층 306호
# 주소 뽑기 성공
# =========================================
#
# 마라탕?! 중국 샤브샤브에서 변화된 음식
# 마라? 매콤하고 아쌀한 맛
#
# 저희 신룽푸마라탕은 시원한 사골육수에 각종신선한 재료를 취향대로 골라 넣어드시는 고객맞춤형 건강식 입니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀, 배추 : 국내산소고기:미국산 양고기 : 호주산 고춧가루 : 중국산 콩,두부피:중국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [메인 메뉴]
# 음식 카테고리 성공
# =========================================
# [사이드 메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [메인 메뉴]
# 음식 카테고리 성공
# =========================================
# 마라탕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 마라반
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 마라샹궈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [사이드 메뉴]
# 음식 카테고리 성공
# =========================================
# 꿔바로우
# 음식메뉴 성공
# ===============
# 찹쌀 탕수육
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 미니전
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 량피
# 음식메뉴 성공
# ===============
# 중국식 비빔쌀국수
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 파인애플 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 코코넛음료 (245ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 삥홍차 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 삥탕쉐리 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 쏸메이탕 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 쨔둬보우 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 강남구 역삼동 673-36
# 주소 뽑기 성공
# =========================================
#
# 품격과 실속이 함께하는 중식당 리밍짬뽕맛으로 유명한 맛집. 중국 청도에서 요리사를 직접 초빙해 만든 품격있는 중식요리.특별한 분과의 약속, 단란한 가족모임,각종 회식모임,연인과의 소중한 시간이라면 중식당 리밍에서 약속하세요.취향대로 선택항 수 있는 면루부터 일품요리와 특선 Set요리, 세심함이 가득담긴 서비스에 기품있는 분위기까지 현명함이 돋보이는 탁월한 선택을 약속드립니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 소고기 : 뉴질랜드,호주산돼지고기 : 국내산,헝가리,오스트리아산닭고기 : 미국산쌀 : 국내산김치 : 중국산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 14000
# 최소 금액 성공
# =========================================
# [면류,탕류]
# 음식 카테고리 성공
# =========================================
# [밥류]
# 음식 카테고리 성공
# =========================================
# [돼지고기&소고기류&닭고기류]
# 음식 카테고리 성공
# =========================================
# [새우류]
# 음식 카테고리 성공
# =========================================
# [혼합류]
# 음식 카테고리 성공
# =========================================
# [냉채류]
# 음식 카테고리 성공
# =========================================
# [리밍셋트메뉴]
# 음식 카테고리 성공
# =========================================
# [특선코스]
# 음식 카테고리 성공
# =========================================
# [더블메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [면류,탕류]
# 음식 카테고리 성공
# =========================================
# 짜장면
# 음식메뉴 성공
# ===============
# 리밍을 대표하는 맛깔나는 인기메뉴.
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 간짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 짬뽕
# 음식메뉴 성공
# ===============
# <인기메뉴>주방장님의 야심작!손님들의 극찬이 끊이지 않는 중독성강한 리밍의 대표적메뉴.
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 울면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 리밍특면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 기스면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 삼선간짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 해물쟁반짜장
# 음식메뉴 성공
# ===============
# 신선한 해물이 듬뿍들어가 더욱 푸짐한 해물쟁반자장.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 불타는쟁반짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 삼선짬뽕
# 음식메뉴 성공
# ===============
# 푸짐한 해물과 매콤얼큰한 국물맛이 오감을 자극하는 삼선짬뽕.
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 고추해장짬뽕
# 음식메뉴 성공
# ===============
# 술먹은 다음날 시원한 속풀이로 최고인 고추짬뽕.
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 사천탕면(굴)
# 음식메뉴 성공
# ===============
# 조개와 굴을 야채와 곁들인 시원한 우동.
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 삼선울면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 삼선우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 볶음짬뽕
# 음식메뉴 성공
# ===============
# 가는 면발과 맑은닭고기 국물 맛이 느껴지는 볶음짬뽕.
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 굴짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 홍굴짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 낙지짬뽕
# 음식메뉴 성공
# ===============
# 신선한 낙지가 들어가 더우 맛있는 낙지짬뽕.
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 콩나물북어해장짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 차돌박이짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 차돌된장짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 리밍특선새우짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 황제전복짬뽕
# 음식메뉴 성공
# ===============
# 전복이 들어가 황제가 된 느낌의 황제짬뽕.
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 삼선짬뽕탕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 군만두
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 물만두
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 캔콜라
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 육칼면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# [밥류]
# 음식 카테고리 성공
# =========================================
# 볶음밥
# 음식메뉴 성공
# ===============
# 다양한 재료를 넣어 강한불에 즉석에서 볶아 밥알이 살아있는 리밍의 볶음밥.
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 짬뽕밥
# 음식메뉴 성공
# ===============
# 시원하고 맛있는 짬뽕과 든든한 밥까지 추가된 짬뽕밥.
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 짜장밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 김치볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 육개장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 수제차돌박이육개장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 삼선볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 새우볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 잡채밥
# 음식메뉴 성공
# ===============
# 중국식 잡채와 야채를 볶은 밥.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 마파두부밥
# 음식메뉴 성공
# ===============
# 리밍만의 특제 양념으로 만들어진 마파두부밥.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 송이덮밥
# 음식메뉴 성공
# ===============
# 자연송이와 은행. 밤. 대추를 넣은 담백한 맛.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 리밍특밥
# 음식메뉴 성공
# ===============
# 중국식 스타일의 특별한 밥.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 마늘볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 게살볶음밥
# 음식메뉴 성공
# ===============
# 게살과 Xo소스로 볶은밥.
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 고추잡채밥
# 음식메뉴 성공
# ===============
# 중국식 잡채에 매콤한 고추가 추가되어 더욱 감칠맛나는 볶음밥.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 참소라해물덮밥
# 음식메뉴 성공
# ===============
# <인기메뉴>참소라와 해물을 푸짐하게넣어 볶아낸 리밍의 대표적 인기메뉴중 한가지.
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 삼선짬뽕밥
# 음식메뉴 성공
# ===============
# 얼큰하고 시원한 삼선짬뽕국물에 밥을 곁들여먹는 든든한 한끼식사.
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 고추해장짬뽕밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 굴짬뽕밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 홍굴짬뽕밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 낙지짬뽕밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 유산슬밥
# 음식메뉴 성공
# ===============
# 동고버섯,죽순,해삼,새우,고기가 곁들여진 부드러운맛의 유산슬과 밥을 동시에.
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 잡탕밥
# 음식메뉴 성공
# ===============
# 해물과 야채를 넣어 볶은 해물덮밥.
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [돼지고기&소고기류&닭고기류]
# 음식 카테고리 성공
# =========================================
# 탕수육
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)바삭하게 튀겨낸 돼지고기에 달콤한 소스와 곁들여먹는 맛.
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 덴뿌라
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 사천탕수육
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)돼지고기를 사용한 새콤달콤한 맛.
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 찹쌀탕수육
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 소고기탕수육
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 라조육
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 잡채
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 고추잡채
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)피망과 소고기를 채썰어 매운고추기름소스를 곁들인 볶음요리.
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 동파육
# 음식메뉴 성공
# ===============
# 중(2~3인분)삼겹살을 중국 특수 조리법으로 기름을 제거하여 청경채로 맛을 살린요리.
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 오향장육 (중)
# 음식메뉴 성공
# ===============
# 중(2~3인분)중국식 보양요리인 오향장우육.
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 난자완스
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 깐풍기
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)닭고기와 매운 마늘소스를 곁들여 볶음.
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 라조기
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)닭고기와 매운 고추볶음.
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 유린기
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)생파와 생고추를 중국식 소스에 재어 닭고기 위에 얹은 요리.
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# [새우류]
# 음식 카테고리 성공
# =========================================
# 간소새우(작은새우)
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)칠리소스를 가미한 작은새우요리.
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 깐풍새우(작은새우)
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)마른고추와 마늘과 콩간장으로 만든 작은새우 요리.
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 크림새우(작은새우)
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)중국본토의 단백한 마요네즈소스를 곁들인 작은새우 볶음.
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 간소중새우
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)칠리소스를 가미한 새우요리.
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# 깐풍중새우
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)마른고추와 마늘과 콩간장으로 만든 중새우요리.
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# 크림중새우
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)중국본토의 단백한 마요네즈소스를 곁들인 새우 볶음.
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# [혼합류]
# 음식 카테고리 성공
# =========================================
# 마파두부
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 양장피
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)오색모양을 낸 톡쏘는 겨자소소의 요리.
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 유산슬
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)동고버섯,죽순,해삼,새우,고기가 곁들여진 부드러운맛의 볶음요리.
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 해삼쥬스
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분)
# 음식정보 성공
# ===============
# 50000
# 금액 성공
# ===============
# 팔보채
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)모든 해물과 야채를 넣어 고추기름에 볶은 요리.
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 게살샥스핀
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분)
# 음식정보 성공
# ===============
# 40000
# 금액 성공
# ===============
# 해물누룽지탕
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분), 대(3~4인분)찹쌀누릉지에 해물과 야채를 곁들여 담아내는 요리.
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 전가복
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분)고급해산물과 신선한 야채를 볶아 소스를 얹은 요리.
# 음식정보 성공
# ===============
# 50000
# 금액 성공
# ===============
# 소양동고
# 음식메뉴 성공
# ===============
# 소 (1~2인분), 중(2~3인분)새우를 다져서 동고버섯에 담아나오는 담백한 요리.
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 게살스프
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# [냉채류]
# 음식 카테고리 성공
# =========================================
# 해파리냉채
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 세가지냉채
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 40000
# 금액 성공
# ===============
# 리밍특냉채
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 45000
# 금액 성공
# ===============
# [리밍셋트메뉴]
# 음식 카테고리 성공
# =========================================
# 탕수육싱글셋트
# 음식메뉴 성공
# ===============
# 탕수육 + 짜장1
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 탕수육1셋트
# 음식메뉴 성공
# ===============
# 탕수육 + 짜장2 + 콜라
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 탕수육2셋트
# 음식메뉴 성공
# ===============
# 탕수육 + 쟁반짜장2 + 콜라
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 탕수육3셋트
# 음식메뉴 성공
# ===============
# 찹쌀탕수육 + 짜장2 + 콜라
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 깐풍기5셋트
# 음식메뉴 성공
# ===============
# 깐풍기 + 짜장2 + 콜라
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 깐쇼새우싱글셋트
# 음식메뉴 성공
# ===============
# 깐쇼새우 + 짜장1
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 양장피6셋트
# 음식메뉴 성공
# ===============
# 양장피 + 짜장2 + 콜라
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 팔보채7셋트
# 음식메뉴 성공
# ===============
# 팔보채 + 짜장2 + 콜라
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 유산슬8셋트
# 음식메뉴 성공
# ===============
# 유산슬 + 짜장2 + 콜라
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 깐쇼새우9셋트
# 음식메뉴 성공
# ===============
# 깐쇼새우 + 짜장2 + 콜라
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# [특선코스]
# 음식 카테고리 성공
# =========================================
# A 코스 (4~5인분)
# 음식메뉴 성공
# ===============
# 탕수육 + 양장피 + 깐풍기
# 음식정보 성공
# ===============
# 55000
# 금액 성공
# ===============
# B 코스 (6~7인분)
# 음식메뉴 성공
# ===============
# 탕수육 + 양장피 + 팔보채 + 고추잡채 + 꽃빵
# 음식정보 성공
# ===============
# 80000
# 금액 성공
# ===============
# C 코스 (9~10인분)
# 음식메뉴 성공
# ===============
# 탕수육 + 양장피 + 고추잡채 + 깐쇼새우 + 팔보채 + 꽃빵
# 음식정보 성공
# ===============
# 100000
# 금액 성공
# ===============
# [더블메뉴]
# 음식 카테고리 성공
# =========================================
# 짬짜면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 볶짜면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 볶짬면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 탕짜면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 탕짬면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 탕볶밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 깐쇼새우+짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 깐쇼새우+짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 깐쇼새우+볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 깐풍기+짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 깐풍기+짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 깐풍기+볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 사이다
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 콜라
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 서초구 서초동 1659-2 1층
# 주소 뽑기 성공
# =========================================
#
# 마파웍 음식은 거짓말을 하지 않습니다
# 정직한 맛, '마파웍은 진리다'
# 푸드플라이와 함께 언제, 어디서나 마파웍을 즐기세요!
#
#
# 가게 소개 뽑기 성공
# =========================================
# 우삼겹 - 미국산(오고기짬뽕)돈등심 - 국내산(북경탕수육)돈후지 - 국내산(마파두부밥, 고추당면잡채밥)돈삼겹 - 독일산(유슬짜장)쌀 - 국내산(마파두부밥, 고추당면잡채밥)배추 - 국내산(오고기짬뽕, 마파두부밥, 고추당면잡채밥)오징어 - 국내산(오고기짬뽕)
#
# 가게 원산지 뽑기 성공
# =========================================
# 5000
# 최소 금액 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [튀김류]
# 음식 카테고리 성공
# =========================================
# [밥류]
# 음식 카테고리 성공
# =========================================
# [면류]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# 북경탕수육 + 유슬짜장 (2그릇)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 북경탕수육 + 마파두부밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 칠리탕수육 + 유슬짜장 (2그릇)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 레몬크림치킨 + 고추당면잡채밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# [튀김류]
# 음식 카테고리 성공
# =========================================
# 북경 탕수육
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 사천 깐풍기
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 칠리 중새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 레몬크림 중새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 칠리탕수육
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 레몬크림치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [밥류]
# 음식 카테고리 성공
# =========================================
# 마파두부밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 고추당면 잡채밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# XO새우치킨 볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 군만두 (10pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# [면류]
# 음식 카테고리 성공
# =========================================
# 오고기 짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 오고기 짬뽕 (곱빼기)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 눈꽃치즈볶음짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 유슬 짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 유슬 짜장 (곱빼기)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 중화 냉모밀
# 음식메뉴 성공
# ===============
# * 다대기 별도
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 코카콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 강남구 삼성동 140-38
# 주소 뽑기 성공
# =========================================
#
# 하얼빈가정식은 대표 메뉴 풍미바지락을 비롯한 다양한 중식을 경험하실 수 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 닭고기,바지락,쌀,밀가루 : 국내산
# 돼지고기 : 네덜란드
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [메뉴]
# 음식 카테고리 성공
# =========================================
# [메뉴]
# 음식 카테고리 성공
# =========================================
# 마파두부세트(2인분)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 어향가지세트(2인분)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 꿔바로우 (3인분)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 풍미바지락 (2인분)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 새우볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 대파소고기볶음
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 38000
# 금액 성공
# ===============
# 우육면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 해물볶음면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 레몬크림새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 38000
# 금액 성공
# ===============
# 풍미깐쇼새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 36000
# 금액 성공
# ===============
# 위샹로우쓰
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 38000
# 금액 성공
# ===============
# 하얼빈 수제군만두 (12pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 양고기 마라탕 훠궈 (4인분)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 48000
# 금액 성공
# ===============
# 마라샹궈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 36000
# 금액 성공
# ===============
# 중국식냉채
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 38000
# 금액 성공
# ===============
# 쯔란양고기
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# 삼선볶음
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 45000
# 금액 성공
# ===============
# 전복깐쇼가자미
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 89000
# 금액 성공
# ===============
# ===========끝===========
# ---6번 식당파싱 시작 ---
# 서울 서초구 서초동 1597-6 1층
# 주소 뽑기 성공
# =========================================
#
# 30년 장인의 불맛 짬뽕!! '뽕사부' 입니다!
#
#
# 가게 소개 뽑기 성공
# =========================================
# 짜장면(고기:국내산. 양파:국내산,중국산)짬뽕(오징어:칠레산, 중국산 야채:국내산, 양파:국내산, 중국산. 굴:국내산, 조개류: 국내산)볶음밥(쌀: 국내산, 새우:베트남, 중국산)불고기잡채밥(쌀: 국내산, 당면:중국산, 고기:미국산깐풍기(닭: 브라질산)새우(중새우: 베트남, 중국산)양장피(야채:국내산, 피:중국산)전가복, 팔보채( 전복: 국내산, 오징어:칠레산, 야채:국내산 쭈꾸미:베트남산)어향동고(표고버섯:국내산, 새우:베트남산,중국산)유산슬(건해삼:러시아산)쌀 : 국내산 소고기 : 호주산 닭고기 : 브라질산, 미국산 김치 : 중국산돼지고기. 야채: 국내산고춧가루 : 국내산/중국산 낙지: 중국산냉짬뽕, 중국냉면, 코다리냉면  (오징어: 칠레산, 새우 : 베트남, 코다리: 국내산 해파리: 태국산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [메뉴]
# 음식 카테고리 성공
# =========================================
# [요리]
# 음식 카테고리 성공
# =========================================
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [계절메뉴]
# 음식 카테고리 성공
# =========================================
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# [메뉴]
# 음식 카테고리 성공
# =========================================
# 짜장면
# 음식메뉴 성공
# ===============
# 각종 야채와 고기를 춘장에 볶아 구수한 짜장소스를 쫄깃한 면에 부어먹는 북경식 면요리
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 뽕사부 짬뽕
# 음식메뉴 성공
# ===============
# 일반맛/매운맛 선택가능사골육수로 끓인 개운하고 칼칼한 맛
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 뽕사부 짬뽕밥
# 음식메뉴 성공
# ===============
# 일반맛/매운맛 선택가능사골육수로 끓인 개운하고 칼칼한 맛
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 순한짬뽕
# 음식메뉴 성공
# ===============
# 부드럽고 담백한 맛
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 굴 짬뽕
# 음식메뉴 성공
# ===============
# 통영산지에서 직송한 신선한 굴맛
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 크림짬뽕
# 음식메뉴 성공
# ===============
# 중화불맛과 어우러진 고소한 크림맛
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 해물짬뽕탕
# 음식메뉴 성공
# ===============
# 얼큰한 국물맛이 일품이며 각종 해산물과 야채로 맛을 낸 음식
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 야채볶음밥
# 음식메뉴 성공
# ===============
# 각종 야채에 중화소스가 곁들여진 담백하고 고소한 맛
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 불고기 잡채밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 치즈 토마토 볶음짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 치즈 토마토 볶음짬뽕밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# [요리]
# 음식 카테고리 성공
# =========================================
# 탕수육
# 음식메뉴 성공
# ===============
# 바삭바삭한 고기튀김에 여러가지 야채를 넣고 볶아 새콤달콤한 소스를 얹어 먹는 요리
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 깐소중새우
# 음식메뉴 성공
# ===============
# 새우를 튀겨 갖은 양념과 케첩소스로 만든 새콤달콤한 요리
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 깐풍중새우
# 음식메뉴 성공
# ===============
# 맛있는 새우튀김에 매콤한 고추기름과 진한 마늘소스로 볶아낸 일품요리
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 크림중새우
# 음식메뉴 성공
# ===============
# 싱싱한 새우를 바삭하게 튀겨내고 고소한 생크림과 연유로 만든 담백하고 부드러운 새우요리
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 양장피
# 음식메뉴 성공
# ===============
# 각종 채소와 해물이 겨자소스에 버무려진 톡 쏘는 맛
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 유린기
# 음식메뉴 성공
# ===============
# 바삭한 닭다리살 튀김과 아삭한 양상추와 장시간 숙성 조림한 새콤 달콤 매콤한 소스를 곁들인 요리
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 깐풍기
# 음식메뉴 성공
# ===============
# 부드러운 닭다리살 튀김에 매콤한 고추기름과 진한 마늘 소스로 볶아낸 일품요리
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# 수제 군만두 (8pcs)
# 음식메뉴 성공
# ===============
# 바삭하고 부드러운 만두피가 고기와 야채속의 개운한 맛을 더욱 풍부하게
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [계절메뉴]
# 음식 카테고리 성공
# =========================================
# 냉 짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 중국 냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 속초코다리 냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 냉콩국수
# 음식메뉴 성공
# ===============
# 계절메뉴
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 서울 강남구 삼성동 159-6
# 주소 뽑기 성공
# =========================================
#
# [짬뽕신]
# 한 그릇 한 그릇에 정성을 담고 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 돼지고기: 국내산
# 소고기: 호주산
# 닭고기: 브라질산
# 낙지: 중국산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [세트]
# 음식 카테고리 성공
# =========================================
# [누들]
# 음식 카테고리 성공
# =========================================
# [라이스]
# 음식 카테고리 성공
# =========================================
# [요리]
# 음식 카테고리 성공
# =========================================
# [세트]
# 음식 카테고리 성공
# =========================================
# 2인세트 A
# 음식메뉴 성공
# ===============
# 짬뽕 + 짜장 + 탕수육(소)
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# 2인세트 B
# 음식메뉴 성공
# ===============
# 짬뽕(2개) + 탕수육(소)
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 2인세트 C
# 음식메뉴 성공
# ===============
# 짜장(2개) + 탕수육(소)
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 2인세트 D
# 음식메뉴 성공
# ===============
# 볶음밥 + 짬뽕 + 탕수육(소)
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 2인세트 E
# 음식메뉴 성공
# ===============
# 볶음밥 + 짜장 + 탕수육(소)
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# 3인세트 1번
# 음식메뉴 성공
# ===============
# 짬뽕(2개) + 짜장 + 탕수육(소)
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# 3인세트 2번
# 음식메뉴 성공
# ===============
# 짬뽕(2개)+ 볶음밥 + 탕수육(소)
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 3인세트 3번
# 음식메뉴 성공
# ===============
# 볶음밥(2개) + 짬뽕 + 탕수육(소)
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# 3인세트 4번
# 음식메뉴 성공
# ===============
# 볶음밥(2개) + 짬뽕 + 탕수육(소)
# 음식정보 성공
# ===============
# 34000
# 금액 성공
# ===============
# 3인세트 5번
# 음식메뉴 성공
# ===============
# 짜장 + 짬뽕 + 볶음밥 + 탕수육(소)
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# [누들]
# 음식 카테고리 성공
# =========================================
# 전복해물짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 꽃게짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 통오징어짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 소불고기짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 소불고기 백짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 굴짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 통낙지짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 하얀짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 사천해물볶음짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 삼선울면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 짜장면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 사천해물볶음짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# [라이스]
# 음식 카테고리 성공
# =========================================
# 소고기볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 게살볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 새우볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 부추잡채밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 마파두부덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 고추잡채덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [요리]
# 음식 카테고리 성공
# =========================================
# 탕수육
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 깐풍탕수육
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 꿔바로우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 사천탕수육
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 깐풍기
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 호두 꿀 화이트새우 (10pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 칠리새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 유린기
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 군만두 (8pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 물만두 (20pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# ===========끝===========
# ---8번 식당파싱 시작 ---
# 서울 강남구 신사동 589-9 알파빌딩 1층
# 주소 뽑기 성공
# =========================================
#
# ◈부 엌 神 이 야 기◈
#
# 2000年前 中國 四川 지방 어느 마을 한 가장에 남루하게 차려 입은 길손 한 분이 찾아왔답니다.
# 극심한 가뭄 끝이라 부엌에 남은 것이라고는 밀가루 한 웅큼과 기름 몇 방울 밖에 없었지만 두 부부는 밀가루와 기름을 다 털어 정성껏 떡을 만들어 길손을 대접했습니다.
# 길손은 흐믓한 마음으로 감사하며 다시 길을 떠났습니다.
# 다음날 부부는 허기진 배에 물이라도 채우려고 부엌에 들어선 순간 깜짝 놀라고 말았습니다.
# 텅텅 비어있던 광주리마다 먹을것이 가득 채워져 있었던 것입니다.
# 남루한 길손, 그분은 나그네가 아니라 한 해 한 번씩 마을을 검점하는 부엌神이었습니다.
#
# 부부의 소박한 정성으로
# 길손을 기다리겠습니다.
# 부엌神이 되어 주십시오.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 돼지고기 : 국내산쌀 : 국내산양파 : 국내산소고기 : 호주산닭고기 : 브라질산김치 : 중국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [누들 (Noodles)]
# 음식 카테고리 성공
# =========================================
# [라이스(Rice)]
# 음식 카테고리 성공
# =========================================
# [소고기 (Beef)]
# 음식 카테고리 성공
# =========================================
# [돼지고기 (Pork)]
# 음식 카테고리 성공
# =========================================
# [닭고기(Chicken)]
# 음식 카테고리 성공
# =========================================
# [새우 (Shrimp)]
# 음식 카테고리 성공
# =========================================
# [잡품류 (Other)]
# 음식 카테고리 성공
# =========================================
# [두부,야채 (Bean curd, Vegetables)]
# 음식 카테고리 성공
# =========================================
# [해삼,전복,관자 (Seacucumbers,Abalones,Scallops)]
# 음식 카테고리 성공
# =========================================
# [상어지느러미류 (Shark'sFin)]
# 음식 카테고리 성공
# =========================================
# [스프 (Soup)]
# 음식 카테고리 성공
# =========================================
# [냉채류(Appetizers)]
# 음식 카테고리 성공
# =========================================
# [음료수]
# 음식 카테고리 성공
# =========================================
# [누들 (Noodles)]
# 음식 카테고리 성공
# =========================================
# 간짜장
# 음식메뉴 성공
# ===============
# 각종 야채와 깊은 맛과 짜장소스의 독특한 맛이 쫄깃한 명발과 어우러진 맛이 일품
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 사천탕면
# 음식메뉴 성공
# ===============
# 매운맛★육수를 우려내 적당히 매콤하면서 시원담백한 맑은 탕면
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 사천탕밥
# 음식메뉴 성공
# ===============
# 매운맛★육수를 우려내 적당히 매콤하면서 시원한 맛의 탕밥
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 홍합짬뽕
# 음식메뉴 성공
# ===============
# 매운맛★신선한 홍합, 야채의 맛이 쫄깃한 면발과 어우러진 매콤한 맛이 일품
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 기스면
# 음식메뉴 성공
# ===============
# 닭육수로 우려낸 국물이 담백하고 시원한 맛의 탕면
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 삼선자장면
# 음식메뉴 성공
# ===============
# 각종 야채, 해물의 깊은 맛과 자장소스의 독특한 맛이 쫄깃한 면발과 어우러진 맛이 일품
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 쟁반자장면
# 음식메뉴 성공
# ===============
# 각종 야채, 새우의 깊은 맛과 볶음자장 소스의 독특한 맛이 어루진 맛이 일품
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 매운짜장면
# 음식메뉴 성공
# ===============
# 매운맛 ★매운 볶음 짜장 소스가 각종 야채 새우와 어우러진 맛이 일품
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 광동면
# 음식메뉴 성공
# ===============
# 매운맛★색다른 매콤함이 느껴지는 광동식 스타일의 비빔면
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 광동밥
# 음식메뉴 성공
# ===============
# 매운맛★색다른 매콤함이 느껴지는 광동식 스타일의 비빔밥
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 굴짬뽕
# 음식메뉴 성공
# ===============
# 신선한 굴과 쫄깃한 면발이 어우러진 매콤한 맛이 일품
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 백짬뽕
# 음식메뉴 성공
# ===============
# 하얀 국물과 여러가지 해물과 쫄깃한 면발이 어우러진 맵지 않은 담백한 맛
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 삼선짬뽕
# 음식메뉴 성공
# ===============
# 각종 해물의 깊은 맛과 맛이 쫄깃한 면발과 어우러진 매콤한 맛이 일품
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 삼선우동
# 음식메뉴 성공
# ===============
# 해물로 우려낸 국물이 감칠맛 나는 룽청 스타일의 우동
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 삼선울면
# 음식메뉴 성공
# ===============
# 해물로 끓인 걸죽하고 담백한 맛
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 우육탕면
# 음식메뉴 성공
# ===============
# 각종 야채, 각종 버섯, 소고기 안심과 쫄깃한 면발이 어우러진 맛이 일품
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 중국식냉면 (하절기)
# 음식메뉴 성공
# ===============
# 30여가지 재료를 2시간 이상 푹 삶아 우려낸 육수와 각종 해물이 어우러진 맛이 일품
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 냉짬뽕 (하절기)
# 음식메뉴 성공
# ===============
# 피망,양파,죽순,표고버섯,해파리,소고기를 함께 볶아내어 깊게 우린 육수와 조화를 이루는 시원한 여름 별미
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 검은 콩국수 (하절기)
# 음식메뉴 성공
# ===============
# 영양만점 검은콩의 쫄깃한 면발이 어우러진 맛이 일품
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 자연송이탕면
# 음식메뉴 성공
# ===============
# 자연송이의 맛이 쫄깃한 면발과 어우러진 맛이 일품
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# [라이스(Rice)]
# 음식 카테고리 성공
# =========================================
# 사천볶음밥
# 음식메뉴 성공
# ===============
# 쇠고기,5가지 야채, 버섯이 어우러진 매콤한 맛이 살아있는 맛
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 볶음밥
# 음식메뉴 성공
# ===============
# 5가지 야채와 계란으로 볶아낸 살아있는 맛
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 짬뽕밥
# 음식메뉴 성공
# ===============
# 짬뽕 국물에 당면, 계란을 풀어 공깃밥을 말아먹는 얼큰한 맛이 일품
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 새우볶음밥
# 음식메뉴 성공
# ===============
# 통통한 꼬리새우를 통째로 넣어 새우의 맛이 살아있는 볶음밥
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 버섯덮밥
# 음식메뉴 성공
# ===============
# 여러가지 버섯야채가 들어간 굴소스에 밥을 비벼먹는 맛이 일품
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 소고기잡채밥
# 음식메뉴 성공
# ===============
# 꼬들꼬들한 당면과 신선한 야채가 어우러져 감칠맛 나는 덮밥
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 소고기마파두부밥
# 음식메뉴 성공
# ===============
# 매운맛★월남고추의 매콤함과 연두부의 부드러움이 어우러진 독특한 소소의 덮밥
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 게살볶음밥
# 음식메뉴 성공
# ===============
# 게살이 어우러진 게살볶음밥
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 해물누룽지탕 (1인분)
# 음식메뉴 성공
# ===============
# 신선한 해산물과 야채가 찹쌀 누룽지와 어우러진 고소하고 담백한 맛이 일품
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 소고기고추잡채밥
# 음식메뉴 성공
# ===============
# 매운맛★부드럽게 채 썬 소고기와 피망의 아삭한 씹는 맛이 살아있는 요리
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 잡탕밥
# 음식메뉴 성공
# ===============
# 여러가지 해물과 야채를 넣은 고급 해물덮밥
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 소고기유산슬밥
# 음식메뉴 성공
# ===============
# 고기, 해산, 야채를 걸쭉하게 볶아낸 유산슬 소스가 입맛을 당기는 덮밥
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 자연송이덮밥
# 음식메뉴 성공
# ===============
# 향긋한 자연송이에 룽청 스타일의 소스를 얹은 덮밥
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 물만두 (15pcs)
# 음식메뉴 성공
# ===============
# 뜨거운 물에 데쳐 나오는 만두
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 군만두 (8pcs)
# 음식메뉴 성공
# ===============
# 기름에 바싹 튀긴 만두
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 춘권 (8pcs)
# 음식메뉴 성공
# ===============
# 밀전병에 야채나 고기, 해물 등을 넣어 말아 기름에 튀긴 음식
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 꽃빵 튀김
# 음식메뉴 성공
# ===============
# 겉은 바삭하고 속은 부드러운 꽃빵 튀김과 달콤한 연유의 조화
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# [소고기 (Beef)]
# 음식 카테고리 성공
# =========================================
# 소고기탕수육
# 음식메뉴 성공
# ===============
# 최고급 안심의 부드러운 쇠고기 튀김에 상큼한 단맛을 잡은 탕수 소스의 새콤달콤함이 조화를 이룬 요리
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 어향우육편
# 음식메뉴 성공
# ===============
# 소고기 안심에 매콤한 어향 소스로 맛을 낸 색다른 소고기 요리
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 자연송이소고기볶음
# 음식메뉴 성공
# ===============
# 자연송이의 향긋하고 독특한 향과 소고기의 육즙이 한데 어울려 맛을 낸 보양식
# 음식정보 성공
# ===============
# 55000
# 금액 성공
# ===============
# 쇠고기 굴소스 볶음
# 음식메뉴 성공
# ===============
# 쇠고기 육즙과 굴소스의 독특한 향이 어울려 감칠맛나는 부드러운 쇠고기 양상추 볶음요리
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 소고기자장볶음
# 음식메뉴 성공
# ===============
# 자장소스에 졸여 감칠맛나는 소고기와 채 썬 파의 신선함이 어울려 느끼함을 없앤 북경요리 꽃빵과 드시면 더욱 좋습니다.(꽃빵 소3pcs  중4pcs 대6pcs 무료제공)
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 소고기고추잡채
# 음식메뉴 성공
# ===============
# 채 썬 소고기와 피망의 아삭한 씹는 맛이 살아있는 요리로 꽃빵으로 싸서 먹는 요리(꽃빵 소3pcs  중 4pcs 대6pcs 무료제공)
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 소고기부추잡채 (계절메뉴)
# 음식메뉴 성공
# ===============
# 부추와 소고기를 볶은 야채요리
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 소고기 양상추쌈
# 음식메뉴 성공
# ===============
# 양상추의 상큼하고 아삭한 맛이 다진 소고기와 어우러진 중국식 쌈요리
# 음식정보 성공
# ===============
# 40000
# 금액 성공
# ===============
# 소고기난자완스
# 음식메뉴 성공
# ===============
# 잡작하게 빚은 경단과 야채로 우려낸 걸쭉한 소스가 더해진 중국식 햄버거
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# [돼지고기 (Pork)]
# 음식 카테고리 성공
# =========================================
# 등심탕수육
# 음식메뉴 성공
# ===============
# 육질을 살려 튀겨낸 아삭한 튀김과 탕수 소스가 어울려 쫀득쫀득 달콤한 탕수육
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 사천탕수육
# 음식메뉴 성공
# ===============
# 매운맛★룽청만의 비법으로 사천요리 특유의 매콤함을 살리고 느낌함을 없앤 탕수육
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 오향삼겹살
# 음식메뉴 성공
# ===============
# 쫄깃한 껍질과 입에 넣었을 때 부드러운 감촉이 일품인 삼겹살 찜요리
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 라조육
# 음식메뉴 성공
# ===============
# 매운맛★룽청 특유의 향긋하며 매콤새콤한 소스와 돼지고기 특유의 부드러움이 조화를 이룬 새로운 맛의 요리
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# [닭고기(Chicken)]
# 음식 카테고리 성공
# =========================================
# 유린기
# 음식메뉴 성공
# ===============
# 달콤, 새콤, 매콤한 맛이 어우러진 바삭한 닭다리살 요리
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 깐풍기
# 음식메뉴 성공
# ===============
# 감칠맛 나는 마늘소스에 바삭한 닭고기를 빨리 볶아내 맛이 살아있는 고소한 닭요리
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 닭고기케슈너츠
# 음식메뉴 성공
# ===============
# 연한 닭고기살과 케슈너츠가 고소하게 씹히는 담백한 요리
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 라조기
# 음식메뉴 성공
# ===============
# 매운맛★부드러운 닭고기살을 바삭하게 튀겨낸 매콤하고 칼칼한 맛의 닭요리
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# [새우 (Shrimp)]
# 음식 카테고리 성공
# =========================================
# 칠리바다가재
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 38000
# 금액 성공
# ===============
# 크림왕새우띠또 (4pcs)
# 음식메뉴 성공
# ===============
# 레몬마늘소스
# 음식정보 성공
# ===============
# 52000
# 금액 성공
# ===============
# 칠리왕새우 (4pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 48000
# 금액 성공
# ===============
# 블랙빈왕새우 (4pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 48000
# 금액 성공
# ===============
# 크림중새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 토마토중새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 칠리중새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 깐풍중새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 레몬중새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 새우두부
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 새우케슈너츠
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# [잡품류 (Other)]
# 음식 카테고리 성공
# =========================================
# 전가복
# 음식메뉴 성공
# ===============
# 해삼, 전복, 새우 등 각종 해산물과 자연송이, 아스파라거스, 죽순 등 몸에 좋은 재료로 정성스럽게 준비한 보양요리
# 음식정보 성공
# ===============
# 88000
# 금액 성공
# ===============
# 원기삼정
# 음식메뉴 성공
# ===============
# 토마토 칠리소스 쇠고기를 겉에 두르고, 부드럽게 볶은 고급 해산물과 야채를 그 안에 담아낸별미
# 음식정보 성공
# ===============
# 88000
# 금액 성공
# ===============
# 어향동고
# 음식메뉴 성공
# ===============
# 통통한 새우를 다져 동고버섯 속을 채운 매콤새콤한 요리로 우리 입맛에 잘 맞는 별미
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 유산슬
# 음식메뉴 성공
# ===============
# 육류와 해산물을 함께 채 썰어 볶은 후 걸쭉하게 만든 중국 본토에서도 사랑받는 요리
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 팔보채
# 음식메뉴 성공
# ===============
# 각종 해산물과 버섯을 매콤하게 조리한 요리
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 양장피
# 음식메뉴 성공
# ===============
# 뜨거운 물에 데친 부드러운 분피에 신선한 야채와 해물을 겨자소스로 버무린 산뜻한 맛의 에피타이저
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# [두부,야채 (Bean curd, Vegetables)]
# 음식 카테고리 성공
# =========================================
# 게살두부
# 음식메뉴 성공
# ===============
# 부드러운 두부와 야들야들한 게살이 어우러진 부드럽고 담백한 요리
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 마파두부
# 음식메뉴 성공
# ===============
# 매운맛 ★두부와 쇠고기가 매콤하게 섞인 얼큰한 사천지방 유명요리
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 가상두부
# 음식메뉴 성공
# ===============
# 매운맛 ★어머니 손맛이 살아있는 중국 가정의 스타일의 푸근한 두부요리
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 청경채굴소스
# 음식메뉴 성공
# ===============
# 굴소스의 향긋함과 청경채의 깔끔함이 어우러진 정갈한 맛의 야채요리
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 모듬야채볶음
# 음식메뉴 성공
# ===============
# 갖가지 야채를 가볍게 볶아 자연의 향을 그대로 즐길 수 있는 담백한 요리
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 자연송이볶음
# 음식메뉴 성공
# ===============
# 살짝 볶은 자연산 햇송이의 향긋함과 신선함이 그대로 살아있는 고급요리
# 음식정보 성공
# ===============
# 65000
# 금액 성공
# ===============
# [해삼,전복,관자 (Seacucumbers,Abalones,Scallops)]
# 음식 카테고리 성공
# =========================================
# 금사오룡해삼
# 음식메뉴 성공
# ===============
# 다진 새우로 속을 채운 해삼에 숙주, 죽순채 등을 볶아 만든 금사를 끓여 새우와 해삼이 어우러진 맛과 금사의 바삭한 씹히는 맛이 어우러진 별미
# 음식정보 성공
# ===============
# 58000
# 금액 성공
# ===============
# 해삼삼겹살찜
# 음식메뉴 성공
# ===============
# 보양 향신료를 넣어 찐 삽겹살에 굴소스로 볶은 해삼을 곁들인 요리로, 부드러우면서도 살살 녹는 맛이 일품인 요리
# 음식정보 성공
# ===============
# 58000
# 금액 성공
# ===============
# 해삼탕
# 음식메뉴 성공
# ...
# 28000
# 금액 성공
# ===============
# 특냉채
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 양장피
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# ===========끝===========
# 10번 오류
# 서울 서초구 서초동 1330 코아텔쉐르빌 2층
# 주소 뽑기 성공
# =========================================
#
# 자원방래는 우리나라 최초의 서비스레지던스호텔인 강남의 코아텔 쉐르빌의 식음료사업부가 자회사로 독립하여
# 이탈리안 레스토랑과 프랑스 베이커리 “힛더스팟” 브랜드에 이어 두번째로 런칭한 정통중국요리 브랜드로서
# 자원방래는 제대로 만든 맛있는 중국요리를 합리적인 가격에 쉽게 접할수 있도록 요리의 전문성과 가격의 합리성에 중점을 두었습니다
#
# 짬뽕국물은 주문 즉시 조리가 들어가기 때문에 별도 제공이 어렵습니다.
# 필요하신 고객님은 계란국으로 제공이 가능하니 요청사항에 적어주시기 바랍니다.
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀, 고춧가루, 돼지고기, 소고기(송이안심), 배추, 두부 : 국내산소고기(오향장육) : 호주산닭고기 : 미국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [NOODLE]
# 음식 카테고리 성공
# =========================================
# [RICE]
# 음식 카테고리 성공
# =========================================
# [BEEF]
# 음식 카테고리 성공
# =========================================
# [CHICKEN]
# 음식 카테고리 성공
# =========================================
# [MEAT]
# 음식 카테고리 성공
# =========================================
# [SEAFOOD]
# 음식 카테고리 성공
# =========================================
# [SHRIMP]
# 음식 카테고리 성공
# =========================================
# [APPETIZER]
# 음식 카테고리 성공
# =========================================
# [NOODLE]
# 음식 카테고리 성공
# =========================================
# 짜장면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 삼선짜장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 삼선짬뽕
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 삼선우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 사천탕면
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 우육탕면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 팔진탕면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 중식냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 수제군만두
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 차돌박이 해물짬뽕
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 생굴짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# [RICE]
# 음식 카테고리 성공
# =========================================
# 게살볶음밥
# 음식메뉴 성공
# ===============
# 짬뽕국물은 주문 즉시 조리가 들어가기 때문에 별도 제공이 어렵습니다.필요하신 고객님은 계란국으로 제공이 가능하니 요청사항에 적어주시기 바랍니다.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 해산물볶음밥
# 음식메뉴 성공
# ===============
# 짬뽕국물은 주문 즉시 조리가 들어가기 때문에 별도 제공이 어렵습니다.필요하신 고객님은 계란국으로 제공이 가능하니 요청사항에 적어주시기 바랍니다.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 새우볶음밥
# 음식메뉴 성공
# ===============
# 짬뽕국물은 주문 즉시 조리가 들어가기 때문에 별도 제공이 어렵습니다.필요하신 고객님은 계란국으로 제공이 가능하니 요청사항에 적어주시기 바랍니다.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 잡채밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 고추잡채밥
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 유산슬밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 잡탕밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 마파두부밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 삼선짬뽕밥
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 삼선짜장밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# [BEEF]
# 음식 카테고리 성공
# =========================================
# 마라쇠고기
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 굴소스쇠고기
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 흑후추안심
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 송이안심
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 43000
# 금액 성공
# ===============
# [CHICKEN]
# 음식 카테고리 성공
# =========================================
# 깐풍기
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 라조기
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 유린기
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 궁보계정
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# [MEAT]
# 음식 카테고리 성공
# =========================================
# 탕수육
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 찹쌀탕수육(꿔바로우)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 라조육
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 깐풍육
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 어향동구
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 고추잡채
# 음식메뉴 성공
# ===============
# 매운맛 ★
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 경장육사
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 어향육사
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 난자완스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# [SEAFOOD]
# 음식 카테고리 성공
# =========================================
# 유산슬
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 고추팔보채
# 음식메뉴 성공
# ===============
# 매운맛★
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 전가복
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 50000
# 금액 성공
# ===============
# 해물누룽지탕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 모듬해물볶음
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 마라관자
# 음식메뉴 성공
# ===============
# 매운맛★
# 음식정보 성공
# ===============
# 45000
# 금액 성공
# ===============
# 전복관자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 58000
# 금액 성공
# ===============
# 송이전복
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 58000
# 금액 성공
# ===============
# [SHRIMP]
# 음식 카테고리 성공
# =========================================
# 칠리중새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# 크림중새우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# 깐풍중새우
# 음식메뉴 성공
# ===============
# 매운맛★
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# 왕새우 (1pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# [APPETIZER]
# 음식 카테고리 성공
# =========================================
# 해파리냉채
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 오향장육
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 3품냉채
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 4품냉채
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 특냉채
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 양장피
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# ===========끝===========
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f09884a45f8>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-2-35774d89dad8> in <module>
#     226
#     227
# --> 228     driver.back()
#     229     driver.implicitly_wait(12)
#     230
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in back(self)
#     811             driver.back()
#     812         """
# --> 813         self.execute(Command.GO_BACK)
#     814
#     815     def forward(self):
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     321             response = conn.urlopen(method, url, **kw)
#     322         else:
# --> 323             response = conn.urlopen(method, u.request_uri, **kw)
#     324
#     325         redirect_location = redirect and response.get_redirect_location()
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     636
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#     640
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     396
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#     400         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=57257): Max retries exceeded with url: /session/0216618ed1b77fb51949ef49c982b456/back (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f09884a45f8>: Failed to establish a new connection: [Errno 111] Connection refused',))
