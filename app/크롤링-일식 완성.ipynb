# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 일식[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[3]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 30:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 일식 데이터(이미지) 수집
soup = BeautifulSoup(html, 'lxml')
img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
count = 1
for i in img:
    img_url = i.get_text("url", strip=True)
    img_url_parse = img_url[4:-1]
    urllib.request.urlretrieve(img_url_parse, f'{count}.japan_food_img.jpg')
    count += 1

# 일식 데이터(식당명) 수집
japan_store_list = []
japan_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in japan_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(japan_store_list):
    print(i, name)


    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 47:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='일식',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=1),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
        print('음식 카테고리 성공')
        print('=========================================')
        
        store_category_foods = menu.select(".row-menu")

        for food in store_category_foods:
            food_menu = food.select_one(".col-menu > strong").get_text(strip=True)
            print(food_menu)
            print('음식메뉴 성공')
            print('===============')
            food_info = food.select_one(".col-menu > span").get_text(strip=True)
            print(food_info)
            print('음식정보 성공')
            print('===============')
            food_money = food.select_one("span.calculate-price").get_text(strip=True)
            food_moneys = food_money.replace(",", "")
            print(food_moneys)
            print('금액 성공')
            print('===============')
            
            Food.objects.create(
            category=food_category,
            name=food_menu,
            price=food_moneys,
            food_info=food_info,
            )

        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:80: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 강남구 역삼동 830-24 아워홈빌딩 1층
# 주소 뽑기 성공
# =========================================
#
# 사보텐은 건강 안전 환경 테마를 바탕으로 엄선된 소재로 철저하게 맛을 관리하며, 유니크한 인테리어와 독창적인 서비스 등으로 늘 앞서가는 최고의 브랜드를 지향하고 있습니다.깨와 소스를 합쳐서,돈카츠를 즐길 수있는 스타일은 사보텐에서 처음으로 시작되었습니다.두툼한 숙성돈육과 바삭한 생 빵가루 튀김, 고소한 깨향 소스와 상큼한 유자드레싱의 완벽한 맛의 조화는 오직 사보텐에서만 맛보실 수 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 쌀:국내산
# 배추김치: 배추-국내산
# 고춧가루-국내산
# 소고기:호주산
# 카츠용 돼지고기:국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 18000
# 최소 금액 성공
# =========================================
# [정식 (Katsu)]
# 음식 카테고리 성공
# =========================================
# [정식 (Rice)]
# 음식 카테고리 성공
# =========================================
# [사이드 (Side)]
# 음식 카테고리 성공
# =========================================
# [소스류 (Sauce)]
# 음식 카테고리 성공
# =========================================
# [음료류 (Beverage)]
# 음식 카테고리 성공
# =========================================
# [정식 (Katsu)]
# 음식 카테고리 성공
# =========================================
# 사보텐 정식
# 음식메뉴 성공
# ===============
# 사보텐 최고의 베스트셀러, 3가지 카츠를 한번에 만나는 푸짐한 구성의 실속 메뉴.
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 제주흑돈 로스카츠 정식
# 음식메뉴 성공
# ===============
# 제주 흑다돈 등심의 프리미엄 메뉴,특제소스와 소금(커리,마늘,녹차) 3종 제공.
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 제주흑돈 히레카츠 정식
# 음식메뉴 성공
# ===============
# 제주 흑다돈 안심의 프리미엄 메뉴,특제소스와 소금(커리,마늘,녹차) 3종 제공.
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 히레카츠 정식
# 음식메뉴 성공
# ===============
# 바삭한 튀김옷과 입안에서 녹는 부드러운 안심의 조화가 일품인 스테디셀러 메뉴.
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 로스카츠 정식
# 음식메뉴 성공
# ===============
# 사보텐만의 비법으로 찾아낸 고기와 지방의 황금비율! 풍부한 육즙이 일품인 정통 돈카츠 메뉴.
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 카사네 카츠 정식
# 음식메뉴 성공
# ===============
# 24겹 겹겹이 쌓은 등심의 풍부한 육즙과 식감의 카츠 정식
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 명란 치즈 카츠 정식
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 24겹 치즈김치 카사네 정식
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 모짜체다치즈카츠 정식
# 음식메뉴 성공
# ===============
# 모짜렐라 치즈 카츠에 체다를 넣어 더욱 부드럽고 진한 치즈 카츠
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 모짜렐라치즈카츠 정식
# 음식메뉴 성공
# ===============
# 고기와 치즈가 함께 어우러져 더욱 고소하고 쫄깃하여 여성고객들에게 인기만점 메뉴.
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 씨푸드 정식
# 음식메뉴 성공
# ===============
# 통통한 통새우 튀김과 새우통살이 그대로 씹히는 새우카츠,부드러운 흰살생선카츠가 조화로운 매니아 메뉴.
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 코돈부르카츠 정식
# 음식메뉴 성공
# ===============
# 24겹돈육사이에 치즈,야채가 들어간 카츠
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# [정식 (Rice)]
# 음식 카테고리 성공
# =========================================
# 카츠동 정식
# 음식메뉴 성공
# ===============
# 사보텐 특제 소스와 카츠, 계란이 어우러진 부드러운 덮밥
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 김치카츠동정식
# 음식메뉴 성공
# ===============
# 돈카츠와 묵은지가 환상적인 조화를 이루는 덮밥 메뉴
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 숯불와규동 정식
# 음식메뉴 성공
# ===============
# 최상급 와규 소고기에 숯불 맛과 소스가 어우러진 덮밥 메뉴
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 카레라이스 정식
# 음식메뉴 성공
# ===============
# 카레와 돈카츠를 함께 즐길 수 있는 일본 정통 카레 덮밥 메뉴.
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# [사이드 (Side)]
# 음식 카테고리 성공
# =========================================
# 미니 돈카츠
# 음식메뉴 성공
# ===============
# 부드럽고 깊은맛의 안심
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 모짜치즈카츠
# 음식메뉴 성공
# ===============
# 두툼한 모짜렐라치즈카츠(단품)
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 생선카츠
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 통새우 카츠 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 통새우 카츠 (5pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 고로케
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 크림치즈 고로케
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밥 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1200
# 금액 성공
# ===============
# [소스류 (Sauce)]
# 음식 카테고리 성공
# =========================================
# 돈까스소스 (320g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3900
# 금액 성공
# ===============
# 참깨소스 (280g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 유자소스 (300g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 샐러드 참깨소스 (50g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# [음료류 (Beverage)]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:214: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 강남구 역삼동 825-24 108호
# 주소 뽑기 성공
# =========================================
#
# 안녕하세요. 노르웨이산 최상급 연어로 품질은 UP!  가격은 DOWN! 연어전문점 스스시시입니다.
# "내 가족에게 만들어주는 음식"이라는 생각을 항상마음에 품고 하나하나 정성스럽게 만든 음식을 맛있게 즐겨주세요 :)
#
#
# 가게 소개 뽑기 성공
# =========================================
# *쌀 : 국내산 ( 경기도 이천 )*연어 : 노르웨이산*한치 : 태국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# [메뉴]
# 음식 카테고리 성공
# =========================================
# [컵라면]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [메뉴]
# 음식 카테고리 성공
# =========================================
# 스스시시 왕연어초밥 (3ea)
# 음식메뉴 성공
# ===============
# 노르웨이산 최상급 연어를 사용하여 만든 손바닥크기의 연어 위에 스스시시만의 소스를 발라먹는 초밥, 락교&생강+장국이 제공됩니다.
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 한치초밥 (5ea)
# 음식메뉴 성공
# ===============
# 락교 & 생강 + 장국이 제공됩니다.
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 유부초밥 (4ea)
# 음식메뉴 성공
# ===============
# 락교&생강+장국이 제공됩니다.
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 연어장덮밥
# 음식메뉴 성공
# ===============
# 쫄깃하고 탱글탱글한 식감의 연어장덮밥, 락교&생강+장국이 제공됩니다.
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 연어포케
# 음식메뉴 성공
# ===============
# 밥 위에 샐러드, 아보카도, 연어를 올려 스스시시의 비법소스와 함께 먹는 한끼식사, 락교 & 생강 + 장국이 제공됩니다.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 연어오차즈케
# 음식메뉴 성공
# ===============
# 녹차우린 물에 밥을 적시고 위에 연어후레이크를 올린 일본음식
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# [컵라면]
# 음식 카테고리 성공
# =========================================
# 신라면 소컵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 튀김우동 소컵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 컵누들 매운맛
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1300
# 금액 성공
# ===============
# 팔도비빔면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1300
# 금액 성공
# ===============
# 나가사끼짬뽕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1400
# 금액 성공
# ===============
# 오징어짬뽕 소컵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 육개장 소컵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 김치사발면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 스프라이트 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 라무네 탄산수 (200ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 트레비 레몬 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 트레비 라임(500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 서초구 서초동 1321-11 플래티넘타워 지하1층
# 주소 뽑기 성공
# =========================================
#
# 저희 카레야상은 직접 끊인 수제 카레를 48시간 숙성을 원칙으로 내 가족이 먹는 음식이란 생각으로 정성껏 요리합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 쌀 : 국내산
# 소고기 : 호주산
# 돼지고기 : 국내산
# 닭고기 : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 10500
# 최소 금액 성공
# =========================================
# [메인메뉴]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [메인메뉴]
# 음식 카테고리 성공
# =========================================
# 기본카레라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 치킨카레라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 모듬까스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 버섯카레라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 알새우카레라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 포크카레라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 소시지카레라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 닭가라아게카레라이스
# 음식메뉴 성공
# ===============
# 기본카레+닭가라아게
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 고로케카레라이스
# 음식메뉴 성공
# ===============
# 기본카레+고로케
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 야채카레라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 생선까스카레라이스
# 음식메뉴 성공
# ===============
# 기본카레+생선까스
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 미트볼카레라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 돈까스카레라이스
# 음식메뉴 성공
# ===============
# 기본카레+돈까스
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 새우튀김카레라이스
# 음식메뉴 성공
# ===============
# 기본카레+새우튀김
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 치킨까스카레라이스
# 음식메뉴 성공
# ===============
# 기본카레+치킨까스
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 비프카레라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 함박카레라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# 커플Set
# 음식메뉴 성공
# ===============
# 2인분비프카레+버섯카레+음료수1+토핑1
# 음식정보 성공
# ===============
# 20500
# 금액 성공
# ===============
# 비프Set (1인분)
# 음식메뉴 성공
# ===============
# 비프카레+돈까스+음료수
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 포크Set (1인분)
# 음식메뉴 성공
# ===============
# 포크카레+돈까스+음료수
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 치킨Set (1인분)
# 음식메뉴 성공
# ===============
# 치킨카레+치킨까스+음료수
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 아이스티 복숭아 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하1층
# 주소 뽑기 성공
# =========================================
#
# 한그릇에 담아낸 일본 가정식 요리 전문점
#
# 돈부리 봄날은, 일본의 정통요리, 가정식 요리, 일본식으로승화된 다양한 양식 요리 등
# 다양한 요리를 한 그릇에 담아낸, 덮밥 요리전문점 입니다.
#
# 가장 쉽고 대중적으로 즐길 수 있는 식사 요리인 덮밥요리를
# 집에서 보다 특별하게 즐길 수 있도록,
# 잘 준비된 ‘선물＇과 ‘꽃＇의 느낌을 더하였습니다.
#
# 디자인과 식재료, 조리법이 어우러져 오감이 즐거운 아름다운 한끼 식사.
# 새로운 형태의 일본 가정식 요리를 돈부리 봄날에서 즐겨보세요.
#
# 저희 돈부리 봄날의 음식을 더 맛있게 즐기기 위해, 일본식 반찬 3종, 양배추 샐러드,
# 흑임자 감자 샐러드, 고급 경기미 ‘참드림‘ 쌀밥을 함께 준비해 드리고 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 돈까스 (돈등심 :  국내산) / 멘치가츠 (우민찌 : 호주산, 돈민찌 : 국내산) / 치킨가라아게 (닭다리살 : 브라질산) / 삼겹살 : 캐나다 산, 독일산 / 차돌박이 : 미국산 / 채끝 스테이크 : 미국산 / 쌀(국내산) /고추가루(중국산) / 김치 (중국산) / 두부(국내산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [돈부리봄날 X 미듬영농조합 (한정판매)]
# 음식 카테고리 성공
# =========================================
# [돈부리봄날 X 서울붓처스]
# 음식 카테고리 성공
# =========================================
# [가정식 돈부리]
# 음식 카테고리 성공
# =========================================
# [일본요리 & 나베]
# 음식 카테고리 성공
# =========================================
# [튀김 & 가츠]
# 음식 카테고리 성공
# =========================================
# [일본식 우동]
# 음식 카테고리 성공
# =========================================
# [커리 우동]
# 음식 카테고리 성공
# =========================================
# [사이드/추가메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [돈부리봄날 X 미듬영농조합 (한정판매)]
# 음식 카테고리 성공
# =========================================
# 우리쌀 단팥빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 순우유 쌀식빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 소시지 치즈빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 먹물 & 떡 크런치빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# [돈부리봄날 X 서울붓처스]
# 음식 카테고리 성공
# =========================================
# 허브솔트럽 찹스테이크와 샐러드, 브레드 Box
# 음식메뉴 성공
# ===============
# 돈부리 봄날과 서울붓처스가 만나, 서울붓처스의 Best of Best 인기메뉴를 선보입니다.※스테이크 구성 : 잠발라야 라이스 기본 제공 + 소스 3종(스테이크 소스, 갈릭&허브솔트, 홀그레인 머스터드) 기본 제공※샐러드&브레드 Box 구성 : 부쉬맨 브레드+허니시나몬버터+미니코울슬로+미니샐러드
# 음식정보 성공
# ===============
# 14300
# 금액 성공
# ===============
# 뉴올리언즈 찹스테이크와 샐러드, 브레드 Box
# 음식메뉴 성공
# ===============
# 돈부리 봄날과 서울붓처스가 만나, 서울붓처스의 Best of Best 인기메뉴를 선보입니다.※스테이크 구성 : 잠발라야 라이스 기본 제공 + 소스 3종(스테이크 소스, 갈릭&허브솔트, 홀그레인 머스터드) 기본 제공※샐러드&브레드 Box 구성 : 부쉬맨 브레드+허니시나몬버터+미니코울슬로+미니샐러드
# 음식정보 성공
# ===============
# 14300
# 금액 성공
# ===============
# 스파이시(치폴레) 찹스테이크와 샐러드, 브레드 Box
# 음식메뉴 성공
# ===============
# 돈부리 봄날과 서울붓처스가 만나, 서울붓처스의 Best of Best 인기메뉴를 선보입니다.※스테이크 구성 : 잠발라야 라이스 기본 제공 + 소스 3종(스테이크 소스, 갈릭&허브솔트, 홀그레인 머스터드) 기본 제공※샐러드&브레드 Box 구성 : 부쉬맨 브레드+허니시나몬버터+미니코울슬로+미니샐러드
# 음식정보 성공
# ===============
# 14300
# 금액 성공
# ===============
# 맥앤치즈와 찹스테이크
# 음식메뉴 성공
# ===============
# 돈부리 봄날과 서울붓처스가 만나, 서울붓처스의 Best of Best 인기메뉴를 선보입니다.※스테이크 구성 : 잠발라야 라이스 기본 제공 + 소스 3종(스테이크 소스, 갈릭&허브솔트, 홀그레인 머스터드) 기본 제공
# 음식정보 성공
# ===============
# 17300
# 금액 성공
# ===============
# 허브솔트럽 웻에이징 살치살 스테이크(200g)와 라이스
# 음식메뉴 성공
# ===============
# 돈부리 봄날과 서울붓처스가 만나, 서울붓처스의 Best of Best 인기메뉴를 선보입니다.※스테이크 구성 : 잠발라야 라이스 기본 제공 + 소스 3종(스테이크 소스, 갈릭&허브솔트, 홀그레인 머스터드) 기본 제공
# 음식정보 성공
# ===============
# 16800
# 금액 성공
# ===============
# 뉴욕 스테이크 플래터 (찹스테이크+살치살 스테이크)
# 음식메뉴 성공
# ===============
# 돈부리 봄날과 서울붓처스가 만나, 서울붓처스의 Best of Best 인기메뉴를 선보입니다.※스테이크 구성 : 잠발라야 라이스 기본 제공 + 소스 3종(스테이크 소스, 갈릭&허브솔트, 홀그레인 머스터드) 기본 제공
# 음식정보 성공
# ===============
# 29800
# 금액 성공
# ===============
# 베이컨, 리치치즈 맥앤치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 수제 허브 통베이컨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 어니언링
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 홈메이드 코울슬로
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# [가정식 돈부리]
# 음식 카테고리 성공
# =========================================
# 소고기 등심 타다키 동
# 음식메뉴 성공
# ===============
# 채끝 스테이크 덮밥
# 음식정보 성공
# ===============
# 12800
# 금액 성공
# ===============
# 규동
# 음식메뉴 성공
# ===============
# 소고기 덮밥
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 차슈동
# 음식메뉴 성공
# ===============
# 통삼겹살 덮밥
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 불맛 오야꼬동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# (일본식)마파두부 돈부리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 차돌박이 규동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 에그 함박동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 버섯크림 함박동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# [일본요리 & 나베]
# 음식 카테고리 성공
# =========================================
# 김치 차돌박이 나베동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# 스끼야끼 나베동
# 음식메뉴 성공
# ===============
# 일본 관동풍 나베요리
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 나가사키 해물 나베동
# 음식메뉴 성공
# ===============
# 나가사키&조개 육수가 어우러진 시원한 나베
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# [튀김 & 가츠]
# 음식 카테고리 성공
# =========================================
# 네기 등심 가츠동
# 음식메뉴 성공
# ===============
# 대파를 듬뿍 올린 등심 가츠 덮밥
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 등심 가츠동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8300
# 금액 성공
# ===============
# 모든 덴뿌라동
# 음식메뉴 성공
# ===============
# 연근,단호박,맛살,새우 3마리
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 커리 등심 가츠동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 치킨 가라아게동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# 데리야끼 멘츠까스동
# 음식메뉴 성공
# ===============
# 소고기 커틀렛 덮밥
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 에비 덴뿌라동
# 음식메뉴 성공
# ===============
# 새우튀김 덮밥
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# [일본식 우동]
# 음식 카테고리 성공
# =========================================
# 오뎅 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 에비 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 김치 차돌박이 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 차돌&덴뿌라 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 명란크림 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11800
# 금액 성공
# ===============
# 철판 차돌박이 야끼우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# [커리 우동]
# 음식 카테고리 성공
# =========================================
# 커리 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 치킨 커리 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# 돈까스 커리 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# [사이드/추가메뉴]
# 음식 카테고리 성공
# =========================================
# 돈까스 추가 (120g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 에비 덴뿌라 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 치킨 가라아게 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 차슈 추가 (100g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 모듬 덴뿌라 추가
# 음식메뉴 성공
# ===============
# 연근, 단호박, 맛살, 새우튀김
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 아지타마고 (계란장조림) 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 반찬 추가
# 음식메뉴 성공
# ===============
# 일본식 반찬 3종, 양배추 샐러드, 흑임자 감자샐러드
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
# 경기도 고급미 ‘참드림' 품종
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 타코야끼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 대만식 블랙티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 대만식 블랙밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# 대만식 타로밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 강남구 역삼동 619-4
# 주소 뽑기 성공
# =========================================
#
# 여기의 카레가 제일 맛있다!,카레라면 여기가 제일이다!라는 의미를 담은 코코이찌방야!멈출수 없는 맛!코코이찌방야 강남점입니다.
#
# 고객 요청에 의해 오복채를 별도 판매하고 있습니다.
# 기본 제공량 이외에 추가로 필요하신 분께서는 별도로 구매해 주시면 됩니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쇠고기 : 호주산돼지고기 : 국내산돼지고기(스피니치베이컨카레) : 외국산(벨기에,오스트리아,스페인 등)닭고기 : 국내산오징어(오징어링, 씨푸드카레) :국내산쌀(밥) : 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [카레]
# 음식 카테고리 성공
# =========================================
# [오무라이스]
# 음식 카테고리 성공
# =========================================
# [하야시라이스]
# 음식 카테고리 성공
# =========================================
# [키즈셋트]
# 음식 카테고리 성공
# =========================================
# [소스추가]
# 음식 카테고리 성공
# =========================================
# [토핑]
# 음식 카테고리 성공
# =========================================
# [샐러드]
# 음식 카테고리 성공
# =========================================
# [음료수]
# 음식 카테고리 성공
# =========================================
# [기타]
# 음식 카테고리 성공
# =========================================
# [카레]
# 음식 카테고리 성공
# =========================================
# 카레
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6600
# 금액 성공
# ===============
# 믹스카레
# 음식메뉴 성공
# ===============
# 토핑 두가지를 동시에 즐기는 믹스메뉴.가장 잘 어울리는 토핑을 모았습니다
# 음식정보 성공
# ===============
# 6600
# 금액 성공
# ===============
# [오무라이스]
# 음식 카테고리 성공
# =========================================
# 치킨크림오무
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 토마토아스파라거스 오무
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10300
# 금액 성공
# ===============
# 버섯크림 오무
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10400
# 금액 성공
# ===============
# 카라아게 오무
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11300
# 금액 성공
# ===============
# 비프 오무
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 로스까스 오무
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11800
# 금액 성공
# ===============
# 하야시 오무
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10600
# 금액 성공
# ===============
# [하야시라이스]
# 음식 카테고리 성공
# =========================================
# 하야시라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9600
# 금액 성공
# ===============
# 버섯하야시라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10100
# 금액 성공
# ===============
# [키즈셋트]
# 음식 카테고리 성공
# =========================================
# 돈까스 키즈세트 (순한맛)
# 음식메뉴 성공
# ===============
# 미니돈까스 1ea + 스마일감자 2ea + 한입핫도그 2ea
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 돈까스 키즈세트 (하이라이스)
# 음식메뉴 성공
# ===============
# 하야시 소스는 데미그라스 소스와 완숙 토마토로 만든 새콤달콤한 맛의 소스입니다.미니돈까스 1ea + 스마일감자 2ea + 한입핫도그 2ea
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 카라아게 키즈세트 (순한맛)
# 음식메뉴 성공
# ===============
# 카라아게 3ea + 스마일감자 2ea + 한입핫도그 2ea
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 카라아게 키즈세트 (하이라이스)
# 음식메뉴 성공
# ===============
# 하야시 소스는 데미그라스 소스와 완숙 토마토로 만든 새콤달콤한 맛의  소스입니다.카라아게 3ea + 스마일감자 2ea + 한입핫도그 2ea
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 별멘치까스 키즈세트 (순한맛)
# 음식메뉴 성공
# ===============
# 별멘치까스 1ea + 스마일감자 2ea + 한입핫도그 2ea
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 별멘치까스 키즈세트 (하이라이스)
# 음식메뉴 성공
# ===============
# 하야시 소스는 데미그라스 소스와 완숙 토마토로 만든 새콤달콤한 맛의 소스입니다.별멘치까스 1ea + 스마일감자 2ea + 한입핫도그 2ea
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# [소스추가]
# 음식 카테고리 성공
# =========================================
# 보통맛 소스 500g 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8200
# 금액 성공
# ===============
# 보통맛 소스 1000g 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16400
# 금액 성공
# ===============
# 순한맛 소스 500g 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8200
# 금액 성공
# ===============
# 순한맛 소스 1000g 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16400
# 금액 성공
# ===============
# [토핑]
# 음식 카테고리 성공
# =========================================
# 치즈 in 로스까스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 닭가슴살 스테이크
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 카라아게
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3200
# 금액 성공
# ===============
# 로스까스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3300
# 금액 성공
# ===============
# 치킨까스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 함박스테이크
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3200
# 금액 성공
# ===============
# 트리플 치즈 in 함박스테이크
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 코코 일품 돈카츠
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 소시지
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3200
# 금액 성공
# ===============
# 왕새우튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3800
# 금액 성공
# ===============
# 크림고로케
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 오징어링
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 새우까스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3200
# 금액 성공
# ===============
# 삶은달걀 (1ea)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# 콘
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 참치
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 하프 카라아게 (3EA)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1600
# 금액 성공
# ===============
# 하프 크림고로케 (1EA)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1400
# 금액 성공
# ===============
# 하프 소시지 (2EA)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1600
# 금액 성공
# ===============
# 하프 오징어링 (4EA)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1400
# 금액 성공
# ===============
# 하프 왕새우튀김 (1EA)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1900
# 금액 성공
# ===============
# [샐러드]
# 음식 카테고리 성공
# =========================================
# 콘 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 참치 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 카라아게 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 계란 참치 콘 샐러드
# 음식메뉴 성공
# ===============
# 계란,참치,콘
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 소시지 콘 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6700
# 금액 성공
# ===============
# 새우까스 콘 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6700
# 금액 성공
# ===============
# 닭가슴살 콘 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [음료수]
# 음식 카테고리 성공
# =========================================
# 웰치스 포도 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 오이오 녹차 (525ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 백산수 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# 카프리썬 (200ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# [기타]
# 음식 카테고리 성공
# =========================================
# 카라아게 콤보
# 음식메뉴 성공
# ===============
# 카라아게 2set (12ea) + 감자튀김 + 살사소스 + 방울토마토
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 닭가슴살 스테이크 콤보
# 음식메뉴 성공
# ===============
# 닭가슴살스테이크 2ea + 감자튀김 + 살사소스 + 방울토마토
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 밥 (100g, 별도용기)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 오복채 (120g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# ===========끝===========
# ---6번 식당파싱 시작 ---
# 서울 강남구 역삼동 826-27 제이스타워 104호
# 주소 뽑기 성공
# =========================================
#
# 핵밥은 인사동 맛집으로 소문난 테이크아웃 스테이크1등 브랜드 핵스테이크의고기굽는 노하우와 숙성방식으로 육즙이 풍부하고 풍미 가득한 스테이크에 자체 개발 특제소스로 깊은맛을 더해 맛있고 다양한 덮밥을 정성껏 만들어 제공합니다.
#
#
# ★8월 1일 ~ 8월 31일★
# 주문금액 만원당 음료 355ml 랜덤증정
#
#
# 가게 소개 뽑기 성공
# =========================================
# 토시살(미국), 소불고기(미국), 우민찌(호주), 목살(벨기에), 항정살(칠레), 연어(칠레), 명란(러시아산), 가라아게(태국산), 쌀(국산), 배추(중국산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 9900
# 최소 금액 성공
# =========================================
# [덮밥]
# 음식 카테고리 성공
# =========================================
# [덮밥]
# 음식 카테고리 성공
# =========================================
# 큐브스테이크 덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 소불고기 덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 명란마요불고기 덮밥
# 음식메뉴 성공
# ===============
# (온명란 X 명란마요 O)
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 소고기간장계란밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 목살슬라이스 덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 매콤목살슬라이스 덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 항정살 덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 매콤항정살 덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 연어회 덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 연어구이 덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 연아밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 가라아게덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 명아밥(명란아보카도덮밥)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 서울 강남구 역삼동 832-31
# 주소 뽑기 성공
# =========================================
#
# 신선한 회와 스시를 맛볼 수 있는 역삼동 맛집 초밥파는횟집입니다!
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# 넙치,조피볼락,참돔,뱀장어,쌀 : 국내산/ 낙지,배추김치 : 중국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [식사메뉴]
# 음식 카테고리 성공
# =========================================
# [스시메뉴]
# 음식 카테고리 성공
# =========================================
# [면/탕]
# 음식 카테고리 성공
# =========================================
# [회식메뉴]
# 음식 카테고리 성공
# =========================================
# [활어회]
# 음식 카테고리 성공
# =========================================
# [세꼬시]
# 음식 카테고리 성공
# =========================================
# [해산물]
# 음식 카테고리 성공
# =========================================
# [튀김메뉴]
# 음식 카테고리 성공
# =========================================
# [구이메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [식사메뉴]
# 음식 카테고리 성공
# =========================================
# 회덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 연어덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 멍게덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 참치회덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 공기밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [스시메뉴]
# 음식 카테고리 성공
# =========================================
# 초밥 (10p)
# 음식메뉴 성공
# ===============
# 광어(3pcs), 연어(2pcs), 새우(2pcs), 한치(1pcs), 계란(1pcs), 계절회(1pcs)
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 특초밥 (13pcs)
# 음식메뉴 성공
# ===============
# 광어(4pcs), 연어(2pcs), 새우(2pcs), 한치(1pcs), 계란(1pcs), 계절회(1pcs), 참치(2pcs)
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 스페셜초밥 (15pcs)
# 음식메뉴 성공
# ===============
# 광어(4pcs), 연어(2pcs), 새우(2pcs), 한치(1pcs), 계란(1pcs), 계절회(1pcs), 참치(2pcs), 장어(2pcs)
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 광어초밥 (12pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 연어초밥 (12pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 광어초밥 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 연어초밥 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 새우초밥 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 지느러미초밥 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 장어초밥 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 참치초밥 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# [면/탕]
# 음식 카테고리 성공
# =========================================
# 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 모밀
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 알탕
# 음식메뉴 성공
# ===============
# 소(2~3인분), 중(3~4인분)
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 조개탕
# 음식메뉴 성공
# ===============
# 소(2~3인분), 중(3~4인분)
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 생우럭탕
# 음식메뉴 성공
# ===============
# 소(2~3인분), 중(3~4인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# [회식메뉴]
# 음식 카테고리 성공
# =========================================
# 육만원 세트 (2~3인분)
# 음식메뉴 성공
# ===============
# 광어 + 우럭 + 해산물 + 초밥
# 음식정보 성공
# ===============
# 60000
# 금액 성공
# ===============
# 팔만원 세트 (3~4인분)
# 음식메뉴 성공
# ===============
# 광어 + 우럭 + 해산물 + 초밥 + 튀김 + 매운탕
# 음식정보 성공
# ===============
# 80000
# 금액 성공
# ===============
# 십만원 세트 (5인분)
# 음식메뉴 성공
# ===============
# 광어 + 우럭 + 연어 + 해산물 + 초밥 + 튀김 + 매운탕
# 음식정보 성공
# ===============
# 100000
# 금액 성공
# ===============
# [활어회]
# 음식 카테고리 성공
# =========================================
# 연어회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분), 대(4인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 광어회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분), 대(4인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 우럭회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분), 대(4인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 광어 + 우럭 회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분), 대(4인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 광어 + 연어 회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분), 대(4인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 광어 + 놀래미 회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분), 대(4인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 광어 + 도다리 회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분), 대(4인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 도다리 회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 놀래미 회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 줄돔 회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 도미회 (1kg)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 50000
# 금액 성공
# ===============
# 농어회 (1kg)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 50000
# 금액 성공
# ===============
# 모듬회
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)광어 + 우럭 + 계절회
# 음식정보 성공
# ===============
# 40000
# 금액 성공
# ===============
# 대 광어회 (4인 이상)
# 음식메뉴 성공
# ===============
# 큰 광어 한마리
# 음식정보 성공
# ===============
# 70000
# 금액 성공
# ===============
# 전어회 (2인분)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 방어 회
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# [세꼬시]
# 음식 카테고리 성공
# =========================================
# 광어 세꼬시
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 우럭 세꼬시
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 놀래미 세꼬시
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 아나고 세꼬시
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 도다리 세꼬시
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 줄돔 세꼬시
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 모듬 세꼬시
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)광어 + 우럭 + 줄돔 + (중사이즈 선택시)도다리
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# [해산물]
# 음식 카테고리 성공
# =========================================
# 멍게
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 개불
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 가리비
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 키조개
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 돌멍게
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 해삼
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 낙지
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 전복
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 소라
# 음식메뉴 성공
# ===============
# 소(2인분), 중(3인분)
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 멍게 + 개불
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 멍게 + 해삼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 멍게 + 개불 + 해삼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 산새우 (12마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# [튀김메뉴]
# 음식 카테고리 성공
# =========================================
# 오징어 튀김
# 음식메뉴 성공
# ===============
# 소(150g), 중(250g)
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 새우 튀김
# 음식메뉴 성공
# ===============
# 소(15마리), 중(25마리)
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 왕새우 튀김
# 음식메뉴 성공
# ===============
# 소(8마리), 중(14마리)
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 모듬 튀김
# 음식메뉴 성공
# ===============
# 소(노바시새우8+왕새우4+오징어100g), 중(노바시새우12+왕새우8+오징어100g)
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# [구이메뉴]
# 음식 카테고리 성공
# =========================================
# 시사모 구이
# 음식메뉴 성공
# ===============
# 소(10마리), 중(20마리)
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 새우소금 구이
# 음식메뉴 성공
# ===============
# 소(10마리), 중(15마리)
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 가리비 구이
# 음식메뉴 성공
# ===============
# 소(4마리(8조각)), 중(6마리(12조각))
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 키조개 구이
# 음식메뉴 성공
# ===============
# 소(1마리), 중(2마리)
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 아나고 구이
# 음식메뉴 성공
# ===============
# 소(1마리), 중(2마리)
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 연어구이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 산새우 구이 (17마리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 전어 구이 (500g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 전어 무침 (300g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---8번 식당파싱 시작 ---
# 서울 강남구 역삼동 825-20 지하1층, 101호
# 주소 뽑기 성공
# =========================================
#
# 스노우폭스는 쉐프들이 매장에서 직접 요리하는 레스토랑과 리테일샵의 장점을 완벽하게 조화시킨 신개념의 "Grab N Go 도시락카페"입니다.
# 당일 만든 음식은 당일만 판매합니다.
# (매장 사정상 10만원 이상 주문 시 취소 콜이 갈 수 있으며, 이틀 전 예약 부탁드립니다.)
#
#
# 가게 소개 뽑기 성공
# =========================================
# -쌀 : 국내산-연어니기리,샐몬 드래곤 롤, 롤 니기리 콤보, 다니엘 스폐셜, 필연 스폐셜, 프리미엄 스시, 연어 -아부리, 샐라델피아롤, 연어데리야끼덮밥 : 연어(노르웨이산)-필라델피아롤 : 훈제 연어(칠레산)-단호한감자 : 감자(미국산)-장어 드레곤 롤, 다니엘 스폐셜, 프리미엄 스시, 통장어덮밥: 장어(중국산)-매콤김치덮밥: 김치(배추:국내산/고춧가루:중국산)-돈육 : 국내산-햄버그오믈렛라이스 : 햄버그(계육:국내산/돈육:국내산)-차슈덮밥 : 돈육(외국산)-제육덮밥 : 돈육(국내산)-미소스프 : 두부(외국산)-닭가슴살 샐러드, 다이어트 샐러드 : 닭가슴살(국내산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [스시롤류]
# 음식 카테고리 성공
# =========================================
# [핫푸드류]
# 음식 카테고리 성공
# =========================================
# [샐러드&디저트]
# 음식 카테고리 성공
# =========================================
# [디톡스워터]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# 연어니기리 세트 (마요소스)
# 음식메뉴 성공
# ===============
# 연어니기리(6pcs) + 캘리포니아롤 + 닭가슴살 샐러드한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 20200
# 금액 성공
# ===============
# 연어니기리 세트 (스파이시소스)
# 음식메뉴 성공
# ===============
# 연어니기리(6pcs) + 캘리포니아롤 + 닭가슴살 샐러드한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 20200
# 금액 성공
# ===============
# 샐몬 드래곤롤 세트 (마요소스)
# 음식메뉴 성공
# ===============
# 샐몬 드래곤롤 + 롤니기리콤보 + 닭가슴살샐러드한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 25600
# 금액 성공
# ===============
# 샐몬 드래곤롤 세트 (스파이시소스)
# 음식메뉴 성공
# ===============
# 샐몬 드래곤롤 + 롤니기리콤보 + 닭가슴살샐러드한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 25600
# 금액 성공
# ===============
# 장어 드래곤롤 세트 (마요소스)
# 음식메뉴 성공
# ===============
# 장어 드래곤롤 + 롤니기리콤보 + 닭가슴살샐러드한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 25600
# 금액 성공
# ===============
# 장어 드래곤롤 세트 (스파이시소스)
# 음식메뉴 성공
# ===============
# 장어 드래곤롤 + 롤니기리콤보 + 닭가슴살샐러드한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 25600
# 금액 성공
# ===============
# 새우 드래곤롤 세트 (마요소스)
# 음식메뉴 성공
# ===============
# 새우 드래곤롤 + 롤니기리콤보 + 닭가슴살샐러드한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 25600
# 금액 성공
# ===============
# 새우 드래곤롤 세트 (스파이시소스)
# 음식메뉴 성공
# ===============
# 새우 드래곤롤 + 롤니기리콤보 + 닭가슴살샐러드한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 25600
# 금액 성공
# ===============
# [스시롤류]
# 음식 카테고리 성공
# =========================================
# 캘리포니아롤 (마일드)
# 음식메뉴 성공
# ===============
# 롤의 베이직! 롤의 정석! 마일드, 스파이시 두가지 종류의 캘리포니아롤!한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 7200
# 금액 성공
# ===============
# 캘리포니아롤 (스파이시)
# 음식메뉴 성공
# ===============
# 롤의 베이직! 롤의 정석! 마일드, 스파이시 두가지 종류의 캘리포니아롤!한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 7200
# 금액 성공
# ===============
# 크런치 캘리포니아롤
# 음식메뉴 성공
# ===============
# 바삭한 크런치가 올라간 캘리포니아롤!한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 7600
# 금액 성공
# ===============
# 필라델피아롤
# 음식메뉴 성공
# ===============
# 고소한 필라델피아 크림치즈와 부드러욲 아보카도, 짭조름한 훈제연어의 완벽한 만남!한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 8400
# 금액 성공
# ===============
# 장어 드래곤롤
# 음식메뉴 성공
# ===============
# 부드럽고 고소한 아보카도와 쫀득쫀득 짭조름한 크래미의 환상적인 조합.한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 새우 드래곤롤
# 음식메뉴 성공
# ===============
# 부드럽고 고소한 아보카도와 쫀득쫀득 짭조름한 크래미의 환상적인 조합.한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 샐몬 드래곤롤
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 연어니기리 (6pcs)
# 음식메뉴 성공
# ===============
# 매일 항공 직송을 통해 온 연어를 손질하여 24시간 저온 숙성합니다.한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 8700
# 금액 성공
# ===============
# 연어니기리 (9pcs)
# 음식메뉴 성공
# ===============
# 매일 항공 직송을 통해 온 연어를 손질하여 24시간 저온 숙성합니다.한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 다니엘 스폐셜  (새우 + 장어)
# 음식메뉴 성공
# ===============
# 드래곤 롤과 니기리를 실속있게 한번에! :)한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 13900
# 금액 성공
# ===============
# 롤 니기리콤보
# 음식메뉴 성공
# ===============
# 캘리포니아 롤과 연어니기리를 실속있게 한번에!한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 연어 아부리
# 음식메뉴 성공
# ===============
# 연어를 직화로 구워 밥위에 올린 정성가득 아부리!한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 9400
# 금액 성공
# ===============
# 프리미엄 스시콤보
# 음식메뉴 성공
# ===============
# 9가지의 싱싱한 스시를 콤보로~연어 + 타마고 + 장어 + 자숙새우 + 대합조개 + 간장새우 + 참치뱃살 + 문어 + 가리비한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 필연스페셜
# 음식메뉴 성공
# ===============
# 필라델피아롤과 연어니기리를 한번에!한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 필받은 유부
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 8700
# 금액 성공
# ===============
# 연어 프리미엄
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 마르코 샐라델피아 롤
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 아이언 닭가슴살 롤
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# [핫푸드류]
# 음식 카테고리 성공
# =========================================
# 매콤고기김치 덮밥
# 음식메뉴 성공
# ===============
# 스노우폭스의 특별한 김치 양념 숙성으로 더욱 깊고 짂한 김치, 국내산 1+ 돈육 ! 인생덮밥 즐기세요:)한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 7600
# 금액 성공
# ===============
# 햄버그오믈렛라이스
# 음식메뉴 성공
# ===============
# 두툼한 햄버그와 고소한 오믈렛, 바삭바삭 새우튀김, 거기에 볼로네제 소스까지! :)한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 7400
# 금액 성공
# ===============
# 따끈어묵탕
# 음식메뉴 성공
# ===============
# 롤과 천생연분! 고소한 유부튀김, 어묵의 황제 쫄깃쫄깃 부산어묵! 어묵탕의 꽃, 동글동글 텐카츠:) 뜨거운물만 부어서 드시면 됩니다한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 브로콜리스프
# 음식메뉴 성공
# ===============
# 크림과 우유, 브로콜리가 가득~! 스노우폭스의 베스트 셀러!한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 1300
# 금액 성공
# ===============
# 미소스프
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# 차슈 덮밥
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 간장불고기덮밥
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 7600
# 금액 성공
# ===============
# [샐러드&디저트]
# 음식 카테고리 성공
# =========================================
# 닭가슴살 샐러드
# 음식메뉴 성공
# ===============
# 질 좋은 국내산 닭으로 만든 훈제 닭가슴살과 싱싱신선 채소! 그리고 스노우폭스의 수제 드레싱이 함께!한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 7600
# 금액 성공
# ===============
# 버섯구이 샐러드 小
# 음식메뉴 성공
# ===============
# 아침마다 팬 그릴로 구워낸 버섯이 푸짐~하게, 고소한 참깨드레싱과 곁들이면 환상의 케미!한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 다이어트 샐러드
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 6200
# 금액 성공
# ===============
# 콘 샐러드
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 단호한 감자샐러드
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 믹스빈 샐러드
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 수제 시리얼바
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 롤썸녀
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# [디톡스워터]
# 음식 카테고리 성공
# =========================================
# 트리플베리 디톡스워터 (500ml)
# 음식메뉴 성공
# ===============
# 매일 아침 배송되는 신선한 생과일로 만듞 싱그러욲 디톡스워터! 3~4번 우려서 하루에 2L를 건강하게!
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 애플라즈베리 디톡스워터 (500ml)
# 음식메뉴 성공
# ===============
# 매일 아침 배송되는 신선한 생과일로 만듞 싱그러욲 디톡스워터! 3~4번 우려서 하루에 2L를 건강하게!
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 오렌지로즈힙 디톡스워터 (500ml)
# 음식메뉴 성공
# ===============
# 매일 아침 배송되는 신선한 생과일로 만듞 싱그러욲 디톡스워터! 3~4번 우려서 하루에 2L를 건강하게!
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 피지워터 (330ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 오미베리 스파클링 (325ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3600
# 금액 성공
# ===============
# 오미베리 티 (325ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3600
# 금액 성공
# ===============
# ===========끝===========
# ---9번 식당파싱 시작 ---
# 서울 강남구 역삼동 738-17 2층
# 주소 뽑기 성공
# =========================================
#
# 마지우마 카레는 일본의 젊은 친구들 사이에서 쓰이는 "정말 맛있다" 라는 의미를 가지고 있습니다.브라운,블랙 카레에 다양한 인사이드토핑,튀김토핑을 취향에 맞게 즐기세요.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 쌀,돼지고기 : 국내산
# 닭고기 : 브라질,태국산
# 소고기 : 호주산
# 배추,고춧가루 : 중국산
# 새우 : 베트남산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 10400
# 최소 금액 성공
# =========================================
# [추천 토핑 카레]
# 음식 카테고리 성공
# =========================================
# [기본카레 메뉴]
# 음식 카테고리 성공
# =========================================
# [튀김토핑]
# 음식 카테고리 성공
# =========================================
# [Half 튀김토핑]
# 음식 카테고리 성공
# =========================================
# [사이드 메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [추천 토핑 카레]
# 음식 카테고리 성공
# =========================================
# 브라운 새우 토마토&아스파라거스 카레
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11600
# 금액 성공
# ===============
# 브라운 치킨 가라게 카레
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10400
# 금액 성공
# ===============
# 브라운 낫또&소세지 카레
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11400
# 금액 성공
# ===============
# 블랙 돈까스 카레 (오징어먹물)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11400
# 금액 성공
# ===============
# 블랙 비프콘 카레 (오징어먹물)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11400
# 금액 성공
# ===============
# 블랙 새우튀김 카레 (오징어먹물)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11400
# 금액 성공
# ===============
# [기본카레 메뉴]
# 음식 카테고리 성공
# =========================================
# 브라운 카레
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 블랙 카레 (오징어먹물)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# [튀김토핑]
# 음식 카테고리 성공
# =========================================
# 돈까스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3900
# 금액 성공
# ===============
# 치킨 가라게 (6pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3900
# 금액 성공
# ===============
# 버팔로윙 (5pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3900
# 금액 성공
# ===============
# 왕새우튀김 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3900
# 금액 성공
# ===============
# 크림치즈고로케 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3900
# 금액 성공
# ===============
# 소세지 (2pcs)
# 음식메뉴 성공
# ===============
#
# ...
# 바삭한 크런치가 올라간 캘리포니아롤(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 7600
# 금액 성공
# ===============
# 샐몬드래곤롤
# 음식메뉴 성공
# ===============
# 부드럽고 고소한 아보카도와 쫀득쫀득 짭조름한 크래미의 환상적인 조합(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 장어 드래곤롤
# 음식메뉴 성공
# ===============
# 부드럽고 고소한 아보카도와 쫀득쫀득 짭조름한 크래미의 환상적인 조합(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 연어니기리 (6pcs)
# 음식메뉴 성공
# ===============
# 매일 항공 직송을 통해 온 연어를 손질하여 24시간 저온 숙성합니다.(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 8700
# 금액 성공
# ===============
# 연어니기리 (9pcs)
# 음식메뉴 성공
# ===============
# 매일 항공 직송을 통해 온 연어를 손질하여 24시간 저온 숙성합니다.(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 롤 니기리콤보 (스파이시)
# 음식메뉴 성공
# ===============
# 캘리포니아 롤과 연어니기리를 실속있게 한번에!(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 롤 니기리콤보 (마일드)
# 음식메뉴 성공
# ===============
# (한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 롤 콤보
# 음식메뉴 성공
# ===============
# 마일드, 스파이시, 아몬드 캘리포니아롤이 한번에. 푸짐하게 한 팩으로 즐기세요!(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 다니엘 스페셜
# 음식메뉴 성공
# ===============
# 드래곤 롤과 니기리를 실속있게 한번에! :)(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 13900
# 금액 성공
# ===============
# 연어 아부리
# 음식메뉴 성공
# ===============
# 연어를 직화로 구워 밥위에 올린 정성가득 아부리!(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 9400
# 금액 성공
# ===============
# 필받은 유부
# 음식메뉴 성공
# ===============
# (한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 8700
# 금액 성공
# ===============
# 필연 스페셜
# 음식메뉴 성공
# ===============
# (한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 필라델피아롤
# 음식메뉴 성공
# ===============
# (한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 8400
# 금액 성공
# ===============
# 연어 프리미엄
# 음식메뉴 성공
# ===============
# 한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다. 이틀 전 예약주시면 불편함 없이 이용 가능합니다
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [핫푸드류]
# 음식 카테고리 성공
# =========================================
# 매콤고기김치 덮밥
# 음식메뉴 성공
# ===============
# 스노우폭스의 특별한 김치 양념 숙성으로 더욱 깊고 짂한 김치, 국내산 1+ 돈육 ! 인생덮밥 즐기세요:)(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 7600
# 금액 성공
# ===============
# 햄버그오믈렛라이스
# 음식메뉴 성공
# ===============
# 두툼한 햄버그와 고소한 오믈렛, 바삭바삭 새우튀김, 거기에 볼로네제 소스까지! :)(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 7400
# 금액 성공
# ===============
# 슈림프 커리 라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9400
# 금액 성공
# ===============
# 따끈어묵탕
# 음식메뉴 성공
# ===============
# 롤과 천생연분! 고소한 유부튀김, 어묵의 황제 쫄깃쫄깃 부산어묵! 어묵탕의 꽃, 동글동글 텐카츠:)뜨거운물만 부어서 드시면 됩니다(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 브로콜리스프
# 음식메뉴 성공
# ===============
# 크림과 우유, 브로콜리가 가득~! 스노우폭스의 베스트 셀러!(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 1300
# 금액 성공
# ===============
# 미소스프
# 음식메뉴 성공
# ===============
# (한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# 옥수수 스프
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 통장어덮밥
# 음식메뉴 성공
# ===============
# (한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 차슈 덮밥
# 음식메뉴 성공
# ===============
# (한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# [샐러드&디저트]
# 음식 카테고리 성공
# =========================================
# 닭가슴살 샐러드
# 음식메뉴 성공
# ===============
# 질 좋은 국내산 닭으로 만든 훈제 닭가슴살과 싱싱신선 채소! 그리고 스노우폭스의 수제 드레싱이 함께!(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 7600
# 금액 성공
# ===============
# 버섯구이 샐러드
# 음식메뉴 성공
# ===============
# 아침마다 팬 그릴로 구워낸 버섯이 푸짐~하게, 고소한 참깨드레싱과 곁들이면 환상의 케미!(한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 콘 샐러드
# 음식메뉴 성공
# ===============
# (한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 단호한 감자샐러드
# 음식메뉴 성공
# ===============
# (한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 자몽 愛 연유
# 음식메뉴 성공
# ===============
# (한 메뉴 대량 주문 시 매장 상황에 따라 주문이 불가할 수 있습니다.)
# 음식정보 성공
# ===============
# 3900
# 금액 성공
# ===============
# 컵과일 (오렌지)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 컵과일 프리미엄 (대)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# 컵과일 프리미엄 (소)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 오메가3 듬뿍 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8400
# 금액 성공
# ===============
# 훈제오리 보양 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8400
# 금액 성공
# ===============
# [디톡스워터]
# 음식 카테고리 성공
# =========================================
# 트리플베리 디톡스워터 (500ml)
# 음식메뉴 성공
# ===============
# 매일 아침 배송되는 신선한 생과일로 만든 싱그러운 디톡스워터! 3~4번 우려서 하루에 2L를 건강하게!
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 애플라즈베리 디톡스워터 (500ml)
# 음식메뉴 성공
# ===============
# 매일 아침 배송되는 신선한 생과일로 만든 싱그러운 디톡스워터! 3~4번 우려서 하루에 2L를 건강하게!
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 오렌지 디톡스워터 (500ml)
# 음식메뉴 성공
# ===============
# 매일 아침 배송되는 신선한 생과일로 만든 싱그러운 디톡스워터! 3~4번 우려서 하루에 2L를 건강하게!
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 오미베리 스파클링 (325ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3600
# 금액 성공
# ===============
# 오미베리 티 (325ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3600
# 금액 성공
# ===============
# 에비앙 (330ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1600
# 금액 성공
# ===============
# ===========끝===========
# ---44번 식당파싱 시작 ---
# 서울 강남구 대치동 896-37
# 주소 뽑기 성공
# =========================================
#
# Mr. sushi
#
# 미스터스시는 오늘 준비한 신선한 재료만 당일 사용하는 것을 원칙으로
# 속임이 없는 착한음식을 지향합니다.
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# 전복 : 완도산   장어 : 페루   도미:국내산,일본산.광어 : 국내산   연어 : 노르웨이산   소고기 : 미국산    쌀:국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [초밥세트]
# 음식 카테고리 성공
# =========================================
# [초밥단품]
# 음식 카테고리 성공
# =========================================
# [회]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [덮밥]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [초밥세트]
# 음식 카테고리 성공
# =========================================
# 특선초밥 (12pcs)
# 음식메뉴 성공
# ===============
# 참돔,광어,연어,참치,소고기,광어지느러미,간장새우매장 당일 재료의 종류와 상태에 따라 구성은 조금씩 틀려질 수 있습니다.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 미스터초밥 (12pcs)
# 음식메뉴 성공
# ===============
# 오토로,메카도로,참돔,광어,연어,참치,광어지느러미,간장새우매장 당일 재료의 종류와 상태에 따라 구성은 조금씩 틀려질 수 있습니다.
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 연어초밥 (10pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 광어초밥 (10pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 광어초밥(5pcs) + 연어초밥(5pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 쇠고기초밥(4pcs) + 광어초밥(4pcs) + 연어초밥(4pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 쇠고기초밥 (10pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# [초밥단품]
# 음식 카테고리 성공
# =========================================
# 오토로 (1pc,참치뱃살)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 전복 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 메카도로 (1pc,황새치뱃살)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 새우장 (1pc,간장절임)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 생새우 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 생새우아부리 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 아카미 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1700
# 금액 성공
# ===============
# 쇠고기 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 엔가와 (1pc,광어지느러미)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 장어 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 광어 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 연어 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 초새우 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1300
# 금액 성공
# ===============
# 유부 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 800
# 금액 성공
# ===============
# 계란 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 800
# 금액 성공
# ===============
# 농어 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 참돔 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 날치알군함말이 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1300
# 금액 성공
# ===============
# [회]
# 음식 카테고리 성공
# =========================================
# 모듬사시미
# 음식메뉴 성공
# ===============
# 참돔,연어,광어,참치매장 당일 재료의 종류와 상태에 따라 구성은 조금씩 틀려질 수 있습니다.
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 광어사시미
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 50000
# 금액 성공
# ===============
# 연어사시미
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 고로케 (3pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 새우튀김 (5pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 모듬튀김 (10pcs)
# 음식메뉴 성공
# ===============
# 단호박튀김(2pcs) + 고구마튀김(2pcs) + 고추튀김(2pcs) + 새우튀김(4pcs)
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 이꾸라
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# [덮밥]
# 음식 카테고리 성공
# =========================================
# 광어회덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 참치회덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 생선회덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 사케동덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---45번 식당파싱 시작 ---
# 서울 강남구 청담동 44-13 1층
# 주소 뽑기 성공
# =========================================
#
# 저희 모어덴스시는 15년 경력의 요리사가 있는 정통 일본요리 음식점입니다.
# 재료부터 고집스럽게 만드는 모어덴스시는 고급 일본요리를 합리적인 가격으로 제공하기 위해 노력하고 있습니다.
#
# 합리적인 고급 일본 요리를 만드는 - 모어덴스시
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 넙치 : 국내산
# 참돔 : 일본산
# 연어 : 노르웨이산
# 장어 : 중국산
# 채끝등심, 돈등심, 쌀, 배추김치 : 국내산
# 부채살 : 호주산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [식사류]
# 음식 카테고리 성공
# =========================================
# [사시미]
# 음식 카테고리 성공
# =========================================
# [롤]
# 음식 카테고리 성공
# =========================================
# [스시 세트]
# 음식 카테고리 성공
# =========================================
# [스시 단품]
# 음식 카테고리 성공
# =========================================
# [음료수]
# 음식 카테고리 성공
# =========================================
# [식사류]
# 음식 카테고리 성공
# =========================================
# 특선알탕 (비조리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 모듬 회덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 일식새우튀김 (8pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 문어초회
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 간장새우덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 특선 대구탕
# 음식메뉴 성공
# ===============
# * 비조리로 제공됩니다.
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 특선 알대구탕
# 음식메뉴 성공
# ===============
# * 비조리로 제공됩니다.
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 일식 수제 돈카츠
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# [사시미]
# 음식 카테고리 성공
# =========================================
# 사시미 모리아와세
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# [롤]
# 음식 카테고리 성공
# =========================================
# 크림치즈 연어롤
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 더블 쉬림프 롤
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [스시 세트]
# 음식 카테고리 성공
# =========================================
# 오늘의 초밥 (10pcs)
# 음식메뉴 성공
# ===============
# 활어2, 연어2, 참치1, 초새우1, 게살1, 가리비1, 유부1, 계란1
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 특 초밥 (12pcs)
# 음식메뉴 성공
# ===============
# 활어 2, 연어 2, 참치 2, 보리새우 1, 초새우 1, 한우등심 1, 대왕문어 1, 바다장어 1, 계란 1
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 스폐셜 초밥 (12pcs)
# 음식메뉴 성공
# ===============
# 활어 2, 연어 2, 참치 2, 한우등심 2, 참치뱃살 1, 광어지느러미 1, 보리새우 1, 민물장어 1
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 아부리 불초밥 (10pcs)
# 음식메뉴 성공
# ===============
# 불에 살짝 구운 초밥연어 3, 참치 3, 한우등심 4
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 한우등심 초밥 (10pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 특 참치 초밥 (10pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 광어 초밥 (10pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 연어 초밥 (10pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 어린이 초밥 (8pcs)
# 음식메뉴 성공
# ===============
# 게살, 계란, 유부, 초새우
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 광어 (5pcs) + 연어 (5pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 광어 (5pcs) + 한우등심 (5pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 연어 (5pcs) + 한우등심 (5pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 광어 + 연어 + 한우 (12pcs)
# 음식메뉴 성공
# ===============
# 광어(4pcs) + 연어(4pcs) + 한우(4pcs)
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 지라시스시 (일본식 회덮밥)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [스시 단품]
# 음식 카테고리 성공
# =========================================
# 참다랑어 뱃살 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 참다랑어 아까미 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 황새치 뱃살 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 한우등심 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 민물장어 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 연어 뱃살 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 광어 지느러미 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 광어 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 연어 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 대왕문어 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 보리새우 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 초새우 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 계란 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 대게살 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 데마끼 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 유부 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# [음료수]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---46번 식당파싱 시작 ---
# 서울 서초구 서초동 1544-2
# 주소 뽑기 성공
# =========================================
#
# 초밥은 사랑입니다!
# 정직,신선,신뢰의 믿음으로 최선을 다하는 김뿌라 서초점이 되겠습니다.
#
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 광어,도미,민물장어,고등어,쌀,배추 : 국내산
# 쇠고기 : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 6000
# 최소 금액 성공
# =========================================
