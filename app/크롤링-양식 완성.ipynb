# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 카페[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[5]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 25:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 카페 데이터(이미지) 수집
soup = BeautifulSoup(html, 'lxml')
img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
count = 1
for i in img:
    img_url = i.get_text("url", strip=True)
    img_url_parse = img_url[4:-1]
    try:
        urllib.request.urlretrieve(img_url_parse, f'{count}.american_food_img.jpg')
    except:
        pass
    count += 1

# 일식 데이터(식당명) 수집
japan_store_list = []
japan_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in japan_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(japan_store_list):
    print(i, name)


    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 38:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='양식',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=1),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
        print('음식 카테고리 성공')
        print('=========================================')
        
        store_category_foods = menu.select(".row-menu")

        for food in store_category_foods:
            food_menu = food.select_one(".col-menu > strong").get_text(strip=True)
            print(food_menu)
            print('음식메뉴 성공')
            print('===============')
            food_info = food.select_one(".col-menu > span").get_text(strip=True)
            print(food_info)
            print('음식정보 성공')
            print('===============')
            food_money = food.select_one("span.calculate-price").get_text(strip=True)
            food_moneys = food_money.replace(",", "")
            print(food_moneys)
            print('금액 성공')
            print('===============')
            
            Food.objects.create(
            category=food_category,
            name=food_menu,
            price=food_moneys,
            food_info=food_info,
            )

        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:83: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 강남구 역삼동 736-41 모닝빌딩 지하1층
# 주소 뽑기 성공
# =========================================
#
# [프리미엄 배달 스테이크 '오스테끼']
#
# 강남 테헤란 최고 핫플레이스!
# 배달앱 양식분야 후기 평점 1위!!
# *역삼동 양식분야
# 푸드플라이/배민라이더스/우버이츠 기준*
#
#
# 오스테끼는 대한민국 공유주방
# HONT의 첫 브랜드로서, 신라호텔 출신 헤드셰프와
# 국내외 유명 외식 브랜드의
# 감각적인 젊은 셰프들이 개발한
# 프리미엄 배달스테이크입니다.
#
# 정통 프렌치 셰프가 정통 수비드 조리법으로
# 스테이크의 부드러움을 극대화하여
# 고급 레스토랑의 맛을
# 여러분의 가정까지 그대로 옮겨 드립니다.
#
# 또한, 고객님들의 다양한 니즈에 부합하고자
# 두 번째 프리미엄 배달 분식 브랜드
# 남해분식을 선보인 바 있습니다.
#
# 남해분식 또한 신라호텔 출신 헤드셰프와
# 유명 일식점 출신 셰프가 콜라보하여
# '기존의 고정관념을 깬 고급스러운 분식'이라는
# 호평을 얻고 있는 브랜드입니다.
#
# 이제 오스테끼의 다양한 스테이크 메뉴,
# 남해분식의 유니크한 분식 메뉴와 함께 주문해
# 더욱 경제적으로 즐겨보세요!
#
#
# 가게 소개 뽑기 성공
# =========================================
# * 쌀 : 국내산* 돼지고기(목살) : 네덜란드산* 소고기(부채살) : 미국산 프라임급 - 최상등급 품질로 상위 2.9%에 위치* 닭다리살 : 국내산* 닭가슴살 : 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 20000
# 최소 금액 성공
# =========================================
# [스테이크 메뉴]
# 음식 카테고리 성공
# =========================================
# [다이어트 메뉴]
# 음식 카테고리 성공
# =========================================
# [사이드 & 디저트]
# 음식 카테고리 성공
# =========================================
# [파스타 & 라이스]
# 음식 카테고리 성공
# =========================================
# [오스테끼X남해분식]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [스테이크 메뉴]
# 음식 카테고리 성공
# =========================================
# 비프스테이크 (부채살)
# 음식메뉴 성공
# ===============
# Small : 스테이크(150g)와 구운야채+갈릭버터라이스+토마토살사+보이차(스틱)Large : 스테이크(200g)와 구운야채+갈릭버터라이스+토마토살사+고구마샐러드+다이슨감자+보이차(스틱)Party : 스테이크(300g)와 구운야채+토마토살사+토마토피클+프렌치프라이+보이차(스틱)
# 음식정보 성공
# ===============
# 16700
# 금액 성공
# ===============
# 안심 스테이크 (L, 150g)
# 음식메뉴 성공
# ===============
# 스테이크(150g)와 구운야채+갈릭버터라이스+토마토살사+고구마샐러드+다이슨감자+보이차(스틱)
# 음식정보 성공
# ===============
# 29700
# 금액 성공
# ===============
# 채끝 스테이크 (L, 200g)
# 음식메뉴 성공
# ===============
# 스테이크(200g)와 구운야채+갈릭버터라이스+토마토살사+고구마샐러드+다이슨감자+보이차(스틱)
# 음식정보 성공
# ===============
# 28700
# 금액 성공
# ===============
# 포크스테이크 (목살)
# 음식메뉴 성공
# ===============
# Small : 스테이크(200g)와 구운야채+갈릭버터라이스+토마토살사+보이차(스틱)Large : 스테이크(250g)와 구운야채+갈릭버터라이스+토마토살사+고구마샐러드+다이슨감자+보이차(스틱)Party : 스테이크(400g)와 구운야채+토마토살사+토마토피클+프렌치프라이+보이차(스틱)
# 음식정보 성공
# ===============
# 12900
# 금액 성공
# ===============
# 삼겹살스테이크 (L, 250g)
# 음식메뉴 성공
# ===============
# 스테이크(250g)와 구운야채+쌀밥+볶음김치+미나리+쌈장+다이슨감자+보이차(스틱)
# 음식정보 성공
# ===============
# 14900
# 금액 성공
# ===============
# 치킨스테이크 (닭다리살)
# 음식메뉴 성공
# ===============
# Small : 스테이크(150g)와 구운야채+갈릭버터라이스+토마토살사+보이차(스틱)Large : 스테이크(200g)와 구운야채+갈릭버터라이스+토마토살사+고구마샐러드+다이슨감자+보이차(스틱)
# 음식정보 성공
# ===============
# 12900
# 금액 성공
# ===============
# [다이어트 메뉴]
# 음식 카테고리 성공
# =========================================
# 헬시박스
# 음식메뉴 성공
# ===============
# 닭가슴살(200g)+샐러드+채소스틱+고구마+보이차(스틱)
# 음식정보 성공
# ===============
# 17700
# 금액 성공
# ===============
# 브라질너트샐러드 (Bowl)
# 음식메뉴 성공
# ===============
# 닭가슴살과 브라질너트, 블랙올리브, 병아리콩, 구운 토마토, 각종 계절 야채를 곁들인 샐러드입니다.
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# [사이드 & 디저트]
# 음식 카테고리 성공
# =========================================
# 프렌치프라이
# 음식메뉴 성공
# ===============
# 바삭바삭 제대로 튀겨 낸, 스테이크에 더할나위 없이 어울리는 감자튀김
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 갈릭버터라이스
# 음식메뉴 성공
# ===============
# 갓 지은 따뜻한 밥에 버터와 마늘을 넣어 볶은 고소한 볶은밥
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 하우스샐러드
# 음식메뉴 성공
# ===============
# 계절별 최적의 채소를 골라 특제 갈릭발사믹 드레싱으로 맛을 낸 기본 샐러드
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 토마토피클
# 음식메뉴 성공
# ===============
# 잘 익은 방울토마토를 오스테키만의 피클 소스에 절이면 스테이크와 찰떡 궁합~
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 토마토살사
# 음식메뉴 성공
# ===============
# 토마토와 프레시바질의 상큼하고 새콤한 조화, 스테이크의 절친!
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 우유치즈크레이프
# 음식메뉴 성공
# ===============
# 부드럽고 달콤한 우유치즈 푸딩을 고소한 크레이프로 감싸 만든 디저트 메뉴
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# [파스타 & 라이스]
# 음식 카테고리 성공
# =========================================
# 비프덮밥
# 음식메뉴 성공
# ===============
# 햄버거 패티를 특제소스로 조리해 밥 위에 한 가득~ 곁들인 버섯, 파프리카와 쓱쓱 비벼 먹으면 꿀맛 보장!
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 포크덮밥
# 음식메뉴 성공
# ===============
# 달콤매콤한 특제소스에 맛있게 볶은 돼지고기 덮밥입니다. 색감과 식감을 책임지는 마늘쫑은 신의 한 수!
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 치킨덮밥
# 음식메뉴 성공
# ===============
# 특제 갈비소스로 바비큐한 부드러운 닭다리살에 구운 야채를 곁들인 맛난 덮밥요리입니다.
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 하와이안 파스타
# 음식메뉴 성공
# ===============
# 레드커리와 코코넛 밀크, 파인애플이 만나 이국적인 느낌이 가득한 파스타입니다.
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 깻잎알리오올리오
# 음식메뉴 성공
# ===============
# 깻잎과 잣으로 만든 깻잎 페스토를 이용해 고소하고 향긋한 알리오올리오 파스타
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# [오스테끼X남해분식]
# 음식 카테고리 성공
# =========================================
# 남해떡볶이 (2인분)
# 음식메뉴 성공
# ===============
# 맛있게 매운 국물 떡볶이. 넉넉한 국물에 튀김을 찍어 먹으면 안성맞춤! 쫀득한 모짜렐라 치즈도 추가해서 즐기세요.
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 레드커리떡볶이
# 음식메뉴 성공
# ===============
# 중독성 있는 레드커리로 무장한 쫄깃한 떡볶이, 자꾸만 당기는 맛!
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 남해김밥
# 음식메뉴 성공
# ===============
# 집에서 정성을 다해 만든 '엄마표 김밥', '포슬 포슬' 식감이 부드럽고 짜지 않아 부담 없어요.
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 불닭김밥
# 음식메뉴 성공
# ===============
# 매운 붉닭이 큼지막하게! 첫맛은 화끈하지만 크림치즈 덕분에 끝맛은 부드러운 묘한 김밥입니다.
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 남해튀김 A
# 음식메뉴 성공
# ===============
# 새우튀김(3개)+아주긴김말이(1개)+단호박튀김(1개)+깻잎고기튀김(1개)
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 남해튀김 B
# 음식메뉴 성공
# ===============
# 통게튀김(1개)+아주긴김말이(1개)+단호박튀김(1개)+깻잎고기튀김(1개)
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 삼겹살볶음면
# 음식메뉴 성공
# ===============
# 매콤한 볶음면에 두툼한 삼겹살을 얹어 더욱 풍성하게!
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 전복한마리덮밥
# 음식메뉴 성공
# ===============
# 오독오독 씹히는 전복 속살과 향긋한 전복 내장을 밥에 얹어 특제 소스와 함께 버무리면 한 끼가 뚝딱~
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 삼겹살덮밥
# 음식메뉴 성공
# ===============
# 그릴에 구워낸 부드러운 삼겹살을 밥 위에 올리고 특제소스로 마무리~
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 김치볶음밥
# 음식메뉴 성공
# ===============
# 잘 숙성시킨 김치와 밥을 삼겹살과 맛깔스럽게 볶아낸, 볶음밥의 끝판왕!
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 이탈리안 콜드브루 (200ml)
# 음식메뉴 성공
# ===============
# 80년 전통의 이탈리아 '무세띠 원두커피'를 엄선, 묵직한 바디감과 강렬한 맛을 가진 콜드브루
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 20배 고농축 보이차 (200ml)
# 음식메뉴 성공
# ===============
# 식사 후 입맛을 깔끔하게 해주고 다이어트에 도움을 주는 보이차
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 패션후르츠주스 (200ml)
# 음식메뉴 성공
# ===============
# 달콤새콤 맛있는 패션후르츠를 100% 착즙하여 만든 디저트 음료
# 음식정보 성공
# ===============
# 3800
# 금액 성공
# ===============
# 유기농 석류주스 (200ml)
# 음식메뉴 성공
# ===============
# 스페인 그라나다 지역의 달콤한 석류품종만 선택, 100% 착즙한 유기농 석류주스
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 피지 미네랄 워터 (500ml)
# 음식메뉴 성공
# ===============
# 청량함과 깨끗한 끝맛으로 마실 때마다 기분 좋은 미네랄워터
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 콜라 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:217: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 강남구 역삼동 640-13
# 주소 뽑기 성공
# =========================================
#
# 광화문은 매일 엄선된 국내산 돼지고기를 직접 망치로 두들겨 만든 돈가스와 손수 개발한 레시피로 메밀 육수를 만들어 내는 돈가스 모밀 전문점 입니다.맛으로 소문난 광화문 돈가스와 메밀을 직접 맛보세요!
#
#
# 가게 소개 뽑기 성공
# =========================================
# 돼지고기,쌀,무우 : 국내산고춧가루 : 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [단품메뉴]
# 음식 카테고리 성공
# =========================================
# [기타메뉴]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# A세트(돈가스 + 작은 메밀)
# 음식메뉴 성공
# ===============
# 돈가스 + 작은 메밀매일 직접 국내산 생고기로 만든 수제 돈가스와 시원한 메밀의 조합
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# B세트(돈가스 + 작은 우동)
# 음식메뉴 성공
# ===============
# 돈가스 + 작은 우동매일 직접 국내산 생고기로 만든 수제돈가스와 우동의 조합
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# C세트(카레라이스 + 작은돈가스)
# 음식메뉴 성공
# ===============
# 카레라이스 + 작은돈가스신선한 재료로 만든 카레와 돈가스의 만남
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# D세트(카레라이스 + 작은우동 or 작은메밀)
# 음식메뉴 성공
# ===============
# 카레라이스 + 작은우동 or 작은메일
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# F세트(우동 + 작은돈가스)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [단품메뉴]
# 음식 카테고리 성공
# =========================================
# 광화문 수제 돈가스
# 음식메뉴 성공
# ===============
# 국내산 최고급 냉장 등심만을 사용한 수제 돈가스 입니다
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 냉메밀
# 음식메뉴 성공
# ===============
# 직접 뽑은 육수의 시원함과 풍부한 메밀함량의 냉모밀
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 카레라이스
# 음식메뉴 성공
# ===============
# 신선한 재료로 직접 만든 카레만을 사용합니다
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 우동
# 음식메뉴 성공
# ===============
# 시원한 육수와 쫀득한 면발이 일품인 광화문만의 우동입니다)
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [기타메뉴]
# 음식 카테고리 성공
# =========================================
# 공기밥추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 메밀면 사리 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 돈가스추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 콜라 355ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 355ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하1층
# 주소 뽑기 성공
# =========================================
#
# 이태리 돈까스는 한국인이 가장 좋아하는 양식 메뉴인
# 파스타와 돈까스를 함께 즐길 수 있는 곳입니다.
#
# 저희 돈까스는, 국내산 생등심을 이탈리안 허브와 직접 만든 빵가루로 숙성하여, 부드러운 식감을 자랑합니다. 여기에, 호텔, 이탈리안 레스토랑 경력 10년의
# 전문 Chef 의 맛을 더하였습니다.
#
# 돈까스라는 평범한 식사 한끼지만 파스타, 스프, 샐러드,
# 에그 샌드위치 등 다양함이 가득합니다.
#
# 저희 매장에서 어릴 적 드시던 추억의 맛과 분위기를 즐겨보세요.
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀(국내산) / 고추가루(중국산) / 김치 (중국산) / 돈까스 (돼지고기 : 국내산) / 함박스테이크 (쇠고기 : 호주산, 돼지고기 : 국내산) / 칠리미트 민찌 (쇠고기 : 호주산, 돼지고기 : 국내산) / 치킨 가라아게 (닭다리 : 브라질산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [이태리돈까스 X 미듬영농조합 (한정판매)]
# 음식 카테고리 성공
# =========================================
# [이태리 X 서울클래식]
# 음식 카테고리 성공
# =========================================
# [이태리 스페샬 ]
# 음식 카테고리 성공
# =========================================
# [이태리 함박]
# 음식 카테고리 성공
# =========================================
# [우동]
# 음식 카테고리 성공
# =========================================
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [음료수]
# 음식 카테고리 성공
# =========================================
# [이태리돈까스 X 종선이네 Collaboration]
# 음식 카테고리 성공
# =========================================
# [이태리돈까스 X 미듬영농조합 (한정판매)]
# 음식 카테고리 성공
# =========================================
# 우리쌀 단팥빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 순우유 쌀식빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 소시지 치즈빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 먹물 & 떡 크런치빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# [이태리 X 서울클래식]
# 음식 카테고리 성공
# =========================================
# 1988 서울 돈까스
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스 + 계란후라이
# 음식정보 성공
# ===============
# 8300
# 금액 성공
# ===============
# 1988 서울 함박
# 음식메뉴 성공
# ===============
# 수제 함박스테이크(160g) + 계란후라이
# 음식정보 성공
# ===============
# 9300
# 금액 성공
# ===============
# 1988 정식
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스 + 수제 함박스테이크(160g) + 계란후라이
# 음식정보 성공
# ===============
# 12800
# 금액 성공
# ===============
# 2080 스폐샬
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스 + 멘치가츠 + 치킨가라아게
# 음식정보 성공
# ===============
# 12800
# 금액 성공
# ===============
# 2080 허브 삼겹
# 음식메뉴 성공
# ===============
# 허브숙성 삼겹살 250g + 그릴 야채
# 음식정보 성공
# ===============
# 15800
# 금액 성공
# ===============
# [이태리 스페샬 ]
# 음식 카테고리 성공
# =========================================
# 허브갈릭 토마토 세트
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스 + 갈릭토마토 파스타
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 매콤 까르보나라 세트
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스 + 매콤 베이컨 까르보나라 파스타
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 할라피뇨 갈릭 오일 세트
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스 + 할리피뇨 갈릭오일 파스타
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 바질 페스토 세트
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스 + 바질 페스토 파스타
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 칠리치즈 미트 세트
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스+ 칠리치즈미트 파스타
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 오븐치즈 피자 돈까스 세트
# 음식메뉴 성공
# ===============
# 피자소스, 토핑과 함께 오븐에 구워낸 치즈 피자 돈까스
# 음식정보 성공
# ===============
# 11800
# 금액 성공
# ===============
# 로제 크림 세트
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스+ 로제 소스 파스타
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 크림커리 세트
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스+ 크림 커리 파스타
# 음식정보 성공
# ===============
# 9300
# 금액 성공
# ===============
# [이태리 함박]
# 음식 카테고리 성공
# =========================================
# 토마토 수제 함박 세트
# 음식메뉴 성공
# ===============
# 수제 함박 스테이크 + 계란 후라이 + 허브갈릭 토마토 파스타
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 크림 수제 함박 세트
# 음식메뉴 성공
# ===============
# 수제 함박스테이크 + 계란후라이 + 매콤 베이컨 까르보나라 파스타
# 음식정보 성공
# ===============
# 11800
# 금액 성공
# ===============
# 칠리치즈 수제 함박 세트
# 음식메뉴 성공
# ===============
# 수제 함박스테이크 + 계란후라이 + 칠리치즈 미트 파스타
# 음식정보 성공
# ===============
# 11800
# 금액 성공
# ===============
# 바질페스토 수제 함박
# 음식메뉴 성공
# ===============
# 수제 함박 스테이크 + 바질페스트 파스타
# 음식정보 성공
# ===============
# 11800
# 금액 성공
# ===============
# 해산물 토마토 세트
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스+해산물 토마토 파스타
# 음식정보 성공
# ===============
# 12800
# 금액 성공
# ===============
# 해산물 크림 세트
# 음식메뉴 성공
# ===============
# 허브갈릭 돈까스+해산물 크림 파스타
# 음식정보 성공
# ===============
# 12800
# 금액 성공
# ===============
# [우동]
# 음식 카테고리 성공
# =========================================
# 오뎅 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 새우튀김 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 김치 차돌박이 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# 커리 우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 치킨 가라아게 커리우동
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# 케이준 감자튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 칠리치즈 감자튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 치킨 가라아게
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 멘치가츠 (소고기 커틀릿)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 타코야끼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# [음료수]
# 음식 카테고리 성공
# =========================================
# 코카콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 칠성사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 대만식 블랙티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 대만식 블랙밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# 대만식 타로 밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# [이태리돈까스 X 종선이네 Collaboration]
# 음식 카테고리 성공
# =========================================
# 간장 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 쌈장 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 장독대 고추장 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 블랙페퍼 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 레몬크림 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하1층
# 주소 뽑기 성공
# =========================================
#
# Concept :  Quintessential NewyorkStyle Steak house for Seoulian
# 서울리안을 위한 전통방식의 뉴욕스타일 스테이크 하우스
#
# Keyword : 아메리칸 스테이크 하우스, 허브, 솔트럽, 홈메이드 스테이크 소스
# 스테이크로 유명한 뉴욕스타일의 스테이크 맛 그대로 선보입니다.
#
# 클래식한 시즐링, 에이징, 그리고 그릴링 &베이킹&씨어링 방식까지 뉴욕의 맛 그대로 서울 강남에서 즐겨보세요. 서울붓처스와 함께하는 우아하고 클래식한 다이닝과 즐거운 홈파티를 추천드립니다.
#
# Meet our charming hand crafted & dry-aged steak with premium salt and freshly ground black pepper & herb.
# Our homemade bacon & meat platter are also our flagship dishes.
#
# We provide best diners with a healthy option to carnivorous indulgence. All main dishes will also be complemented by an innovative collection of side dishes.
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# 스테이크 (부채살스테이크, 찹스테이크 : 미국산) / 쌀(국내산) /고추 가루(중국산)/ 깍두기 (중국산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [대표메뉴]
# 음식 카테고리 성공
# =========================================
# [찹 스테이크 BOX]
# 음식 카테고리 성공
# =========================================
# [파스타 + 찹스테이크 BOX]
# 음식 카테고리 성공
# =========================================
# [에이징 프리미엄 스테이크 BOX]
# 음식 카테고리 성공
# =========================================
# [Meat Platter]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [쌀빵]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [대표메뉴]
# 음식 카테고리 성공
# =========================================
# 허브솔트럽 찹 스테이크 & 샐러드, 브레드 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 잠발라야 볶음밥 + 소스 3종 + 샐러드&브레드 Box
# 음식정보 성공
# ===============
# 14300
# 금액 성공
# ===============
# 스파이시(치폴레) 찹스테이크 & 샐러드, 브레드 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 잠발라야 볶음밥 + 소스 3종 + 샐러드&브레드 Box
# 음식정보 성공
# ===============
# 14300
# 금액 성공
# ===============
# 까르보나라 파스타 & 찹스테이크 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 파스타 + 소스 3종 + 샐러드&브레드 Box
# 음식정보 성공
# ===============
# 18800
# 금액 성공
# ===============
# 맥앤치즈 & 찹스테이크 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 맥앤치즈 + 소스 3종 + 샐러드&브레드 Box
# 음식정보 성공
# ===============
# 19800
# 금액 성공
# ===============
# 허브솔트럽 웻 에이징 부채살 스테이크 (200g)와 샐러드, 브레드 Box
# 음식메뉴 성공
# ===============
# 드라이에이징 스테이크 + 잠발라야 볶음밥 + 소스 3종 + 샐러드&브레드 Box
# 음식정보 성공
# ===============
# 19300
# 금액 성공
# ===============
# 롱소시지 칠리치즈 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3800
# 금액 성공
# ===============
# [찹 스테이크 BOX]
# 음식 카테고리 성공
# =========================================
# 허브솔트럽 찹 스테이크 & 샐러드, 브레드 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 잠발라야 볶음밥 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 14300
# 금액 성공
# ===============
# 뉴올리언즈찹스테이크 & 샐러드, 브레드 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 잠발라야 볶음밥 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 14300
# 금액 성공
# ===============
# 스파이시(치폴레) 찹스테이크 & 샐러드, 브레드 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 잠발라야 볶음밥 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 14300
# 금액 성공
# ===============
# 허브솔트럽 찹 스테이크 & 라이스
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 잠발라야 볶음밥 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 11800
# 금액 성공
# ===============
# 뉴올리언즈 찹 스테이크 & 라이스
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 잠발라야 볶음밥 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 11800
# 금액 성공
# ===============
# 스파이시(치폴레) 찹 스테이크 & 라이스
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 잠발라야 볶음밥 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 11800
# 금액 성공
# ===============
# [파스타 + 찹스테이크 BOX]
# 음식 카테고리 성공
# =========================================
# 까르보나라 파스타 & 찹스테이크 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 파스타 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 18800
# 금액 성공
# ===============
# 토마토 파스타 & 찹스테이크 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 파스타 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 18800
# 금액 성공
# ===============
# 칠리치즈 파스타 & 찹스테이크 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 파스타 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 19800
# 금액 성공
# ===============
# 바질페스토 파스타 & 찹스테이크 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 파스타 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 19800
# 금액 성공
# ===============
# 오일 파스타 & 찹스테이크 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 파스타 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 18800
# 금액 성공
# ===============
# 맥앤치즈 & 찹스테이크 Box
# 음식메뉴 성공
# ===============
# 찹 스테이크 + 파스타 + 소스 3종 + 샐러드&브레드 Box스테이크 소스 3종 : 홈메이드 스테이크 소스, 홈메이드 갈릭&허브솔트, 홀그레인머스타드
# 음식정보 성공
# ===============
# 19800
# 금액 성공
# ===============
# [에이징 프리미엄 스테이크 BOX]
# 음식 카테고리 성공
# =========================================
# 허브솔트럽 웻 에이징 부채살 스테이크 (200g) + 라이스
# 음식메뉴 성공
# ===============
# 웻에이징 부채살 스테이크 + 잠발라야 볶음밥 또는 파스타 + 소스 3종 + 샐러드&브레드 Box
# 음식정보 성공
# ===============
# 16800
# 금액 성공
# ===============
# 허브솔트럽 웻 에이징 부채살 스테이크 (200g)와 샐러드, 브레드 Box
# 음식메뉴 성공
# ===============
# 웻에이징 부채살 스테이크 + 잠발라야 볶음밥 또는 파스타 + 소스 3종 + 샐러드&브레드 Box
# 음식정보 성공
# ===============
# 19300
# 금액 성공
# ===============
# 허브솔트럽 웻 에이징 부채살 스테이크 (200g) & 파스타
# 음식메뉴 성공
# ===============
# 웻에이징 부채살 스테이크 + 잠발라야 볶음밥 또는 파스타 + 소스 3종 + 샐러드&브레드 Box
# 음식정보 성공
# ===============
# 24800
# 금액 성공
# ===============
# 허브솔트럽 웻 에이징 부채살 스테이크 (200g) & 맥앤치즈 Box
# 음식메뉴 성공
# ===============
# 웻에이징 부채살 스테이크 + 잠발라야 볶음밥 또는 파스타 + 소스 3종 + 샐러드&브레드 Box
# 음식정보 성공
# ===============
# 25800
# 금액 성공
# ===============
# [Meat Platter]
# 음식 카테고리 성공
# =========================================
# 뉴욕 스테이크 플래터 (찹스테이크 + 부채살 스테이크)
# 음식메뉴 성공
# ===============
# 플래터 + 잠발라야 라이스 + 샐러드&브레드 Box + 소스 3종
# 음식정보 성공
# ===============
# 29800
# 금액 성공
# ===============
# 서울 돈까스 플래터 (돈까스+찹스테이크)
# 음식메뉴 성공
# ===============
# 플래터 + 잠발라야 라이스 + 샐러드&브레드 Box + 소스 3종
# 음식정보 성공
# ===============
# 23800
# 금액 성공
# ===============
# 도쿄 함박 플래터 (함박+찹스테이크)
# 음식메뉴 성공
# ===============
# 플래터 + 잠발라야 라이스 + 샐러드&브레드 Box + 소스 3종
# 음식정보 성공
# ===============
# 23800
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 베이컨, 리치치즈 맥앤치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 수제 허브 통베이컨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 잠발라야 볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 어니언링
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 케이준 감자튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 칠리치즈 감자튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 홈메이드 코울슬로
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스테이크 소스 3종
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# [쌀빵]
# 음식 카테고리 성공
# =========================================
# 쌀 단팥빵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 순우유 쌀식빵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 소시지 치즈빵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 먹물 & 떡 크런치빵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 코카콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 칠성사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 대만식 블랙티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 대만식 블랙밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# 대만식 타로 밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하1층
# 주소 뽑기 성공
# =========================================
#
# Concept :우리가 꿈꾸는 즐겁고,맛있는 파스타
#
#
# 에그런은한국사람들이 꿈꾸는 즐겁고 맛있는 파스타를 만드는 곳입니다.
# 우리에게 가장 친숙한계란후라이부터수란,스카치에그까지 다양한 계란요리를 곁들인 파스타와
# 우리가 좋아하는 청양고추,꽈리고추,짱아찌,대파,명란,쭈꾸미를 듬뿍넣은 재미있고 친숙한 파스타까지
# 다양한파스타요리를에그런에서만나보세요.
#
#
#
# 에그런은우리모두를 위한 해장요리부터 떡볶이파스타,특별한날을 위한 정통파스타까지,
# 더 즐겁고 친숙한 파스타를 만듭니다.
#
#
#
# 어렵게만 느껴졌던 파스타를 보다 즐겁고 쉽게에그런과함께 만나보세요.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쭈꾸미 : 태국산  / 베이컨 : 혼합 / 닭다리살 : 브라질산 /  쌀 : 국내산 /고추 가루 : 중국산  / 스카치에그 (소고기 : 호주산, 돼지고기 : 국내산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [에그파스타]
# 음식 카테고리 성공
# =========================================
# [국물파스타]
# 음식 카테고리 성공
# =========================================
# [셰프의 스페셜파스타]
# 음식 카테고리 성공
# =========================================
# [떡볶이파스타]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [쌀빵]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [에그파스타]
# 음식 카테고리 성공
# =========================================
# (오일) 에그 알리오올리오 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# (토마토) 갈릭 아라비아따 에그 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# (크림) 리얼 에그 까르보나라
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# (크림) 매콤 청양고추 까르보나라
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# [국물파스타]
# 음식 카테고리 성공
# =========================================
# (토마토) 해물 토마토 해장 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# (크림) 해물 크림 해장 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# (크림) 양송이 수프 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# [셰프의 스페셜파스타]
# 음식 카테고리 성공
# =========================================
# (맥앤치즈) 베이컨&맥앤치즈
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# (크림) 대파명란크림 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# (크림) 쉬림프 로제 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# (크림) 불쭈꾸미 로제 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# (미트소스) 소시지치킨 잠발라야 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# (오일) 꽈리고추 간장치킨 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# (오일) 갓짱아찌 명란 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# [떡볶이파스타]
# 음식 카테고리 성공
# =========================================
# 까르보나라 떡볶이 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 로제 떡볶이 파스타
# 음식메뉴 성공
# ===============
# 파스타 + 수제 핑크 피클 + 망고젤리푸딩
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 코슬로우
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 케이준 감자튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 메이플 빠스(맛탕)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 양송이수프
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 어니언링
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 스카치 에그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 칠리치즈 감자튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 가라아게 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 콥 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# [쌀빵]
# 음식 카테고리 성공
# =========================================
# 쌀 단팥빵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 먹물, 떡크런치빵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 순우유 쌀식빵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 소시지 치즈빵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 코카콜라 500ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 칠성사이다 500ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 대만식 블랙티(Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 대만식 블랙밀크티(Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# 대만식 타로밀크티(Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# ===========끝===========
# ---6번 식당파싱 시작 ---
# 서울 강남구 역삼동 668-9 지하1층
# 주소 뽑기 성공
# =========================================
#
# WRAP'S 를 찾아주셔서 감사합니다.
# 최근 10개이상의 대량주문이 많습니다.
# 랩스는 대표 1인이 조리 및 운영하는 업장이며 주문 즉시
# 만들다보니 일반 소량주문과 동시작업이 어렵습니다.
# 시간에 쫓겨 급하게 만들어 보내드리고싶지 않은
# 마음에 부득이 주문을 받지못하는점 죄송하게 생각합니다.
# 10개이상의 주문은 당일 3시간 이전에 미리 아래의
# 번호로 예약해주시면 요청하시는 시간에 맞추어
# 정성껏,맛있게 준비해드리겠습니다.
# 찾아주셔서 다시한번 감사드립니다.
# 예약전화)) 010-4939-0910
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀 - 국내산소고기 - 호주산닭고기 - 브라질산돼지고기 (삼겹살 - 캐나다산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [메인메뉴]
# 음식 카테고리 성공
# =========================================
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [메인메뉴]
# 음식 카테고리 성공
# =========================================
# B.S.T 랩
# 음식메뉴 성공
# ===============
# 베이컨, 진한 파마산 치즈, 시금치, 토마토, 양파(Parmesan Cheese + Spinach + Bacon + Tomato + Pickled Onion)
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# Spicy Roast Chicken 랩
# 음식메뉴 성공
# ===============
# 닭안심, 시금치, 토마토, 양파(Roast Chicken + Spinach + Tomato + Pickled Onion)
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# Fresh Ricotta Cheese 랩 <견과류 토핑>
# 음식메뉴 성공
# ===============
# 리코타치즈, 크렌베리, 시금치, 토마토, 양파Ricotta Cheese + Dried Cranberries + Spinach + Tomato + Pickled Onion
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# Bulgogi 랩
# 음식메뉴 성공
# ===============
# 소불고기, 표고버섯, 시금치 페스토(견과류 포함), 시금치, 양파(Bulgogi + Mushroom + Spinach Pesto + Spinach + Onion)
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 스파이시 쉬림프 랩
# 음식메뉴 성공
# ===============
# 매콤한 새우, 계란, 시금치, 양파, 토마토(Spicy Shrimp + Egg + Spinach + Onion + Tomato)
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# Chunky Turkey 랩 (견과류 포함 - 제거 불가능)
# 음식메뉴 성공
# ===============
# 터키브레스트햄, 계란, 감자, 오이, 크렌베리(TurkeyBreastHam + Egg + Potato + Cucumber + Dried Cranberries)
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 떡갈비리또
# 음식메뉴 성공
# ===============
# 떡갈비, 표고버섯, 밥, 시금치, 양파, 토마토(Grilled Short Rib Patties + Rice + Spinach + Tomato + Onion + Mushroom)
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# 감자튀김
# 음식메뉴 성공
# ===============
# 케이쥰 감자튀김
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 감자튀김 + 윙
# 음식메뉴 성공
# ===============
# 케이쥰 감자튀김 + 버팔로 윙(3pcs)
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 버팔로 윙 (5pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 서울 서초구 양재동 11-149
# 주소 뽑기 성공
# =========================================
#
# 라그릴리아는 정통 이탈리안 요리를 새롭게 해석한 맛있는 요리와 전문 소믈리에가 엄선한 와인,
# 다양한 수제맥주를 함께 즐길 수 있는 이탈리안 캐주얼 레스토랑입니다.
# 신선한 재료로 쉐프가 정성을 다해 만든 라그릴리아 메뉴를 이제 집에서도 즐겨보세요.
#
# 정통 이탈리아의 맛과 멋을 느끼실 수 있습니다.
#
# (배달 시 매장에서 나가는 영수증으로 해피포인트 2% 적립이 가능합니다.)
#
#
# 가게 소개 뽑기 성공
# =========================================
# 시저샐러드 [닭고기_국내산, 돼지고기_미국산]크리스피 치킨 샐러드 [닭고기_태국산]에그&베이컨 피자 [돼지고기_미국산]버섯&페페로니 피자 [돼지고기_국내산,외국산(미국,아일랜드,스페인 등), 소고기_호주산]가든 비앙카 [돼지고기_이탈리아산]해산물 토마토 스파게티 [오징어_국내산]로얄 까르보나라 스파게티 [돼지고기_미국산]크림 볼로네제 스파게티 [소고기_국내산 한우, 돼지고기_국내산]포르치니 버섯 리조또 [소고기_호주산, 쌀_국내산]갈비 리조또 [돼지고기_캐나다산,미국산, 쌀_국내산]해산물 리조또 [오징어_국내산, 쌀_국내산]채끝등심/안심 스테이크 [소고기_호주산]한우 안심 스테이크 [소고기_국내산 한우]윈터 비프 샐러드[소고기:미국산]
#
# 가게 원산지 뽑기 성공
# =========================================
# 20000
# 최소 금액 성공
# =========================================
# [[겨울 신메뉴]]
# 음식 카테고리 성공
# =========================================
# [샐러드]
# 음식 카테고리 성공
# =========================================
# [피자]
# 음식 카테고리 성공
# =========================================
# [파스타 박스]
# 음식 카테고리 성공
# =========================================
# [리조또 박스]
# 음식 카테고리 성공
# =========================================
# [스테이크 박스]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [[겨울 신메뉴]]
# 음식 카테고리 성공
# =========================================
# 윈터 비프 샐러드
# 음식메뉴 성공
# ===============
# 달콤한 글루코시 과일무, 아티초크, 토마토 등 다양한 채소와 오리엔탈 소스를 더한 소고기, 상큼한 랜치 드레싱을 곁들인 샐러드
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 가자미 오일 스파게티 박스
# 음식메뉴 성공
# ===============
# 치미추리 소스를 곁들인 바삭한 가자미 튀김과 구운 마늘, 올리브, 토마토를 넣어 만든 담백한 오일 스파게티와 데일리 샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 통영 굴 크림 스파게티 박스
# 음식메뉴 성공
# ===============
# 통통하게 살이 오른 제철 통영 굴과 시금치를 가득 넣은 소스 위에 바삭한 굴 크럼블을 올려 풍미가 가득한 스페셜 스파게티와 데일리 샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# [샐러드]
# 음식 카테고리 성공
# =========================================
# 시저 샐러드
# 음식메뉴 성공
# ===============
# 신선한 로메인과드레싱,아삭한 식감을 느낄수 있는 시저 샐러드
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 새우 버섯 샐러드
# 음식메뉴 성공
# ===============
# 신선한 채소와 그릴에 구운 버섯, 리코타 치즈를 함께 즐길 수 있는 샐러드
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# 크리스피 치킨 샐러드
# 음식메뉴 성공
# ===============
# 바삭하게 튀긴 순살치킨과 매콤달콤한 드레싱이 어우러진 크리스피 치킨 샐러드
# 음식정보 성공
# ===============
# 14900
# 금액 성공
# ===============
# [피자]
# 음식 카테고리 성공
# =========================================
# 마르게리따
# 음식메뉴 성공
# ===============
# 치즈와 바질로 맛을 더한 토마토 소스 마르게리따
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 에그&베이컨 피자
# 음식메뉴 성공
# ===============
# 고소한 달걀과 바삭한 베이컨이 어우러진 에그&베이컨 피자
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 꽈뜨로 포르마지
# 음식메뉴 성공
# ===============
# 4가지 치즈가 토핑된 꽈뜨로 포르마지
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 버섯&페페로니 피자
# 음식메뉴 성공
# ===============
# 양송이 버섯과 페페로니가 올라간 버섯&페페로니 피자
# 음식정보 성공
# ===============
# 19900
# 금액 성공
# ===============
# 풍기 피자
# 음식메뉴 성공
# ===============
# 3가지 버섯을 넣어 깊은 풍미를 느낄 수 있는 풍기 피자
# 음식정보 성공
# ===============
# 19900
# 금액 성공
# ===============
# 가든비앙카
# 음식메뉴 성공
# ===============
# 신선한 루꼴라와 프로슈토, 방울토마토가 어우러진 가든 비앙카
# 음식정보 성공
# ===============
# 20900
# 금액 성공
# ===============
# [파스타 박스]
# 음식 카테고리 성공
# =========================================
# 로얄 까르보나라 스파게티 박스
# 음식메뉴 성공
# ===============
# 수란을 곁들인 진한 크림 소스의 로얄 까르보나라와 데일리 샐럳,, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 해산물 토마토 스파게티 박스
# 음식메뉴 성공
# ===============
# 신선한 해산물을 넣어 맛을 낸 토마토 파스타와 데일리, 샐러드, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 모짜렐라 로제소스 빠빠델레 박스
# 음식메뉴 성공
# ===============
# 진한 로제크림 소스와 모짜렐라 치즈로 맛을 낸 빠빠델레 파스타와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 쉬림프 로제 빠빠델레 박스
# 음식메뉴 성공
# ===============
# 새우의 깊은 맛이 느껴지는 진한 로제크림 소스의 쉬림프 빠빠델레 파스타와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 알리오 올리오 스파게티 박스
# 음식메뉴 성공
# ===============
# 마늘향이 풍부하게 살아 있는 담백한 오일 파스타와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 14900
# 금액 성공
# ===============
# 봉골레 스파게티 박스
# 음식메뉴 성공
# ===============
# 신선한 조개로 가득한 오일 파스타와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 새우 날치알 크림 스파게티 박스
# 음식메뉴 성공
# ===============
# 라그릴리아 인기 메뉴 새우,날치알이 들어간 크림 파스타와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# 크림 볼로네제 스파게티 박스
# 음식메뉴 성공
# ===============
# 부드러운 크림이 더해진 볼로네제 파스타와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 18900
# 금액 성공
# ===============
# [리조또 박스]
# 음식 카테고리 성공
# =========================================
# 해산물 리조또 박스
# 음식메뉴 성공
# ===============
# 신선한 해산물을 넣어 맛을 낸 토마토 소스 리조또와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 22900
# 금액 성공
# ===============
# 포르치니 버섯 리조또 박스
# 음식메뉴 성공
# ===============
# 담백하고 진한 풍미가 있는 포르치니 버섯을 넣어 만든 리조또와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 20900
# 금액 성공
# ===============
# 갈비 리조또 박스
# 음식메뉴 성공
# ===============
# 라그릴리아의 특별 소스로 양념한 돼지갈비와브로콜리, 완두콩을 넣어 만든 리조또를 함께 즐기는 메뉴에 데일리 샐러드, 콘샐러드가 함께 제공되는 박스
# 음식정보 성공
# ===============
# 22900
# 금액 성공
# ===============
# [스테이크 박스]
# 음식 카테고리 성공
# =========================================
# 채끝등심 스테이크 박스
# 음식메뉴 성공
# ===============
# "집에서 즐기는 라그릴리아의 맛있는 채끝등심 스테이크와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스굽기는 M.W으로 제공됩니다."
# 음식정보 성공
# ===============
# 29900
# 금액 성공
# ===============
# 안심 스테이크 박스
# 음식메뉴 성공
# ===============
# "집에서 즐기는 라그릴리아의 맛있는 안심 스테이크와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스굽기는 M.W으로 제공됩니다."
# 음식정보 성공
# ===============
# 34900
# 금액 성공
# ===============
# 한우 안심 스테이크 박스
# 음식메뉴 성공
# ===============
# "집에서 즐기는 라그릴리아의 맛있는 국내산 한우1+ 안심 스테이크와 데일리 샐러드, 콘샐러드가 함께 제공되는 박스굽기는 M.W으로 제공됩니다."
# 음식정보 성공
# ===============
# 49900
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 오생수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# 오생수 스파클링 라임
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# ===========끝===========
# ---8번 식당파싱 시작 ---
# 서울 강남구 도곡동 420-8 1층
# 주소 뽑기 성공
# =========================================
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# 소고기:호주산,돼지고기(베이컨:미국산),소시지(돼지고기:국내산.외국산)소시지(돼지고기:국내산.소고기:호주산)닭고기(국내산,브라질산)오징어(국내산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [작품파스타메뉴]
# 음식 카테고리 성공
# =========================================
# [작품리조또메뉴]
# 음식 카테고리 성공
# =========================================
# [작품피자M메뉴]
# 음식 카테고리 성공
# =========================================
# [작품피자L메뉴]
# 음식 카테고리 성공
# =========================================
# [2인set메뉴]
# 음식 카테고리 성공
# =========================================
# [3인~5인set메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [작품파스타메뉴]
# 음식 카테고리 성공
# =========================================
# 명품빠네파스타
# 음식메뉴 성공
# ===============
# 바삭하면서 부드러운 빵에 특제 새우크림 소스로 매콤하고 풍미가 있는 크림 파스타
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 뽀모도로
# 음식메뉴 성공
# ===============
# 생토마토와 마늘, 바질로 만든 정통 이탈리안 파스타
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 새우칠리
# 음식메뉴 성공
# ===============
# 신선한 새우와 칠리소스가 어우러진 매콤한 파스타
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 알리오올리오
# 음식메뉴 성공
# ===============
# 마늘, 앤쵸비, 올리브오일이 어우러진 깔끔한 맛의 대표적인 오일 파스타
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 칠리로제
# 음식메뉴 성공
# ===============
# 신선한 새우와 칠리소스, 크림소스가 어우러진 매콤하면서 부드러운 파스타
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 할라페뇨
# 음식메뉴 성공
# ===============
# 할라페뇨와 마늘, 앤쵸비, 올리브오일이 어우러진 매콤한 맛의 오일 파스타
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 까르보나라
# 음식메뉴 성공
# ===============
# 베이컨, 양송이가 듬뿍 담긴 정통 크림파스타
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 뽀모로제
# 음식메뉴 성공
# ===============
# 생토마토와 마늘 바질로 만든 소스에 크림소스를 곁들인 부드러운 맛의 파스타
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 볼로네제
# 음식메뉴 성공
# ===============
# 생토마토와 간소고기로 맛을 낸 볼로냐지방의 명품인포만감이 있는 파스타
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# [작품리조또메뉴]
# 음식 카테고리 성공
# =========================================
# 버섯토마토리조또
# 음식메뉴 성공
# ===============
# 버섯, 브로콜리, 새우에 토마토소스를 곁들여 부드럽고 상큼한맛을 느낄 수 있는 리조또
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 해물토마토리조또
# 음식메뉴 성공
# ===============
# 풍성한 해산물로 맛을 낸 토마토 리조또
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 풍기&베이컨리조또
# 음식메뉴 성공
# ===============
# 다앙한 버섯과 베이컨 채소등으로 맛을 낸크림리조또
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# [작품피자M메뉴]
# 음식 카테고리 성공
# =========================================
# 모짜렐라마르게리따피자 (M)
# 음식메뉴 성공
# ===============
# 최상급 모짜렐라 치즈 2종과 생토마토 바질소스가 어우러진 환상적인 맛의 피자.작품의 히트 작
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 까망베르피자 (M)
# 음식메뉴 성공
# ===============
# 국내 최상급 모짜렐라 치즈에 프랑스 까망베르치즈가 어우러진 꿀에 찍어 먹는 고소 담백한 피자
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 마르게리따피자 (M)
# 음식메뉴 성공
# ===============
# 국내 최상급 모짜렐라 치즈의 깊은 맛을느낄 수 있는 담백한 피자
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 고구마피자 (M)
# 음식메뉴 성공
# ===============
# 후르츠 칵테일과 고구마가 어우러진 달콤한 피자
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고르곤졸라피자 (M)
# 음식메뉴 성공
# ===============
# 고르곤졸라 치즈 특유의 향과 신선한 모짜렐라치즈가 어우러진 꿀에 찍어먹는 달콤한 피자
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 디아볼라피자 (M)
# 음식메뉴 성공
# ===============
# 블랙올리브와 페퍼로니가 어우러진 담백한 페퍼로니 피자
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 불고기피자 (M)
# 음식메뉴 성공
# ===============
# 호주산 청정우로 만든 불고기와 신선한 야채,할라페뇨가 어우러진 고급스런 매콤한 맛의 피자
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 칠리핫치킨피자 (M)
# 음식메뉴 성공
# ===============
# 칠리소스와 치킨, 체다치즈가 어우러져 매콤하면서 고소한 피자
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 콤비네이션피자 (M)
# 음식메뉴 성공
# ===============
# 신선한 야채와 2종의 햄 콤비로 담백한 맛을 내는 피자
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 하와이아나피자 (M)
# 음식메뉴 성공
# ===============
# 파인애플과 과일치즈의 환상적인 하모니로 고소한 햄맛이 어우러진 달콤담백한 치즈피자
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# [작품피자L메뉴]
# 음식 카테고리 성공
# =========================================
# 모짜렐라마르게리따피자 (L)
# 음식메뉴 성공
# ===============
# 최상급 모짜렐라 치즈 2종과 생토마토 바질소스가 어우러진 환상적인 맛의 피자. 작품의 히트 작
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 까망베르피자 (L)
# 음식메뉴 성공
# ===============
# 국내 최상급 모짜렐라 치즈에 프랑스 까망베르치즈가 어우러진 꿀에 찍어 먹는 고소 담백한 피자
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 마르게리따피자 (L)
# 음식메뉴 성공
# ===============
# 국내 최상급 모짜렐라 치즈의 깊은 맛을 느낄 수 있는 담백한 피자
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# 고구마피자 (L)
# 음식메뉴 성공
# ===============
# 후르츠 칵테일과 고구마가 어우러진 달콤한 피자
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 고르곤졸라피자 (L)
# 음식메뉴 성공
# ===============
# 고르곤졸라 치즈 특유의 향과 신선한 모짜렐라치즈가 어우러진 꿀에 찍어먹는 달콤한 피자
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 디아볼라피자 (L)
# 음식메뉴 성공
# ===============
# 블랙올리브와 페퍼로니가 어우러진 담백한 페퍼로니피자
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 불고기피자 (L)
# 음식메뉴 성공
# ===============
# 호주산 청정우로 만든 불고기와 신선한 야채,할라페뇨가 어우러진 고급스런 매콤한 맛의 피자
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 칠리핫치킨피자 (L)
# 음식메뉴 성공
# ===============
# 칠리소스와 치킨, 체다치즈가 어우러져 매콤하면서 고소한 피자
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 콤비네이션피자 (L)
# 음식메뉴 성공
# ===============
# 신선한 야채와 2종의 햄 콤비로 담백한 맛을 내는 피자
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 하와이아나피자 (L)
# 음식메뉴 성공
# ===============
# 파인애플과 과일치즈의 환상적인 하모니로 고소한 햄맛이 어우러진 달콤담백한 치즈피자
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# [2인set메뉴]
# 음식 카테고리 성공
# =========================================
# 고르곤졸라+뽀모로제+캔음료+피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 디아볼라+까르보나라+캔음료+피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 마르게리따+알리오올리오+캔음료+피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 하와이아나+새우칠리+캔음료+피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 모짜렐라마르게리따+빠네+캔음료+피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 44000
# 금액 성공
# ===============
# 모짜렐라마르게리따+해물토마토리조또+캔음료+피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 45000
# 금액 성공
# ===============
# [3인~5인set메뉴]
# 음식 카테고리 성공
# =========================================
# 디아볼라L+알리오올리오+뽀모도로+음료pet1병+피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 55000
# 금액 성공
# ===============
# 불고기L+뽀모도로+뽀모로제+음료pet1병+피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 62000
# 금액 성공
# ===============
# 모짜렐라마르게리따+빠네+새우칠리로제+캔음료+피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 73000
# 금액 성공
# ===============
# 모짜렐라마르게리따+까르보나라+해물토마토리조또+캔음료+피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 75000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라(355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 콜라(1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 스프라이트(355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스프라이트(1.5L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 페리에(라임)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# ===========끝===========
# ---9번 식당파싱 시작 ---
# 서울 강남구 삼성동 159 코엑스몰 지하1층 i-104호
# 주소 뽑기 성공
# =========================================
#
# 디.퀸즈는 ‘가장 신선한 재료로 정직하게 만든 최고의 요리를 제공한다’는 기본원칙을 가진 다이닝 레스토랑입니다.
# 풍부한 육즙과 부드러운 식감을 느낄 수 있는 스테이크와 신선하고 좋은 식재료로 정성껏 만든 다양한 파스타,
# 이탈리아 피자 장인의 레시피와 이탈리아에서 직수입한 식재를 사용하여 더욱 맛있는 피자까지 디.퀸즈에서 최고의 요리를 즐겨보세요!
#
# (배달 시 매장에서 나가는 영수증으로 해피포인트 2% 적립이 가능합니다.)
#
#
# 가게 소개 뽑기 성공
# =========================================
# [립아이 스테이크] 소고기:호주산,400g[치킨 스테이크] 닭고기:국내산[갈비 스테이크] 돼지고기:캐나다산,미국산, 쌀:국내산[채끝등심 스테이크, 안심 스테이크] 소고기:호주산[시저 샐러드] 돼지고기:국내산[오리엔탈 비프 샐러드] 소고기:미국산[로얄 까르보나라] 돼지고기:미국산[해산물 파스타 스튜] 오징어:국내산, 꽃게:중국산[버섯&페페로니 피자] 돼지고기:국내산,외국산, 소고기:호주산[모짜렐라 치킨 그라탕] 닭고기:국내산, 쌀:국내산[홍합꼬제와 감자튀김] 쌀:국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 20000
# 최소 금액 성공
# =========================================
# [스테이크]
# 음식 카테고리 성공
# =========================================
# [샐러드]
# 음식 카테고리 성공
# =========================================
# [오일 파스타]
# 음식 카테고리 성공
# =========================================
# [크림/로제 파스타]
# 음식 카테고리 성공
# =========================================
# [토마토 파스타]
# 음식 카테고리 성공
# =========================================
# [피자]
# 음식 카테고리 성공
# =========================================
# [리조또]
# 음식 카테고리 성공
# =========================================
# [비어 메뉴 (Beer menu)]
# 음식 카테고리 성공
# =========================================
# [음료 (Beverage)]
# 음식 카테고리 성공
# =========================================
# [스테이크]
# 음식 카테고리 성공
# =========================================
# 립아이 스테이크
# 음식메뉴 성공
# ===============
# 육즙 가득한 고소한 립아이 스테이크에 향긋한 허브향과 마늘, 레몬을 넣어만든 치미추리 소스, 바삭한 프렌치 프라이를 함께 즐기는 2~3인용 스페셜 스테이크
# 음식정보 성공
# ===============
# 59900
# 금액 성공
# ===============
# 치킨 스테이크
# 음식메뉴 성공
# ===============
# 바삭하게 그릴에 구워 낸 치킨 스테이크
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 갈비 스테이크
# 음식메뉴 성공
# ===============
# 디퀸즈 특제 양념으로 맛을 낸 갈비에 모짜렐라 치즈를 얹어 고소함을 더한 스테이크
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 채끝 등심 스테이크
# 음식메뉴 성공
# ===============
# *가니쉬는 추가주문 하셔야 합니다.풍부한 육즙과 향, 부드러운 식감을 느낄 수 있는 채끝 등심 스테이크
# 음식정보 성공
# ===============
# 29900
# 금액 성공
# ===============
# 안심 스테이크
# 음식메뉴 성공
# ===============
# *가니쉬는 추가주문 하셔야 합니다.풍부한 육즙과 향, 부드러운 식감을 느낄 수 있는 안심 스테이크
# 음식정보 성공
# ===============
# 34900
# 금액 성공
# ===============
# [샐러드]
# 음식 카테고리 성공
# =========================================
# 시저 샐러드
# 음식메뉴 성공
# ===============
# 신선한 로메인과 특별한 드레싱으로 아삭한 식감을 느낄 수 있는 샐러드
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 새우&버섯 샐러드
# 음식메뉴 성공
# ===============
# 그릴에 구운 버섯과 담백한 새우가 어우러진 샐러드
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 오리엔탈 비프 샐러드
# 음식메뉴 성공
# ===============
# 오리엔탈 소스를 더한 소고기에 아티초크, 토마토 등 다양한 채소와 상큼한 랜치 드레싱을 곁들인 샐러드
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# [오일 파스타]
# 음식 카테고리 성공
# =========================================
# 봉골레 오일 파스타
# 음식메뉴 성공
# ===============
# 깊은 조개의 맛을 느낄 수 있는 오일 파스타
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# 비프 오리엔탈 파스타
# 음식메뉴 성공
# ===============
# 소고기와 숙주, 버섯을 가득 넣고 매콤한 오리엔탈 소스로 맛을 낸 파스타
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 한치 오일 파스타
# 음식메뉴 성공
# ===============
# 한치를 듬뿍 넣고 볶아낸 담백하고 매콤한 오일 파스타
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# [크림/로제 파스타]
# 음식 카테고리 성공
# =========================================
# 로얄 까르보나라
# 음식메뉴 성공
# ===============
# 수란을 곁들인 진하고 부드러운 크림소스 파스타
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 버팔로 로제 빠빠델레 파스타
# 음식메뉴 성공
# ===============
# 후레쉬 버팔로 모짜렐라 치즈로 맛을 낸 진한 맛의 로제 크림소스 파스타
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# 새우 날치알 크림 파스타
# 음식메뉴 성공
# ===============
# 탱탱한 새우와 톡톡 터지는 날치알이 들어간 크림 파스타
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# 굴 크림 파스타
# 음식메뉴 성공
# ===============
# 통통한 제철 굴과 시금치를 가득 넣고, 바삭한 굴 크럼블로 풍미를 더한 굴 크림 스파게티
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# [토마토 파스타]
# 음식 카테고리 성공
# =========================================
# 리코타 토마토 파스타
# 음식메뉴 성공
# ===============
# 고소하고 진한 풍미의 리코타 치즈와 토마토소스가 조화되어 부드러운 파스타
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 해산물 파스타 스튜
# 음식메뉴 성공
# ===============
# 깔끔하고 칼칼한 해산물 스튜와 함께 즐기는 파스타
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# [피자]
# 음식 카테고리 성공
# =========================================
# 꽈뜨로 포르마지 피자
# 음식메뉴 성공
# ===============
# 4가지 치즈가 토핑되어 진한 치즈 맛을 느낄 수 있는 피자
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 버섯&페페로니 피자
# 음식메뉴 성공
# ===============
# 양송이 버섯과 페퍼로니를 듬뿍 올려 맛을 더한 피자
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 풍기 피자
# 음식메뉴 성공
# ===============
# 양송이 버섯, 느타리 버섯과 치즈, 머쉬룸 크림을 넣어 진한 버섯 향이 가득한 풍기 피자
# 음식정보 성공
# ===============
# 20500
# 금액 성공
# ===============
# [리조또]
# 음식 카테고리 성공
# =========================================
# 모짜렐라 치킨 그라탕
# 음식메뉴 성공
# ===============
# 고소하고 진한 모짜렐라 치즈가 듬뿍 들어간 치킨 그라탕
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 연어 스테이크 리조또
# 음식메뉴 성공
# ===============
# 고소한 연어 스테이크와 향긋한 커리 소스의 리조또
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [비어 메뉴 (Beer menu)]
# 음식 카테고리 성공
# =========================================
# 홍함꼬제와 감자튀김
# 음식메뉴 성공
# ===============
# 홍합과 향긋한 화이트 와인이 어우러진 따뜻한 홍합 스튜와 바삭한 프렌치 프라이
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 감자튀김
# 음식메뉴 성공
# ===============
# 시즈닝이 된 두꺼운 웨지감자 또는 바삭한 후렌치후라이
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ...
# 페리에 (330ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# ===========끝===========
# ---35번 식당파싱 시작 ---
# 서울 강남구 도곡동 467
# 주소 뽑기 성공
# =========================================
#
# 카페톨릭스가 생각하는 가치들은...
#
# 첫째, 진정성입니다.
# 누구를 따라하거나, 자신이 아닌 누구인척 살아가는 것이 아니라, 자신만의 스토리를 가지고 있기 때문에 자꾸 만나고 싶은 사람이 있습니다. 카페톨릭스가 추구하는 진정성도 그런것입니다. 함께하는 분들이 '이건 진심이야'라고 느낄 수 있는...
#
# 둘째, 그 이상을 추구한다는 것입니다.
# 돈을 벌거나 인정을 얻기 위함을 넘어서서, 작더라도 깊은 생각과 신념이 그 사람의 행동 속에 나타나 있을 때, 예사롭지 않은 매력을 느끼게 됩니다. 무언가를 추구한다는 것은 시간, 정성, 깊이가 요구됩니다. 그리고 그 시간과 정성은 결국 Quality로 나타납니다. Luxury는 돈으로 살 수 있지만Quality는 돈으로 살 수 없습니다.
#
# 셋째, 나누는 것을 말합니다.
# 예사롭지 않은 사람은 남들과 경쟁하는 사람이 아니라 '참 다른 사람입니다' 그리고 타인의 다른 의견이나 방식에 방어적이지 않고, 오히려 잘듣고 감동을 받습니다. 자신의 밥그릇에 관심이 없기 때문에 자신이 가진 것을 그냥 나누어주고, 또 새롭게 성장하는 것을 두려워하지 않습니다.
#
# 마지막으로, '말로할 수 없는 무엇인가'가 느껴지는 것입니다.
# 때로는 표현할 수 는 없어도 마음으로 느껴지는 것이 있습니다. 그 안에 뭔가 생기가 있고 에너지가 넘칩니다. 삶을 돌아보게하고, 다시 생각하게 만들고, 그냥 멍하게도 할 수 있는... 말로는 설명안되는 그런 것이죠.
#
#
# 푸드플라이 배달주문시 카페톨릭스포인트적립이불가합니다.
# 푸드플라이 배달주문시 메뉴에 있는추가 품목을 제외한 나머지(ex 면 or 떡 추가)는불가합니다.
#
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# -우리업소에서는 "국내산 쌀, 고기(소고기,돼지고기)"만 사용합니다.-우리업소에서는 "연어(노르웨이), 오징어(국내산,베트남,태국), 새우(베트남), 홍합(국내산)"을 사용합니다.
#
# 가게 원산지 뽑기 성공
# =========================================
# 20000
# 최소 금액 성공
# =========================================
# [브런치 (Bruch)]
# 음식 카테고리 성공
# =========================================
# [스프 (Soup)]
# 음식 카테고리 성공
# =========================================
# [샐러드 (Salad)]
# 음식 카테고리 성공
# =========================================
# [안주]
# 음식 카테고리 성공
# =========================================
# [퀘사디아 (Quesadilla)]
# 음식 카테고리 성공
# =========================================
# [플래터 (Platter)]
# 음식 카테고리 성공
# =========================================
# [라이스 (Rice)]
# 음식 카테고리 성공
# =========================================
# [누들 (Noodle)]
# 음식 카테고리 성공
# =========================================
# [음료 (Drinks)]
# 음식 카테고리 성공
# =========================================
# [차 (Tea)]
# 음식 카테고리 성공
# =========================================
# [브런치 (Bruch)]
# 음식 카테고리 성공
# =========================================
# 바게트 프렌치 토스트
# 음식메뉴 성공
# ===============
# 바게트 빵을 슬라이스해서 바싹 촉촉하게 적셔 구운 프렌치토스트
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 고메 치즈 버거
# 음식메뉴 성공
# ===============
# 홀스래디쉬소스,무피클이 들어간 치즈버거
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 트러플마요 프렌치프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# [스프 (Soup)]
# 음식 카테고리 성공
# =========================================
# 홈메이드 스프
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# [샐러드 (Salad)]
# 음식 카테고리 성공
# =========================================
# 그린 샐러드
# 음식메뉴 성공
# ===============
# 레몬 유자 드레싱으로 더욱 상큼해진 톨릭스표 하우스 샐러드
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 해산물 메밀 샐러드
# 음식메뉴 성공
# ===============
# 다양한 해산물과 레몬 와사비를 곁들인 웰빙 누들 샐러드
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 구운 버섯 샐러드
# 음식메뉴 성공
# ===============
# 발사믹 드레싱에 구운 가지, 주키니호박, 새송이 버섯, 표고 버섯, 믹스야채(그린비타민/라디치오/치커리/양상추)가 어우러진 따뜻한 샐러드
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 구아카몰 스테이크 샐러드
# 음식메뉴 성공
# ===============
# 한우 스테이크를 썰어 올려 토마토드레싱에 버무린 샐러드. 와인 안주로 추천!
# 음식정보 성공
# ===============
# 22500
# 금액 성공
# ===============
# 프레시 연어 아보카도 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# [안주]
# 음식 카테고리 성공
# =========================================
# 깔라마리튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 칠리소스닭봉날개튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 간장소스닭봉날개튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# [퀘사디아 (Quesadilla)]
# 음식 카테고리 성공
# =========================================
# 갈릭크림 퀘사디아
# 음식메뉴 성공
# ===============
# 토티아에 갈릭크림소스와 새우를 넣어 구운 오븐 요리
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 치폴레 치킨 퀘사디아
# 음식메뉴 성공
# ===============
# 토티아에 살짝 매콤한 치폴레 소스와 치킨을 넣은 오븐 요리
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# [플래터 (Platter)]
# 음식 카테고리 성공
# =========================================
# 주꾸미 불고기 떡볶이
# 음식메뉴 성공
# ===============
# 말이 필요없는 도곡동 카페 톨릭스의 인기메뉴
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 치즈 함박 스테이크
# 음식메뉴 성공
# ===============
# 패티 위에 치즈가 녹아있는 톨릭스 만의 함박 스테이크
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# [라이스 (Rice)]
# 음식 카테고리 성공
# =========================================
# 스테이크 덮밥
# 음식메뉴 성공
# ===============
# 다시물에 절인 무채와 한우 소고기를 썰어 올린 덮밥
# 음식정보 성공
# ===============
# 22500
# 금액 성공
# ===============
# 라타튜이 비프 커리
# 음식메뉴 성공
# ===============
# 가지, 호박, 버섯, 토마토의 풍미를 더한 라타튜이 스타일 비프 커리
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# XO소스 해산물 필라프
# 음식메뉴 성공
# ===============
# XO소스로 맛을 낸 해산물 볶음밥 위에 구운 왕새우를 올린 요리
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 버섯 도리아
# 음식메뉴 성공
# ===============
# 네 가지 버섯의 풍미와 고소한 치즈가 어우러진 굴소스 볶음밥
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [누들 (Noodle)]
# 음식 카테고리 성공
# =========================================
# 이태리 토마토 짬뽕
# 음식메뉴 성공
# ===============
# 각종 해산물,야채,매운 토마토 수프에 스파게티면을 튀겨 넣은 이탈리안 짬뽕
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 누룽지 파스타
# 음식메뉴 성공
# ===============
# 얼큰하고 매콤한 해산물 토마토 국물에 눌러붙은 누룽지를 함께 먹는 파스타
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 빠네 크림 파스타
# 음식메뉴 성공
# ===============
# 빵 속에 들어간 베이컨 버섯 크림 파스타
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 볼로네즈
# 음식메뉴 성공
# ===============
# 진한 사골육수와 포치니 소스의 볼로냐 스타일 토마토파스타
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 새우 파타이
# 음식메뉴 성공
# ===============
# 새우가 들어간 태국의 볶음면 요리
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [음료 (Drinks)]
# 음식 카테고리 성공
# =========================================
# 에스프레소 (Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 아메리카노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 콜드 브루 아이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 콜드 브루 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 제로 콜라 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 페리에 (플레인, 330ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 레몬 에이드
# 음식메뉴 성공
# ===============
# 신선한 레몬을 직접 짜서 만든 레몬 에이드
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 자몽 에이드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 오렌지 유자 에이드
# 음식메뉴 성공
# ===============
# 오렌지즙의 신선함과 유자의 향긋함을 동시에 느낄 수 있는 상큼 에이드
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 토마토 생과일쥬스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 오렌지 생과일쥬스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 청귤깔라만시에이드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# [차 (Tea)]
# 음식 카테고리 성공
# =========================================
# 허니 레몬 티 (Hot)
# 음식메뉴 성공
# ===============
# 신선한 레몬을 직접 짜서 만든 레몬 티
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 오렌지 유자 티 (Hot)
# 음식메뉴 성공
# ===============
# 오렌지즙의 신선한 유자의 향긋함을 동시에 느낄 수 있는 상큼 티
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 페퍼민트
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 생강차
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 진저라떼 (Only Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 카모마일
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# ===========끝===========
# ---36번 식당파싱 시작 ---
# 서울 강남구 삼성동 143-19 지하1층 101호
# 주소 뽑기 성공
# =========================================
#
# 도스타코스는
# 하나, 모든 음식에 MSG를 전혀 사용하지 않습니다.
# 둘, 100% 천연치즈 만을 사용합니다.
# 셋, 매일 아침 모든 소스와 재료를 정성껏 준비합니다.
#
# 좋은음식을 위해 흘리는 땀을 소중히 생각합니다
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀 : 국내산&베트남 / 새우 : 베트남&태국산 / 소고기 : 호주산 / 닭고기,돼지고기 : 미국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 7000
# 최소 금액 성공
# =========================================
# [타코 (Taco)]
# 음식 카테고리 성공
# =========================================
# [께사디아 (Quesadilla)]
# 음식 카테고리 성공
# =========================================
# [샐러드 (Salsada)]
# 음식 카테고리 성공
# =========================================
# [엔칠라다 (Enchilada)]
# 음식 카테고리 성공
# =========================================
# [고기 부리또 (Burrito meat)]
# 음식 카테고리 성공
# =========================================
# [새우 & 생선 부리또(Burrito shrimp & fish)]
# 음식 카테고리 성공
# =========================================
# [채식 부리또 (Burrito vegetable)]
# 음식 카테고리 성공
# =========================================
# [부리또 볼 (Burrito bowl)]
# 음식 카테고리 성공
# =========================================
# [치미창가(Chimichanga)]
# 음식 카테고리 성공
# =========================================
# [나쵸&감자튀김 (Nacho&Fries)]
# 음식 카테고리 성공
# =========================================
# [사이드 (Side Order)]
# 음식 카테고리 성공
# =========================================
# [음료 (Beverages)]
# 음식 카테고리 성공
# =========================================
# [타코 (Taco)]
# 음식 카테고리 성공
# =========================================
# 소프트타코 (2pcs)
# 음식메뉴 성공
# ===============
# 고기선택 + 마일드살사 + 생양파 + 할라페뇨 + 사워크림 + 양상추 + 치즈
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 빠스톨타코 (2pcs)
# 음식메뉴 성공
# ===============
# 돼지고기 + 생양파 + 할라페뇨 + 고수 + 후레시살사
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 하드타코 (2pcs)
# 음식메뉴 성공
# ===============
# 고기선택 + 핫소스 + 사우어크림 + 양상추 + 후레시살사 + 치즈
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# [께사디아 (Quesadilla)]
# 음식 카테고리 성공
# =========================================
# 새우 치즈 께사디야 (4pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 고기 치즈 께사디야 (4pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 루꼴라 치즈 께사디야 (4pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 치즈 께사디야 (4pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# [샐러드 (Salsada)]
# 음식 카테고리 성공
# =========================================
# 허브 치킨 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 갈릭 새우 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 오리지널 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# [엔칠라다 (Enchilada)]
# 음식 카테고리 성공
# =========================================
# 새우 & 라이스 치뽈레 앤칠라다
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13800
# 금액 성공
# ===============
# 고기 & 라이스 치뽈레 앤칠라다
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# [고기 부리또 (Burrito meat)]
# 음식 카테고리 성공
# =========================================
# 고기 & 새우 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 고기 & 통마늘 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 고기 & 리프라이드 빈 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 고기 & 아보카도 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10500
# 금액 성공
# ===============
# 고기 & 파히타 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 고기 & 라이스 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# [새우 & 생선 부리또(Burrito shrimp & fish)]
# 음식 카테고리 성공
# =========================================
# 새우 라이스 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 새우 감자 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# [채식 부리또 (Burrito vegetable)]
# 음식 카테고리 성공
# =========================================
# 볶음야채 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 감자 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# 야채 부리또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# [부리또 볼 (Burrito bowl)]
# 음식 카테고리 성공
# =========================================
# 허브치킨 & 구운가지 부리또 볼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 고기 & 버터 머슈룸 부리또 볼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 고기 & 치뽈레 살사 부리또 볼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 볶음야채 부리또 볼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# [치미창가(Chimichanga)]
# 음식 카테고리 성공
# =========================================
# 아보카도 치미창가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 고기 치미창가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# [나쵸&감자튀김 (Nacho&Fries)]
# 음식 카테고리 성공
# =========================================
# 나쵸 피에스타
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 칠리빈 & 비프 감자튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 감자튀김
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 칩스 & 살사
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# [사이드 (Side Order)]
# 음식 카테고리 성공
# =========================================
# 나쵸 칩스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 슬라이스 아보카도
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 라임 슬라이스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 과카몰리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 칠리 비프
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 후레쉬 살사
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 그린 살사
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 마일드 살사
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 칠리빈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 후레시 피클
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 후레쉬 체다 치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 핫소스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 쌰워크림
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 나쵸치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 할라페뇨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# [음료 (Beverages)]
# 음식 카테고리 성공
# =========================================
# 콜라 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 스프라이드 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 닥터페퍼 (360ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스프라이트 (캔,360ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 콜라 (캔, 360ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 하리또스 자몽 (370ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 하리또스 구아바 (370ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 하리또스 망고 (370ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 하리또스 라임 (370ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 하리또스 파인애플 (370ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# ===========끝===========
# ---37번 식당파싱 시작 ---
# 서울 강남구 대치동 651
# 주소 뽑기 성공
# =========================================
#
# 아웃백 스테이크하우스는 광활하고 자유로운 호주 오지의 분위기와 맛을 가득 담은 정통 스테이크하우스입니다.
# 1988년, 크리스 설리반, 로버트 바샴, 팀 개넌, 그리고 트루디 쿠퍼라는 네 명의 친구들이 캐주얼한 분위기의 정통 스테이크하우스를 플로리다 템파에 오픈하였습니다. 곧 질 좋은 홈메이드 음식과 정통 스테이크를 제공하는 레스토랑이라는 입소문을 타고 전세계에 체인을 열게 되었습니다.
# 한국 아웃백은 1997년 첫번째 매장을 오픈한 이래 No.1 스테이크하우스로 성장하였습니다.
# 매일 매장에서 신선한 재료로 직접 준비되는 트루 홈메이드 메뉴와 아웃백만의 레시피로 특별한 정통 스테이크 아웃백 스테이크하우스가 한국뿐 아니라 전 세계에서 사랑받는 비결입니다
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쇠고기-호주산(달링 포인트 스트립,퀸즈랜드 립아이, 퀸즈랜드 갈릭 립아이, 로얄 빅토리아 휠렛, 아웃백 스케폇 서로인,뉴욕 스트립, 갈릭 립아이,캘리포니아 스테이크 샐러드,투움바 안심 파스타,짐붐바 스테이크,아웃백 홈메이드 수프(비프칠리),찹스테이크 앤 치킨콤보, 찹스테이크,카카두 스테이크 그릴러,짐붐바 등심 스테이크) 돼지고기-돼지갈비:프랑스산(베이비 백 립, 레인지랜드 립레츠,기브미파이브), 외국산-(베이컨:토핑용) / 닭고기- 국내산(기브미파이브, 크리스피 쿠가부라 윙, 치킨텐더 샐러드, 치킨 핑거), - 국내산과 태국산을 섞음(바비큐치킨, 그릴드 데리야끼 치킨, 찹 스테이크 앤 치킨 콤보, 찹스테이크), - 태국산(카카두 스테이크 그릴러, 짐붐바 등심 스테이크) / 오징어- 국내산/ 쌀- 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
