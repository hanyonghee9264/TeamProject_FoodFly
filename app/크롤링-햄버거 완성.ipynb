# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 카페[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[8]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 25:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 카페 데이터(이미지) 수집
soup = BeautifulSoup(html, 'lxml')
img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
count = 1
for i in img:
    img_url = i.get_text("url", strip=True)
    img_url_parse = img_url[4:-1]
    try:
        urllib.request.urlretrieve(img_url_parse, f'{count}.burger_food_img.jpg')
    except:
        pass
    count += 1

# 일식 데이터(식당명) 수집
japan_store_list = []
japan_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in japan_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(japan_store_list):
    print(i, name)


    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 16:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='햄버거',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=1),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
        print('음식 카테고리 성공')
        print('=========================================')
        
        store_category_foods = menu.select(".row-menu")

        for food in store_category_foods:
            food_menu = food.select_one(".col-menu > strong").get_text(strip=True)
            print(food_menu)
            print('음식메뉴 성공')
            print('===============')
            food_info = food.select_one(".col-menu > span").get_text(strip=True)
            print(food_info)
            print('음식정보 성공')
            print('===============')
            food_money = food.select_one("span.calculate-price").get_text(strip=True)
            food_moneys = food_money.replace(",", "")
            print(food_moneys)
            print('금액 성공')
            print('===============')
            
            Food.objects.create(
            category=food_category,
            name=food_menu,
            price=food_moneys,
            food_info=food_info,
            )

        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:83: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 서초구 서초동 1303
# 주소 뽑기 성공
# =========================================
#
# 치킨,햄버거,후렌치후라이가 모두 맛있는 파파이스!이제 푸드플라이에서도 주문하세요~ ^^아메리카노는 아이스만 주문가능합니다.
# 배달가능지역을 확인해 주세요~ 푸드플라이 라이더가 아닌 매장 자체적으로 딜리버리를 하기때문에 음식배송문의는 매장쪽으로 부탁드립니다.
# 매장번호 : 02-532-7835
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 닭,돼지고기 : 국내산소고기 : 호주산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 11000
# 최소 금액 성공
# =========================================
# [치킨세트]
# 음식 카테고리 성공
# =========================================
# [버거세트]
# 음식 카테고리 성공
# =========================================
# [테이크아웃팩]
# 음식 카테고리 성공
# =========================================
# [치킨단품]
# 음식 카테고리 성공
# =========================================
# [버거단품]
# 음식 카테고리 성공
# =========================================
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [치킨세트]
# 음식 카테고리 성공
# =========================================
# 핑거휠레세트
# 음식메뉴 성공
# ===============
# 핑거휠레4조각 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 싱글세트
# 음식메뉴 성공
# ===============
# 치킨2 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 7200
# 금액 성공
# ===============
# 위키드세트
# 음식메뉴 성공
# ===============
# 위키드치킨 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 7100
# 금액 성공
# ===============
# 더블팩
# 음식메뉴 성공
# ===============
# 치킨4 + 밀크비스켓2 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 팝패밀리팩
# 음식메뉴 성공
# ===============
# 치킨8+핑거휠레2+케이준윙2+밀크비스킷2
# 음식정보 성공
# ===============
# 24100
# 금액 성공
# ===============
# 듀오팩
# 음식메뉴 성공
# ===============
# 치킨2 + 핑거휠레2 + 케이준윙2 + 비스킷2 + 선택1 + 콜라2잔Regular
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 케이준치킨팩
# 음식메뉴 성공
# ===============
# 케이준익스트림버거1 + 치킨휠레버거1 + 치킨2조각 + 콜라2잔Regular
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [버거세트]
# 음식 카테고리 성공
# =========================================
# 케이준통버거세트
# 음식메뉴 성공
# ===============
# 케이준통샌트위치세트 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 8100
# 금액 성공
# ===============
# 치즈베이컨 치킨버거세트
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 케이준익스트림버거세트
# 음식메뉴 성공
# ===============
# 케이준익스트림버거 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 7200
# 금액 성공
# ===============
# 치킨휠레버거세트
# 음식메뉴 성공
# ===============
# 치킨휠레버거 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 7200
# 금액 성공
# ===============
# 핫페퍼로스트맛치킨버거세트
# 음식메뉴 성공
# ===============
# 핫페퍼로스트맛치킨버거 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 7300
# 금액 성공
# ===============
# 닭달버거세트
# 음식메뉴 성공
# ===============
# 닭달버거 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 통새우버거세트
# 음식메뉴 성공
# ===============
# 통새우버거 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 불고기버거세트
# 음식메뉴 성공
# ===============
# 불고기버거 + 선택1 + 콜라Regular
# 음식정보 성공
# ===============
# 6100
# 금액 성공
# ===============
# [테이크아웃팩]
# 음식 카테고리 성공
# =========================================
# 치킨8조각팩 (8pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 팝패밀리팩
# 음식메뉴 성공
# ===============
# 치킨8 + 핑거휠레2 + 케이준윙2 + 비스킷2
# 음식정보 성공
# ===============
# 24100
# 금액 성공
# ===============
# 케이준윙팩 (12pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 핑거휠레팩 (12pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# [치킨단품]
# 음식 카테고리 성공
# =========================================
# 치킨(스파이시)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 치킨 (마일드)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 핑거휠레 2조각
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2600
# 금액 성공
# ===============
# 케이준윙 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2600
# 금액 성공
# ===============
# 위키드치킨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4700
# 금액 성공
# ===============
# [버거단품]
# 음식 카테고리 성공
# =========================================
# 케이준통버거
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 치즈베이컨치킨버거
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 케이준익스트림버거
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 치킨휠레버거
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 핫페퍼로스트맛치킨버거
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 닭달버거
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4700
# 금액 성공
# ===============
# 통새우버거
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 불고기버거
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3900
# 금액 성공
# ===============
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# 케이준 후렌치후라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 콘샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 코울슬로
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 밀크비스킷 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1900
# 금액 성공
# ===============
# 치즈스틱 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 소스 (핫칠리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 400
# 금액 성공
# ===============
# 소스 (어니언크림)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 400
# 금액 성공
# ===============
# 소스 (머스타드)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 100
# 금액 성공
# ===============
# 소스 (체다치즈)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 600
# 금액 성공
# ===============
# 토핑 (치즈)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 400
# 금액 성공
# ===============
# 토핑 (베이컨)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 사이다
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 미란다
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 넥스콜라
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 오렌지주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 레모네이드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 아이스 아메리카노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:217: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 강남구 역삼동 827-37
# 주소 뽑기 성공
# =========================================
#
# World Top 2% USDA Prime Beef 의 뉴욕 스테이크 하우스 스타일의 수제 버거를 New Yorker 들이 만들고 있는 NY B&B Burger & Bagel 입니다. 가장 맛있는 버거라고 외국인들이 먼저 인정! 수준높은 Craft Burger와 Craft Beer 를 즐겨보세요. -CEO Mark
#
# 나이프와 포크는 제공되지 않습니다.
#
#
#
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 쇠고기 : 미국산
# 닭고기 : 국내산
# 야채 : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [비앤비 콤보 (The B&B Combo)]
# 음식 카테고리 성공
# =========================================
# [오지 콤보 (The"OG" Combo)]
# 음식 카테고리 성공
# =========================================
# [블루문 콤보(Bleu Moon Combo)]
# 음식 카테고리 성공
# =========================================
# [페퍼잭 시티 콤보 (PepperJackCity Combo)]
# 음식 카테고리 성공
# =========================================
# [와사비 콤보 (The Wasaaabi Combo)]
# 음식 카테고리 성공
# =========================================
# [부바검프 콤보 (BubbaGump Combo)]
# 음식 카테고리 성공
# =========================================
# [돈꼴레온 콤보 (DonCorleone Combo)]
# 음식 카테고리 성공
# =========================================
# [치킨 클럽 브레드 콤보 (ChickenClub-Breaded)]
# 음식 카테고리 성공
# =========================================
# [래리 다비드 콤보 (LarryDavid Combo)]
# 음식 카테고리 성공
# =========================================
# [부바 콤보 (The Bubba Combo)]
# 음식 카테고리 성공
# =========================================
# [치킨 클럽 그릴 콤보 (ChickenClub-Grilled)]
# 음식 카테고리 성공
# =========================================
# [케이준 벌드랩 콤보 (CajunBirdWrap Combo)]
# 음식 카테고리 성공
# =========================================
# [사이드 (Side)]
# 음식 카테고리 성공
# =========================================
# [비앤비 콤보 (The B&B Combo)]
# 음식 카테고리 성공
# =========================================
# 비앤비 버거 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.아메리칸치즈, 베이컨, 상치, 토마토, 양파, 스폐셜 소스, USDA prime beef 140g
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 비앤비 버거 + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.아메리칸치즈, 베이컨, 상치, 토마토, 양파, 스폐셜 소스, USDA prime beef 140g
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 비앤비 버거 + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.아메리칸치즈, 베이컨, 상치, 토마토, 양파, 스폐셜 소스, USDA prime beef 140g
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# [오지 콤보 (The"OG" Combo)]
# 음식 카테고리 성공
# =========================================
# 오지 버거 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.생모짜렐라, 페퍼로니, 홈메이드이탈리언소스, 바질, USDA prime beef 140g
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 오지 버거 + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.생모짜렐라, 페퍼로니, 홈메이드이탈리언소스, 바질, USDA prime beef 140g
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 오지 버거 + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.생모짜렐라, 페퍼로니, 홈메이드이탈리언소스, 바질, USDA prime beef 140g
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# [블루문 콤보(Bleu Moon Combo)]
# 음식 카테고리 성공
# =========================================
# 블루문 버거 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.블루치즈스프레드, 베이컨, 상치, 토마토, 양파, USDA prime beef 140g
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 블루문 버거 + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.블루치즈스프레드, 베이컨, 상치, 토마토, 양파, USDA prime beef 140g
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 블루문 버거 + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.블루치즈스프레드, 베이컨, 상치, 토마토, 양파, USDA prime beef 140g
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# [페퍼잭 시티 콤보 (PepperJackCity Combo)]
# 음식 카테고리 성공
# =========================================
# 페퍼잭 시티 버거 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.페패잭치즈, 구운피망, 구운양파, 할로피뇨, 허브마요, USDA prime beef 140g
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 페퍼잭 시티 버거 + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.페패잭치즈, 구운피망, 구운양파, 할로피뇨, 허브마요, USDA prime beef 140g
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 페퍼잭 시티 버거 + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.페패잭치즈, 구운피망, 구운양파, 할로피뇨, 허브마요, USDA prime beef 140g
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# [와사비 콤보 (The Wasaaabi Combo)]
# 음식 카테고리 성공
# =========================================
# 와사비 버거 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.페패잭치즈, 표고버섯, 구운양파, 와사비마요, USDA prime beef 140g
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 와사비 버거 + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.페패잭치즈, 표고버섯, 구운양파, 와사비마요, USDA prime beef 140g
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 와사비 버거 + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.페패잭치즈, 표고버섯, 구운양파, 와사비마요, USDA prime beef 140g
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# [부바검프 콤보 (BubbaGump Combo)]
# 음식 카테고리 성공
# =========================================
# 부바검프 버거 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.케이준새우, 아메리컨치즈, 상치, 토마토, 양파, 케이준마요,usda prime beef 140g
# 음식정보 성공
# ===============
# 27500
# 금액 성공
# ===============
# 부바검프 버거 + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.케이준새우, 아메리컨치즈, 상치, 토마토, 양파, 케이준마요,usda prime beef 140g
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 부바검프 버거 + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 패티는 미디움 웰던으로 제공됩니다.케이준새우, 아메리컨치즈, 상치, 토마토, 양파, 케이준마요,usda prime beef 140g
# 음식정보 성공
# ===============
# 30500
# 금액 성공
# ===============
# [돈꼴레온 콤보 (DonCorleone Combo)]
# 음식 카테고리 성공
# =========================================
# 돈꼴레온 샌드위치 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 빵가루입힌닭고기, 생모짤렐라, 홈메이드 이탈리언소스, 바질
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 돈꼴레온 샌드위치 + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 빵가루입힌닭고기, 생모짤렐라, 홈메이드 이탈리언소스, 바질
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 돈꼴레온 샌드위치 + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 빵가루입힌닭고기, 생모짤렐라, 홈메이드 이탈리언소스, 바질
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# [치킨 클럽 브레드 콤보 (ChickenClub-Breaded)]
# 음식 카테고리 성공
# =========================================
# 치킨클럽브레드 샌드위치 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 빵가루프라이 or 그릴한 닭고기, 베이컨, 생모짜렐라, 상치, 토마토, 양파, 스페셜소스, 허브마요
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 치킨클럽브레드 샌드위치 + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 빵가루프라이 or 그릴한 닭고기, 베이컨, 생모짜렐라, 상치, 토마토, 양파, 스페셜소스, 허브마요
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 치킨클럽브레드 샌드위치 + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 빵가루프라이 or 그릴한 닭고기, 베이컨, 생모짜렐라, 상치, 토마토, 양파, 스페셜소스, 허브마요
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# [래리 다비드 콤보 (LarryDavid Combo)]
# 음식 카테고리 성공
# =========================================
# 래리데이빗베이글샌드위치 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 베이글, 훈제연어, 케이퍼, 양파, 딜 크림치즈
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 래리데이빗베이글샌드위치  + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 베이글, 훈제연어, 케이퍼, 양파, 딜 크림치즈
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 래리데이빗베이글샌드위치  + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 베이글, 훈제연어, 케이퍼, 양파, 딜 크림치즈
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# [부바 콤보 (The Bubba Combo)]
# 음식 카테고리 성공
# =========================================
# 부바 샌드위치 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 케이준새우, 상치, 토마토, 양파, 케이준마요
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 부바 샌드위치 + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 케이준새우, 상치, 토마토, 양파, 케이준마요
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 부바 샌드위치 + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 케이준새우, 상치, 토마토, 양파, 케이준마요
# 음식정보 성공
# ===============
# 22500
# 금액 성공
# ===============
# [치킨 클럽 그릴 콤보 (ChickenClub-Grilled)]
# 음식 카테고리 성공
# =========================================
# 치킨클럽그릴 샌드위치 + 프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 빵가루프라이 or 그릴한 닭고기, 베이컨, 생모짜렐라, 상치, 토마토, 양파, 스페셜소스, 허브마요
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 치킨클럽그릴 샌드위치 + 파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 빵가루프라이 or 그릴한 닭고기, 베이컨, 생모짜렐라, 상치, 토마토, 양파, 스페셜소스, 허브마요
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 치킨클럽그릴 샌드위치 + 어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 빵가루프라이 or 그릴한 닭고기, 베이컨, 생모짜렐라, 상치, 토마토, 양파, 스페셜소스, 허브마요
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# [케이준 벌드랩 콤보 (CajunBirdWrap Combo)]
# 음식 카테고리 성공
# =========================================
# 케이준 벌드 +_프렌치 프라이즈 (French Fries)
# 음식메뉴 성공
# ===============
# 빵가루프라이 닭고기, 베이컨, 체다치즈, 상치, 토마토, 양파, 또띠아랩,케이준마요
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 케이준 벌드 +_파마산 갈릭 프라이즈 (Parmesan Garlic Fries)
# 음식메뉴 성공
# ===============
# 빵가루프라이 닭고기, 베이컨, 체다치즈, 상치, 토마토, 양파, 또띠아랩,케이준마요
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 케이준 벌드 +_어니언 링 (Onion Rings)
# 음식메뉴 성공
# ===============
# 빵가루프라이 닭고기, 베이컨, 체다치즈, 상치, 토마토, 양파, 또띠아랩,케이준마요
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# [사이드 (Side)]
# 음식 카테고리 성공
# =========================================
# 치킨 윙 (Chicken Wings BBQ, 6pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 맥인치즈 (Mac n Cheese)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 맥앤치즈 베이컨 (Mac n Cheese Bacon)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 맥앤치즈 쉬림프 (Mac n Cheese Shrimp)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 케이준 검보 (Cajun Gumbo)
# 음식메뉴 성공
# ===============
# 치킨, 돼지고기, 양파, 샐러리, 페퍼, 토마토, 쌀, 갈릭브레드
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 칠리 (Chili)
# 음식메뉴 성공
# ===============
# 칠리소스, 쇠고기, 피망, 양파, 키드니빈
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 강남구 역삼동 825-22 2층
# 주소 뽑기 성공
# =========================================
#
# 다른 수제버거집 맛있게 드셔보시고 바이투헤븐을 찾아주시면 감사드리겠습니다.
# “수제버거”란 타이틀이 부끄럽지 않도록 만들었습니다. 최선을 다하겠습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 소고기:미국산빵:밀가루(캐나다/미국)야채(토마토,로메인,양파):국산치즈:수입산
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [버거]
# 음식 카테고리 성공
# =========================================
# [프라이]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [버거]
# 음식 카테고리 성공
# =========================================
# 러스틱
# 음식메뉴 성공
# ===============
# 싱글패티, 더블패티 선택 가능패티 굽기는 미디움 웰던으로 제공됩니다.아메리칸 치즈, 구운 양파
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 페퍼
# 음식메뉴 성공
# ===============
# 싱글패티, 더블패티 선택 가능패티 굽기는 미디움 웰던으로 제공됩니다.화이트치즈, 페퍼마요(+청양고추)
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 그린치
# 음식메뉴 성공
# ===============
# 싱글패티, 더블패티 선택 가능패티 굽기는 미디움 웰던으로 제공됩니다.화이트치즈, 케일, 베이컨, 와사비마요(+적양파)
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 헤븐
# 음식메뉴 성공
# ===============
# 싱글패티, 더블패티 선택 가능패티 굽기는 미디움 웰던으로 제공됩니다.아메리칸 치즈, 로메인, 토마토, 베이컨, 적양파, 피클, 사우전아일랜드소스
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 헬
# 음식메뉴 성공
# ===============
# 싱글패티, 더블패티 선택 가능패티 굽기는 미디움 웰던으로 제공됩니다.아메리칸 치즈, 로메인, 토마토, 베이컨, 적양파, 핫치폴레소스
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 홀리
# 음식메뉴 성공
# ===============
# 싱글패티, 더블패티 선택 가능패티 굽기는 미디움 웰던으로 제공됩니다.화이트 치즈, 토마토, 과카몰리, 렌치소스
# 음식정보 성공
# ===============
# 10500
# 금액 성공
# ===============
# 멜팅
# 음식메뉴 성공
# ===============
# 싱글패티, 더블패티 선택 가능패티 굽기는 미디움 웰던으로 제공됩니다.맥앤치즈, 베이컨
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 화이트 비치
# 음식메뉴 성공
# ===============
# 싱글패티, 더블패티 선택 가능패티 굽기는 미디움 웰던으로 제공됩니다.화이트 치즈, 파인애플, 케일, 베이컨, 렌치소스
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 칠리 정글
# 음식메뉴 성공
# ===============
# 싱글패티, 더블패티 선택 가능패티 굽기는 미디움 웰던으로 제공됩니다.아메리칸 치즈, 적양파, 칠리소스
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [프라이]
# 음식 카테고리 성공
# =========================================
# 오리지널 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 치즈 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 어니언 마요 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 마그마 프라이
# 음식메뉴 성공
# ===============
# 2인기준매운맛 ★
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 맥앤치즈 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 칠리 치즈 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 과카몰리 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 컬리 프라이
# 음식메뉴 성공
# ===============
# 2인기준*컬리프라이는 자체 시즈닝으로 개인차마다 짤 수도 있습니다.*
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 컬리 치즈 프라이
# 음식메뉴 성공
# ===============
# 2인기준*컬리프라이는 자체 시즈닝으로 개인차마다 짤 수도 있습니다.*
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 컬리 마그마 프라이
# 음식메뉴 성공
# ===============
# 매운맛 ★2인기준*컬리프라이는 자체 시즈닝으로 개인차마다 짤 수도 있습니다.*
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 컬리 칠리 치즈 프라이
# 음식메뉴 성공
# ===============
# 2인기준*컬리프라이는 자체 시즈닝으로 개인차마다 짤 수도 있습니다.*
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 컬리 과카몰리 프라이
# 음식메뉴 성공
# ===============
# 2인기준*컬리프라이는 자체 시즈닝으로 개인차마다 짤 수도 있습니다.*
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 코우슬로
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 맥앤치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 칠리 맥앤치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 과카몰리&칩스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 칠리치즈&칩스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 제로콜라 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 닥터페퍼 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 립톤 아이스티 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 마운틴듀 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 트레비 레몬 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 트레비 라임 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 강남구 역삼동 796-29 1층 122-123호
# 주소 뽑기 성공
# =========================================
#
# 다른 수제버거집 맛있게 드셔보시고바이투헤븐을찾아주시면 감사드리겠습니다.
# “수제버거”란 타이틀이 부끄럽지 않도록 만들었습니다.최선을 다하겠습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 소고기 - U.S.A빵-밀가루(캐나다/미국)야채(토마토,로메인,양파)-국산치즈-수입산
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [버거]
# 음식 카테고리 성공
# =========================================
# [프라이]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [버거]
# 음식 카테고리 성공
# =========================================
# 러스틱
# 음식메뉴 성공
# ===============
# 아메리칸치즈,구운양파100% 소고기 패티, 기본굽기는 미디움 웰던 입니다.
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 페퍼
# 음식메뉴 성공
# ===============
# 화이트치즈, 페퍼마요100% 소고기 패티, 기본굽기는 미디움 웰던 입니다.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 슈퍼마리오
# 음식메뉴 성공
# ===============
# 아메리칸치즈, 갈릭오일, 양송이, 새송이, 구운양파, 바비큐소스100% 소고기 패티, 기본굽기는 미디움 웰던 입니다.
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 헤븐
# 음식메뉴 성공
# ===============
# 아메리칸치즈, 적양파, 로메인, 베이컨, 토마토, 피클 사우전아일랜드소스100% 소고기 패티, 기본굽기는 미디움 웰던 입니다.
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 치즈러버
# 음식메뉴 성공
# ===============
# 베이컨, 체다치즈, 모짜렐라치즈, 할라피뇨마요, 해쉬브라운100% 소고기 패티, 기본굽기는 미디움 웰던 입니다.
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 마그마
# 음식메뉴 성공
# ===============
# 아메리칸치즈,베이컨,적양파,블로네즈소스,로메인100% 소고기 패티, 기본굽기는 미디움 웰던 입니다.
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 홀리
# 음식메뉴 성공
# ===============
# 화이트치즈, 토마토, 과카몰리, 렌치소스100% 소고기 패티, 기본굽기는 미디움 웰던 입니다.
# 음식정보 성공
# ===============
# 10500
# 금액 성공
# ===============
# 화이트비치
# 음식메뉴 성공
# ===============
# 화이트치즈, 파인애플, 케일, 베이컨, 렌치소스100% 소고기 패티, 기본굽기는 미디움 웰던 입니다.
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 칠리정글
# 음식메뉴 성공
# ===============
# 아메리칸치즈, 적양파, 칠리소스100% 소고기 패티, 기본굽기는 미디움 웰던 입니다.
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [프라이]
# 음식 카테고리 성공
# =========================================
# 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 치즈 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 어니언 & 마요 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 마그마 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 맥앤치즈 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 칠리&치즈 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 과카몰리 프라이
# 음식메뉴 성공
# ===============
# 2인기준
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 컬리 프라이
# 음식메뉴 성공
# ===============
# 2인기준*컬리프라이는 자체 시즈닝으로 개인차마다 짤 수도 있습니다.*
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 컬리 치즈프라이
# 음식메뉴 성공
# ===============
# 2인기준*컬리프라이는 자체 시즈닝으로 개인차마다 짤 수도 있습니다.*
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 컬리 마그마 프라이
# 음식메뉴 성공
# ===============
# 2인기준*컬리프라이는 자체 시즈닝으로 개인차마다 짤 수도 있습니다.*
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 컬리 칠리 & 치즈 프라이
# 음식메뉴 성공
# ===============
# 2인기준*컬리프라이는 자체 시즈닝으로 개인차마다 짤 수도 있습니다.*
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 컬리 과카몰리 프라이
# 음식메뉴 성공
# ===============
# 2인기준*컬리프라이는 자체 시즈닝으로 개인차마다 짤 수도 있습니다.*
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 코우슬로
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 맥앤치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 칠리맥앤치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 과카몰리&칩스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 칠리치즈&칩스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 제로콜라 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 닥터페퍼 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 립톤 아이스티 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 마운틴듀 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 트레비 레몬 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 트레비 라임 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 서초구 반포동 735-2 1층
# 주소 뽑기 성공
# =========================================
#
# 깊은 맛으로 유명한 신논현역 수제버거 맛집 경성버거입니다.
# 다양한 수제버거를 제공하고 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 소고기:호주산베이컨:미국산로메인/루꼴라/양파/토마토:국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [버거]
# 음식 카테고리 성공
# =========================================
# [세트 메뉴]
# 음식 카테고리 성공
# =========================================
# [버거]
# 음식 카테고리 성공
# =========================================
# 경성 버거
# 음식메뉴 성공
# ===============
# 소고기 140g, 베이컨, 아메리칸치즈, 로메인, 양파, 토마토
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 핫 버거
# 음식메뉴 성공
# ===============
# 소고기 140g, 청양고추 20g, 스위트치즈, 로메인, 양파
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 치즈 버거
# 음식메뉴 성공
# ===============
# 소고기 140g, 아메리칸치즈, 스위트치즈, 모짜렐라치즈, 로메인, 구운양파
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 칠리 버거
# 음식메뉴 성공
# ===============
# 소고기 110g, 스위트치즈, 로메인, 양파, 토마토, 루꼴라, 칠리콘카르네
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 쉬림프 버거
# 음식메뉴 성공
# ===============
# 소고기 110g, 새우, 아메리칸치즈, 로메인, 양파, 토마토
# 음식정보 성공
# ===============
# 10500
# 금액 성공
# ===============
# 머쉬룸 버거
# 음식메뉴 성공
# ===============
# 소고기 140g, 버섯, 몬스타치즈, 루꼴라, 로메인, 토마토
# 음식정보 성공
# ===============
# 10500
# 금액 성공
# ===============
# 더블 버거
# 음식메뉴 성공
# ===============
# 소고기 110g(x2), 베이컨(x2), 아메리칸치즈, 스위스치즈, 로메인, 양파, 토마토
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# [세트 메뉴]
# 음식 카테고리 성공
# =========================================
# 경성버거 + 프렌치프라이 + 음료 세트
# 음식메뉴 성공
# ===============
# 경성버거 + 프렌치프라이 + 음료(선택)
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 경성버거 + 어니언링 + 음료 세트
# 음식메뉴 성공
# ===============
# 경성버거 + 어니언링 + 음료(선택)
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 경성버거 + 스위트포테이토 + 음료 세트
# 음식메뉴 성공
# ===============
# 경성버거 + 스위트포테이토 + 음료(선택)
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 핫버거 + 프렌치프라이 + 음료 세트
# 음식메뉴 성공
# ===============
# 핫버거 + 프렌치프라이 + 음료(선택)
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 핫버거 + 어니언링 + 음료 세트
# 음식메뉴 성공
# ===============
# 핫버거 + 어니언링 + 음료(선택)
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 핫버거 + 스위트포테이토 + 음료 세트
# 음식메뉴 성공
# ===============
# 경성버거 + 스위트포테이토 + 음료(선택)
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 치즈버거 + 프렌치프라이 + 음료 세트
# 음식메뉴 성공
# ===============
# 치즈버거 + 프렌치프라이 + 음료 (선택)
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 치즈버거 + 어니언링 + 음료 세트
# 음식메뉴 성공
# ===============
# 치즈버거 + 어니언링 + 음료 (선택)
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 치즈버거 + 스위트포테이토 + 음료 세트
# 음식메뉴 성공
# ===============
# 경성버거 + 스위트포테이토 + 음료(선택)
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 칠리버거 + 프렌치프라이 + 음료 세트
# 음식메뉴 성공
# ===============
# 칠리버거 + 프렌치프라이 + 음료(선택)
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 칠리버거 + 어니언링 + 음료 세트
# 음식메뉴 성공
# ===============
# 칠리버거 + 프렌치프라이 + 음료(선택)
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 칠리버거 + 스위트포테이토 + 음료 세트
# 음식메뉴 성공
# ===============
# 칠리버거 + 스위트포테이토 + 음료(선택)
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 쉬림프버거 + 프렌치프라이 + 음료 세트
# 음식메뉴 성공
# ===============
# 쉬림프버거 + 프렌치프라이 + 음료(선택)
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 쉬림프버거 + 어니언링 + 음료 세트
# 음식메뉴 성공
# ===============
# 쉬림프버거 + 어니언링 + 음료(선택)
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 쉬림프버거 + 스위트포테이토 + 음료 세트
# 음식메뉴 성공
# ===============
# 쉬림프버거 + 스위트포테이토 + 음료(선택)
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 머쉬룸 버거 + 프렌치프라이 + 음료 세트
# 음식메뉴 성공
# ===============
# 머쉬룸버거 + 프렌치프라이 + 음료(선택)
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 머쉬룸버거 + 어니언링 + 음료 세트
# 음식메뉴 성공
# ===============
# 쉬림프버거 + 어니언링 + 음료(선택)
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 머쉬룸버거 + 프렌치프라이 + 음료 세트
# 음식메뉴 성공
# ===============
# 머쉬룸버거 + 프렌치프라이 + 음료(선택)
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 더블버거 + 프렌치프라이 + 음료 세트
# 음식메뉴 성공
# ===============
# 더블버거 + 프렌치프라이 + 음료(선택)
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 더블버거 + 어니언링 + 음료 세트
# 음식메뉴 성공
# ===============
# 더블버거 + 어니언링 + 음료(선택)
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# 더블버거 + 스위트포테이토 + 음료 세트
# 음식메뉴 성공
# ===============
# 더블버거 + 스위트포테이토 + 음료(선택)
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# ===========끝===========
# ---6번 식당파싱 시작 ---
# 서울 강남구 역삼동 709 테헤란아이파크상가 10호
# 주소 뽑기 성공
# =========================================
#
# 아메리칸스타일 수제버거전문점  '미트앤번버거샵'은 아메리칸스타일의 버거 레스토랑입니다.
# 이름그대로 버거의 기본이자 핵심인 고기(패티)와 번에 충실한 클래식한 버거샵을 추구하고 있습니다.
# 최적의 고기배합으로 매일 갈아만든 신선한 패티와 먹기에 적합한 사이즈의 깔끔하고 담백한 번을 사용하여
# 기본에 충실하면서도 다양한 취향을 만족시켜줄 수 있는 버거샵입니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 소고기 : 미국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [수제버거]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [프라이즈]
# 음식 카테고리 성공
# =========================================
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [수제버거]
# 음식 카테고리 성공
# =========================================
# 베이컨 치즈버거
# 음식메뉴 성공
# ===============
# 아메리칸 치즈, 구운 양파, 베이컨
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# 미트 앤 번 수프림
# 음식메뉴 성공
# ===============
# 아메리칸 치즈, 적양파, 토마토, 양상추, 피클 ,슈프림소스
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 미트 앤 번 클래식
# 음식메뉴 성공
# ===============
# 아메리칸 치즈, 적양파, 베이컨, 계란프라이
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 트럼프
# 음식메뉴 성공
# ===============
# 체다 치즈, 베이컨, 홀스래디쉬 소스
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 데 라 소울
# 음식메뉴 성공
# ===============
# 몬테레이 잭 치즈, 할라피뇨 소스
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 볼케이노
# 음식메뉴 성공
# ===============
# 몬테레이 잭 치즈, 적양파, 토마토, 양상추, 치폴레 소스
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 알로하
# 음식메뉴 성공
# ===============
# 아메리칸 치즈, 구운 파인애플, 양상추, 데리야끼 소스
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 미트 앤 칠리
# 음식메뉴 성공
# ===============
# 체다 치즈, 적양파, 토마토, 칠리소스
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 캔자스 시티
# 음식메뉴 성공
# ===============
# 아메리칸 치즈, 구운 양파, 베이컨, 바비큐 소스
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# 베이컨 치즈버거 세트
# 음식메뉴 성공
# ===============
# 베이컨 치즈버거 + 프렌치 프라이즈 + 음료
# 음식정보 성공
# ===============
# 12300
# 금액 성공
# ===============
# 미트 앤 번 수프림 세트
# 음식메뉴 성공
# ===============
# 미트 앤 번 수프림 + 프렌치 프라이즈 + 음료
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 미트 앤 번 클래식 세트
# 음식메뉴 성공
# ===============
# 미트 앤 번 클래식 + 프렌치 프라이즈 + 음료
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 트럼프 세트
# 음식메뉴 성공
# ===============
# 트럼프 + 프렌치 프라이즈 + 음료
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 데 라 소울 세트
# 음식메뉴 성공
# ===============
# 데 라 소울 + 프렌치 프라이즈 + 음료
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 볼케이노 세트
# 음식메뉴 성공
# ===============
# 볼케이노 + 프렌치 프라이즈 + 음료
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 알로하 세트
# 음식메뉴 성공
# ===============
# 알로하 + 프렌치 프라이즈 + 음료
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 미트 앤 칠리 세트
# 음식메뉴 성공
# ===============
# 미트 앤 칠리 + 프렌치 프라이즈 + 음료
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 캔자스 시티 세트
# 음식메뉴 성공
# ===============
# 캔자스 시티 + 프렌치 프라이즈 + 음료
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# [프라이즈]
# 음식 카테고리 성공
# =========================================
# 프렌치 프라이즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 치즈 프라이즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 슈프림 프라이즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 칠리 치즈 프라이즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10500
# 금액 성공
# ===============
# 고구마 프라이즈 with 메이플 마요
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10500
# 금액 성공
# ===============
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# 코울슬로
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 콘샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 맥앤치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 칠리 맥앤치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 코카콜라 제로 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 닥터페퍼 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 페리에 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 오렌지주스 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 마운틴듀 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 웰치스 포도 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 웰치스 청포도 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 웰치스 딸기 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 진저에일 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 마마 에이드 오렌지 (330ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 마마 에이드 레몬 (330ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 마마 에이드 패션 (330ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 서울 강남구 역삼동 707-34 한신인터밸리24 지하1층 B113호
# 주소 뽑기 성공
# =========================================
#
# 스테프핫도그의 시작은 덴마크 '튤립푸드 컴퍼니'의 '스테프핫도그 홀베어'라는 브랜드에서부터 시작됩니다. '스테프핫도그 홀베어'는 덴마크에서만 4,300개의 매장과 판매대를 운영중이고, 유럽에서는 '스테프핫도그 홀베어'로 불리며 가장 인지도 높은 핫도그 브랜드로 자리매김하였습니다. 국내에서는 긴 상호명을 줄여 '스테프핫도그'로 론칭 후 프랜차이즈 시스템을 도입하여 전국 각지의 직영 및 가맹점, 특수매장 등 다양한 곳에서 만나볼 수 있는 국내 핫도그 브랜드입니다.
#
# 자사에서 유통하고 있는 소시지는 100% 덴마크 돈육을 사용하여 제조된 제품으로 현재 문제가 되고있는 독일,네덜란드 돈육과는 관련이 없습니다.
# 당사에서 제공하고 있는 소시지는 70도 이상에서 가열 가공된 살균제품입니다.
# E형 간염 바이러스 검사에 관련하여 어떠한 조치도 받은 바 없음을 알려드립니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# ﻿돼지고기 : 덴마크산
# 쌀,닭가슴살 : 국내산
# 베이컨 : 미국산
# 냉동닭날개 : 태국산
# 순살치킨 : 중국산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 7000
# 최소 금액 성공
# =========================================
# [세트]
# 음식 카테고리 성공
# =========================================
# [핫도그]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [세트]
# 음식 카테고리 성공
# =========================================
# 스테프연인팩
# 음식메뉴 성공
# ===============
# 스테프핫도그 + 프렌치불고기 + 후렌치후라이 + 허브치즈스틱(2pcs) + 음료 택2
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 트러플든든팩
# 음식메뉴 성공
# ===============
# 바비큐핫도그 + 치즈온핫도그 + 콘샐러드 + 케이준후라이 + 칠리치킨(2pcs) + 음료 택2
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 핫도그 set
# 음식메뉴 성공
# ===============
# 핫도그 택1 + 사이드 택1 + 음료 택1
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [핫도그]
# 음식 카테고리 성공
# =========================================
# 플레인 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3800
# 금액 성공
# ===============
# 스위트바비큐 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4400
# 금액 성공
# ===============
# 칠리덕 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 치즈온 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 스테프 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 어니언링 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 프렌치 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 바비큐 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 치즈덕 (샤워덕)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 후렌치후라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 콘샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 어니언링
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 케이준 후라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2400
# 금액 성공
# ===============
# 허브치즈스틱 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2400
# 금액 성공
# ===============
# 칠리치킨 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2600
# 금액 성공
# ===============
# 순살치킨 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2700
# 금액 성공
# ===============
# 그릴소시지
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2400
# 금액 성공
# ===============
# 메디소시지
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# 덴마크킹 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 미니핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3300
# 금액 성공
# ===============
# 에그머핀
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3300
# 금액 성공
# ===============
# 츄러스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 케이준 샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 아메리카노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3300
# 금액 성공
# ===============
# 카페라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4400
# 금액 성공
# ===============
# 자몽에이드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3800
# 금액 성공
# ===============
# 오렌지에이드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3800
# 금액 성공
# ===============
# 레몬에이드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3800
# 금액 성공
# ===============
# 딸기쥬스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3800
# 금액 성공
# ===============
# 딸기바나나쥬스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4400
# 금액 성공
# ===============
# 골드키위쥬스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4400
# 금액 성공
# ===============
# ===========끝===========
# ---8번 식당파싱 시작 ---
# 서울 강남구 대치동 894 지상 2층 202호
# 주소 뽑기 성공
# =========================================
#
# 이태원더버거는 2016년도에 이태원에서 본점을 시작하여 대한민국 최고의 수제버거를 목표로 합니다.
# 저희 버거는 최고급 소고기패티를 직접 작업하여 코코넛 숯불에 직화그릴방식으로 구워 내고, 아침마다 신선한 야채를 하나씩 직접 손질하며, 매일 두 번 저온숙성 자연발효한 잡곡 번을 구워내서 만들어집니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 햄버거-소고기 미국산-닭고기 태국산 및 브라질산-새우 베트남산칠리소스-소소기 미국산-돼지고기 미국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 8900
# 최소 금액 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [버거]
# 음식 카테고리 성공
# =========================================
# [프라이즈]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# 아보카딕트 버거 세트
# 음식메뉴 성공
# ===============
# 아보카딕트 버거 + 감자튀김 + 음료 선택 1
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# 빅 더블 버거 세트
# 음식메뉴 성공
# ===============
# 빅 더블 버거 + 감자튀김 + 음료 선택 1
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# 칠리치즈 버거 세트
# 음식메뉴 성공
# ===============
# 칠리치즈 버거 + 감자튀김 + 음료 선택 1
# 음식정보 성공
# ===============
# 14900
# 금액 성공
# ===============
# 클래식버거 세트
# 음식메뉴 성공
# ===============
# 클래식버거 + 감자튀김 + 음료 선택 1
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# BBQ베이컨치즈버거 세트
# 음식메뉴 성공
# ===============
# BBQ베이컨치즈버거 + 감자튀김 + 음료 선택 1
# 음식정보 성공
# ===============
# 12900
# 금액 성공
# ===============
# 더버거 세트
# 음식메뉴 성공
# ===============
# 더버거 + 감자튀김 + 음료 선택 1
# 음식정보 성공
# ===============
# 13900
# 금액 성공
# ===============
# 쉬림프 세트
# 음식메뉴 성공
# ===============
# 쉬림프버거 + 감자튀김 + 음료 선택 1
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# [버거]
# 음식 카테고리 성공
# =========================================
# 아보카딕트 버거
# 음식메뉴 성공
# ===============
# Avocado 2, Beef Patty, Bacon, Cheese, Lattuce, Tomato, Onion, Pickle소고기 패티, 치즈, 베이컨을 아보카도가 아래위로 감싼 부드러운 맛이 일품인 버거
# 음식정보 성공
# ===============
# 13900
# 금액 성공
# ===============
# 빅 더블 버거
# 음식메뉴 성공
# ===============
# Beef Patty 2, Bacon 2, Cheese 2, Lattuce, Tomato, Onion, Pickle소고기 패티 투장, 베이컨도 치즈도 두배, Meat Lover들을 위한 빅더블 사이즈 버거
# 음식정보 성공
# ===============
# 13900
# 금액 성공
# ===============
# 칠리치즈 버거
# 음식메뉴 성공
# ===============
# Beef Patty, Chili Sauce, Cheese, Lattuce, Tomato, Onion, Pickle
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 클래식 버거
# 음식메뉴 성공
# ===============
# Beef Patty, Cheese, Lattuce, Tomato, Onion, Pickle오리지날 클래식 치즈 버거
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# BBQ베이컨치즈버거
# 음식메뉴 성공
# ===============
# Caramelized Onion, Bacon, Beef patty, Cheese, Lettuce,  Tomato, Onion, Pickle, BBQ sauce히커리 BBQ 소스, 베이컨, 구운양파와 소고기패티의 완벽한 조화
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 더버거
# 음식메뉴 성공
# ===============
# Fried Egg, Bacon, Beef patty, Cheese, Lettuce,  Tomato, Onion, Pickle, Spicy sauce베이컨과 계란, 치즈가 들어간 매콤한 버거
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 쉬림프
# 음식메뉴 성공
# ===============
# 4 Shrimps, Beef patty, Cheese, Lettuce,  Tomato, Onion, Pickle, Spicy sauce탱탱한 4마리 통새우와 소고기 패티, 매콤한 특제소스가 환상적인 조합의 버거
# 음식정보 성공
# ===============
# 12900
# 금액 성공
# ===============
# [프라이즈]
# 음식 카테고리 성공
# =========================================
# 케이준 프라이즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6900
# 금액 성공
# ===============
# 치즈 프라이즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 어니언 크림 프라이즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 칠리 치즈 프라이즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 코울슬로(레귤러)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 코카콜라(355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 코카콜라 제로(250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 스프라이트(355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# ===========끝===========
# ---9번 식당파싱 시작 ---
# 서울 강남구 논현동 226-7
# 주소 뽑기 성공
# =========================================
#
# ☆GOURMET
# ☆ORGANIC
# ☆FRESH
#
# "BEST FOOD,
# GOOD PRICE"
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쇠고기: 호주산
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [버거 (Five Two Burger)]
# 음식 카테고리 성공
# =========================================
# [세트 메뉴 (Set Menu)]
# 음식 카테고리 성공
# =========================================
# [프라이 (Fries)]
# 음식 카테고리 성공
# =========================================
# [칠리콘 까르네]
# 음식 카테고리 성공
# =========================================
# [에이드 (Ade)]
# 음식 카테고리 성공
# =========================================
# [주스 (Juice)]
# 음식 카테고리 성공
# =========================================
# [아이스티]
# 음식 카테고리 성공
# =========================================
# [캔음료]
# 음식 카테고리 성공
# =========================================
# [병음료]
# 음식 카테고리 성공
# =========================================
# [버거 (Five Two Burger)]
# 음식 카테고리 성공
# =========================================
# 트리플 치이즈 버거
# 음식메뉴 성공
# ===============
# 5oz 패티 모짜렐라치즈, 아메리칸 &스위스 치즈, 그릴드 어니언, 크림소스
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 크런치 보이 버거
# 음식메뉴 성공
# ===============
# 5oz 패티, 스위스치즈, 로메인, 토마토, 포테이토칩스, 칠리갈릭소스
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 화이브앤투 버거
# 음식메뉴 성공
# ===============
# 5oz 패티, 아메리칸치즈, 로메인, 토마토,코셔딜 피클, 레드어니언, 베이컨, 홈메이드소스
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 택 맥스 버거
# 음식메뉴 성공
# ===============
# 4oz 패티, 스위스치즈, 칠리콘까르네, 찹(로메인, 토마토, 레드어니언)
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 뉴요커 버거
# 음식메뉴 성공
# ===============
# 50z 패티, 뮌스터치즈, 로메인, 토마토, 그릴드 머쉬룸 & 파프리카, 타르타르 & 비트소스
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 그린 그릭스 버거
# 음식메뉴 성공
# ===============
# 5oz 패티, 모짜렐라 & 아메리칸치즈, 찹(로메인, 토마토, 레드어니언, 파프리카), 홈메이드소스
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 알로하와이 버거
# 음식메뉴 성공
# ===============
# 5oz 패티, 하바티치즈, 로메인, 토마토, 레드어니언, 그릴드 파인애플, 바베큐소스
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 필리스 버거
# 음식메뉴 성공
# ===============
# 5oz 패티, 고다치즈, 로메인, 토마토, 레드어니언, 파프리카, 필리스테이크
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# 웨스턴빅맨 버거
# 음식메뉴 성공
# ===============
# 4oz 더블패티, 스위스 & 아메리칸 치즈, 로메인, 더블토마토, 코셔딜 피클, 레드어니언, 더블베이컨, 홈메이드소스
# 음식정보 성공
# ===============
# 12900
# 금액 성공
# ===============
# [세트 메뉴 (Set Menu)]
# 음식 카테고리 성공
# =========================================
# 프렌치프라이 + 소다
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 어니어링 + 소다
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 고구마프라이 + 소다
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 쉬림프 볼 + 소다
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# [프라이 (Fries)]
# 음식 카테고리 성공
# =========================================
# 프렌치프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 어니언링
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 고구마프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 치즈 프렌치 프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 쉬림프 볼 & 갈릭프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [칠리콘 까르네]
# 음식 카테고리 성공
# =========================================
# 칠리 나쵸 & 베이컨
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 칠리 프렌치 프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 칠리 치킨 윙 봉 & 텐더
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 칠리 쉬림프 프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [에이드 (Ade)]
# 음식 카테고리 성공
# =========================================
# 자몽 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 라임 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 레몬 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 오렌지 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 망고 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 파인애플 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 오미자 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 유자 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 석류 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 키위 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 수박 에이드 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# [주스 (Juice)]
# 음식 카테고리 성공
# =========================================
# 오렌지 쥬스 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 자몽 쥬스 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 애플 쥬스 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 망고 쥬스 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 파인애플 쥬스 (Take-out 잔)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 수박주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [아이스티]
# 음식 카테고리 성공
# =========================================
# 레몬 아이스티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 망고 아이스티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 피치 아이스티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [캔음료]
# 음식 카테고리 성공
# ...
# [버거 (단품)]
# 음식 카테고리 성공
# =========================================
# 레오 (단품)
# 음식메뉴 성공
# ===============
# 양파, 피클, 토마토, 베이컨, 애니멀소스 ,로메인, 아메리칸치즈
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 루키 (단품)
# 음식메뉴 성공
# ===============
# 햇양파를 그리들에 카라멜색으로 굽고, 아메리칸 치즈와 함께 100% 간 소고기 등심패티를 건강하게 즐길수 가장 기본적인 어메리칸 스타일의 버거.
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 맥 (단품)
# 음식메뉴 성공
# ===============
# 숙성 체다치즈와 마카로니를 섞어 그 위에 오레가노와 카이엔 페퍼, 베이컨을 올린 아메리칸 다이닝 스타일의 버거.
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 하바나 (단품)
# 음식메뉴 성공
# ===============
# 할라피뇨 스프레드와 마요네즈, 멕시코의 하바네로 고추 파우더를 가미한 토핑에 스위스 아메리칸 더블치즈를 올린 멕시칸 스타일의 매콤한 버거청양고추보다 맵습니다~주문시 참고하세요~
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 콜911 (단품)
# 음식메뉴 성공
# ===============
# 1단계 : 가볍게 매콤한 정도2단계 : 즐겁게 매운 정도, 청량고추의 맵기3단계 : 화끈하게 매운 정도, 맥시코 고추 하바네로 맵기파이어벨의 대표 버거.여러가지 향신료와 신선한 재료가 들어간 스파이시 데미그라스 소스와 아메리칸치즈, 토마토,할라피뇨,로메인 3가지 야채까지 들어간 스파이스 버거.청양고추보다 맵습니다~주문시 참고하세요~
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 에그이고 (단품)
# 음식메뉴 성공
# ===============
# 아메리칸치즈, 토마토, 계란후라이, 랜치드레싱, 로메인, 베이컨
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 칠리킹 (단품)
# 음식메뉴 성공
# ===============
# 직접 만들어 전통 아메리칸 비프칠리와 패티의 조화가 어울리는 칠리버거
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 베버리힐즈버거 (단품)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 리틀도쿄 (단품)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# [버거 (세트)]
# 음식 카테고리 성공
# =========================================
# 레오 (세트)
# 음식메뉴 성공
# ===============
# 양파, 피클, 토마토, 베이컨, 애니멀소스 ,로메인, 아메리칸치즈
# 음식정보 성공
# ===============
# 14900
# 금액 성공
# ===============
# 루키 (세트)
# 음식메뉴 성공
# ===============
# 햇양파를 그리들에 카라멜색으로 굽고, 아메리칸 치즈와 함께 100% 간 소고기 등심패티를 건강하게 즐길수 가장 기본적인 어메리칸 스타일의 버거.
# 음식정보 성공
# ===============
# 12900
# 금액 성공
# ===============
# 맥 (세트)
# 음식메뉴 성공
# ===============
# 숙성 체다치즈와 마카로니를 섞어 그 위에 오레가노와 카이엔 페퍼, 베이컨을 올린 아메리칸 다이닝 스타일의 버거.
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 하바나 (세트)
# 음식메뉴 성공
# ===============
# 할라피뇨 스프레드와 마요네즈, 멕시코의 하바네로 고추 파우더를 간미한 토핑에 스위스 아메리칸 더블치즈를 올린 멕시칸 스타일의 매콤한 버거청양고추보다 맵습니다~주문시 참고하세요~
# 음식정보 성공
# ===============
# 14500
# 금액 성공
# ===============
# 콜911 (세트)
# 음식메뉴 성공
# ===============
# 1단계 : 가볍게 매콤한 정도2단계 : 즐겁게 매운 정도, 청량고추의 맵기3단계 : 화끈하게 매운 정도, 맥시코 고추 하바네로 맵기파이어벨의 대표 버거.여러가지 향신료와 신선한 재료가 들어간 스파이시 데미그라스 소스와 아메리칸치즈, 토마토,할라피뇨,로메인 3가지 양채까지 들어간 스파이스 버거.청양고추보다 맵습니다~주문시 참고하세요~
# 음식정보 성공
# ===============
# 14900
# 금액 성공
# ===============
# 에그이고 (세트)
# 음식메뉴 성공
# ===============
# 아메리칸치즈, 토마토, 계란후라이, 랜치드레싱, 로메인, 베이컨
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# 칠리킹 (세트)
# 음식메뉴 성공
# ===============
# 직접 만들어 전통 아메리칸 비프칠리와 패티의 조화가 어울리는 칠리버거
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# 베버리힐즈버거 (세트)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# 리틀도쿄 (세트)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# [프라이즈 & 사이드메뉴]
# 음식 카테고리 성공
# =========================================
# 웨지프라이
# 음식메뉴 성공
# ===============
# 매력적인 모습을 가진 웨지 스타일의 프렌치 프라이
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 치즈프라이
# 음식메뉴 성공
# ===============
# 프라이 위에 녹진한 치즈가 뿌려져 있는 어메리칸 스타일의 프렌치 프라이
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 렌치 & 베이컨 프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 칠리 치즈 프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10500
# 금액 성공
# ===============
# 코울슬로
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 마카로니 & 치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 립톤 아이스티 복숭아 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 닥터페퍼 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 마운틴듀 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 트레비 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# ===========끝===========
# ---11번 식당파싱 시작 ---
# 서울 서초구 서초동 1578-4 동궁빌딩 2층 202호
# 주소 뽑기 성공
# =========================================
#
# 천연발효종을 이용해 24시간 저온 숙성을 거친 반죽을 이른 아침 소울버킷 만의 3가지 스페셜 번으로 구워냅니다.
# 각 버거의 특징에 맞게 번, 수제소스, 신선한 야채들과 메인 재료들이 어울어져 깔끔하고 맛있는 수제버거를 즐기실 수 있습니다.
# 매달 바뀌는 이 달의 버거 또한 독특한 맛과 신선한 재미를 느끼실 수 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 소고기 미국산닭고기 국내산생선 광어 국내산오징어 연안산, 국내산새우,베트남
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# 비프버거 세트
# 음식메뉴 성공
# ===============
# 버거(Burger) + 사이드 선택 1 + 탄산음료
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 치킨버거 세트
# 음식메뉴 성공
# ===============
# 버거(Burger) + 사이드 선택 1 + 탄산음료
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 피쉬버거 세트
# 음식메뉴 성공
# ===============
# 버거(Burger) + 사이드 선택 1 + 탄산음료
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 새우버거 세트
# 음식메뉴 성공
# ===============
# 버거(Burger) + 사이드 선택 1 + 탄산음료
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 이달의 버거 세트
# 음식메뉴 성공
# ===============
# 찹스테이크 버거 + 사이드 선택 1 + 탄산음료
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# ===========끝===========
# ---12번 식당파싱 시작 ---
# 서울 강남구 대치동 919-17 2층 102호
# 주소 뽑기 성공
# =========================================
# 2011년 부터 지역 맛집으로 꾸준히 사랑받아온 알레스 플레이스가 한티역 부근에 새롭게 오픈하였습니다.
#
# 가게 소개 뽑기 성공
# =========================================
# 빵:국내산 치즈 : 미국산 소고기 : 호주산감자튀김: 네덜란드  베이컨:미국산양상추,토마토 : 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [버거 (Burger)]
# 음식 카테고리 성공
# =========================================
# [프라이즈 (Fries)]
# 음식 카테고리 성공
# =========================================
# [플레이트 (Plate)]
# 음식 카테고리 성공
# =========================================
# [음료 (Drinks)]
# 음식 카테고리 성공
# =========================================
# [버거 (Burger)]
# 음식 카테고리 성공
# =========================================
# 치즈 버거
# 음식메뉴 성공
# ===============
# 알렉스 플레이스의 기본 버거
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# 더블 치즈 버거
# 음식메뉴 성공
# ===============
# 더블 패티와 더블 체다치즈로 양도 두배 맛도 두배!
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 베이컨 잼 버거
# 음식메뉴 성공
# ===============
# 알렉스 플레이스의 대표햄버거.시애틀 정통 베이컨잼을 맛볼 수 있는 버거.
# 음식정보 성공
# ===============
# 6900
# 금액 성공
# ===============
# 불고기 잼 버거
# 음식메뉴 성공
# ===============
# 한국인이 제일 좋아하는 불고기를 잼으로 만들어 곁들인 버거
# 음식정보 성공
# ===============
# 6900
# 금액 성공
# ===============
# 칠리 버거
# 음식메뉴 성공
# ===============
# 토마토와 강낭콩을 베이스로 만든 매콤한 칠리 소스를 곁들인 버거
# 음식정보 성공
# ===============
# 6900
# 금액 성공
# ===============
# 하와이안 버거
# 음식메뉴 성공
# ===============
# 구운 파인애플과 바비큐 소스를 곁들인 버거
# 음식정보 성공
# ===============
# 6900
# 금액 성공
# ===============
# 치즈 앤 에그 버거
# 음식메뉴 성공
# ===============
# 치즈버거 위에 계란후라이를 올린 버거
# 음식정보 성공
# ===============
# 6400
# 금액 성공
# ===============
# 베이컨 치즈 버거
# 음식메뉴 성공
# ===============
# 그릴에 구운 베이컨를 녹인 치즈와 곁들인 버거
# 음식정보 성공
# ===============
# 7200
# 금액 성공
# ===============
# 베이컨 에그 버거
# 음식메뉴 성공
# ===============
# 그릴에 구운 베이컨과 계란 후라이를 곁들인 버거
# 음식정보 성공
# ===============
# 7700
# 금액 성공
# ===============
# 스파이시 페퍼잭 버거
# 음식메뉴 성공
# ===============
# 매콤한 할라피뇨와 페퍼잭 치즈를 곁들인 버거
# 음식정보 성공
# ===============
# 7300
# 금액 성공
# ===============
# 더블 베이컨 에그 버거
# 음식메뉴 성공
# ===============
# 햄버거 마니아를 위한 대형버거. 더블패티와 더블치즈 구운 베이컨, 계란후라이를 곁들인 버거
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 소세지 버거
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# [프라이즈 (Fries)]
# 음식 카테고리 성공
# =========================================
# 감자튀김 (150g)
# 음식메뉴 성공
# ===============
# 겉은 바삭 안은 촉촉 스트레이트 컷 감자
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 치즈 감자튀김 (150g)
# 음식메뉴 성공
# ===============
# 감자튀김 위에 체다치즈를 듬뿍 녹여 올린 스트레이트 컷 감자
# 음식정보 성공
# ===============
# 3700
# 금액 성공
# ===============
# 칠리 감자튀김 (150g)
# 음식메뉴 성공
# ===============
# 감자튀김 위에 소고기, 토마토, 강낭콩으로 만든 칠리를 올린 스트레이트 컷 감자
# 음식정보 성공
# ===============
# 4700
# 금액 성공
# ===============
# 칠리 치즈 감자튀김 (150g)
# 음식메뉴 성공
# ===============
# 감자튀김 위에 녹인치즈와 칠리를 모두 올린 스트레이트 컷 감자
# 음식정보 성공
# ===============
# 6200
# 금액 성공
# ===============
# 해쉬브라운
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [플레이트 (Plate)]
# 음식 카테고리 성공
# =========================================
# 치킨 윙 (6pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 소세지 (3pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [음료 (Drinks)]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 마운틴듀  (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 트레비 레몬 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 웰치스 포도 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 골든메달 애플주스 (296ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# ===========끝===========
# ---13번 식당파싱 시작 ---
# 서울 강남구 삼성동 112-5 라마다서울호텔
# 주소 뽑기 성공
# =========================================
#
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 소고기 : 호주산
# 돼지고기 : 칠레산
# 치킨 : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 11000
# 최소 금액 성공
# =========================================
# [버거]
# 음식 카테고리 성공
# =========================================
# [치킨]
# 음식 카테고리 성공
# =========================================
# [프라이]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [버거]
# 음식 카테고리 성공
# =========================================
# 카퍼 싱글 버거
# 음식메뉴 성공
# ===============
# 두툼한 시그니처 소고기패티 & 치즈
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 카퍼 더블 버거
# 음식메뉴 성공
# ===============
# 시그니처 소고기패티 와 치즈를 2장씩!
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 베이컨 BBQ 버거
# 음식메뉴 성공
# ===============
# 훈제향 가득한 BBQ소스와 베이컨 버거
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 비프칠리 할라피뇨 버거
# 음식메뉴 성공
# ===============
# 풍미작렬 매콤 칠리소스와 할라피뇨 버거
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 블루 치즈 버거
# 음식메뉴 성공
# ===============
# 치즈 매니아를 위한 블루치즈! 그 위에 카라멜라이즈드된 어니언을 추가한 버거
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 트러플 머쉬룸 버거
# 음식메뉴 성공
# ===============
# 트러플 오일로 버무려진 버섯을 올려 한 층 고급스러운 맛의 버거
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 풀드포크 슬라이더스 버거
# 음식메뉴 성공
# ===============
# 12시간 이상 스모크된 풀드포크를 사용한 미니버거(2pcs)
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 램&비프 버거
# 음식메뉴 성공
# ===============
# 양&소의 콜라보! 은은한 양고기 향을 즐길 수 있는 버거
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 쉬림프 모짜 버거
# 음식메뉴 성공
# ===============
# 육즙 가득 소고기와 오동통한 통새우의 환상 조화!
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# [치킨]
# 음식 카테고리 성공
# =========================================
# 수비드 치킨
# 음식메뉴 성공
# ===============
# 수비드 공법을 이용하여 겉은 바삭! 속은 부드러운 카퍼룸의 시그니처 치킨
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 오리지날 버팔로 윙 (4pcs)
# 음식메뉴 성공
# ===============
# 미국식 정통 버팔로 윙
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 오리지날 버팔로 윙 (8pcs)
# 음식메뉴 성공
# ===============
# 미국식 정통 버팔로 윙
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [프라이]
# 음식 카테고리 성공
# =========================================
# 오리지날 프라이즈
# 음식메뉴 성공
# ===============
# 신선한 감자채로 튀겨낸 감자튀김
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 칠리 치즈 프라이즈
# 음식메뉴 성공
# ===============
# 비프칠리,살사,사워크림,할라피뇨,치즈를 곁들인 감자튀김
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 트러플 프라이즈
# 음식메뉴 성공
# ===============
# 트러플 오일과 그라나 파다노 치즈로 버무려진 고급스러운 감자튀김
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 제로콜라 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 닥터페퍼 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 웰치스 청포도 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 오렌지 주스 (350ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 포도 주스 (350ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# ===========끝===========
# ---14번 식당파싱 시작 ---
# 서울 강남구 대치동 939-28 운성빌딩 1층
# 주소 뽑기 성공
# =========================================
#
# 맛에 놀라고 가격에 또 한번 놀라다!
# 홍대맛집 유럽식 수제버거왓츠피데
#
#
# 가게 소개 뽑기 성공
# =========================================
# 돼지고기, 닭고기 : 국내산쇠고기 : 호주산베이컨 : 미국산닭고기(치킨윙) : 덴마크산,태국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 7000
# 최소 금액 성공
# =========================================
# [포켓피데]
# 음식 카테고리 성공
# =========================================
# [샐러드]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [포켓피데]
# 음식 카테고리 성공
# =========================================
# 왓츠피데
# 음식메뉴 성공
# ===============
# 패티, 체다치즈, 토마토, 야채, 홀그레인소스
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 미트칠리치즈피데
# 음식메뉴 성공
# ===============
# 모짜렐라치즈, 체다치즈, 미트칠리소스
# 음식정보 성공
# ===============
# 6300
# 금액 성공
# ===============
# 할라피뇨불고기피데
# 음식메뉴 성공
# ===============
# 할라피뇨, 소불고기, 토마토, 야채, 홀그레인소스
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 쉬림프피데
# 음식메뉴 성공
# ===============
# 통새우패티, 토마토, 야채, 타르타르소스
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 갈릭치킨피데
# 음식메뉴 성공
# ===============
# 닭가슴살, 토마토, 야채, 갈릭소스
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 불고기피데
# 음식메뉴 성공
# ===============
# 소불고기, 토마토, 야채, 홀그레인소스
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# B.L.T 피데
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6300
# 금액 성공
# ===============
# [샐러드]
# 음식 카테고리 성공
# =========================================
# 리코타치즈샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 갈릭렐리쉬치킨샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 프렌치프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 케이준프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 치킨윙
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 미트칠리치즈프라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 치킨텐더
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3900
# 금액 성공
# ===============
# 양송이 스프
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3900
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 아메리카노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 카페라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 탄산수 (산펠레그리노) 250ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 레몬 탄산수에이드 200ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 그린자몽 탄산수에이드 200ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 오렌지 탄산수에이드 200ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 블러드오렌지 탄산수에이드 200ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 그린런치 건강쥬스(샘 비타민) 375ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 프롯런치 건강쥬스(샘 비타민) 375ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 샐러드런치 건강쥬스(샘 비타민) 375ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 애플주스(골드메달) 100%
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 레몬 무탄산에이드(허버츠) 473ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 딸기레몬 무탄산에이드(허버츠) 473ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 망고레몬 무탄산에이드(허버츠) 473ml
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# ===========끝===========
# ---15번 식당파싱 시작 ---
# 서울 강남구 개포동 1245-12
# 주소 뽑기 성공
# =========================================
#
# 맛에 놀라고 가격에 또 한번 놀라다!
# 홍대맛집 유럽식 수제버거왓츠피데
#
#
# 가게 소개 뽑기 성공
# =========================================
# 왓츠코피데- 소고기:국내산, 돼지고기:국내산갈릭치킨코피데- 닭고기:국내산불고기코피데- 불고기:국내산돈까스- 돈육:제주도산, 쌀:국내산치킨윙- 닭고기:덴마크산, 태국산토핑- 베이컨:미국산, 계란:국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 7000
# 최소 금액 성공
# =========================================
