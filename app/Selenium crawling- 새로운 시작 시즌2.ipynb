# %% [markdown]
# ## 한식

# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 한식[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[2]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 40:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 한식 데이터(이미지) 수집
# soup = BeautifulSoup(html, 'lxml')
# img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
# count = 1
# for i in img:
#     img_url = i.get_text("url", strip=True)
#     img_url_parse = img_url[4:-1]
#     urllib.request.urlretrieve(img_url_parse, f'{count}.korea_food_img.jpg')
#     count += 1

# 한식 데이터(식당명) 수집
korea_store_list = []
korea_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in korea_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(korea_store_list):
    print(i, name)


    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 11:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')

    store_details_menu = soup.select('.left-section > .menu-category')
    for menu in store_details_menu:
        # 음식 메뉴
        store_menu = menu.select_one(".pull-left").find_next('strong').get_text(strip=True)
#         store_menus.append(store_menu)
        print(store_menu)
        print('음식 메뉴 성공')
        print('=========================================')

        # 음식 정보
        store_description = menu.select_one('.pull-left > span').get_text("", strip=True)
#         store_descriptions.append(store_description)
        print(store_description)
        print('음식 정보 성공')
        print('=========================================')

        # 음식 가격
        store_price = menu.select_one("span.calculate-price").get_text(strip=True)
        a = re.split(',', store_price)
        aprice = ''
        for i in a:
            aprice += i
        price = int(aprice)
#         store_prices.append(price)
        print(price)
        print('음식 가격 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='한식',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=2),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
    # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
    print('음식 카테고리 성공')
    print('=========================================')
    
    for menu in store_details_menu:
        # 음식 메뉴
        store_menu = menu.select_one(".pull-left").find_next('strong').get_text(strip=True)
#         store_menus.append(store_menu)
        print(store_menu)
        print('음식 메뉴 성공')
        print('=========================================')

        # 음식 정보
        store_description = menu.select_one('.pull-left > span').get_text("", strip=True)
#         store_descriptions.append(store_description)
        print(store_description)
        print('음식 정보 성공')
        print('=========================================')

        # 음식 가격
        store_price = menu.select_one("span.calculate-price").get_text(strip=True)
        a = re.split(',', store_price)
        aprice = ''
        for i in a:
            aprice += i
        price = int(aprice)
#         store_prices.append(price)
        print(price)
        print('음식 가격 성공')
        print('=========================================')
    
        Food.objects.create(
            category=food_category,
            name=store_menu,
            price=price,
            food_info=store_description,
        )
    
    
        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)


print('**************끝났따!!!!!!!!!!!!!!!!!*********************')
driver.close()
      
    
#     print('================== 가게 하나 끝 ==================')
    # 팝업나올시 해결

# 한식 데이터(식당명) 수집
print(korea_store_list)
# 가게주소
print(store_addresss)
# 가게 소개
print(store_info_list)
# 가게 원산지 정보
print(store_origin_infos)
# 가게 최소금액
print(store_moneyss)
# 가게 음식 카테고리
print(store_menu_category)
# 가게 음식 메뉴
print(store_menus)
# 음식 가격
print(store_prices)
# 음식 정보
print(store_descriptions)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:80: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-6 전원빌딩 지하 1층
# 주소 뽑기 성공
# =========================================
#
# [CHEFLY] 당신만을 위한 셰프의 한끼
#
# 대한민국 대표 셰프들의 요리를
# 온라인주문+즉시조리+즉시배송으로
# 원하는 시간과 장소에서 편하게 즐기실 수 있는
# 신개념 온라인 음식배달 서비스입니다
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# [메인메뉴_완조리]
#
# 단짠단짠 밥도둑 연어새우장 덮밥:새우 (에콰도르), 연어 (노르웨이산), 계란(국내산)
# 피타브래드에 싸먹는 허니갈릭 닭가슴살 시저샐러드:로메인(국내산), 닭가슴살(국내산), 계란(국내산), 베이컨(수입산), 디종머스터드(미국산)
# 특제간장으로 맛을 살린여수 새꼬막비빔밥 :새꼬막(국내산), 채소류(국내산, 중국산), 고춧가루(국내산)
# 스파이시 마살라 쉬림프를 올린 동남아풍 레드커리 :새우(베트남산), 채소류(국내산, 중국산), 레드커리페이스트(태국산), 휘핑크림(국내산)
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또 : 닭다리살(브라질산), 치킨파우더(대만산), 잡곡(국내산), 고르곤졸라(이탈리아산)
# 매콤한 낙지 콩나물비빔밥 : 쌀(국내산), 낙지(중국산), 채소류(국내산)
# 그라나파다노를 곁들인 닭다리살 김치볶음밥 :김치(국내산), 쌀(국내산), 계란(국내산), 채소류(국내산), 정육(브라질산), 그라나파다노(이탈리아산), 트러플오일(이탈리아산), 굴소스(홍콩산), 두반장(중국산)
# 소불고기 궁중 비빔밥 '골동반' :소고기(호주산), 계란(국내산), 시금치(국내산), 튀각(국내산), 쌀(국내산), 미역(국내산), 고사리(중국산), 당근(중국산), 청포묵(중국산), 숙주(중국산), 은행(중국산)
# 국내산 생등심 돈가츠 덮밥 '가츠동' :돼지등심(국내산), 계란(국내산), 쌀(국내산), 채소류(국내산), 간장(일본산), 단무지(중국산), 락교(중국산)
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# 단짠단짠 밥도둑 연어새우장 덮밥
# 음식 카테고리 성공
# =========================================
# 피타브래드에 싸먹는 허니갈릭 닭가슴살 시저샐러드
# 음식 카테고리 성공
# =========================================
# 특제간장으로 맛을 살린 여수 새꼬막비빔밥
# 음식 카테고리 성공
# =========================================
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또
# 음식 카테고리 성공
# =========================================
# 매콤한 낙지 콩나물 비빔밥
# 음식 카테고리 성공
# =========================================
# 그라나파다노를 곁들인 닭다리살 김치볶음밥
# 음식 카테고리 성공
# =========================================
# 소불고기 궁중 비빔밥 '골동반'
# 음식 카테고리 성공
# =========================================
# 국내산 생등심 돈가츠 덮밥 '가츠동'
# 음식 카테고리 성공
# =========================================
# 영양부추무침을 곁들인 대패삼겹살 덮밥과 된장국
# 음식 카테고리 성공
# =========================================
# 스파이시 마살라 쉬림프를 올린 동남아풍 레드커리
# 음식 카테고리 성공
# =========================================
# 고소하고 상큼한 흑임자 알감자 샐러드
# 음식 메뉴 성공
# =========================================
# 버터에 노릇노릇하게 구운 알감자에 볶음 흑임자 드레싱의 고소함과 레몬 드레싱의 상큼함을 가미했습니다.포슬포슬한 알감자와 상큼한 토마토, 아삭한 브로콜리까지!지금까지 없던 맛과 멋, 건강까지 고려한 셰플리의 야심작입니다. 소소하지만 확실한 행복을 즐겨보세요~
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
#
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]셰플리 인기메뉴 재출시!향신료 풍미 가득, 입맛 당기는 동남아풍 부드러운 레드커리에 스파이시하게 구운 케이준 쉬림프를 올린 인기 앵콜메뉴컬리플라워, 연근, 그린빈, 단호박, 느타리버섯 등 5가지의 다채로운 야채를 오븐에 구워 영양소 파괴는 최소화하고, 부드러운 식감과 푸짐함은 극대화하였습니다.지나간 여름 휴가가 떠오르는 동남아의 향미와, 다가올 가을이 기대되는 맛과 멋이 공존하는 셰플리표 레드커리를 즐겨보세요!CHEF'S TIP식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요.커리소스를 고루 부어서 잘 비벼드세요.사이드로 드린 할라피뇨는 취향에 맞게 즐겨보세요.
# 음식 정보 성공
# =========================================
# 12000
# 음식 가격 성공
# =========================================
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:253: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-6 전원빌딩 지하1층 (셰플리 강남키친과 동일)
# 주소 뽑기 성공
# =========================================
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 히말라야 핑크 솔트로 맛을 더한 오리지널 삼겹살 (200g) :삼겹살(스페인), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 향긋한 유자향을 품은 된장 삼겹구이 (200g) :삼겹살(스페인), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 매콤달콤 홍시 고추장 돼지불고기 (250g)  :앞다리살(미국), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 배즙으로 단맛을 살린 간장 돼지 불고기 (200g)  :목살(캐나다), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 특제 복분자 간장 소스에 재운 인생 LA갈비 (250g) :LA갈비(미국), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 직화 고추장 불고기 덮밥 :앞다리살(미국), 쌀(국내산), 김치(국내산)
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# 히말라야 핑크 솔트로 맛을 더한 오리지널 삼겹살 200g
# 음식 카테고리 성공
# =========================================
# 향긋한 유자향을 품은 된장 삼겹구이 200g
# 음식 카테고리 성공
# =========================================
# 매콤달콤 홍시 고추장 돼지불고기 250g
# 음식 카테고리 성공
# =========================================
# 배즙으로 단맛을 살린 간장 돼지 불고기 200g
# 음식 카테고리 성공
# =========================================
# 특제 복분자 간장 소스에 재운 인생 LA갈비 250g
# 음식 카테고리 성공
# =========================================
# 직화 고추장 불고기 덮밥
# 음식 카테고리 성공
# =========================================
# 히말라야 핑크 솔트로 맛을 더한 오리지널 삼겹살 200g
# 음식 메뉴 성공
# =========================================
# "한국인이 좋아하는 삼겹살"   남녀노소 누구나 좋아하는 삼겹살에 히말라야 핑크 소금으로 특별함을 더하였습니다.히말라야 핑크 소금은 2억년 전 히말라야의 순수함을 그대로 간직한 천연조미료로 인위적인 정제과정을 거치지 않아 간수의 쓴맛이 적어 고기의 감칠맛을 극대화 시켜 줄 뿐만 아니라, 100% 순수한 자연 암염으로 84종 이상의 각종 미네랄 성분이 포함되어 있는 깨끗하고 건강한 식재료입니다.직화 반상의 오리지널 삼겹살은 핑크 소금으로 간을 하여 삼겹살에 건강함과 특별함을 더하였습니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요.당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식 정보 성공
# =========================================
# 13000
# 음식 가격 성공
# =========================================
# 향긋한 유자향을 품은 된장 삼겹구이 200g
# 음식 메뉴 성공
# =========================================
# "유자와 된장소스의 운명적 만남"  유자 된장 소스로 고기의 잡내는 없애고 부드러운 식감은 극대화 하였습니다.유자의 껍질에 풍부한 비타민P는 혈압을 안정시키고 비타민C가 풍부한 과육에는 항산화 성분이 많기 때문에 면역력을 증가시켜주고, 혈관 벽을 튼튼하게 해줘 고혈압에도 효과적입니다.향긋한 유자향과 고소한 된장이 어우러져 독특하면서도 입안 가득 풍미를 느끼실 수 있습니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세
었을 경우 뚜껑을 열고 전자레인지에30초데워주세요.국은 용기에 덜어 전자레인지에 넣어주세요.
# 음식 정보 성공
# =========================================
# 11000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 강남구 역삼동 831-25
# 주소 뽑기 성공
# =========================================
#
# 안녕하세요. 짚신매운갈비찜을 찾아주신 고객님 진심으로 환영합니다.저희는 특별한 비법을 가지고 있지는 않습니다. 다만, 한분 한분 방문해주시는 분들께 어머니의 정성과도 같은 마음으로 늘 한결같은 맛을 전해드리겠습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 돼지고기 : 미국산소고기 : 뉴질랜드산김치,고춧가루,쌀,고추만두 : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 19000
# 최소 금액 성공
# =========================================
# [메뉴]
# 음식 카테고리 성공
# =========================================
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# 짚신 소갈비찜 (2인분, 400g)
# 음식 메뉴 성공
# =========================================
# 공기밥 미포함매운음식은 입맛을 돋우며 스트레스를 날려주고 고추에 들어있는 캡사이신이란 성분은 몸의 대사기능을 높여 지방축적을 막고 이미 몸 속에 달라붙은 지방을 연소시켜 다이어트에도 효과적입니다.
# 음식 정보 성공
# =========================================
# 32000
# 음식 가격 성공
# =========================================
# 당면 (비조리) 추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# [메뉴]
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# 짚신 소갈비찜 (2인분, 400g)
# 음식 메뉴 성공
# =========================================
# 공기밥 미포함매운음식은 입맛을 돋우며 스트레스를 날려주고 고추에 들어있는 캡사이신이란 성분은 몸의 대사기능을 높여 지방축적을 막고 이미 몸 속에 달라붙은 지방을 연소시켜 다이어트에도 효과적입니다.
# 음식 정보 성공
# =========================================
# 32000
# 음식 가격 성공
# =========================================
# 당면 (비조리) 추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 강남구 역삼동 831-6 1층
# 주소 뽑기 성공
# =========================================
#
# 따뜻함, 건강함, 편리함을 추구하는 아시아 누들&라이스 레스토랑으로 아시아 각 지역의 특색 있는 요리를 선보입니다.
# 길거리와 먹거리라는 단어를 조합한 스트릿(strEAT)에서는 규동, 카라이멘, 오니기리 등 심플함과 정직함으로 만들어진 메뉴에
# 각국 아시아의 고유 문화와 맛을 담아냈으며, 푸드플라이를 통해 어디서나 간편하게 건강한 식사를 즐길 수 있습니다.
#
# (배달 시 매장에서 나가는 영수증으로 해피포인트 2% 적립이 가능합니다.)
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀_국내산대만식 돼지 조림 덮밥(돼지고기_독일산)명란 아보카도 덮밥(돼지고기, 두부, 명란_국내산)대만식 마늘쫑 볶음 덮밥(돼지고기_국내산)해산물 날치알 볶음밥(오징어_중국산)삼겹 철판구이(돼지고기_독일산/갈치(양념젓갈),명란_국내산)야채 고로케(돼지고기_국내산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [라이스&누들]
# 음식 카테고리 성공
# =========================================
# [철판구이]
# 음식 카테고리 성공
# =========================================
# 대만식 돼지 조림 덮밥
# 음식 메뉴 성공
# =========================================
# 오향, 팔각 등의 향이 진하게 우러나온 돼지고기 조림에 간장 맛을 들인 달걀과 볶은 청경채를 함께 곁들여 먹는 대만식 조림 덮밥
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 삼겹 철판구이
# 음식 메뉴 성공
# =========================================
# 철판에서 구워내 불맛이 살아있는 삼겹살에 명란, 와사비, 갈치 속젓의 삼합 소스까지 곁들여 더 맛있는 구이 메뉴*17시부터 주문 가능*
# 음식 정보 성공
# =========================================
# 21000
# 음식 가격 성공
# =========================================
# [라이스&누들]
# [철판구이]
# 음식 카테고리 성공
# =========================================
# 대만식 돼지 조림 덮밥
# 음식 메뉴 성공
# =========================================
# 오향, 팔각 등의 향이 진하게 우러나온 돼지고기 조림에 간장 맛을 들인 달걀과 볶은 청경채를 함께 곁들여 먹는 대만식 조림 덮밥
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 삼겹 철판구이
# 음식 메뉴 성공
# =========================================
# 철판에서 구워내 불맛이 살아있는 삼겹살에 명란, 와사비, 갈치 속젓의 삼합 소스까지 곁들여 더 맛있는 구이 메뉴*17시부터 주문 가능*
# 음식 정보 성공
# =========================================
# 21000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 강남구 역삼동 837-26 삼일프라자 1층
# 주소 뽑기 성공
# =========================================
#
# 한끼든든 퓨전 한식 수제직화도시락!!
# 직화락은 직화제육볶음과 직화오징어볶음을 메인으로 하는 직화볶음요리 전문점, 직화도시락 입니다.
# 직화도시락과 더불어 다양한 도시락을 즐겨보세요.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 오징어,쌀,계란,돈가스,떡갈비,닭고기 : 국내산돼지고기 : 미국산     김치 : 국내산,중국산고추가루: 중국산 국내산혼합양배추 .파. 양파: 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [직화류]
# 음식 카테고리 성공
# =========================================
# [직화플러스토핑류]
# 음식 카테고리 성공
# =========================================
# [볶음만따로]
# 음식 카테고리 성공
# =========================================
# [프리미엄]
# 음식 카테고리 성공
# =========================================
# [그외]
# 음식 카테고리 성공
# =========================================
# [돈가스류]
# 음식 카테고리 성공
# =========================================
# [카레류]
# 음식 카테고리 성공
# =========================================
# [스낵]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# 후덜덜 돼지
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 (with 계란후라이와 볶음김치, 옛날소세지와 고기위에 파채!!)
# 음식 정보 성공
# =========================================
# 6900
# 음식 가격 성공
# =========================================
# 후덜덜 (돼지) + 스팸 도시락
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 + 스팸
# 음식 정보 성공
# =========================================
# 7100
# 음식 가격 성공
# =========================================
# 후덜덜 1Box
# 음식 메뉴 성공
# =========================================
# 밥을 제외하고 직화제육볶음만 들어간 메뉴입니다.
# 음식 정보 성공
# =========================================
# 10900
# 음식 가격 성공
# =========================================
# 한끼라도 후덜덜
# 음식 메뉴 성공
# =========================================
# 후덜덜 돼지 + 모듬(돈가스+떡갈비+왕새우+소세지+군만두)
# 음식 정보 성공
# =========================================
# 15900
# 음식 가격 성공
# =========================================
# 매콤닭강정 도시락
# 음식 메뉴 성공
# =========================================
# 매콤한 닭강정 도시락
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 아사삭 돈가스
# 음식 메뉴 성공
# =========================================
# 국내산 돼지고기 등심으로 주문즉시 바삭하게 튀겨낸 돈가스와 해쉬브라운
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 카레돈가스 도시락
# 음식 메뉴 성공
# =========================================
# 카레와 돈가스
# 음식 정보 성공
# =========================================
# 7000
# 음식 가격 성공
# =========================================
# 치즈스틱(4ea)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 후덜덜직화1인 정식세트
# 음식 메뉴 성공
# =========================================
# 후덜덜돼지직화도시락 + 리코타발사믹샐러드 + 오늘의3종반찬 + 김치찌개
# 음식 정보 성공
# =========================================
# 17000
# 음식 가격 성공
# =========================================
# 콜라(355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# [직화류]
# [직화플러스토핑류]
# [볶음만따로]
# [프리미엄]
# [그외]
# [돈가스류]
# [카레류]
# [스낵]
# [세트메뉴]
# [음료]
# 음식 카테고리 성공
# =========================================
# 후덜덜 돼지
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 (with 계란후라이와 볶음김치, 옛날소세지와 고기위에 파채!!)
# 음식 정보 성공
# =========================================
# 6900
# 음식 가격 성공
# =========================================
# 후덜덜 (돼지) + 스팸 도시락
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 + 스팸
# 음식 정보 성공
# =========================================
# 7100
# 음식 가격 성공
# =========================================
# 후덜덜 1Box
# 음식 메뉴 성공
# =========================================
# 밥을 제외하고 직화제육볶음만 들어간 메뉴입니다.
# 음식 정보 성공
# =========================================
# 10900
# 음식 가격 성공
# =========================================
# 한끼라도 후덜덜
# 음식 메뉴 성공
# =========================================
# 후덜덜 돼지 + 모듬(돈가스+떡갈비+왕새우+소세지+군만두)
# 음식 정보 성공
# =========================================
# 15900
# 음식 가격 성공
# =========================================
# 매콤닭강정 도시락
# 음식 메뉴 성공
# =========================================
# 매콤한 닭강정 도시락
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 아사삭 돈가스
# 음식 메뉴 성공
# =========================================
# 국내산 돼지고기 등심으로 주문즉시 바삭하게 튀겨낸 돈가스와 해쉬브라운
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 카레돈가스 도시락
# 음식 메뉴 성공
# =========================================
# 카레와 돈가스
# 음식 정보 성공
# =========================================
# 7000
# 음식 가격 성공
# =========================================
# 치즈스틱(4ea)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 후덜덜직화1인 정식세트
# 음식 메뉴 성공
# =========================================
# 후덜덜돼지직화도시락 + 리코타발사믹샐러드 + 오늘의3종반찬 + 김치찌개
# 음식 정보 성공
# =========================================
# 17000
# 음식 가격 성공
# =========================================
# 콜라(355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---6번 식당파싱 시작 ---
# 서울 강남구 역삼동 817-26 1,2층
# 주소 뽑기 성공
# =========================================
#
#
#
# 식신로드, 생생정보, 생방송오늘저녁 등 각종 방송 및 입에서 입으로 이미 검증된 강남 맛집, 이제 백억하누의 음식을 푸드플라이를 통해 집에서 편하게 접하실 수 있습니다.
# 항상 고객이 만족하실수 있는 음식 및 서비스로 고객님을 모시겠습니다.
# 백억하누 강남 본점 많이 이용해주세요^^
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# *쌀 : 국내산*소고기 : 국내산 한우*갈비탕 : 미국산*전복 : 국내산*김치 : 국내산*누룽지 : 국내산*김치찌개 배추김치 : 중국산*돼지고기 : 목전지 미국산, 삼겹 독일산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [신메뉴]
# 음식 카테고리 성공
# =========================================
# [식사메뉴]
# 음식 카테고리 성공
# =========================================
# [갈비탕&냉면]
# 음식 카테고리 성공
# =========================================
# [육류]
# 음식 카테고리 성공
# =========================================
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# 1++한우차돌박이 (2인분)
# 음식 메뉴 성공
# =========================================
# 기본반찬 5종 + 추가반찬 3종 서비스식사 및 안주로 최고! 정육점에서도 찾기 힘든 우리나라 최고급 차돌박이를 집에서 즐기실 수 있습니다.
# 음식 정보 성공
# =========================================
# 38000
# 음식 가격 성공
# =========================================
# 백억 특정식
# 음식 메뉴 성공
# =========================================
# 한우불고기 + 한우된장찌개 + 고등어구이 (2인기준 1마리) + 추가반찬 3종
# 음식 정보 성공
# =========================================
# 17500
# 음식 가격 성공
# =========================================
# 백억 영양 전복갈비탕
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 15500
# 음식 가격 성공
# =========================================
# 한우 육회 (200g)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 24900
# 음식 가격 성공
# =========================================
# 새알만두 (10pcs)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2500
# 음식 가격 성공
# =========================================
# [신메뉴]
# [식사메뉴]
# [갈비탕&냉면]
# [육류]
# [사이드메뉴]
# [음료]
# 음식 카테고리 성공
# =========================================
# 1++한우차돌박이 (2인분)
# 음식 메뉴 성공
# =========================================
# 기본반찬 5종 + 추가반찬 3종 서비스식사 및 안주로 최고! 정육점에서도 찾기 힘든 우리나라 최고급 차돌박이를 집에서 즐기실 수 있습니다.
# 음식 정보 성공
# =========================================
# 38000
# 음식 가격 성공
# =========================================
# 백억 특정식
# 음식 메뉴 성공
# =========================================
# 한우불고기 + 한우된장찌개 + 고등어구이 (2인기준 1마리) + 추가반찬 3종
# 음식 정보 성공
# =========================================
# 17500
# 음식 가격 성공
# =========================================
# 백억 영양 전복갈비탕
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 15500
# 음식 가격 성공
# =========================================
# 한우 육회 (200g)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 24900
# 음식 가격 성공
# =========================================
# 새알만두 (10pcs)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2500
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 서울 강남구 역삼동 642-1
# 주소 뽑기 성공
# =========================================
#
# 대한민국 대표 찜닭 브랜드 봉추찜닭!!!더이상 말이 필요없는 그곳!!!최고의 찜닭을 이제 원하는곳에서도 드실수 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 닭,쌀,고추,배추 : 국내산김치고춧가루 : 국내산,중국산혼합강황떡: 쌀  국내산치즈알떡: 치즈  호주산
#
# 가게 원산지 뽑기 성공
# =========================================
# 22000
# 최소 금액 성공
# =========================================
# [찜닭]
# 음식 카테고리 성공
# =========================================
# [공기밥]
# 음식 카테고리 성공
# =========================================
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# [음료수]
# 음식 카테고리 성공
# =========================================
# 찜닭(대, 4~5인분)
# 음식 메뉴 성공
# =========================================
# 동치미 4그릇이 제공됩니다.메뉴 특성상 면이 불거나, 국물이 줄어들 수 있습니다.
# 음식 정보 성공
# =========================================
# 48000
# 음식 가격 성공
# =========================================
# 공깃밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# 치즈알떡추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 사이다
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# [찜닭]
# [공기밥]
# [추가 메뉴]
# [음료수]
# 음식 카테고리 성공
# =========================================
# 찜닭(대, 4~5인분)
# 음식 메뉴 성공
# =========================================
# 동치미 4그릇이 제공됩니다.메뉴 특성상 면이 불거나, 국물이 줄어들 수 있습니다.
# 음식 정보 성공
# =========================================
# 48000
# 음식 가격 성공
# =========================================
# 공깃밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# 치즈알떡추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 사이다
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---8번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하1층
# 주소 뽑기 성공
# =========================================
#
# 돼지런은 매일매일 공수하는 생삼겹의 풍미를 높이기 위해
# 생 로즈마리, 월계수, 올리브 유 등 다양한 허브를 넣고조리합니다.
#
# 고기가 맛있는 최적의 온도인 -2도에서 고기전용 숙성고로 숙성하며,
# 때문에 저희 고기의 풍미는 다른 곳과는 다르다고 자부합니다.
#
# 숙성육의 풍미와 감칠맛을 가장 잘 느낄 수 있는 다양한 소스와
# 식사도 돼지런의 또 다른 자랑입니다.
#
# 또한, Chef 의 노하우가 들어간 볶은 천일염 마늘소금, 볶음 쌈장, 생와사비 등
# 고기를 맛있게 즐기실 수 있는 소스를 더하였습니다.
#
# 이제, 더 맛있는 허브 숙성 돼지고기를집에서 즐겨보세요.
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# * 배추김치(중국산)* 고춧가루(중국산)* 쌀(국내산)* 삼겹살 (캐나다산)* 목살 (국내산, 캐나다산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [숙성 돼지고기]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [돼지런 X 종선이네 Collaboration]
# 음식 카테고리 성공
# =========================================
# [돼지런 X 미듬영농조합 (한정판매)]
# 음식 카테고리 성공
# =========================================
# 허브 숙성 삼겹살 세트 (250g)
# 음식 메뉴 성공
# =========================================
# 고기+김치찌개+쌀밥+반찬세트 (볶음김치,매실부추 파절이, 수제 짱아찌, 무쌈),소스 3종 (수제쌈장, 볶은 천일염, 와사비), 캔콜라
# 음식 정보 성공
# =========================================
# 15500
# 음식 가격 성공
# =========================================
# 깍두기 볶음밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 간장 닭강정 (반마리)
# 음식 메뉴 성공
# =========================================
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 우리쌀 단팥빵
# 음식 메뉴 성공
# =========================================
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식 정보 성공
# =========================================
# 2500
# 음식 가격 성공
# =========================================
# [숙성 돼지고기]
# [사이드]
# [음료]
# [돼지런 X 종선이네 Collaboration]
# [돼지런 X 미듬영농조합 (한정판매)]
# 음식 카테고리 성공
# =========================================
# 허브 숙성 삼겹살 세트 (250g)
# 음식 메뉴 성공
# =========================================
# 고기+김치찌개+쌀밥+반찬세트 (볶음김치,매실부추 파절이, 수제 짱아찌, 무쌈),소스 3종 (수제쌈장, 볶은 천일염, 와사비), 캔콜라
# 음식 정보 성공
# =========================================
# 15500
# 음식 가격 성공
# =========================================
# 깍두기 볶음밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 간장 닭강정 (반마리)
# 음식 메뉴 성공
# =========================================
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 우리쌀 단팥빵
# 음식 메뉴 성공
# =========================================
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식 정보 성공
# =========================================
# 2500
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---9번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하1층
# 주소 뽑기 성공
# =========================================
#
# 투박하지만 정성이 가득한 한국인의 밥상은
# 최근엔 그 맛과 멋, 그리고 풍부한 영양소로 전세계적으로 사랑을 받고 있습니다.
# 그 중에서도 돼지, 소 불고기 백반은 직장인, 남녀요소가 즐겨먹는 한국인의 대표적인 식사메뉴 입니다.
# 호작도는 조선시대, 복을 기원하며 선물하는 그림이었고 화가들도 먹여 살렸던 그림이었다고 합니다.
# 한국인의 대표적인 ‘한끼 식사＇인 불백에 대표적인 좋은 기운과 복의 상징인 호랑이의 좋은 기운을 담았습니다.
# 호작도의 좋은 의미처럼 저희 호랑이 불백도 매일매일의 식사에 좋은 기운과 건강, 행운이 가득하시길 바라는마음에서 정성껏 만들었습니다.
# 한국인의 대표적인 한끼식사인 불백에 좋은 기운과 건강, 복의 상징인 호작도의 의미를 담았습니다.
# 호랑이 불백의 한끼 식사는 직접 숙성된 장으로 만든 불백, 찌개, 약고추장, 들기름, 고급쌀 등 다양한 영양소와 좋은재료가 가득합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 불백, 덮밥 (돼지고기 : 미국산)불백, 덮밥 (소고기 : 호주산, 미국산)황태 : 러시아산쭈꾸미 : 베트남산쌀(국내산)고추 가루(중국산)/ 김치 (중국산) / 두부(국내산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [불백덮밥]
# 음식 카테고리 성공
# =========================================
# [스폐셜불백]
# 음식 카테고리 성공
# =========================================
# [찜닭갈비]
# 음식 카테고리 성공
# =========================================
# [찌개세트]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# 고추장 제육 덮밥
# 음식 메뉴 성공
# =========================================
# 덮밥 + 반찬3종 + 북엇국 + 약고추장 + 미니약과
# 음식 정보 성공
# =========================================
# 7800
# 음식 가격 성공
# =========================================
# 고추장 돼지 불백 (300g)
# 음식 메뉴 성공
# =========================================
# 돼지불백+반찬3종+밥+북엇국+미니약과
# 음식 정보 성공
# =========================================
# 10800
# 음식 가격 성공
# =========================================
# 마늘간장 찜닭갈비
# 음식 메뉴 성공
# =========================================
# 찜닭갈비 + 반찬3종 + 북엇국 + 밥 + 미니약과 + 쌈야채
# 음식 정보 성공
# =========================================
# 10800
# 음식 가격 성공
# =========================================
# 황태 콩나물국 세트
# 음식 메뉴 성공
# =========================================
# 찌개+반찬3종+밥+미니약과
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 코카콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# [불백덮밥]
# [스폐셜불백]
# [찜닭갈비]
# [찌개세트]
# [음료]
# 음식 카테고리 성공
# =========================================
# 고추장 제육 덮밥
# 음식 메뉴 성공
# =========================================
# 덮밥 + 반찬3종 + 북엇국 + 약고추장 + 미니약과
# 음식 정보 성공
# =========================================
# 7800
# 음식 가격 성공
# =========================================
# 고추장 돼지 불백 (300g)
# 음식 메뉴 성공
# =========================================
# 돼지불백+반찬3종+밥+북엇국+미니약과
# 음식 정보 성공
# =========================================
# 10800
# 음식 가격 성공
# =========================================
# 마늘간장 찜닭갈비
# 음식 메뉴 성공
# =========================================
# 찜닭갈비 + 반찬3종 + 북엇국 + 밥 + 미니약과 + 쌈야채
# 음식 정보 성공
# =========================================
# 10800
# 음식 가격 성공
# =========================================
# 황태 콩나물국 세트
# 음식 메뉴 성공
# =========================================
# 찌개+반찬3종+밥+미니약과
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 코카콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---10번 식당파싱 시작 ---
# 서울 강남구 논현동 198-12 1층
# 주소 뽑기 성공
# =========================================
#
# [유쾌한 사람들이 만드는 '유쾌한접시']는 국내산 한우 육회전문점입니다.
# '앞으로 천천히 걸어 가더라도 뒤로는 걷지 말자'는 경영이념을 바탕으로 2007년 처음 문을 열어 치열한 자영업계의 생존경쟁에서도 폐점율없이현재 신사, 신논현, 논현, 대치, 방배동에 다섯개의 직영 매장을 운영하고 있으며 직원들의 유쾌함과 한땀한땀의 노력으로 남녀노소 누구에게나 꾸준한 사랑을 이어가고 있습니다.얼리지 않은 최상급 국내산 한우 육회를 비롯해 건강한 재료들을 사용한 한식 메뉴 개발, 가장 맛있고 건강한 음식으로 한식 세계화에 한 걸음씩 다가서기 위한 유쾌한접시의 끊임없는 노력은 계속 되고 있습니다.
# 많은 이용 바랍니다.
# 감사합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 소고기 : 국내산 한우,돼지고기김치 : 중국산쌀: 미국산고춧가루: 중국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 14000
# 최소 금액 성공
# =========================================
# **************끝났따!!!!!!!!!!!!!!!!!*********************
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
len(korea_store_list)
# Out:
# 181

# %%
len(store_addresss)
# Out:
# 120

# %%
len(store_info_list)
# Out:
# 120

# %%
len(store_origin_infos)
# Out:
# 120

# %%
len(store_moneyss)
# Out:
# 120

# %%
len(store_menu_category)
# Out:
# 52

# %%
len(store_menus)
# Out:
# 2310

# %%
len(store_prices)
# Out:
# 2310

# %%
len(store_descriptions)
# Out:
# 2310

# %%
# DB 삭제
# Store.objects.all().delete()

num = 1
for col in korea_store_list:
    store = Store.objects.create(
        pk=num,
#         store_category=1,
        name=col,
        store_info=store_info_list[korea_store_list.index(col)],
        origin_info=store_origin_infos[korea_store_list.index(col)],
        owner=User.objects.get(pk=2),
        least_cost=store_moneyss[korea_store_list.index(col)],
    )
    FoodCategory.objects.create(name=1, store=store)
    num += 1
    
    

    print(col)
# Out:
# (120, {'store.StoreImage': 0, 'store.Store': 120})

# %% [markdown]
# ## 다시 시작!

# %% [markdown]
# ## 한식 시작!

# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 한식[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[2]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 40:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 한식 데이터(이미지) 수집
# soup = BeautifulSoup(html, 'lxml')
# img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
# count = 1
# for i in img:
#     img_url = i.get_text("url", strip=True)
#     img_url_parse = img_url[4:-1]
#     urllib.request.urlretrieve(img_url_parse, f'{count}.korea_food_img.jpg')
#     count += 1

# 한식 데이터(식당명) 수집
korea_store_list = []
korea_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in korea_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(korea_store_list):
    print(i, name)


    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 11:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')

    store_details_menu = soup.select('.left-section > .menu-category')
    for menu in store_details_menu:
        # 음식 메뉴
        store_menu = menu.select_one(".pull-left").find_next('strong').get_text(strip=True)
#         store_menus.append(store_menu)
        print(store_menu)
        print('음식 메뉴 성공')
        print('=========================================')

        # 음식 정보
        store_description = menu.select_one('.pull-left > span').get_text("", strip=True)
#         store_descriptions.append(store_description)
        print(store_description)
        print('음식 정보 성공')
        print('=========================================')

        # 음식 가격
        store_price = menu.select_one("span.calculate-price").get_text(strip=True)
        a = re.split(',', store_price)
        aprice = ''
        for i in a:
            aprice += i
        price = int(aprice)
#         store_prices.append(price)
        print(price)
        print('음식 가격 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='한식',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=1),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
    # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
    print('음식 카테고리 성공')
    print('=========================================')
    
    for menu in store_details_menu:
        # 음식 메뉴
        store_menu = menu.select_one(".pull-left").find_next('strong').get_text(strip=True)
#         store_menus.append(store_menu)
        print(store_menu)
        print('음식 메뉴 성공')
        print('=========================================')

        # 음식 정보
        store_description = menu.select_one('.pull-left > span').get_text("", strip=True)
#         store_descriptions.append(store_description)
        print(store_description)
        print('음식 정보 성공')
        print('=========================================')

        # 음식 가격
        store_price = menu.select_one("span.calculate-price").get_text(strip=True)
        a = re.split(',', store_price)
        aprice = ''
        for i in a:
            aprice += i
        price = int(aprice)
#         store_prices.append(price)
        print(price)
        print('음식 가격 성공')
        print('=========================================')
    
        Food.objects.create(
            category=food_category,
            name=store_menu,
            price=price,
            food_info=store_description,
        )
    
    
        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)


print('**************끝났따!!!!!!!!!!!!!!!!!*********************')
driver.close()
      
    
#     print('================== 가게 하나 끝 ==================')
    # 팝업나올시 해결

# 한식 데이터(식당명) 수집
print(korea_store_list)
# 가게주소
print(store_addresss)
# 가게 소개
print(store_info_list)
# 가게 원산지 정보
print(store_origin_infos)
# 가게 최소금액
print(store_moneyss)
# 가게 음식 카테고리
print(store_menu_category)
# 가게 음식 메뉴
print(store_menus)
# 음식 가격
print(store_prices)
# 음식 정보
print(store_descriptions)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:80: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-6 전원빌딩 지하 1층
# 주소 뽑기 성공
# =========================================
#
# [CHEFLY] 당신만을 위한 셰프의 한끼
#
# 대한민국 대표 셰프들의 요리를
# 온라인주문+즉시조리+즉시배송으로
# 원하는 시간과 장소에서 편하게 즐기실 수 있는
# 신개념 온라인 음식배달 서비스입니다
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# [메인메뉴_완조리]
#
# 단짠단짠 밥도둑 연어새우장 덮밥:새우 (에콰도르), 연어 (노르웨이산), 계란(국내산)
# 피타브래드에 싸먹는 허니갈릭 닭가슴살 시저샐러드:로메인(국내산), 닭가슴살(국내산), 계란(국내산), 베이컨(수입산), 디종머스터드(미국산)
# 특제간장으로 맛을 살린여수 새꼬막비빔밥 :새꼬막(국내산), 채소류(국내산, 중국산), 고춧가루(국내산)
# 스파이시 마살라 쉬림프를 올린 동남아풍 레드커리 :새우(베트남산), 채소류(국내산, 중국산), 레드커리페이스트(태국산), 휘핑크림(국내산)
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또 : 닭다리살(브라질산), 치킨파우더(대만산), 잡곡(국내산), 고르곤졸라(이탈리아산)
# 매콤한 낙지 콩나물비빔밥 : 쌀(국내산), 낙지(중국산), 채소류(국내산)
# 그라나파다노를 곁들인 닭다리살 김치볶음밥 :김치(국내산), 쌀(국내산), 계란(국내산), 채소류(국내산), 정육(브라질산), 그라나파다노(이탈리아산), 트러플오일(이탈리아산), 굴소스(홍콩산), 두반장(중국산)
# 소불고기 궁중 비빔밥 '골동반' :소고기(호주산), 계란(국내산), 시금치(국내산), 튀각(국내산), 쌀(국내산), 미역(국내산), 고사리(중국산), 당근(중국산), 청포묵(중국산), 숙주(중국산), 은행(중국산)
# 국내산 생등심 돈가츠 덮밥 '가츠동' :돼지등심(국내산), 계란(국내산), 쌀(국내산), 채소류(국내산), 간장(일본산), 단무지(중국산), 락교(중국산)
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# 단짠단짠 밥도둑 연어새우장 덮밥
# 음식 카테고리 성공
# =========================================
# 피타브래드에 싸먹는 허니갈릭 닭가슴살 시저샐러드
# 음식 카테고리 성공
# =========================================
# 특제간장으로 맛을 살린 여수 새꼬막비빔밥
# 음식 카테고리 성공
# =========================================
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또
# 음식 카테고리 성공
# =========================================
# 매콤한 낙지 콩나물 비빔밥
# 음식 카테고리 성공
# =========================================
# 그라나파다노를 곁들인 닭다리살 김치볶음밥
# 음식 카테고리 성공
# =========================================
# 소불고기 궁중 비빔밥 '골동반'
# 음식 카테고리 성공
# =========================================
# 국내산 생등심 돈가츠 덮밥 '가츠동'
# 음식 카테고리 성공
# =========================================
# 영양부추무침을 곁들인 대패삼겹살 덮밥과 된장국
# 음식 카테고리 성공
# =========================================
# 스파이시 마살라 쉬림프를 올린 동남아풍 레드커리
# 음식 카테고리 성공
# =========================================
# 고소하고 상큼한 흑임자 알감자 샐러드
# 음식 메뉴 성공
# =========================================
# 버터에 노릇노릇하게 구운 알감자에 볶음 흑임자 드레싱의 고소함과 레몬 드레싱의 상큼함을 가미했습니다.포슬포슬한 알감자와 상큼한 토마토, 아삭한 브로콜리까지!지금까지 없던 맛과 멋, 건강까지 고려한 셰플리의 야심작입니다. 소소하지만 확실한 행복을 즐겨보세요~
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 단짠단짠 밥도둑 연어새우장 덮밥
# 음식 메뉴 성공
# =========================================
# ★단체주문 추천메뉴★[~20:30 주문가능]SNS를 뜨겁게 달군 자꾸만 생각나는 중독의 그 맛!특제 간장에서 잘 숙성시킨 새우와 연어를 고슬고슬하게 갓 지은 밥 위에 얹어 감칠맛나게 푸짐한 한끼를 구성했습니다.고소한 버터와 함께 계란 노른자를 톡 터뜨려 따뜻한 밥을 코팅해주고, 부드러운 연어와 탱탱한 새우를 한 숟가락 가득 떠먹어보세요.비린맛은 ZERO! 입 안에서
HEF'S TIP식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요.커리소스를 고루 부어서 잘 비벼드세요.사이드로 드린 할라피뇨는 취향에 맞게 즐겨보세요.
# 음식 정보 성공
# =========================================
# 12000
# 음식 가격 성공
# =========================================
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:253: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-6 전원빌딩 지하1층 (셰플리 강남키친과 동일)
# 주소 뽑기 성공
# =========================================
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 히말라야 핑크 솔트로 맛을 더한 오리지널 삼겹살 (200g) :삼겹살(스페인), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 향긋한 유자향을 품은 된장 삼겹구이 (200g) :삼겹살(스페인), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 매콤달콤 홍시 고추장 돼지불고기 (250g)  :앞다리살(미국), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 배즙으로 단맛을 살린 간장 돼지 불고기 (200g)  :목살(캐나다), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 특제 복분자 간장 소스에 재운 인생 LA갈비 (250g) :LA갈비(미국), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 직화 고추장 불고기 덮밥 :앞다리살(미국), 쌀(국내산), 김치(국내산)
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# 히말라야 핑크 솔트로 맛을 더한 오리지널 삼겹살 200g
# 음식 카테고리 성공
# =========================================
# 향긋한 유자향을 품은 된장 삼겹구이 200g
# 음식 카테고리 성공
# =========================================
# 매콤달콤 홍시 고추장 돼지불고기 250g
# 음식 카테고리 성공
# =========================================
# 배즙으로 단맛을 살린 간장 돼지 불고기 200g
# 음식 카테고리 성공
# =========================================
# 특제 복분자 간장 소스에 재운 인생 LA갈비 250g
# 음식 카테고리 성공
# =========================================
# 직화 고추장 불고기 덮밥
# 음식 카테고리 성공
# =========================================
# 히말라야 핑크 솔트로 맛을 더한 오리지널 삼겹살 200g
# 음식 메뉴 성공
# =========================================
# "한국인이 좋아하는 삼겹살"   남녀노소 누구나 좋아하는 삼겹살에 히말라야 핑크 소금으로 특별함을 더하였습니다.히말라야 핑크 소금은 2억년 전 히말라야의 순수함을 그대로 간직한 천연조미료로 인위적인 정제과정을 거치지 않아 간수의 쓴맛이 적어 고기의 감칠맛을 극대화 시켜 줄 뿐만 아니라, 100% 순수한 자연 암염으로 84종 이상의 각종 미네랄 성분이 포함되어 있는 깨끗하고 건강한 식재료입니다.직화 반상의 오리지널 삼겹살은 핑크 소금으로 간을 하여 삼겹살에 건강함과 특별함을 더하였습니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요.당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식 정보 성공
# =========================================
# 13000
# 음식 가격 성공
# =========================================
# 향긋한 유자향을 품은 된장 삼겹구이 200g
# 음식 메뉴 성공
# =========================================
# "유자와 된장소스의 운명적 만남"  유자 된장 소스로 고기의 잡내는 없애고 부드러운 식감은 극대화 하였습니다.유자의 껍질에 풍부한 비타민P는 혈압을 안정시키고 비타민C가 풍부한 과육에는 항산화 성분이 많기 때문에 면역력을 증가시켜주고, 혈관 벽을 튼튼하게 해줘 고혈압에도 효과적입니다.향긋한 유자향과 고소한 된장이 어우러져 독특하면서도 입안 가득 풍미를 느끼실 수 있습니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요   당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식 정보 성공
# =========================================
#
니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요.당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식 정보 성공
# =========================================
# 13000
# 음식 가격 성공
# =========================================
# 향긋한 유자향을 품은 된장 삼겹구이 200g
# 음식 메뉴 성공
# =========================================
# "유자와 된장소스의 운명적 만남"  유자 된장 소스로 고기의 잡내는 없애고 부드러운 식감은 극대화 하였습니다.유자의 껍질에 풍부한 비타민P는 혈압을 안정시키고 비타민C가 풍부한 과육에는 항산화 성분이 많기 때문에 면역력을 증가시켜주고, 혈관 벽을 튼튼하게 해줘 고혈압에도 효과적입니다.향긋한 유자향과 고소한 된장이 어우러져 독특하면서도 입안 가득 풍미를 느끼실 수 있습니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요   당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식 정보 성공
# =========================================
# 14000
# 음식 가격 성공
# =========================================
# 매콤달콤 홍시 고추장 돼지불고기 250g
# 음식 메뉴 성공
# =========================================
# "고추장에 빠진 홍시의 완벽한 하모니"  매~콤한 특제 고추장에 맛있게 익은 홍시를 갈아 넣어 감칠맛 나는 단맛을 더하였습니다.홍시는 자외선으로부터 눈세포를 보호하는 성분과 비타민A와 비타민C가 풍부해 감기를 예방하며 면역력을 높여주고 숙취해소에 탁월한 역할을 합니다.24시간 저온 숙성으로 양념 맛이 깊게 배어들게 하여 불 맛나게 구웠습니다. 홍시의 달콤함과 고추장의 매콤함이 조화롭게 어우러지는 직화 불고기입니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요.당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식 정보 성공
# =========================================
# 13000
# 음식 가격 성공
# =========================================
# 배즙으로 단맛을 살린 간장 돼지 불고기 200g
# 음식 메뉴 성공
# =========================================
# "기사식당의 돼지불백 맛 그대로"  국적불문, 남녀노소 누구나 좋아하는 불고기! 인위적인 연육제를 사용하지 않아 건강함을 더하였습니다.배를 갈아 만든 달짝지근한 특제 간장 소스에 숙성하여 부드러운 고기를 불 맛나게 직화로 구운 불고기입니다.맛있으면서도 건강한 한 상, 특히 아이들이 너무나 사랑하는 메뉴입니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요.당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식 정보 성공
# =========================================
# 14000
# 음식 가격 성공
# =========================================
# 특제 복분자 간장 소스에 재운 인생 LA갈비 250g
# 음식 메뉴 성공
# =========================================
# "특제소스에 재워 부드럽고 달달한 인생 LA갈비"  장시간 숙성으로 양념이 충분히 배어들어 육질은 부드럽게, 맛은 더 풍부하게복분자에는 항산화 물질인 폴리페놀과 안토시아닌이 함유되어 노화를 방지해주고 항암효과에 탁월합니다.복분자를 포함한 15가지의 재료로 맛을 낸 특제 양념과 직화반상만의 특별한 레시피로 맛의 깊이를 더욱 풍부하게 만들었습니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요.당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식 정보 성공
# =========================================
# 19000
# 음식 가격 성공
# =========================================
# 직화 고추장 불고기 덮밥
# 음식 메뉴 성공
# =========================================
# "매콤달콤한 홍시 고추장 불고기와 각종 야채의 환상적 조화＂ 직화반상의 마약같은 홍시 고추장 불고기!누~구나 좋아하는 고추장 불고기를 직화로 구워 불맛을 살리고 향긋한 미나리, 갖은 야채를 곁들여 든든한 한끼를 준비했습니다.직화반상's TIP함께 제공된 국과 김치를 곁들여 드세요.식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요.국은 용기에 덜어 전자레인지에 넣어주세요.
# 음식 정보 성공
# =========================================
# 11000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 강남구 역삼동 831-6 1층
# 주소 뽑기 성공
# =========================================
#
# 따뜻함, 건강함, 편리함을 추구하는 아시아 누들&라이스 레스토랑으로 아시아 각 지역의 특색 있는 요리를 선보입니다.
# 길거리와 먹거리라는 단어를 조합한 스트릿(strEAT)에서는 규동, 카라이멘, 오니기리 등 심플함과 정직함으로 만들어진 메뉴에
# 각국 아시아의 고유 문화와 맛을 담아냈으며, 푸드플라이를 통해 어디서나 간편하게 건강한 식사를 즐길 수 있습니다.
#
# (배달 시 매장에서 나가는 영수증으로 해피포인트 2% 적립이 가능합니다.)
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀_국내산대만식 돼지 조림 덮밥(돼지고기_독일산)명란 아보카도 덮밥(돼지고기, 두부, 명란_국내산)대만식 마늘쫑 볶음 덮밥(돼지고기_국내산)해산물 날치알 볶음밥(오징어_중국산)삼겹 철판구이(돼지고기_독일산/갈치(양념젓갈),명란_국내산)야채 고로케(돼지고기_국내산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [라이스&누들]
# 음식 카테고리 성공
# =========================================
# [철판구이]
# 음식 카테고리 성공
# =========================================
# 대만식 돼지 조림 덮밥
# 음식 메뉴 성공
# =========================================
# 오향, 팔각 등의 향이 진하게 우러나온 돼지고기 조림에 간장 맛을 들인 달걀과 볶은 청경채를 함께 곁들여 먹는 대만식 조림 덮밥
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 삼겹 철판구이
# 음식 메뉴 성공
# =========================================
# 철판에서 구워내 불맛이 살아있는 삼겹살에 명란, 와사비, 갈치 속젓의 삼합 소스까지 곁들여 더 맛있는 구이 메뉴*17시부터 주문 가능*
# 음식 정보 성공
# =========================================
# 21000
# 음식 가격 성공
# =========================================
# [라이스&누들]
# [철판구이]
# 음식 카테고리 성공
# =========================================
# 대만식 돼지 조림 덮밥
# 음식 메뉴 성공
# =========================================
# 오향, 팔각 등의 향이 진하게 우러나온 돼지고기 조림에 간장 맛을 들인 달걀과 볶은 청경채를 함께 곁들여 먹는 대만식 조림 덮밥
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 삼겹 철판구이
# 음식 메뉴 성공
# =========================================
# 철판에서 구워내 불맛이 살아있는 삼겹살에 명란, 와사비, 갈치 속젓의 삼합 소스까지 곁들여 더 맛있는 구이 메뉴*17시부터 주문 가능*
# 음식 정보 성공
# =========================================
# 21000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 강남구 역삼동 836 한스빌상가 1층
# 주소 뽑기 성공
# =========================================
#
# 49년 역사를 자랑하는 '연탄초벌구이점 십원집'니다.
# 반세기전부터 이어져 내려오는 십원집만의 비법,
# 한국인 전통의 푸근한 인정이 넘치는 십원집은 언제나 양심적인 가격으로 모시겠습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# *삼겹살;독일산산 *불고기;미국산  *족발;스페인산  *닭발;국내산+덴마크산  *막창;미국산  *곰창;국내산  *황태;러시아산  *오징어;국내산  *쭈꾸미;베트남산  *돼지갈비;미국산+스페인산 *미꾸라지;국내산  *쌀;국내산  *김치;중국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 20000
# 최소 금액 성공
# =========================================
# [연탄불고기 도시락]
# 음식 카테고리 성공
# =========================================
# [연탄불고기/삼겹살 SET]
# 음식 카테고리 성공
# =========================================
# [연탄매운족발/닭발/곱창/막창 SET]
# 음식 카테고리 성공
# =========================================
# [연불냉면]
# 음식 카테고리 성공
# =========================================
# [찌개]
# 음식 카테고리 성공
# =========================================
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# 연탄불고기 도시락
# 음식 메뉴 성공
# =========================================
# 연탄불고기 + 김치찌개 + 쌈야채 + 공깃밥 + 기타반찬
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 연탄불고기 (400g, 2인분)set
# 음식 메뉴 성공
# =========================================
# 연탄불고기400g/2인분+쌈야채(2인분)+김치찌개+계란찜+공깃밥(2인분)
# 음식 정보 성공
# =========================================
# 23000
# 음식 가격 성공
# =========================================
# 연탄매운족발 set
# 음식 메뉴 성공
# =========================================
# 연탄매운족발 (350g) + 셀프주먹밥 (1인분) + 계란찜
# 음식 정보 성공
# =========================================
# 20000
# 음식 가격 성공
# =========================================
# 연불 물냉면
# 음식 메뉴 성공
# =========================================
# 연탄불고기(150g) + 물냉면
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 김치찌개만 (1인분)
# 음식 메뉴 성공
# =========================================
# 완조리공깃밥 별도기본반찬은 제공되지 않습니다.
# 음식 정보 성공
# =========================================
# 7000
# 음식 가격 성공
# =========================================
# 계란찜
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 4000
# 음식 가격 성공
# =========================================
# [연탄불고기 도시락]
# [연탄불고기/삼겹살 SET]
# [연탄매운족발/닭발/곱창/막창 SET]
# [연불냉면]
# [찌개]
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# 연탄불고기 도시락
# 음식 메뉴 성공
# =========================================
# 연탄불고기 + 김치찌개 + 쌈야채 + 공깃밥 + 기타반찬
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 연탄불고기 (400g, 2인분)set
# 음식 메뉴 성공
# =========================================
# 연탄불고기400g/2인분+쌈야채(2인분)+김치찌개+계란찜+공깃밥(2인분)
# 음식 정보 성공
# =========================================
# 23000
# 음식 가격 성공
# =========================================
# 연탄매운족발 set
# 음식 메뉴 성공
# =========================================
# 연탄매운족발 (350g) + 셀프주먹밥 (1인분) + 계란찜
# 음식 정보 성공
# =========================================
# 20000
# 음식 가격 성공
# =========================================
# 연불 물냉면
# 음식 메뉴 성공
# =========================================
# 연탄불고기(150g) + 물냉면
# 음식 정보 성공
# =========================================
# 8000
# 음식 가격 성공
# =========================================
# 김치찌개만 (1인분)
# 음식 메뉴 성공
# =========================================
# 완조리공깃밥 별도기본반찬은 제공되지 않습니다.
# 음식 정보 성공
# =========================================
# 7000
# 음식 가격 성공
# =========================================
# 계란찜
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 4000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 강남구 역삼동 837-26 삼일프라자 1층
# 주소 뽑기 성공
# =========================================
#
# 한끼든든 퓨전 한식 수제직화도시락!!
# 직화락은 직화제육볶음과 직화오징어볶음을 메인으로 하는 직화볶음요리 전문점, 직화도시락 입니다.
# 직화도시락과 더불어 다양한 도시락을 즐겨보세요.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 오징어,쌀,계란,돈가스,떡갈비,닭고기 : 국내산돼지고기 : 미국산     김치 : 국내산,중국산고추가루: 중국산 국내산혼합양배추 .파. 양파: 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [직화류]
# 음식 카테고리 성공
# =========================================
# [직화플러스토핑류]
# 음식 카테고리 성공
# =========================================
# [볶음만따로]
# 음식 카테고리 성공
# =========================================
# [프리미엄]
# 음식 카테고리 성공
# =========================================
# [그외]
# 음식 카테고리 성공
# =========================================
# [돈가스류]
# 음식 카테고리 성공
# =========================================
# [카레류]
# 음식 카테고리 성공
# =========================================
# [스낵]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# 후덜덜 돼지
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 (with 계란후라이와 볶음김치, 옛날소세지와 고기위에 파채!!)
# 음식 정보 성공
# =========================================
# 6900
# 음식 가격 성공
# =========================================
# 후덜덜 (돼지) + 스팸 도시락
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 + 스팸
# 음식 정보 성공
# =========================================
# 7100
# 음식 가격 성공
# =========================================
# 후덜덜 1Box
# 음식 메뉴 성공
# =========================================
# 밥을 제외하고 직화제육볶음만 들어간 메뉴입니다.
# 음식 정보 성공
# =========================================
# 10900
# 음식 가격 성공
# =========================================
# 한끼라도 후덜덜
# 음식 메뉴 성공
# =========================================
# 후덜덜 돼지 + 모듬(돈가스+떡갈비+왕새우+소세지+군만두)
# 음식 정보 성공
# =========================================
# 15900
# 음식 가격 성공
# =========================================
# 매콤닭강정 도시락
# 음식 메뉴 성공
# =========================================
# 매콤한 닭강정 도시락
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 아사삭 돈가스
# 음식 메뉴 성공
# =========================================
# 국내산 돼지고기 등심으로 주문즉시 바삭하게 튀겨낸 돈가스와 해쉬브라운
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 카레돈가스 도시락
# 음식 메뉴 성공
# =========================================
# 카레와 돈가스
# 음식 정보 성공
# =========================================
# 7000
# 음식 가격 성공
# =========================================
# 치즈스틱(4ea)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 후덜덜직화1인 정식세트
# 음식 메뉴 성공
# =========================================
# 후덜덜돼지직화도시락 + 리코타발사믹샐러드 + 오늘의3종반찬 + 김치찌개
# 음식 정보 성공
# =========================================
# 17000
# 음식 가격 성공
# =========================================
# 콜라(355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# [직화류]
# [직화플러스토핑류]
# [볶음만따로]
# [프리미엄]
# [그외]
# [돈가스류]
# [카레류]
# [스낵]
# [세트메뉴]
# [음료]
# 음식 카테고리 성공
# =========================================
# 후덜덜 돼지
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 (with 계란후라이와 볶음김치, 옛날소세지와 고기위에 파채!!)
# 음식 정보 성공
# =========================================
# 6900
# 음식 가격 성공
# =========================================
# 후덜덜 (돼지) + 스팸 도시락
# 음식 메뉴 성공
# =========================================
# 직화로 요리한 매콤한 제육볶음 + 스팸
# 음식 정보 성공
# =========================================
# 7100
# 음식 가격 성공
# =========================================
# 후덜덜 1Box
# 음식 메뉴 성공
# =========================================
# 밥을 제외하고 직화제육볶음만 들어간 메뉴입니다.
# 음식 정보 성공
# =========================================
# 10900
# 음식 가격 성공
# =========================================
# 한끼라도 후덜덜
# 음식 메뉴 성공
# =========================================
# 후덜덜 돼지 + 모듬(돈가스+떡갈비+왕새우+소세지+군만두)
# 음식 정보 성공
# =========================================
# 15900
# 음식 가격 성공
# =========================================
# 매콤닭강정 도시락
# 음식 메뉴 성공
# =========================================
# 매콤한 닭강정 도시락
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 아사삭 돈가스
# 음식 메뉴 성공
# =========================================
# 국내산 돼지고기 등심으로 주문즉시 바삭하게 튀겨낸 돈가스와 해쉬브라운
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 카레돈가스 도시락
# 음식 메뉴 성공
# =========================================
# 카레와 돈가스
# 음식 정보 성공
# =========================================
# 7000
# 음식 가격 성공
# =========================================
# 치즈스틱(4ea)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 후덜덜직화1인 정식세트
# 음식 메뉴 성공
# =========================================
# 후덜덜돼지직화도시락 + 리코타발사믹샐러드 + 오늘의3종반찬 + 김치찌개
# 음식 정보 성공
# =========================================
# 17000
# 음식 가격 성공
# =========================================
# 콜라(355ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---6번 식당파싱 시작 ---
# 서울 강남구 역삼동 817-26 1,2층
# 주소 뽑기 성공
# =========================================
#
#
#
# 식신로드, 생생정보, 생방송오늘저녁 등 각종 방송 및 입에서 입으로 이미 검증된 강남 맛집, 이제 백억하누의 음식을 푸드플라이를 통해 집에서 편하게 접하실 수 있습니다.
# 항상 고객이 만족하실수 있는 음식 및 서비스로 고객님을 모시겠습니다.
# 백억하누 강남 본점 많이 이용해주세요^^
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# *쌀 : 국내산*소고기 : 국내산 한우*갈비탕 : 미국산*전복 : 국내산*김치 : 국내산*누룽지 : 국내산*김치찌개 배추김치 : 중국산*돼지고기 : 목전지 미국산, 삼겹 독일산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [신메뉴]
# 음식 카테고리 성공
# =========================================
# [식사메뉴]
# 음식 카테고리 성공
# =========================================
# [갈비탕&냉면]
# 음식 카테고리 성공
# =========================================
# [육류]
# 음식 카테고리 성공
# =========================================
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# 1++한우차돌박이 (2인분)
# 음식 메뉴 성공
# =========================================
# 기본반찬 5종 + 추가반찬 3종 서비스식사 및 안주로 최고! 정육점에서도 찾기 힘든 우리나라 최고급 차돌박이를 집에서 즐기실 수 있습니다.
# 음식 정보 성공
# =========================================
# 38000
# 음식 가격 성공
# =========================================
# 백억 특정식
# 음식 메뉴 성공
# =========================================
# 한우불고기 + 한우된장찌개 + 고등어구이 (2인기준 1마리) + 추가반찬 3종
# 음식 정보 성공
# =========================================
# 17500
# 음식 가격 성공
# =========================================
# 백억 영양 전복갈비탕
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 15500
# 음식 가격 성공
# =========================================
# 한우 육회 (200g)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 24900
# 음식 가격 성공
# =========================================
# 새알만두 (10pcs)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2500
# 음식 가격 성공
# =========================================
# [신메뉴]
# [식사메뉴]
# [갈비탕&냉면]
# [육류]
# [사이드메뉴]
# [음료]
# 음식 카테고리 성공
# =========================================
# 1++한우차돌박이 (2인분)
# 음식 메뉴 성공
# =========================================
# 기본반찬 5종 + 추가반찬 3종 서비스식사 및 안주로 최고! 정육점에서도 찾기 힘든 우리나라 최고급 차돌박이를 집에서 즐기실 수 있습니다.
# 음식 정보 성공
# =========================================
# 38000
# 음식 가격 성공
# =========================================
# 백억 특정식
# 음식 메뉴 성공
# =========================================
# 한우불고기 + 한우된장찌개 + 고등어구이 (2인기준 1마리) + 추가반찬 3종
# 음식 정보 성공
# =========================================
# 17500
# 음식 가격 성공
# =========================================
# 백억 영양 전복갈비탕
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 15500
# 음식 가격 성공
# =========================================
# 한우 육회 (200g)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 24900
# 음식 가격 성공
# =========================================
# 새알만두 (10pcs)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2500
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 서울 강남구 역삼동 642-1
# 주소 뽑기 성공
# =========================================
#
# 대한민국 대표 찜닭 브랜드 봉추찜닭!!!더이상 말이 필요없는 그곳!!!최고의 찜닭을 이제 원하는곳에서도 드실수 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 닭,쌀,고추,배추 : 국내산김치고춧가루 : 국내산,중국산혼합강황떡: 쌀  국내산치즈알떡: 치즈  호주산
#
# 가게 원산지 뽑기 성공
# =========================================
# 22000
# 최소 금액 성공
# =========================================
# [찜닭]
# 음식 카테고리 성공
# =========================================
# [공기밥]
# 음식 카테고리 성공
# =========================================
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# [음료수]
# 음식 카테고리 성공
# =========================================
# 찜닭(대, 4~5인분)
# 음식 메뉴 성공
# =========================================
# 동치미 4그릇이 제공됩니다.메뉴 특성상 면이 불거나, 국물이 줄어들 수 있습니다.
# 음식 정보 성공
# =========================================
# 48000
# 음식 가격 성공
# =========================================
# 공깃밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# 치즈알떡추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 사이다
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# [찜닭]
# [공기밥]
# [추가 메뉴]
# [음료수]
# 음식 카테고리 성공
# =========================================
# 찜닭(대, 4~5인분)
# 음식 메뉴 성공
# =========================================
# 동치미 4그릇이 제공됩니다.메뉴 특성상 면이 불거나, 국물이 줄어들 수 있습니다.
# 음식 정보 성공
# =========================================
# 48000
# 음식 가격 성공
# =========================================
# 공깃밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# 치즈알떡추가
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3000
# 음식 가격 성공
# =========================================
# 사이다
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 1000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---8번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하1층
# 주소 뽑기 성공
# =========================================
#
# 돼지런은 매일매일 공수하는 생삼겹의 풍미를 높이기 위해
# 생 로즈마리, 월계수, 올리브 유 등 다양한 허브를 넣고조리합니다.
#
# 고기가 맛있는 최적의 온도인 -2도에서 고기전용 숙성고로 숙성하며,
# 때문에 저희 고기의 풍미는 다른 곳과는 다르다고 자부합니다.
#
# 숙성육의 풍미와 감칠맛을 가장 잘 느낄 수 있는 다양한 소스와
# 식사도 돼지런의 또 다른 자랑입니다.
#
# 또한, Chef 의 노하우가 들어간 볶은 천일염 마늘소금, 볶음 쌈장, 생와사비 등
# 고기를 맛있게 즐기실 수 있는 소스를 더하였습니다.
#
# 이제, 더 맛있는 허브 숙성 돼지고기를집에서 즐겨보세요.
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# * 배추김치(중국산)* 고춧가루(중국산)* 쌀(국내산)* 삼겹살 (캐나다산)* 목살 (국내산, 캐나다산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [숙성 돼지고기]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [돼지런 X 종선이네 Collaboration]
# 음식 카테고리 성공
# =========================================
# [돼지런 X 미듬영농조합 (한정판매)]
# 음식 카테고리 성공
# =========================================
# 허브 숙성 삼겹살 세트 (250g)
# 음식 메뉴 성공
# =========================================
# 고기+김치찌개+쌀밥+반찬세트 (볶음김치,매실부추 파절이, 수제 짱아찌, 무쌈),소스 3종 (수제쌈장, 볶은 천일염, 와사비), 캔콜라
# 음식 정보 성공
# =========================================
# 15500
# 음식 가격 성공
# =========================================
# 깍두기 볶음밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 간장 닭강정 (반마리)
# 음식 메뉴 성공
# =========================================
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 우리쌀 단팥빵
# 음식 메뉴 성공
# =========================================
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식 정보 성공
# =========================================
# 2500
# 음식 가격 성공
# =========================================
# [숙성 돼지고기]
# [사이드]
# [음료]
# [돼지런 X 종선이네 Collaboration]
# [돼지런 X 미듬영농조합 (한정판매)]
# 음식 카테고리 성공
# =========================================
# 허브 숙성 삼겹살 세트 (250g)
# 음식 메뉴 성공
# =========================================
# 고기+김치찌개+쌀밥+반찬세트 (볶음김치,매실부추 파절이, 수제 짱아찌, 무쌈),소스 3종 (수제쌈장, 볶은 천일염, 와사비), 캔콜라
# 음식 정보 성공
# =========================================
# 15500
# 음식 가격 성공
# =========================================
# 깍두기 볶음밥
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 3500
# 음식 가격 성공
# =========================================
# 콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# 간장 닭강정 (반마리)
# 음식 메뉴 성공
# =========================================
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식 정보 성공
# =========================================
# 9000
# 음식 가격 성공
# =========================================
# 우리쌀 단팥빵
# 음식 메뉴 성공
# =========================================
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식 정보 성공
# =========================================
# 2500
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---9번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하1층
# 주소 뽑기 성공
# =========================================
#
# 투박하지만 정성이 가득한 한국인의 밥상은
# 최근엔 그 맛과 멋, 그리고 풍부한 영양소로 전세계적으로 사랑을 받고 있습니다.
# 그 중에서도 돼지, 소 불고기 백반은 직장인, 남녀요소가 즐겨먹는 한국인의 대표적인 식사메뉴 입니다.
# 호작도는 조선시대, 복을 기원하며 선물하는 그림이었고 화가들도 먹여 살렸던 그림이었다고 합니다.
# 한국인의 대표적인 ‘한끼 식사＇인 불백에 대표적인 좋은 기운과 복의 상징인 호랑이의 좋은 기운을 담았습니다.
# 호작도의 좋은 의미처럼 저희 호랑이 불백도 매일매일의 식사에 좋은 기운과 건강, 행운이 가득하시길 바라는마음에서 정성껏 만들었습니다.
# 한국인의 대표적인 한끼식사인 불백에 좋은 기운과 건강, 복의 상징인 호작도의 의미를 담았습니다.
# 호랑이 불백의 한끼 식사는 직접 숙성된 장으로 만든 불백, 찌개, 약고추장, 들기름, 고급쌀 등 다양한 영양소와 좋은재료가 가득합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 불백, 덮밥 (돼지고기 : 미국산)불백, 덮밥 (소고기 : 호주산, 미국산)황태 : 러시아산쭈꾸미 : 베트남산쌀(국내산)고추 가루(중국산)/ 김치 (중국산) / 두부(국내산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [불백덮밥]
# 음식 카테고리 성공
# =========================================
# [스폐셜불백]
# 음식 카테고리 성공
# =========================================
# [찜닭갈비]
# 음식 카테고리 성공
# =========================================
# [찌개세트]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# 고추장 제육 덮밥
# 음식 메뉴 성공
# =========================================
# 덮밥 + 반찬3종 + 북엇국 + 약고추장 + 미니약과
# 음식 정보 성공
# =========================================
# 7800
# 음식 가격 성공
# =========================================
# 고추장 돼지 불백 (300g)
# 음식 메뉴 성공
# =========================================
# 돼지불백+반찬3종+밥+북엇국+미니약과
# 음식 정보 성공
# =========================================
# 10800
# 음식 가격 성공
# =========================================
# 마늘간장 찜닭갈비
# 음식 메뉴 성공
# =========================================
# 찜닭갈비 + 반찬3종 + 북엇국 + 밥 + 미니약과 + 쌈야채
# 음식 정보 성공
# =========================================
# 10800
# 음식 가격 성공
# =========================================
# 황태 콩나물국 세트
# 음식 메뉴 성공
# =========================================
# 찌개+반찬3종+밥+미니약과
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 코카콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# [불백덮밥]
# [스폐셜불백]
# [찜닭갈비]
# [찌개세트]
# [음료]
# 음식 카테고리 성공
# =========================================
# 고추장 제육 덮밥
# 음식 메뉴 성공
# =========================================
# 덮밥 + 반찬3종 + 북엇국 + 약고추장 + 미니약과
# 음식 정보 성공
# =========================================
# 7800
# 음식 가격 성공
# =========================================
# 고추장 돼지 불백 (300g)
# 음식 메뉴 성공
# =========================================
# 돼지불백+반찬3종+밥+북엇국+미니약과
# 음식 정보 성공
# =========================================
# 10800
# 음식 가격 성공
# =========================================
# 마늘간장 찜닭갈비
# 음식 메뉴 성공
# =========================================
# 찜닭갈비 + 반찬3종 + 북엇국 + 밥 + 미니약과 + 쌈야채
# 음식 정보 성공
# =========================================
# 10800
# 음식 가격 성공
# =========================================
# 황태 콩나물국 세트
# 음식 메뉴 성공
# =========================================
# 찌개+반찬3종+밥+미니약과
# 음식 정보 성공
# =========================================
# 6800
# 음식 가격 성공
# =========================================
# 코카콜라 (500ml)
# 음식 메뉴 성공
# =========================================
#
# 음식 정보 성공
# =========================================
# 2000
# 음식 가격 성공
# =========================================
# ===========끝===========
# ---10번 식당파싱 시작 ---
# 서울 강남구 역삼동 809-9 1층
# 주소 뽑기 성공
# =========================================
#
# 강남 논현동에 위치한 최고의 맛집
# 한우물회, 고인돌갈비 전문점
# 생생정보통, VJ특공대 등 맛집프로그램 방영
#
#
# 가게 소개 뽑기 성공
# =========================================
# 배추김치(국내산)소고기탕국,고추잡채 : 국내산(한우)쌀 : 국내산소고기(호주산)갈비살(미국산)고춧가루(국내산)수육(호주산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# **************끝났따!!!!!!!!!!!!!!!!!*********************
# []
# []
# []
# []
# []
# []
# []
# []
# []
