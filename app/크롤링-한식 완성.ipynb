# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 한식[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[2]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 40:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 한식 데이터(이미지) 수집
# soup = BeautifulSoup(html, 'lxml')
# img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
# count = 1
# for i in img:
#     img_url = i.get_text("url", strip=True)
#     img_url_parse = img_url[4:-1]
#     urllib.request.urlretrieve(img_url_parse, f'{count}.korea_food_img.jpg')
#     count += 1

# 한식 데이터(식당명) 수집
korea_store_list = []
korea_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in korea_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(korea_store_list):
    print(i, name)

    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        time.sleep(3)
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 100:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='한식',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=1),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
        print('음식 카테고리 성공')
        print('=========================================')
        
        store_category_foods = menu.select(".row-menu")

        for food in store_category_foods:
            food_menu = food.select_one(".col-menu > strong").get_text(strip=True)
            print(food_menu)
            print('음식메뉴 성공')
            print('===============')
            food_info = food.select_one(".col-menu > span").get_text(strip=True)
            print(food_info)
            print('음식정보 성공')
            print('===============')
            food_money = food.select_one("span.calculate-price").get_text(strip=True)
            food_moneys = food_money.replace(",", "")
            print(food_moneys)
            print('금액 성공')
            print('===============')
            
            Food.objects.create(
            category=food_category,
            name=food_menu,
            price=food_moneys,
            food_info=food_info,
            )

        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:79: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-6 전원빌딩 지하 1층
# 주소 뽑기 성공
# =========================================
#
# [CHEFLY] 당신만을 위한 셰프의 한끼
#
# 대한민국 대표 셰프들의 요리를
# 온라인주문+즉시조리+즉시배송으로
# 원하는 시간과 장소에서 편하게 즐기실 수 있는
# 신개념 온라인 음식배달 서비스입니다
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# [메인메뉴_완조리]
#
# 콰트로 치즈 아라비아따 볼로네제 파스타: 소고기(호주산), 치킨파우더(대만산)
# 단짠단짠 밥도둑 연어새우장 덮밥:새우(에콰도르산), 연어 (노르웨이산), 계란(국내산)
# 피타브래드에 싸먹는 허니갈릭 닭가슴살 시저샐러드:로메인(국내산), 닭가슴살(국내산), 계란(국내산), 베이컨(수입산), 디종머스터드(미국산)
# 특제간장으로 맛을 살린여수 새꼬막비빔밥 :새꼬막(국내산), 채소류(국내산, 중국산), 고춧가루(국내산)
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또 : 닭다리살(브라질산), 치킨파우더(대만산), 잡곡(국내산), 고르곤졸라(이탈리아산)
# 매콤한 낙지 콩나물비빔밥 : 쌀(국내산), 낙지(중국산), 채소류(국내산)
# 그라나파다노를 곁들인 닭다리살 김치볶음밥 :김치(국내산), 쌀(국내산), 계란(국내산), 채소류(국내산), 정육(브라질산), 그라나파다노(이탈리아산), 트러플오일(이탈리아산), 굴소스(홍콩산), 두반장(중국산)
# 소불고기 궁중 비빔밥 '골동반' :소고기(호주산), 계란(국내산), 시금치(국내산), 튀각(국내산), 쌀(국내산), 미역(국내산), 고사리(중국산), 당근(중국산), 청포묵(중국산), 숙주(중국산), 은행(중국산)
# 국내산 생등심 돈가츠 덮밥 '가츠동' :돼지등심(국내산), 계란(국내산), 쌀(국내산), 채소류(국내산), 간장(일본산), 단무지(중국산), 락교(중국산)
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# 콰트로 치즈 아라비아따 볼로네제 파스타
# 음식 카테고리 성공
# =========================================
# 단짠단짠 밥도둑 연어새우장 덮밥
# 음식 카테고리 성공
# =========================================
# 피타브래드에 싸먹는 허니갈릭 닭가슴살 시저샐러드
# 음식 카테고리 성공
# =========================================
# 특제간장으로 맛을 살린 여수 새꼬막비빔밥
# 음식 카테고리 성공
# =========================================
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또
# 음식 카테고리 성공
# =========================================
# 매콤한 낙지 콩나물 비빔밥
# 음식 카테고리 성공
# =========================================
# 그라나파다노를 곁들인 닭다리살 김치볶음밥
# 음식 카테고리 성공
# =========================================
# 소불고기 궁중 비빔밥 '골동반'
# 음식 카테고리 성공
# =========================================
# 국내산 생등심 돈가츠 덮밥 '가츠동'
# 음식 카테고리 성공
# =========================================
# 영양부추무침을 곁들인 대패삼겹살 덮밥과 된장국
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# 고소하고 상큼한 흑임자 알감자 샐러드
# 음식메뉴 성공
# ===============
# 버터에 노릇노릇하게 구운 알감자에 볶음 흑임자 드레싱의 고소함과 레몬 드레싱의 상큼함을 가미했습니다.포슬포슬한 알감자와 상큼한 토마토, 아삭한 브로콜리까지!지금까지 없던 맛과 멋, 건강까지 고려한 셰플리의 야심작입니다. 소소하지만 확실한 행복을 즐겨보세요~
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 종가집 김치 50g
# 음식메뉴 성공
# ===============
# 전통한식에 모던을 담다 '종가집' X 당신만을 위한 셰프의 한끼 '셰플리'종가집에서 관리하는 최상급 국내산 농산물을 100% 사용하였으며, 종가집 특유의 신선발효비법(유산균)으로 풍부한 감칠맛이 일품인 김치입니다.
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 오렌지 필로 풍미를 더한 수제 티라미수
# 음식메뉴 성공
# ===============
# 기분전환이 필요한 당신을 위한 셰플리만의 프리미엄 디저트.아몬드 리큐르 향 에스프레소로 적신 핑거쿠키, 마스카포네 치즈와  다크커버춰 초콜릿 위에 오렌지 필로 풍미를 더한 티라미수*원산지 : 다크커버춰(프랑스산), 마스카포네(이탈리아산), 사보이아르디(이탈리아산), 계란(국내산), 생크림(국내산), 오렌지(미국산), 리큐르(네덜란드산)
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 반숙계란 니스와즈 샐러드
# 음식메뉴 성공
# ===============
# 올리브, 그린빈, 알감자, 참치 등 각종 건강 재료에 와인비니거로 제조한 프렌치 드레싱과 반숙계란을 곁들인 프랑스 니스 풍의 지중해식 샐러드*원산지 : 그린빈(중국산), 감자(국내산), 블랙올리브(스페인산), 계란(국내산), 참치(우너양산), 로메인(국내산), 방울토마토(국내산)
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 고소한 명란마요 밥
# 음식메뉴 성공
# ===============
# 밥도둑의 대명사 명란과 고소한 참기름, 김가루로 입맛을 살릴 셰플리 첫 한식 사이드 메뉴*원산지 : 쌀 (국내산), 명란 (러시아산)
# 음식정보 성공
# ===============
# 2700
# 금액 성공
# ===============
# 명란마요소스 치킨 가라아게(5조각)
# 음식메뉴 성공
# ===============
# 겉은 바삭하고 속은 촉촉하게 튀겨낸 닭다리살을 명란과 마요네즈 등으로 셰프가 직접 배합하여 만든 특제 소스에 찍어먹는 일본 대표 가정식*원산지 :정육(태국산), 명란(러시아산)
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 트러플향 감자튀김
# 음식메뉴 성공
# ===============
# 세계 3대 진미 중 하나인 트러플의 향을 느끼실 수 있는 감자튀김고소하고 짭조름한 맛은 맥주와 함께 드실 때에 더 맛있습니다(케첩 없이도 맛있게 드실 수 있습니다)*원산지 : 감자튀김(미국산), 트러플오일(이탈리아산)
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 뉴욕식 버팔로윙(5조각)
# 음식메뉴 성공
# ===============
# 셰플리가 직접 배합한 뉴욕식 바베큐소스를 하나하나 정성껏 발라 구운 뒤 파슬리와 아몬드로 마무리하여 고소하고 매콤달콤한 맛이 특징인 오리지널 치킨윙*원산지: 치킨윙(태국산)
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 흰 밥 추가
# 음식메뉴 성공
# ===============
# *원산지 : 쌀(국내산)
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 피나콜라다 코코넛 시럽을 곁들인 상큼한 파인애플
# 음식메뉴 성공
# ===============
# 상큼한 파인애플 위에 뿌려진 부드러운 코코넛 시럽의 환상적인 조화!떠나는 여름이 아쉬운 당신을 위해 준비한 동남아 스타일의 디저트입니다.과즙 가득 새콤달콤한 파인애플 위에 풍미 가득한 피나콜라다 코코넛 시럽을 곁들이면 이 곳이 바로 휴양지 해변가!
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 마이빈스 더치커피
# 음식메뉴 성공
# ===============
# 콜롬비아/브라질/과테말라를 블랜딩하여 제조일자 표기로 믿음을 더한 더치커피! 물과 더치커피의 1:3 황금비율로 시원한 얼음 또는 뜨거운 물과  함께 드실 수 있습니다. (기본 컵 제공됩니다)
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 마르티넬리 스파클링 애플주스
# 음식메뉴 성공
# ===============
# 최고품질의 사과로만 만든 100% 천연 사과탄산주스물, 향료, 설탕을 넣지 않아 사과 본연의 깔끔한 맛을 느낄 수 있습니다
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 산펠레그리노 폼펠모 자몽
# 음식메뉴 성공
# ===============
# 산펠레그리노 탄산수에 자몽향과 맛을 가미한 제품자몽의 달콤 쌉싸름한 맛은 음료의 향을 한층 더 끌어올려 주고, 달콤한 맛이 신맛을 부드럽게 감싸주는 기분좋은 끝맛을 느껴보세요고품질의 자몽주스와 신선한 귤향을 첨가하여 마시는 순간 상쾌함과 함께 갈증이 해소됩니다
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 오미베리 베리티
# 음식메뉴 성공
# ===============
# 오미자열매 3송이가 그대로~ 천연원료만을 사용하였으며, 항산화 물질이 피로회복에 효과가 있어 무더운 여름 건강과 맛 둘 다 잡아보세요
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 산펠레그리노 아란시아타 로싸
# 음식메뉴 성공
# ===============
# 산펠레그리노 천연 탄산수에 시칠리아산 레드 오렌지 원액을 함유하고 있는 부드러운 레드오렌지 탄산음료잘 익은 블러드 오렌지의 강렬한 향과 부드럽고 우아한 단맛을 느껴보세요
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 코카콜라
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 코카콜라 제로
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 스프라이트
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 콰트로 치즈 아라비아따 볼로네제 파스타
# 음식 카테고리 성공
# =========================================
# 콰트로 치즈 아라비아따 볼로네제 파스타
# 음식메뉴 성공
# ===============
# ★단체주문 추천메뉴★[~20:30 주문가능]MERRY CHRISTMAS~설레는 연말을 맞이하여 셰플리가 준비한 맛있는 선물!최적의 알 단테 식감을 살린 펜네, 푸실리 면에 정성을 다해 오랜시간 끓인 홈메이드 스타일의 볼로네제 소스를 얹어 이탈리아 볼로냐 지방의 정통 가정식 파스타를 재현하였습니다.감칠맛 나게 매콤한 토마토 소스에 프로볼로네, 체다, 그뤼에르, 모짜렐라 치즈가 듬뿍!추운 겨울, 셰플리표 파스타와 함께 낭만과 여유가 넘치는 미식의 나라 이탈리아로 떠나보세요~마음까지 따뜻하게 채워주는 분위기 있는 한 끼와 함께 지난 한 해를 돌아보고 새로올 한 해를 맞이해보세요. 다채롭고 세련된 향과 풍미는 와인 안주로도 제격입니다.CHEF'S TIP식었을 경우 뚜껑을 열고 전자레인지에 30초 데워 주세요.면과 소스가 섞이도록 잘 비벼주세요.함께 드린 할라피뇨는 메인과 함께 드실 때 맛있습니다.
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 단짠단짠 밥도둑 연어새우장 덮밥
# 음식 카테고리 성공
# =========================================
# 단짠단짠 밥도둑 연어새우장 덮밥
# 음식메뉴 성공
# ===============
# ★단체주문 추천메뉴★[~20:30 주문가능]SNS를 뜨겁게 달군 자꾸만 생각나는 중독의 그 맛!특제 간장에서 잘 숙성시킨 새우와 연어를 고슬고슬하게 갓 지은 밥 위에 얹어 감칠맛나게 푸짐한 한끼를 구성했습니다.고소한 버터와 함께 계란 노른자를 톡 터뜨려 따뜻한 밥을 코팅해주고, 부드러운 연어와 탱탱한 새우를 한 숟가락 가득 떠먹어보세요.비린맛은 ZERO! 입 안에서 톡톡터지는 날치알의 재밌는 식감과 상큼하게 채 썬 양파와 초생강, 무순으로 뒷맛까지 담백하고 깔끔하게~첫 숟가락부터 반하게 될 셰플리표 연어새우장 덮밥.행복한 비명이 절로 나오는 알차고 야무진 한 끼를 즐겨보세요.CHEF'S TIP전자레인지에 데우지 않으셔도 맛있게 드실 수 있습니다.다양한 토핑을 밥과 함께 잘 비벼 드세요.달걀 노른자는 기호에 맞게 즐겨보세요.
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 피타브래드에 싸먹는 허니갈릭 닭가슴살 시저샐러드
# 음식 카테고리 성공
# =========================================
# 피타브래드에 싸먹는 허니갈릭 닭가슴살 시저샐러드
# 음식메뉴 성공
# ===============
# ★단체주문 추천메뉴★[~20:30 주문가능]신선한 로메인과 루꼴라가 듬뿍! 누구나 좋아할만한 시저샐러드에 특제 허니갈릭 소스를 발라 구운 닭가슴살과, 콜비잭 치즈, 블랙올리브, 적양파, 베이컨, 삶은 달걀, 방울토마토를 올려 다채로운 비주얼만큼 푸짐하게 구성했습니다.구운 피타브래드에 신선한 채소와 각종 고명을 취향껏 함께 올려 싸먹어보세요. 셰플리만의 홈메이드 시저 드레싱에 청양고추로 약간의 매콤함을 더해 뒷맛까지 깔끔한 한끼를 즐기실 수 있습니다.CHEF'S TIP피타브래드를 부드럽게 즐기시려면 전자레인지에 30초 데워주세요.드레싱은 기호에 맞게 샐러드와 충분히 섞어 드세요.다양한 토핑과 샐러드를 함께 드시면 더 맛있습니다.
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 특제간장으로 맛을 살린 여수 새꼬막비빔밥
# 음식 카테고리 성공
# =========================================
# 특제간장으로 맛을 살린 여수 새꼬막비빔밥
# 음식메뉴 성공
# ===============
# ★단체주문 추천메뉴★[~20:30 주문가능]2017 미슐랭 가이드 서울편에 등재된 모던한식 레스토랑 '민스키친(MIN'S KITCHEN)'의 김민지 오너셰프의 노하우를 바탕으로 셰플리 키친팀이 구현한 꼬막비빔밥제철을 맞이한 신선한 여수 새꼬막을 사용하여 쫄깃하고 탱탱한 식감이 일품인 비빔밥궁채, 아삭고추, 미나리, 쪽파, 부추 등 파릇파릇한 색감의 5가지 초록 채소와 아삭한 콩나물의 환상적 조화!매콤하면서도 감칠맛 나는 특제 숙성 간장으로 양념하여 비린맛 없이 여수 꼬막 특유의 맛과 풍미를 즐기실 수 있습니다.올 겨울, 남해 바다가 눈 앞에 펼쳐지는 셰플리표 꼬막 한 상을 느껴보세요. 혼밥, 혼술로도 제격입니다.-인공조미료를 쓰지 않아 재료 본연의 맛을 즐기실 수 있습니다.CHEF'S TIP전자레인지에 데우지 않으셔도 맛있게 드실 수 있습니다.다양한 채소를 밥과 함께 잘 비벼드세요.비빔밥과 미역국을 곁들여 먹으면 더욱 맛있습니다.
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또
# 음식 카테고리 성공
# =========================================
# 허브향 닭다리살 구이와 매콤한 고르곤졸라 크림 곡물 리조또
# 음식메뉴 성공
# ===============
# ★단체주문 추천메뉴★[~20:30 주문가능]서래마을의 유명 레스토랑 '도우룸 바이 스와니예(Doughroom by Soigne)' 윤대현 헤드셰프의 레시피로부터 영감을 받아 셰플리 키친팀만의 방식으로 재해석하여 탄생한 요리현미와 보리를 믹스하여 밥알의 탱글함을 살린 고르곤졸라 크림리조또에 청양고추를 넣어 느끼함은 잡고, 특별하게 구운 황금팽이로 풍미는 더하였습니다장시간 마리네이드하여 허브향을 입힌 부드러운 오븐구이 닭다리살과 신선한 이태리 파슬리를 얹어 마무리한 정성 가득한 리조또입니다CHEF'S TIP식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요.황금팽이버섯은 리조또와 함께 섞어 드시면 더욱 맛있습니다.사이드로 드린 할라피뇨는 취향에 맞게 즐겨보세요.
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 매콤한 낙지 콩나물 비빔밥
# 음식 카테고리 성공
# =========================================
# 매콤한 낙지 콩나물 비빔밥
# 음식메뉴 성공
# ===============
# ★단체주문 추천메뉴★[~20:30 주문가능]한남동의 파인다이닝 레스토랑인 "탑"의 헤드셰프 조용재 셰프가 개발한 낙지덮밥.사골육수로 맛을 낸 특제 양념과 날치알을 매칭하여, 낙지 볶음에 감칠 맛을 극대화 하였습니다.맛있게 매운 맛으로 입 맛을 자극하고 아삭한 콩나물과 다양한 야채와의 조화가 어우러지는 한끼입니다.CHEF'S TIP식었을 경우 별도로 제공된 용기에 담아 전자레인지에30초데워주세요.고명과 함께 비벼드세요.덮밥과 된장국을 곁들여 먹으면 더욱 맛있습니다.
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 그라나파다노를 곁들인 닭다리살 김치볶음밥
# 음식 카테고리 성공
# =========================================
# 그라나파다노를 곁들인 닭다리살 김치볶음밥
# 음식메뉴 성공
# ===============
# ★단체주문 추천메뉴★[~20:30 주문가능]이태원 복합문화공간 어그로빌리지(Uhgro Village)에 위치한 프렌치비스트로 바이휴고(By HUGO)의 원영호 헤드셰프가 셰플리를 위해 직접 개발한 시그니처 김치볶음밥매콤한 김치에 진한맛을 위한 두반장과 굴소스를 섞고 고소한 닭다리살을 푸짐하게 넣어 밥과 빠르게 볶은 다음, 반숙 계란 후라이와 그라나파다노 치즈를 얹고 황금팽이버섯과 쪽파, 트러플오일로 마무리하였습니다뻔한 맛의 김치볶음밥이 아닌 고급스러운 셰프의 요리를 만나보세요인공조미료를 쓰지 않아 재료 본연의 맛을 즐기실 수 있습니다CHEF'S TIP식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요비비지 마시고 모든 재료들을 함께 떠서 드세요
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 소불고기 궁중 비빔밥 '골동반'
# 음식 카테고리 성공
# =========================================
# 소불고기 궁중 비빔밥 '골동반'
# 음식메뉴 성공
# ===============
# ★단체주문 추천메뉴★[~20:30 주문가능]불고기 양념으로 조리한 소고기를 메인으로 다양한 채소와 나물, 계란 등을 셰플리가 직접 배합한 고추장과 함께 비벼먹는 전통 궁중 비빔밥궁궐에서 먹는 비빔밥인 '골동반'을 셰플리 키친팀에서 재현한 음식으로, 우리에게 친숙한 불고기부터 맛깔나게 버무린 나물, 비빔밥 재료로는 생소한 부각까지 다양한 고명들을 하나하나 정성을 다해 조리하여 용기에 보기좋게 담고, 깔끔한 미역국까지 함께 준비합니다취향에 맞게 고추장을 넣은 다음 잘 비벼드시면 든든하면서도 건강한 한끼를 즐기실 수 있습니다인공조미료를 쓰지 않아 재료 본연의 맛을 즐기실 수 있습니다CHEF'S TIP식었을 경우 별도 제공해드린 용기에 담아 전자레인지에30초데워주세요따로 담아드린 고추장은 취향에 맞게 넣어드세요함께 드린 미역국은 비빔밥과 함께 드실 때 맛있습니다
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 국내산 생등심 돈가츠 덮밥 '가츠동'
# 음식 카테고리 성공
# =========================================
# 국내산 생등심 돈가츠 덮밥 '가츠동'
# 음식메뉴 성공
# ===============
# ★단체주문 추천메뉴★[~20:30 주문가능]갓 튀긴 일본식 돈가츠에 달짝지근한 간장소스와 계란, 양파 등을 부어 구워낸 다음 밥 위에 얹어먹는 일본의 덮밥 요리얼리지 않은 국내산 돈육 생등심을 두툼하게 잘라 빵가루를 입혀 고온에서 바삭하게 튀겨낸 다음 그 위에 키친에서 직접 만든 일본식 간장소스를 넣어 섞은 계란과 양파 등을 부어 한 번 더 조리합니다넉넉한 양으로 드린 돈가츠를 소스와 계란으로 촉촉해진 밥과 함께 떠서 드셔보세요인공조미료를 쓰지 않아 재료 본연의 맛을 즐기실 수 있습니다CHEF'S TIP식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요비비지 마시고 모든 재료들을 함께 떠서 드세요함께 드린 단무지와 락교는 메인과 함께 드실 때 맛있습니다
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 영양부추무침을 곁들인 대패삼겹살 덮밥과 된장국
# 음식 카테고리 성공
# =========================================
# 영양부추무침을 곁들인 대패삼겹살 덮밥과 된장국
# 음식메뉴 성공
# ===============
# ★단체주문 추천메뉴★[~20:30 주문가능]2017 미슐랭 가이드 서울편에 등재된 모던한식 레스토랑 '민스키친(MIN'S KITCHEN)'의 김민지 오너셰프가 셰플리 고객들을 위해 특별히 준비한 한식 메뉴양념에 재워둔 대패삼겹살을 직화로 넉넉히 구워내 불맛을 살려 밥 위에 얹고, 셰프 특제 소스로 맛깔나게 무쳐낸 영양부추와 양파를 함께 곁들여 깔끔한 한국식 덮밥을 즐기실 수 있습니다함께 드린 된장국은 식었을 경우 별도 제공해드린 용기에 담아 전자레인지에 30초 데워드시면 더욱 맛있습니다.CHEF'S TIP비비지 마시고 고명과 밥을 함께 떠서 드세요전자레인지30초로 더욱 따뜻하게 드세요
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:214: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-6 전원빌딩 지하1층 (셰플리 강남키친과 동일)
# 주소 뽑기 성공
# =========================================
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 히말라야 핑크 솔트로 맛을 더한 오리지널 삼겹살 (200g) :삼겹살(스페인), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 향긋한 유자향을 품은 된장 삼겹구이 (200g) :삼겹살(스페인), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 매콤달콤 홍시 고추장 돼지불고기 (250g)  :앞다리살(미국), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 배즙으로 단맛을 살린 간장 돼지 불고기 (200g)  :목살(캐나다), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 특제 복분자 간장 소스에 재운 인생 LA갈비 (250g) :LA갈비(미국), 쌀(국내산), 김치(국산), 오징어(중국산), 낙지(중국산), 대두(외국산)
# 직화 고추장 불고기 덮밥 :앞다리살(미국), 쌀(국내산), 김치(국내산)
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# 히말라야 핑크 솔트로 맛을 더한 오리지널 삼겹살 200g
# 음식 카테고리 성공
# =========================================
# 향긋한 유자향을 품은 된장 삼겹구이 200g
# 음식 카테고리 성공
# =========================================
# 매콤달콤 홍시 고추장 돼지불고기 250g
# 음식 카테고리 성공
# =========================================
# 배즙으로 단맛을 살린 간장 돼지 불고기 200g
# 음식 카테고리 성공
# =========================================
# 특제 복분자 간장 소스에 재운 인생 LA갈비 250g
# 음식 카테고리 성공
# =========================================
# 직화 고추장 불고기 덮밥
# 음식 카테고리 성공
# =========================================
# 히말라야 핑크 솔트로 맛을 더한 오리지널 삼겹살 200g
# 음식 카테고리 성공
# =========================================
# 히말라야 핑크 솔트로 맛을 더한 오리지널 삼겹살 200g
# 음식메뉴 성공
# ===============
# "한국인이 좋아하는 삼겹살"   남녀노소 누구나 좋아하는 삼겹살에 히말라야 핑크 소금으로 특별함을 더하였습니다.히말라야 핑크 소금은 2억년 전 히말라야의 순수함을 그대로 간직한 천연조미료로 인위적인 정제과정을 거치지 않아 간수의 쓴맛이 적어 고기의 감칠맛을 극대화 시켜 줄 뿐만 아니라, 100% 순수한 자연 암염으로 84종 이상의 각종 미네랄 성분이 포함되어 있는 깨끗하고 건강한 식재료입니다.직화 반상의 오리지널 삼겹살은 핑크 소금으로 간을 하여 삼겹살에 건강함과 특별함을 더하였습니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요.당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 향긋한 유자향을 품은 된장 삼겹구이 200g
# 음식 카테고리 성공
# =========================================
# 향긋한 유자향을 품은 된장 삼겹구이 200g
# 음식메뉴 성공
# ===============
# "유자와 된장소스의 운명적 만남"  유자 된장 소스로 고기의 잡내는 없애고 부드러운 식감은 극대화 하였습니다.유자의 껍질에 풍부한 비타민P는 혈압을 안정시키고 비타민C가 풍부한 과육에는 항산화 성분이 많기 때문에 면역력을 증가시켜주고, 혈관 벽을 튼튼하게 해줘 고혈압에도 효과적입니다.향긋한 유자향과 고소한 된장이 어우러져 독특하면서도 입안 가득 풍미를 느끼실 수 있습니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요   당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 매콤달콤 홍시 고추장 돼지불고기 250g
# 음식 카테고리 성공
# =========================================
# 매콤달콤 홍시 고추장 돼지불고기 250g
# 음식메뉴 성공
# ===============
# "고추장에 빠진 홍시의 완벽한 하모니"  매~콤한 특제 고추장에 맛있게 익은 홍시를 갈아 넣어 감칠맛 나는 단맛을 더하였습니다.홍시는 자외선으로부터 눈세포를 보호하는 성분과 비타민A와 비타민C가 풍부해 감기를 예방하며 면역력을 높여주고 숙취해소에 탁월한 역할을 합니다.24시간 저온 숙성으로 양념 맛이 깊게 배어들게 하여 불 맛나게 구웠습니다. 홍시의 달콤함과 고추장의 매콤함이 조화롭게 어우러지는 직화 불고기입니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요.당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 배즙으로 단맛을 살린 간장 돼지 불고기 200g
# 음식 카테고리 성공
# =========================================
# 배즙으로 단맛을 살린 간장 돼지 불고기 200g
# 음식메뉴 성공
# ===============
# "기사식당의 돼지불백 맛 그대로"  국적불문, 남녀노소 누구나 좋아하는 불고기! 인위적인 연육제를 사용하지 않아 건강함을 더하였습니다.배를 갈아 만든 달짝지근한 특제 간장 소스에 숙성하여 부드러운 고기를 불 맛나게 직화로 구운 불고기입니다.맛있으면서도 건강한 한 상, 특히 아이들이 너무나 사랑하는 메뉴입니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요.당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 특제 복분자 간장 소스에 재운 인생 LA갈비 250g
# 음식 카테고리 성공
# =========================================
# 특제 복분자 간장 소스에 재운 인생 LA갈비 250g
# 음식메뉴 성공
# ===============
# "특제소스에 재워 부드럽고 달달한 인생 LA갈비"  장시간 숙성으로 양념이 충분히 배어들어 육질은 부드럽게, 맛은 더 풍부하게복분자에는 항산화 물질인 폴리페놀과 안토시아닌이 함유되어 노화를 방지해주고 항암효과에 탁월합니다.복분자를 포함한 15가지의 재료로 맛을 낸 특제 양념과 직화반상만의 특별한 레시피로 맛의 깊이를 더욱 풍부하게 만들었습니다.직화반상's TIP함께 제공된 친환경 쌈과 두부쌈장을 곁들여 보세요.당일도정한 쌀로 지은 밥과 엄선된 반찬을 더해 만족스러운 직화 한상을 준비하였습니다.
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 직화 고추장 불고기 덮밥
# 음식 카테고리 성공
# =========================================
# 직화 고추장 불고기 덮밥
# 음식메뉴 성공
# ===============
# "매콤달콤한 홍시 고추장 불고기와 각종 야채의 환상적 조화＂ 직화반상의 마약같은 홍시 고추장 불고기!누~구나 좋아하는 고추장 불고기를 직화로 구워 불맛을 살리고 향긋한 미나리, 갖은 야채를 곁들여 든든한 한끼를 준비했습니다.직화반상's TIP함께 제공된 국과 김치를 곁들여 드세요.식었을 경우 뚜껑을 열고 전자레인지에30초데워주세요.국은 용기에 덜어 전자레인지에 넣어주세요.
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 강남구 역삼동 831-25
# 주소 뽑기 성공
# =========================================
#
# 안녕하세요. 짚신매운갈비찜을 찾아주신 고객님 진심으로 환영합니다.저희는 특별한 비법을 가지고 있지는 않습니다. 다만, 한분 한분 방문해주시는 분들께 어머니의 정성과도 같은 마음으로 늘 한결같은 맛을 전해드리겠습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 돼지고기 : 미국산소고기 : 뉴질랜드산김치,고춧가루,쌀,고추만두 : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 19000
# 최소 금액 성공
# =========================================
# [메뉴]
# 음식 카테고리 성공
# =========================================
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# [메뉴]
# 음식 카테고리 성공
# =========================================
# 짚신 소갈비찜 (2인분, 400g)
# 음식메뉴 성공
# ===============
# 공기밥 미포함매운음식은 입맛을 돋우며 스트레스를 날려주고 고추에 들어있는 캡사이신이란 성분은 몸의 대사기능을 높여 지방축적을 막고 이미 몸 속에 달라붙은 지방을 연소시켜 다이어트에도 효과적입니다.
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# 짚신 돼지갈비찜 (2인분, 400g)
# 음식메뉴 성공
# ===============
# 공기밥 미포함부드러운 돼지고기와 매콤한 양념의 조화
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 주먹밥
# 음식메뉴 성공
# ===============
# 참기름을 두른 밥위에 김가루와 날치알을 올려 직접 만들어먹는 주먹밥. (밥 한공기정도)
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 고추만두 반접시(5pcs)
# 음식메뉴 성공
# ===============
# 고추모양의 만두안에 매콤한 청양고추가 약간 가미된 메뉴.
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 고추만두 한접시(10pcs)
# 음식메뉴 성공
# ===============
# 고추모양의 만두안에 매콤한 청양고추가 약간 가미된 메뉴.
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 참치마요주먹밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 쿨피스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# 당면 (비조리) 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 떡 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 버섯 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 감자 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 옹심이 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 모듬 사리 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 강남구 역삼동 831-6 1층
# 주소 뽑기 성공
# =========================================
#
# 따뜻함, 건강함, 편리함을 추구하는 아시아 누들&라이스 레스토랑으로 아시아 각 지역의 특색 있는 요리를 선보입니다.
# 길거리와 먹거리라는 단어를 조합한 스트릿(strEAT)에서는 규동, 카라이멘, 오니기리 등 심플함과 정직함으로 만들어진 메뉴에
# 각국 아시아의 고유 문화와 맛을 담아냈으며, 푸드플라이를 통해 어디서나 간편하게 건강한 식사를 즐길 수 있습니다.
#
# (배달 시 매장에서 나가는 영수증으로 해피포인트 2% 적립이 가능합니다.)
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀_국내산대만식 돼지 조림 덮밥(돼지고기_독일산)명란 아보카도 덮밥(돼지고기, 두부, 명란_국내산)대만식 마늘쫑 볶음 덮밥(돼지고기_국내산)해산물 날치알 볶음밥(오징어_중국산)삼겹 철판구이(돼지고기_독일산/갈치(양념젓갈),명란_국내산)야채 고로케(돼지고기_국내산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [라이스&누들]
# 음식 카테고리 성공
# =========================================
# [철판구이]
# 음식 카테고리 성공
# =========================================
# [라이스&누들]
# 음식 카테고리 성공
# =========================================
# 대만식 돼지 조림 덮밥
# 음식메뉴 성공
# ===============
# 오향, 팔각 등의 향이 진하게 우러나온 돼지고기 조림에 간장 맛을 들인 달걀과 볶은 청경채를 함께 곁들여 먹는 대만식 조림 덮밥
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 명란 아보카도 덮밥
# 음식메뉴 성공
# ===============
# 돼지고기로 만든 완자와 짭쪼름한 명란, 담백한 아보카도가 어우러진 덮밥
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 대만식 마늘쫑 볶음 덮밥
# 음식메뉴 성공
# ===============
# 잘게 갈아낸 돼지고기와 마늘쫑을 스트릿만의 특제 소스에 매콤하게 볶아낸 대만식 볶음 덮밥
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 해산물 날치알 볶음밥
# 음식메뉴 성공
# ===============
# 탱글한 새우, 오징어, 날치알 등 신선한 해산물과 각종 채소를 뜨거운 철판 위에 볶아낸 철판 볶음밥
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# [철판구이]
# 음식 카테고리 성공
# =========================================
# 삼겹 철판구이
# 음식메뉴 성공
# ===============
# 철판에서 구워내 불맛이 살아있는 삼겹살에 명란, 와사비, 갈치 속젓의 삼합 소스까지 곁들여 더 맛있는 구이 메뉴*17시부터 주문 가능*
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 강남구 역삼동 792-6
# 주소 뽑기 성공
# =========================================
#
# 저희 업소는 불맛과 향을 내는 어떠한 보조재료를 넣지않고 요리합니다.
# 손님께서 주문하시면 그 즉시 오직 불의 강,약으로만 조리하기에 음식에서 풍기는 깊고 풍부한 불맛과 향기가 어우러져 더욱 맛있는 음식을 드실 수 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀 국내산 / 삼겹살 칠레산 / 김치찜김치 국내산 / 김치찜고기 칠레산 / 고추가루 중국산 / 김치  중국산 / 소갈비살 미국산 / 쭈꾸미 중국산 / 제육 미국산 / 소왕갈비 미국산 / 뼈해장국 외국산 /
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [식사메뉴]
# 음식 카테고리 성공
# =========================================
# [고기+냉면]
# 음식 카테고리 성공
# =========================================
# [알뜰원플러스 고기만 메뉴 ]
# 음식 카테고리 성공
# =========================================
# [찜/탕]
# 음식 카테고리 성공
# =========================================
# [패밀리SET]
# 음식 카테고리 성공
# =========================================
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [식사메뉴]
# 음식 카테고리 성공
# =========================================
# 직화소갈비살구이
# 음식메뉴 성공
# ===============
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리감치
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 직화통삼겹살구이
# 음식메뉴 성공
# ===============
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리김치
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 직화대패삼겹살구이
# 음식메뉴 성공
# ===============
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리김치
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 직화매운삼겹살구이
# 음식메뉴 성공
# ===============
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리김치
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 직화제육볶음
# 음식메뉴 성공
# ===============
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리김치
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 직화돼지갈비구이
# 음식메뉴 성공
# ===============
# 공기밥 인수대로 제공반찬+국+쌈+쌈장+고추+마늘+파채(콩나물)+겉저리김치
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [고기+냉면]
# 음식 카테고리 성공
# =========================================
# 소갈비살 + 냉면 (1인분)
# 음식메뉴 성공
# ===============
# 공깃밥별도, 겉절이, 쌈야채 제공
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 돼지갈비 + 냉면 (1인분)
# 음식메뉴 성공
# ===============
# 공깃밥 별도,겉절이,쌈야채 제공
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 삼겹살 + 냉면 (1인분)
# 음식메뉴 성공
# ===============
# 공깃밥별도, 겉절이, 쌈야채 제공
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 대패삼겹살 + 냉면 (1인분)
# 음식메뉴 성공
# ===============
# 공깃밥별도, 겉절이, 쌈야채 제공
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 매운삼겹살 + 냉면 (1인분)
# 음식메뉴 성공
# ===============
# 공깃밥별도, 겉절이, 쌈야채 제공
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 제육볶음 + 냉면 (1인분)
# 음식메뉴 성공
# ===============
# 공깃밥 별도,겉절이,쌈야채 제공
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 물냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 비빔냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# [알뜰원플러스 고기만 메뉴 ]
# 음식 카테고리 성공
# =========================================
# 소갈비살 (450g)
# 음식메뉴 성공
# ===============
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식정보 성공
# ===============
# 42000
# 금액 성공
# ===============
# 통삼겹 (600g)
# 음식메뉴 성공
# ===============
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식정보 성공
# ===============
# 37000
# 금액 성공
# ===============
# 대패삼겹 (600g)
# 음식메뉴 성공
# ===============
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식정보 성공
# ===============
# 38000
# 금액 성공
# ===============
# 매운삼겹 (600g)
# 음식메뉴 성공
# ===============
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식정보 성공
# ===============
# 41000
# 금액 성공
# ===============
# 제육볶음 (750g)
# 음식메뉴 성공
# ===============
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 돼지갈비 (840g)
# 음식메뉴 성공
# ===============
# 공기밥별도서비스 : 뼈해장국 또는 선지해장국 中 선택 1
# 음식정보 성공
# ===============
# 40000
# 금액 성공
# ===============
# [찜/탕]
# 음식 카테고리 성공
# =========================================
# 소왕갈비탕 (1인분)
# 음식메뉴 성공
# ===============
# 공깃밥은 인분 수에 따라 제공됩니다소왕갈비탕 + 반찬 2종
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 육개장
# 음식메뉴 성공
# ===============
# 공깃밥은 인분 수에 따라 제공됩니다소왕갈비탕 + 반찬 2종
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 선지양평해장국
# 음식메뉴 성공
# ===============
# 공깃밥은 인분 수에 따라 제공됩니다소왕갈비탕 + 반찬 2종
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 뼈해장국 (1인)
# 음식메뉴 성공
# ===============
# 공깃밥은 인분 수에 따라 제공됩니다소왕갈비탕 + 반찬 2종
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 김치찜 (2인분)
# 음식메뉴 성공
# ===============
# 공깃밥은 인분 수에 따라 제공됩니다소왕갈비탕 + 반찬 2종
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 제육덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# [패밀리SET]
# 음식 카테고리 성공
# =========================================
# SET A (4인분)
# 음식메뉴 성공
# ===============
# 직화소갈비살(2인) + 직화돼지갈비구이(2인) + 공깃밥 + 계란찜
# 음식정보 성공
# ===============
# 54000
# 금액 성공
# ===============
# SET B (4인분)
# 음식메뉴 성공
# ===============
# 직화소갈비살(2인) + 직화통삼겹살구이(2인) + 공깃밥 + 버섯토핑
# 음식정보 성공
# ===============
# 51000
# 금액 성공
# ===============
# 모듬세트 (6인분)
# 음식메뉴 성공
# ===============
# 직화소갈비살(2인) + 직화통삼겹살구이(2인) + 직화제육볶음(2인) + 공깃밥 + 계란찜
# 음식정보 성공
# ===============
# 70000
# 금액 성공
# ===============
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 계란찜
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 치즈계란찜
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 기본반찬(겉저리+파채)set
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 버섯추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 비엔나소세지추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 쌈추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 겉절이추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 콜라 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 사이다 (1.25L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# ===========끝===========
# ---6번 식당파싱 시작 ---
# 서울 강남구 역삼동 837-26 삼일프라자 1층
# 주소 뽑기 성공
# =========================================
#
# 한끼든든 퓨전 한식 수제직화도시락!!
# 직화락은 직화제육볶음과 직화오징어볶음을 메인으로 하는 직화볶음요리 전문점, 직화도시락 입니다.
# 직화도시락과 더불어 다양한 도시락을 즐겨보세요.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 오징어,쌀,계란,돈가스,떡갈비,닭고기 : 국내산돼지고기 : 미국산     김치 : 국내산,중국산고추가루: 중국산 국내산혼합양배추 .파. 양파: 국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [직화류]
# 음식 카테고리 성공
# =========================================
# [직화플러스토핑류]
# 음식 카테고리 성공
# =========================================
# [볶음만따로]
# 음식 카테고리 성공
# =========================================
# [프리미엄]
# 음식 카테고리 성공
# =========================================
# [그외]
# 음식 카테고리 성공
# =========================================
# [돈가스류]
# 음식 카테고리 성공
# =========================================
# [카레류]
# 음식 카테고리 성공
# =========================================
# [스낵]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [직화류]
# 음식 카테고리 성공
# =========================================
# 후덜덜 돼지
# 음식메뉴 성공
# ===============
# 직화로 요리한 매콤한 제육볶음 (with 계란후라이와 볶음김치, 옛날소세지와 고기위에 파채!!)
# 음식정보 성공
# ===============
# 6900
# 금액 성공
# ===============
# 두근두근 반반
# 음식메뉴 성공
# ===============
# 직화 제육볶음과 직화 오징어볶음을 모두 즐기고 싶은 분들께 강추! (with 계란후라이와 볶음김치, 옛날소세지와 고기위에 파채!!)
# 음식정보 성공
# ===============
# 7400
# 금액 성공
# ===============
# [직화플러스토핑류]
# 음식 카테고리 성공
# =========================================
# 후덜덜 (돼지) + 스팸 도시락
# 음식메뉴 성공
# ===============
# 직화로 요리한 매콤한 제육볶음 + 스팸
# 음식정보 성공
# ===============
# 7100
# 금액 성공
# ===============
# 두근두근 (반반) + 스팸 도시락
# 음식메뉴 성공
# ===============
# 직화 제육볶음과 직화 오징어볶음 + 스팸
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 후덜덜 (돼지) + 새우 도시락
# 음식메뉴 성공
# ===============
# 직화로 요리한 매콤한 제육볶음 + 새우
# 음식정보 성공
# ===============
# 7100
# 금액 성공
# ===============
# 두근두근 (반반) + 새우 도시락
# 음식메뉴 성공
# ===============
# 직화 제육볶음과 직화 오징어볶음 + 새우
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 후덜덜 (돼지) + 소세지 도시락
# 음식메뉴 성공
# ===============
# 직화로 요리한 매콤한 제육볶음 + 소세지
# 음식정보 성공
# ===============
# 7300
# 금액 성공
# ===============
# 두근두근 (반반) + 소세지 도시락
# 음식메뉴 성공
# ===============
# 직화 제육볶음과 직화 오징어볶음 + 소세지
# 음식정보 성공
# ===============
# 7700
# 금액 성공
# ===============
# 후덜덜 (돼지) + 생선가스 도시락
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# 두근두근 (반반) + 생선가스 도시락
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8200
# 금액 성공
# ===============
# 후덜덜 (돼지) + 떡갈비 도시락
# 음식메뉴 성공
# ===============
# 직화로 요리한 매콤한 제육볶음 + 떡갈비
# 음식정보 성공
# ===============
# 8300
# 금액 성공
# ===============
# 두근두근 (반반) + 떡갈비 도시락
# 음식메뉴 성공
# ===============
# 직화 제육볶음과 직화 오징어볶음 + 떡갈비
# 음식정보 성공
# ===============
# 8700
# 금액 성공
# ===============
# 후덜덜 (돼지) + 돈가스 도시락
# 음식메뉴 성공
# ===============
# 직화로 요리한 매콤한 제육볶음 + 돈가스
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 두근두근 (반반) + 돈가스 도시락
# 음식메뉴 성공
# ===============
# 직화 제육볶음과 직화 오징어볶음 + 돈가스
# 음식정보 성공
# ===============
# 9200
# 금액 성공
# ===============
# [볶음만따로]
# 음식 카테고리 성공
# =========================================
# 후덜덜 1Box
# 음식메뉴 성공
# ===============
# 밥을 제외하고 직화제육볶음만 들어간 메뉴입니다.
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 부르부르 1Box
# 음식메뉴 성공
# ===============
# 밥을 제외하고 직화오징어볶음만 들어간 메뉴입니다.
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 반반 1Box
# 음식메뉴 성공
# ===============
# 밥을 제외하고 반반볶음(직화제육볶음,직화오징어볶음)만 들어간 메뉴입니다.
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# [프리미엄]
# 음식 카테고리 성공
# =========================================
# 한끼라도 후덜덜
# 음식메뉴 성공
# ===============
# 후덜덜 돼지 + 모듬(돈가스+떡갈비+왕새우+소세지+군만두)
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# 한끼라도 부르부르
# 음식메뉴 성공
# ===============
# 부르부르 오징어 + 모듬(돈가스+떡갈비+왕새우+소세지+군만두)
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# 한끼라도 반반
# 음식메뉴 성공
# ===============
# 두근두근 반반 + 모듬(돈가스+떡갈비+왕새우+소세지+군만두)
# 음식정보 성공
# ===============
# 16400
# 금액 성공
# ===============
# 김치찌개 추가
# 음식메뉴 성공
# ===============
# 공깃밥 미포함
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 뜨끈한 소고기 미역국 추가
# 음식메뉴 성공
# ===============
# 공깃밥 미포함
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 공기밥 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 볶음김치 추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 800
# 금액 성공
# ===============
# [그외]
# 음식 카테고리 성공
# =========================================
# 매콤닭강정 도시락
# 음식메뉴 성공
# ===============
# 매콤한 닭강정 도시락
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 스팸 도시락
# 음식메뉴 성공
# ===============
# 담백한 스팸 도시락
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 치킨 도시락
# 음식메뉴 성공
# ===============
# 치킨도시락
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 탕수육 도시락
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 추억의 도시락
# 음식메뉴 성공
# ===============
# 볶음김치 + 계란 + 밥
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 칠리새우 도시락
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7700
# 금액 성공
# ===============
# [돈가스류]
# 음식 카테고리 성공
# =========================================
# 아사삭 돈가스
# 음식메뉴 성공
# ===============
# 국내산 돼지고기 등심으로 주문즉시 바삭하게 튀겨낸 돈가스와 해쉬브라운
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 더블돈가스
# 음식메뉴 성공
# ===============
# 돈가스가 두배
# 음식정보 성공
# ===============
# 8200
# 금액 성공
# ===============
# 돈가스 새우
# 음식메뉴 성공
# ===============
# 돈가스와 왕새우튀김을 한번에 즐길 수 있는 메뉴입니다.
# 음식정보 성공
# ===============
# 7200
# 금액 성공
# ===============
# 수제돈갈비
# 음식메뉴 성공
# ===============
# 떡갈비와 돈가스를 한번에 즐길 수 있는 메뉴입니다.
# 음식정보 성공
# ===============
# 7800
# 금액 성공
# ===============
# 옛날떡갈비 도시락
# 음식메뉴 성공
# ===============
# 담백한 떡갈비와 추억의 도시락
# 음식정보 성공
# ===============
# 6200
# 금액 성공
# ===============
# 떡갈비닭강정 도시락
# 음식메뉴 성공
# ===============
# 떡갈비와 매콤닭강정
# 음식정보 성공
# ===============
# 8200
# 금액 성공
# ===============
# 생선가스 도시락
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 생선가스새우 도시락
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6100
# 금액 성공
# ===============
# [카레류]
# 음식 카테고리 성공
# =========================================
# 카레돈가스 도시락
# 음식메뉴 성공
# ===============
# 카레와 돈가스
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 카레새우 도시락
# 음식메뉴 성공
# ===============
# 카레와 왕새우튀김(2pcs)
# 음식정보 성공
# ===============
# 6600
# 금액 성공
# ===============
# 카레떡갈비 도시락
# 음식메뉴 성공
# ===============
# 카레와 떡갈비
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 카레소세지 도시락
# 음식메뉴 성공
# ===============
# 카레와 소세지
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 카레옛날도시락
# 음식메뉴 성공
# ===============
# 카레와 추억의 도시락
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 카레스팸 도시락
# 음식메뉴 성공
# ===============
# 카레와 스팸2장
# 음식정보 성공
# ===============
# 6600
# 금액 성공
# ===============
# [스낵]
# 음식 카테고리 성공
# =========================================
# 치즈스틱(4ea)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 김말이(6ea)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 군만두(6ea)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 치킨 1box
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 케이준감자튀김 (300g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 매콤닭강정 1box
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 치킨반반 1Box (400g)
# 음식메뉴 성공
# ===============
# (매콤닭강정 + 치킨)
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 왕새우 1Box (8ea)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# 후덜덜직화1인 정식세트
# 음식메뉴 성공
# ===============
# 후덜덜돼지직화도시락 + 리코타발사믹샐러드 + 오늘의3종반찬 + 김치찌개
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 두근두근반반직화1인 정식세트
# 음식메뉴 성공
# ===============
# 두근두근반반직화도시락 + 리코타발사믹샐러드 + 오늘의3종반찬 + 김치찌개
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# 후덜덜직화 2인 정식세트
# 음식메뉴 성공
# ===============
# 후덜덜돼지직화1Box + 추억의도시락2개 + 리코타발사믹샐러드 + 오늘의반찬3종 + 김치찌개
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 두근두근반반직화2인 정식세트
# 음식메뉴 성공
# ===============
# 두근두근반반직화1Box + 추억의도시락2개 + 리코타발사믹샐러드 + 오늘의반찬3종 + 김치찌개
# 음식정보 성공
# ===============
# 29500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라(355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다(355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 웰치스 포도 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 서울 강남구 역삼동 817-26 1,2층
# 주소 뽑기 성공
# =========================================
#
#
#
# 식신로드, 생생정보, 생방송오늘저녁 등 각종 방송 및 입에서 입으로 이미 검증된 강남 맛집, 이제 백억하누의 음식을 푸드플라이를 통해 집에서 편하게 접하실 수 있습니다.
# 항상 고객이 만족하실수 있는 음식 및 서비스로 고객님을 모시겠습니다.
# 백억하누 강남 본점 많이 이용해주세요^^
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# *쌀 : 국내산*소고기 : 국내산 한우*갈비탕 : 미국산*전복 : 국내산*김치 : 국내산*누룽지 : 국내산*김치찌개 배추김치 : 중국산*돼지고기 : 목전지 미국산, 삼겹 독일산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [신메뉴]
# 음식 카테고리 성공
# =========================================
# [식사메뉴]
# 음식 카테고리 성공
# =========================================
# [갈비탕&냉면]
# 음식 카테고리 성공
# =========================================
# [육류]
# 음식 카테고리 성공
# =========================================
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [신메뉴]
# 음식 카테고리 성공
# =========================================
# 1++한우차돌박이 (2인분)
# 음식메뉴 성공
# ===============
# 기본반찬 5종 + 추가반찬 3종 서비스식사 및 안주로 최고! 정육점에서도 찾기 힘든 우리나라 최고급 차돌박이를 집에서 즐기실 수 있습니다.
# 음식정보 성공
# ===============
# 38000
# 금액 성공
# ===============
# 백억한우불고기 (2인분, 조리)
# 음식메뉴 성공
# ===============
# 국내산 한우 최고등급 1++ (400g)  + 기본반찬 + 추가반찬 3종 + 공깃밥 2개 제공각종 언론에서 극찬한 서울식 한우 불고기
# 음식정보 성공
# ===============
# 44000
# 금액 성공
# ===============
# [식사메뉴]
# 음식 카테고리 성공
# =========================================
# 백억 특정식
# 음식메뉴 성공
# ===============
# 한우불고기 + 한우된장찌개 + 고등어구이 (2인기준 1마리) + 추가반찬 3종
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# 한우 육회 비빔밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 한우불고기 + 한우된장찌개
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 묵은지 김치찌개
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 한우 불고기 덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 한우 소고기 국밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 누룽지탕 정식
# 음식메뉴 성공
# ===============
# 누룽지탕 + 한우된장찌개
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# [갈비탕&냉면]
# 음식 카테고리 성공
# =========================================
# 백억 영양 전복갈비탕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 백억 영양 특갈비탕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 백억 영양 갈비탕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 전복 회냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 물냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 비빔냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# [육류]
# 음식 카테고리 성공
# =========================================
# 한우 육회 (200g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 24900
# 금액 성공
# ===============
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# 새알만두 (10pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 추가반찬 3종
# 음식메뉴 성공
# ===============
# 단호박샐러드 + 야채샐러드 + 절임장아찌 3종
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# ===========끝===========
# ---8번 식당파싱 시작 ---
# 서울 강남구 역삼동 642-1
# 주소 뽑기 성공
# =========================================
#
# 대한민국 대표 찜닭 브랜드 봉추찜닭!!!더이상 말이 필요없는 그곳!!!최고의 찜닭을 이제 원하는곳에서도 드실수 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 닭,쌀,고추,배추 : 국내산김치고춧가루 : 국내산,중국산혼합강황떡: 쌀  국내산치즈알떡: 치즈  호주산
#
# 가게 원산지 뽑기 성공
# =========================================
# 22000
# 최소 금액 성공
# =========================================
# [찜닭]
# 음식 카테고리 성공
# =========================================
# [공기밥]
# 음식 카테고리 성공
# =========================================
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# [음료수]
# 음식 카테고리 성공
# =========================================
# [찜닭]
# 음식 카테고리 성공
# =========================================
# 찜닭(대, 4~5인분)
# 음식메뉴 성공
# ===============
# 동치미 4그릇이 제공됩니다.메뉴 특성상 면이 불거나, 국물이 줄어들 수 있습니다.
# 음식정보 성공
# ===============
# 48000
# 금액 성공
# ===============
# 찜닭(중, 3~4인분)
# 음식메뉴 성공
# ===============
# 동치미 3그릇이 제공됩니다.메뉴 특성상 면이 불거나, 국물이 줄어들 수 있습니다.
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 찜닭(소, 2~3인분)
# 음식메뉴 성공
# ===============
# 동치미 2그릇이 제공됩니다.메뉴 특성상 면이 불거나, 국물이 줄어들 수 있습니다.
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# [공기밥]
# 음식 카테고리 성공
# =========================================
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [추가 메뉴]
# 음식 카테고리 성공
# =========================================
# 치즈알떡추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 강황떡추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 섞어떡 추가 (치즈알떡 + 강황떡)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 당면추가
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# [음료수]
# 음식 카테고리 성공
# =========================================
# 사이다
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 콜라
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# ===========끝===========
# ---9번 식당파싱 시작 ---
# 서울 서초구 서초동 1317-31 세계빌딩 3층
# 주소 뽑기 성공
# =========================================
#
# 산지 제철 식재로 만든 건강한 밥상
#
# 계절의 흐름에 따라 순리에 맞게 키워낸 생명의 먹을거리야말로 우리의 몸을 가장 잘 이해하고 따뜻하게 품어줄 수 있습니다.
#
# 계절밥상은 우리 땅, 채소, 우리의 풍토가 빚어낸 다양한 발표 식품들이 '진짜 우리의 맛', 진짜 최고의 먹을거리'라고 믿습니다
#
# 우리 몸과 마음의 건강을 생각하는 한식 브랜드 '계절밥상'은 제철 음식의 의미와 가치를 나와 내가 살고 있는 땅과의 관계를 다시 생각하게 할 것 입니다.
#
# CJ푸드빌은 '자연스러운 삶'을 꿈꾸는 사람들을 위해 사계절이 있는 그래서 소박하지만 건강하고 자연스러운 밥상을 고민 한 끝에 '계절밥상'이라는 한식 브랜드를 탄생시켰습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 아삭 깍두기 볶음밥:(쌀:국내산)오동통 꼬막 볶음밥:(쌀:국내산)제철 쌈밥 도시락:쌀:(국내산, 오징어어묵무침(오징어:원양산)유부초밥&닭튀김도시락:(유부초밥(쌀:국내산), 오징어어묵무침(오징어:원양산)), 옛날치킨(닭고기:브라질산)충무김밥&닭튀김도시락:(충무김밥(쌀:국내산), 오징어어묵무침(오징어:원양산), 옛날치킨(닭고기:브라질산))고추장 삼겹살 도시락:(쌀:국내산, 돼지고기:독일산+칠레산)마포식 돼지 간장구이 도시락:(쌀:국내산, 돼지고기:미국산, 배추김치 [배추(:국내산),고춧가루(국내산)])달콤 호박죽:(찹쌀가루:국내산)김치말이 국수:(콩:외국산)백미밥:(쌀:국내산)바삭 옛날치킨:(닭고기:브라질산)양념 옛날치킨:(닭고기:브라질산)고추장 삼겹살 직화구이:(돼지고기:독일산+칠레산)마포식 돼지 간장구이:(돼지고기:미국산)쌈장 닭구이:(닭고기:브라질산)계절밥상 모둠구이:(고추장삼겹살(돼지고기:독일산,칠레산), 쌈장닭(닭고기: 브라질산), 마포식돼지간장(돼지고기: 미국산))
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [볶음밥/덮밥]
# 음식 카테고리 성공
# =========================================
# [실속 도시락]
# 음식 카테고리 성공
# =========================================
# [곁들임&분식]
# 음식 카테고리 성공
# =========================================
# [주전부리]
# 음식 카테고리 성공
# =========================================
# [직화구이]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [별미]
# 음식 카테고리 성공
# =========================================
# [볶음밥/덮밥]
# 음식 카테고리 성공
# =========================================
# 아삭 깍두기 볶음밥
# 음식메뉴 성공
# ===============
# 아삭한 깍두기를 넣고 매콤하게 볶은 계절밥상 대표 볶음밥
# 음식정보 성공
# ===============
# 6900
# 금액 성공
# ===============
# 오통통 꼬막 볶음밥
# 음식메뉴 성공
# ===============
# 쫄깃하고 오통통한 꼬막살을 넣은 별미 볶음밥
# 음식정보 성공
# ===============
# 8300
# 금액 성공
# ===============
# [실속 도시락]
# 음식 카테고리 성공
# =========================================
# 제철 쌈밥 도시락
# 음식메뉴 성공
# ===============
# 건강한 제철 쌈밥과 계절밥상 부침개를 곁들인 도시락
# 음식정보 성공
# ===============
# 7200
# 금액 성공
# ===============
# 유부초밥&옛날치킨 도시락
# 음식메뉴 성공
# ===============
# 새콤달콤 유부 초밥과 옛날치킨을 곁들인 알찬 도시락
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 충무김밥&옛날치킨 도시락
# 음식메뉴 성공
# ===============
# 충무김밥과 옛날치킨을 곁들인 알찬 도시락
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 고추장 삼겹살 도시락
# 음식메뉴 성공
# ===============
# 비법 고추장 소스를 발라 직화로 구운 고추장 삼겹살을 넉넉하게 담은 도시락
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 마포식 돼지 간장구이 도시락
# 음식메뉴 성공
# ===============
# 남녀노소 누구나 좋아하는 돼지고기 간장구이 도시락
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# [곁들임&분식]
# 음식 카테고리 성공
# =========================================
# 달콤 호박죽
# 음식메뉴 성공
# ===============
# 아침 식사로,  다이어트 중에도, 밥 맛 없는 날에도~ 달콤한 호박죽
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 김치말이 국수
# 음식메뉴 성공
# ===============
# 진하고 개운한 김치 국물에 쌀면을 넣은 김치말이 국수.[TIP!] 직화구이와 함께 드시면 환상 궁합
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 마늘 풍미 떡볶이
# 음식메뉴 성공
# ===============
# 마늘 풍미가 더해진 매콤한 고추장 떡볶이
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 눈꽃치즈 떡볶이
# 음식메뉴 성공
# ===============
# 소복히 올린 치즈의 고소한 맛을 더한 고추장 떡볶이
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 바삭 왕교자
# 음식메뉴 성공
# ===============
# 노릇하게 튀겨낸 속이 알찬 왕교자 튀김
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 스윗 칠리 왕교자
# 음식메뉴 성공
# ===============
# 매콤달콤한 칠리 소스로 버무린 비빔 왕교자
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 백미밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 달걀후라이
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [주전부리]
# 음식 카테고리 성공
# =========================================
# 바삭 옛날치킨
# 음식메뉴 성공
# ===============
# 바삭하게 튀겨 낸 계절밥상 순살 옛날치킨
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 양념 옛날치킨
# 음식메뉴 성공
# ===============
# 바삭하게 튀겨 낸 순살에 특제 양념으로 버무린 양념치킨
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# [직화구이]
# 음식 카테고리 성공
# =========================================
# 고추장 삼겹살 직화구이 (공기밥 별도)
# 음식메뉴 성공
# ===============
# 비법 고추장 소스를 발라 직화로 구워 불 맛 가득한 삼겹살구이와 쌈채소
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 마포식 돼지 간장구이 (공기밥 별도)
# 음식메뉴 성공
# ===============
# 달콤 짭조롬한 간장 소스에 양념하여 구운 돼지구이와 쌈채소
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 쌈장 닭구이 (공기밥 별도)
# 음식메뉴 성공
# ===============
# 특제 쌈장 소스를 발라 구워 낸 닭다리살구이와 쌈채소
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 계절밥상 모둠구이 (공기밥 별도)
# 음식메뉴 성공
# ===============
# 계절밥상 인기메뉴 직화구이 3종을 모두 맛볼 수 있는 모듬구이
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (245ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 사이다 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 생수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [별미]
# 음식 카테고리 성공
# =========================================
# 계절밥상 바닐라 아이스크림
# 음식메뉴 성공
# ===============
# 인공 바닐라 향이 아닌 진짜 바닐라빈을 사용하여 깊은 풍미가 일품인 바닐라 아이스크림유의사항: 보냉팩에 담아 제공되며, 보냉유지시간은 40분~1시간입니다.
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# 계절밥상 녹차 아이스크림
# 음식메뉴 성공
# ===============
# 빛을 보지 않고 자란 보성 차광녹차의 함량을 높여진한 향과 맛을 낸 녹차 아이스크림유의사항: 보냉팩에 담아 제공되며, 보냉유지시간은 40분~1시간입니다.
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# ===========끝===========
# ---10번 식당파싱 시작 ---
# 서울 강남구 역삼동 669-21 지하1층
# 주소 뽑기 성공
# =========================================
#
# 돼지런은 매일매일 공수하는 생삼겹의 풍미를 높이기 위해
# 생 로즈마리, 월계수, 올리브 유 등 다양한 허브를 넣고조리합니다.
#
# 고기가 맛있는 최적의 온도인 -2도에서 고기전용 숙성고로 숙성하며,
# 때문에 저희 고기의 풍미는 다른 곳과는 다르다고 자부합니다.
#
# 숙성육의 풍미와 감칠맛을 가장 잘 느낄 수 있는 다양한 소스와
# 식사도 돼지런의 또 다른 자랑입니다.
#
# 또한, Chef 의 노하우가 들어간 볶은 천일염 마늘소금, 볶음 쌈장, 생와사비 등
# 고기를 맛있게 즐기실 수 있는 소스를 더하였습니다.
#
# 이제, 더 맛있는 허브 숙성 돼지고기를집에서 즐겨보세요.
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# * 배추김치(중국산)* 고춧가루(중국산)* 쌀(국내산)* 삼겹살 (캐나다산)* 목살 (국내산, 캐나다산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 12000
# 최소 금액 성공
# =========================================
# [숙성 돼지고기]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [돼지런 X 종선이네 Collaboration]
# 음식 카테고리 성공
# =========================================
# [돼지런 X 미듬영농조합 (한정판매)]
# 음식 카테고리 성공
# =========================================
# [숙성 돼지고기]
# 음식 카테고리 성공
# =========================================
# 허브 숙성 삼겹살 세트 (250g)
# 음식메뉴 성공
# ===============
# 고기+김치찌개+쌀밥+반찬세트 (볶음김치,매실부추 파절이, 수제 짱아찌, 무쌈),소스 3종 (수제쌈장, 볶은 천일염, 와사비), 캔콜라
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 허니 고추장 삼겹살 세트 (250g)
# 음식메뉴 성공
# ===============
# 고기+김치찌개+쌀밥+반찬세트 (볶음김치,매실부추 파절이, 수제 짱아찌, 무쌈),소스 3종 (수제쌈장, 볶은 천일염, 와사비), 캔콜라
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 블랙페퍼 삼겹살 세트 (250g)
# 음식메뉴 성공
# ===============
# 고기+김치찌개+쌀밥+반찬세트 (볶음김치,매실부추 파절이, 수제 짱아찌, 무쌈),소스 3종 (수제쌈장, 볶은 천일염, 와사비), 캔콜라
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 수원식 마늘 간장 삼겹살 세트 (250g)
# 음식메뉴 성공
# ===============
# 고기+김치찌개+쌀밥+반찬세트 (볶음김치,매실부추 파절이, 수제 짱아찌, 무쌈),소스 3종 (수제쌈장, 볶은 천일염, 와사비), 캔콜라
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 2인세트
# 음식메뉴 성공
# ===============
# 고기 (2종 선택) +김치찌개 2개+ 쌀밥 2개+반찬세트 (볶음김치,매실부추 파절이, 수제 짱아찌, 무쌈),소스 3종 (수제쌈장, 볶은 천일염, 와사비), 콜라 500ml
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 된장박이 삼겹살 세트(250g)
# 음식메뉴 성공
# ===============
# 고기+김치찌개+쌀밥+반찬세트 (볶음김치,매실부추 파절이, 수제 짱아찌, 무쌈),소스 3종 (수제쌈장, 볶은 천일염, 와사비), 캔콜라
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# 고추장 껍삼 세트(300g)
# 음식메뉴 성공
# ===============
# 삼겹살&돼지껍데기+김치찌개+쌀밥+반찬세트(볶음김치, 매실부추 파절이, 수제 짱아찌, 무쌈), 소스3종 (수제쌈장, 볶음 천일염, 와사비), 캔콜라
# 음식정보 성공
# ===============
# 16500
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 깍두기 볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 알 많이 계란찜
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 모짜렐라 콘치즈 김치전
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 김치찌개
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 묵은지 김치찌개
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 차돌 된장찌개
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
# 한국최고 품종. 참드림 (경기 5호)
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 칠성사이다 (500ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 대만식 블랙티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 대만식 블랙밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# 대만식 타로밀크티 (Large)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2900
# 금액 성공
# ===============
# [돼지런 X 종선이네 Collaboration]
# 음식 카테고리 성공
# =========================================
# 간장 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 쌈장 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 장독대 고추장 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 블랙페퍼 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 레몬크림 닭강정 (반마리)
# 음식메뉴 성공
# ===============
# 돼지런과 종선이네가 만나, 종선이네 Best Menu를 선보입니다.구성 : 쌈, 피클
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 마늘간장 찜닭갈비
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 볶음 짜장 찜닭갈비
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 허니고추장 찜닭갈비
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 불닭 찜닭갈비
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# [돼지런 X 미듬영농조합 (한정판매)]
# 음식 카테고리 성공
# =========================================
# 우리쌀 단팥빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 순우유 쌀식빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 소시지 치즈빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 먹물 & 떡 크런치빵
# 음식메뉴 성공
# ===============
# 경기도 평택의 유기농 쌀가루와 최고급 친환경만 엄선하여 천연재료로 만든 쌀빵
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# ...
# 공깃밥 별도
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 양지무침
# 음식메뉴 성공
# ===============
# 공깃밥 별도
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 모듬수육전골 (2~3인분)
# 음식메뉴 성공
# ===============
# 공깃밥 별도깊은향의 수삼과 다양한 부위의 고기가 듬뿍 들어간 영양보충에 으뜸인 모듬수육 전골
# 음식정보 성공
# ===============
# 40000
# 금액 성공
# ===============
# 육개장 전골 (2~3인분)
# 음식메뉴 성공
# ===============
# 공깃밥 별도
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 대장갈비찜 (2~3인분)
# 음식메뉴 성공
# ===============
# 공깃밥 별도
# 음식정보 성공
# ===============
# 45000
# 금액 성공
# ===============
# 부대전골 (2~3인분)
# 음식메뉴 성공
# ===============
# 공깃밥 별도
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 대장손만두전골 (2~3인분)
# 음식메뉴 성공
# ===============
# 공깃밥 별도
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 파인 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---94번 식당파싱 시작 ---
# 서울 강남구 대치동 890-45 1층
# 주소 뽑기 성공
# =========================================
#
# "불 피우고 자리 깔면"
# 그곳이 해장옥
# 오늘은 이 국밥 한 그릇으로 세상을 호령하세요!!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 소고기, 김치(배추,고춧가루), 쌀 : 국내산
# 꽃게 : 중국산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [국밥]
# 음식 카테고리 성공
# =========================================
# [요리]
# 음식 카테고리 성공
# =========================================
# [배숙이]
# 음식 카테고리 성공
# =========================================
# [달빵]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [국밥]
# 음식 카테고리 성공
# =========================================
# 해장국밥 (공깃밥 별도)
# 음식메뉴 성공
# ===============
# 공깃밥 별도,김치제공해장국집 아들인 내 친구 엄마의 비법 선지국밥
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 한우국밥 (공깃밥 별도)
# 음식메뉴 성공
# ===============
# 공깃밥 별도,김치제공아까 그 친구 엄마의 또 하나의 숨겨진 한우 국밥
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 꽃게콩탕 (공깃밥 별도)
# 음식메뉴 성공
# ===============
# 공깃밥 별도,김치제공콩을 갈아 육수, 시래기, 꽃게를 넣어 끓인 고소한 콩국밥
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 술국 (공깃밥 별도)
# 음식메뉴 성공
# ===============
# 공깃밥 별도,김치제공해장할 땐 해장국, 술 마실 땐 술국
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 한우 떡국 (공깃밥 별도)
# 음식메뉴 성공
# ===============
# 공깃밥 별도,김치제공
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 미나리 꽁치 비빔밥
# 음식메뉴 성공
# ===============
# 공깃밥 포함독소 해독에 좋은 미나리, 바삭한 꽁치와 직접 만든 간장 소스가 들어간 비빔밥
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# [요리]
# 음식 카테고리 성공
# =========================================
# 한우 빙쌈 (공깃밥 별도)
# 음식메뉴 성공
# ===============
# 공깃밥 별도,김치제공향긋한 깻잎채와 차가운 수육의 물아일체
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 한우 수육 (공깃밥 별도)
# 음식메뉴 성공
# ===============
# 공깃밥 별도,김치제공지금까지의 수육은 잊으셔도 될 맛
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 곱창전골 (조리)
# 음식메뉴 성공
# ===============
# 공깃밥 별도,김치제공음식을 살짝 데워서 바로 드실 수 있도록 조리했으나 차가워질 경우 전자레인지에 데워서 드시거나 냄비에 끓여드세요
# 음식정보 성공
# ===============
# 49000
# 금액 성공
# ===============
# 곱창전골 (비조리)
# 음식메뉴 성공
# ===============
# 공깃밥 별도, 김치제공가스, 인덕션에 직접 조리 가능한 포장용기입니다.전자레인지 및 재사용은 불가능 합니다.다대기, 들깨가루, 육수를 용기에 부은 뒤 약 7분간 끓여주세요우동면은 개인취향에 따라 알맞게 넣어주세요
# 음식정보 성공
# ===============
# 49000
# 금액 성공
# ===============
# 매콤한우 내장볶음
# 음식메뉴 성공
# ===============
# 공깃밥 별도, 김치제공쫄깃한 한우 내장, 매콤한 비법 양념과 채소를 넣어 맛있게 볶아낸 요리
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 홧병전골(볶음밥 제외)
# 음식메뉴 성공
# ===============
# 화끈한 홧병전골로 묵혀놨던 스트레스를 날려버리세요
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# [배숙이]
# 음식 카테고리 성공
# =========================================
# 배숙이 (250ml)
# 음식메뉴 성공
# ===============
# 주당인 사장이 숙취해소를 위해 약 8-10시간 중불로 달여 만든 헛개나무꿀 배음료.진짜 술 깹니다.
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [달빵]
# 음식 카테고리 성공
# =========================================
# 달빵
# 음식메뉴 성공
# ===============
# 탄수화물과 당분의 조화가 술로 인한 두통을 없애는 단팥빵
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---95번 식당파싱 시작 ---
# 서울 서초구 서초동 1555-9
# 주소 뽑기 성공
# =========================================
#
# 음식은 눈으로 만나 코 끝을 스쳐 입으로 맞이한다 그래서 음식은 단순히 먹는 것이 아니라 함께 즐기는 것이다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 소고기: 국내산 한우
# 섞박지: 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# [식사]
# 음식 카테고리 성공
# =========================================
# [안주]
# 음식 카테고리 성공
# =========================================
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# [식사]
# 음식 카테고리 성공
# =========================================
# 곰탕
# 음식메뉴 성공
# ===============
# 공깃밥, 김치, 섞박지 미포함한우곰탕으로 깊은 국물 맛의 대표 메뉴입니다.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 살로만
# 음식메뉴 성공
# ===============
# 공깃밥, 김치, 섞박지 미포함살코기 위주로 된 곰탕입니다.
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 특 곰탕
# 음식메뉴 성공
# ===============
# 공깃밥, 김치, 섞박지 미포함육수와 고기양이 많은 곰탕입니다.
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# [안주]
# 음식 카테고리 성공
# =========================================
# 곰술국
# 음식메뉴 성공
# ===============
# 조리, 비조리 선택
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 수육
# 음식메뉴 성공
# ===============
# 조리, 비조리 선택뜨끈한 국물과 같이 드시는 술안주입니다.
# 음식정보 성공
# ===============
# 46000
# 금액 성공
# ===============
# 규아상전골
# 음식메뉴 성공
# ===============
# 조리,비조리 선택한우 수제 만두전골
# 음식정보 성공
# ===============
# 37000
# 금액 성공
# ===============
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# 규아상 (한우수제만두,10pcs)
# 음식메뉴 성공
# ===============
# 조리, 비조리 선택가능찐만두
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 쌀면사리 (비조리)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 섞박지
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# ===========끝===========
# ---96번 식당파싱 시작 ---
# 서울 강남구 논현동 267-1 1층 2호
# 주소 뽑기 성공
# =========================================
# 김치찌개 전문점 '단지'입니다.
#
# 가게 소개 뽑기 성공
# =========================================
#
# 쌀,김치,고춧가루,돼지고기,닭,오리 : 국내산
# 고등어 : 노르웨이산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 13000
# 최소 금액 성공
# =========================================
# [메인]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [메인]
# 음식 카테고리 성공
# =========================================
# 양푼이 김치찌개 (2인분)
# 음식메뉴 성공
# ===============
# 공기밥 포함
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 양푼이 김치찌개 (3인분)
# 음식메뉴 성공
# ===============
# 공기밥 포함
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 김치 고등어조림 (2인분)
# 음식메뉴 성공
# ===============
# 공기밥 포함
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 김치 고등어조림 (3인분)
# 음식메뉴 성공
# ===============
# 공기밥 포함
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 매운갈비김치찜 (2인분)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# 매운갈비김치찜 (3인분)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 39000
# 금액 성공
# ===============
# 제육볶음
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 오징어덮밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 김치볶음밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 계란말이
# 음식메뉴 성공
# ===============
# 공기밥 미포함
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---97번 식당파싱 시작 ---
# 서울 서초구 잠원동 39-10
# 주소 뽑기 성공
# =========================================
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 한우뼈,머리고기 : 국내산(한우)
# 소갈비,도가니,꼬리,사골 : 미국산
# 목심,양지,사태,꼬리,사골 : 호주산
# 쌀,배추,무,만두,떡 : 국내산
# 배추김치 : 배추(국내산), 고추가룻(중국산)
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 7000
# 최소 금액 성공
# =========================================
# [식사]
# 음식 카테고리 성공
# =========================================
# [수육,찜]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [식사]
# 음식 카테고리 성공
# =========================================
# 한결설렁탕
# 음식메뉴 성공
# ===============
# 공깃밥 기본제공양지 + 도가니 + 머리고기뽀얀 사골국물에 양지, 도가니, 머리고기를 넣고 끓여 진한 국물과 다양한 고기맛이 일품입니다.
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 특설렁탕
# 음식메뉴 성공
# ===============
# 공깃밥 기본제공설렁탕에 쫄깃하고 부드러운 도가니를 추가한 깔끔한 맛의 인기메뉴 입니다.
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 설렁탕
# 음식메뉴 성공
# ===============
# 공깃밥 기본제공기름기를 제거하여 담백한 맛의 뽀얀 국물맛이 일품입니다.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 만두설렁탕
# 음식메뉴 성공
# ===============
# 공깃밥 기본제공진한 설렁탕에 육즙이 풍부한 고기만두를 함께 즐기세요~
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 사골우거지국밥
# 음식메뉴 성공
# ===============
# 공깃밥 기본제공사골국물에 우거지를 넣어 얼큰하고 구수한 맛이 일품입니다.
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 만두냉면
# 음식메뉴 성공
# ===============
# 공깃밥 별도냉면의 부족함을 만두로 채우세요.
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 함흥냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 사골떡만두국
# 음식메뉴 성공
# ===============
# 공깃밥 별도설렁탕 육수 사골국물에 끓인 더욱 고소한 맛의 떡만두국
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 사골떡국
# 음식메뉴 성공
# ===============
# 공깃밥 별도설렁탕 육수 사골국물에 끓인 더욱 고소한 맛의 떡국
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 버섯소불고기전골 (2인분, 목심, 260g)
# 음식메뉴 성공
# ===============
# 공깃밥 포함신선한 생고기에 각종버섯과 싱싱한 야채를 곁들인 맛과 영양이 풍부한 전골요리
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 버섯소불고기전골 (3인분, 목심, 390g)
# 음식메뉴 성공
# ===============
# 공깃밥 포함신선한 생고기에 각종버섯과 싱싱한 야채를 곁들인 맛과 영양이 풍부한 전골요리
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 갈비탕
# 음식메뉴 성공
# ===============
# 공깃밥 기본제공인삼, 대추, 팽이버섯등이 첨가된 진한 육수가 어우러진 깔끔한 맛
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 특 갈비탕
# 음식메뉴 성공
# ===============
# 공깃밥 기본제공갈비의 양을 추가하여 더욱 넉넉하게 드실수 있습니다.
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 도가니탕
# 음식메뉴 성공
# ===============
# 공깃밥 기본제공담백하고 깔끔한 사골 국물에 쫄깃하고 부드러운 도가니의 맛이 일품입니다.
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 꼬리곰탕
# 음식메뉴 성공
# ===============
# 공깃밥 기본제공소꼬리의 영양이 한가득 담긴 전통 보양식
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 삼계탕
# 음식메뉴 성공
# ===============
# 공깃밥 별도하절기 메뉴 입니다.엄선된 100% 국내산재료(생밤, 생은행, 대추, 인삼, 찹쌀, 닭)로 알차게 속을채운 후 진한 사골국물에 끓여내어뽀얗고 고소한 맛이 일품입니다.
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 찐만두 (고기만두, 9pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [수육,찜]
# 음식 카테고리 성공
# =========================================
# 수육 (2~3인분)
# 음식메뉴 성공
# ===============
# 사골육수 국물에 차돌양지와 머리고기를 넣고 인삼, 대추, 피망, 버섯등 신선한 야채를 곁들인 담백한 전골요리
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 접시수육 (양지)
# 음식메뉴 성공
# ===============
# 엄선된 차돌양지살을 대형 가마솥에서 익혀 담백하고 부드럽습니다.
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 모둠수육 (소, 2~3인분)
# 음식메뉴 성공
# ===============
# 사골육수 국물에 차돌양지와 머리고기, 도가니를 넣고 인삼, 대추, 피망, 버섯등 신선한 야채를 곁들인 담백한 전골요리
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 모둠수육 (대, 3~4인분)
# 음식메뉴 성공
# ===============
# 사골육수 국물에 차돌양지와 머리고기, 도가니를 넣고 인삼, 대추, 피망, 버섯등 신선한 야채를 곁들인 담백한 전골요리
# 음식정보 성공
# ===============
# 49000
# 금액 성공
# ===============
# 도가니수육 (소, 2~3인분)
# 음식메뉴 성공
# ===============
# 사골육수 국물에 쫄깃하고 부드러운 도가니를 넣고 인삼, 대추, 피망, 버섯등 신선한 야채를 곁들인 담백한 전골요리
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 도가니수육 (대, 3~4인분)
# 음식메뉴 성공
# ===============
# 사골육수 국물에 쫄깃하고 부드러운 도가니를 넣고 인삼, 대추, 피망, 버섯등 신선한 야채를 곁들인 담백한 전골요리
# 음식정보 성공
# ===============
# 49000
# 금액 성공
# ===============
# 매운소갈비찜 (소, 2~3인분)
# 음식메뉴 성공
# ===============
# 엄선된 양질의 갈비와 인삼, 대추, 피망, 버섯등 신선한 야채를 곁들인 매콤달콤한 맛의 인기메뉴
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 매운소갈비찜 (대, 3~4인분)
# 음식메뉴 성공
# ===============
# 엄선된 양질의 갈비와 인삼, 대추, 피망, 버섯등 신선한 야채를 곁들인 매콤달콤한 맛의 인기메뉴
# 음식정보 성공
# ===============
# 49000
# 금액 성공
# ===============
# 간장 갈비찜 (소, 2~3인분)
# 음식메뉴 성공
# ===============
# 엄선된 양질의 갈비와 인삼, 대추, 피망, 버섯등 신선한 야채를 곁들인 맵지 않고 달콤한 맛의 인기메뉴
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 간장 갈비찜 (대, 3~4인분)
# 음식메뉴 성공
# ===============
# 엄선된 양질의 갈비와 인삼, 대추, 피망, 버섯등 신선한 야채를 곁들인 맵지 않고 달콤한 맛의 인기메뉴
# 음식정보 성공
# ===============
# 49000
# 금액 성공
# ===============
# 꼬리찜 (소, 2인분)
# 음식메뉴 성공
# ===============
# 과도한 업무와 스트레스로 기력이 허약해진 현대인에게 추천하는 몸보신용 스테미너 보신음식
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 꼬리찜 (중, 3인분)
# 음식메뉴 성공
# ===============
# 과도한 업무와 스트레스로 기력이 허약해진 현대인에게 추천하는 몸보신용 스테미너 보신음식
# 음식정보 성공
# ===============
# 48000
# 금액 성공
# ===============
# 꼬리찜 (대, 4인분)
# 음식메뉴 성공
# ===============
# 과도한 업무와 스트레스로 기력이 허약해진 현대인에게 추천하는 몸보신용 스테미너 보신음식
# 음식정보 성공
# ===============
# 69000
# 금액 성공
# ===============
# 도가니 무침
# 음식메뉴 성공
# ===============
# 새콤 달콤한 고추장소스와 각종 야채가 어우러진 한결설렁탕만의 독특한 인기메뉴.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 파인애플 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 웰치스 포도 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---98번 식당파싱 시작 ---
# 서울 강남구 논현동 248-1
# 주소 뽑기 성공
# =========================================
#
# 오랜시간 많은 고객분들에게 꾸준한 사랑을 받고 있는 50년 정통대가원(구 대도식당)입니다.
# 최상급 한우와 전통의 맛, 정식한 맛 그대로만 고집합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 생등심 : 소고기(국내산)
# 한우 육개장,한우 대가곰탕,곰 칼국수 : 소고기(호주산),사골(국내산)
# 한우 도가니탕 : 사골(국내산),도가니(국내산,미국산)
# 냉면 고기 : 소고기(호주산)
# 쌀,배추, : 국내산
# 김치,고춧가루 : 중국산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [식사]
# 음식 카테고리 성공
# =========================================
# [세트 메뉴]
# 음식 카테고리 성공
# =========================================
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# [음료수]
# 음식 카테고리 성공
# =========================================
# [식사]
# 음식 카테고리 성공
# =========================================
# 깍두기 볶음밥 (2인분)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15500
# 금액 성공
# ===============
# 생등심 (180g)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 40000
# 금액 성공
# ===============
# 한우곰탕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 우렁강된장비빔밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 한우도가니탕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 한우육개장
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 한우만두곰탕
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 물냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 비빔냉면
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 곰탕칼국수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [세트 메뉴]
# 음식 카테고리 성공
# =========================================
# 숯불고기 물냉면 세트
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# 숯불고기 비빔냉면 세트
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13000
# 금액 성공
# ===============
# [추가메뉴]
# 음식 카테고리 성공
# =========================================
# 공깃밥
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# [음료수]
# 음식 카테고리 성공
# =========================================
# 콜라 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 사이다 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# ===========끝===========
# ---99번 식당파싱 시작 ---
# 서울 강남구 대치동 891-41 2층
# 주소 뽑기 성공
# =========================================
#
# 고품격 프리미엄 부대찌개의 새로운 맛을 느껴보세요!
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쇠고기, 돼지고기, 소시지, 햄 : 미국산쌀 : 국내산쌀 : 국내산김치 : 중국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
