# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 카페[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[11]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 25:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 카페 데이터(이미지) 수집
soup = BeautifulSoup(html, 'lxml')
img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
count = 1
for i in img:
    img_url = i.get_text("url", strip=True)
    img_url_parse = img_url[4:-1]
    try:
        urllib.request.urlretrieve(img_url_parse, f'{count}.pizza_food_img.jpg')
    except:
        pass
    count += 1

# 일식 데이터(식당명) 수집
japan_store_list = []
japan_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in japan_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(japan_store_list):
    print(i, name)


    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 5:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='피자',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=1),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
        print('음식 카테고리 성공')
        print('=========================================')
        
        store_category_foods = menu.select(".row-menu")

        for food in store_category_foods:
            food_menu = food.select_one(".col-menu > strong").get_text(strip=True)
            print(food_menu)
            print('음식메뉴 성공')
            print('===============')
            food_info = food.select_one(".col-menu > span").get_text(strip=True)
            print(food_info)
            print('음식정보 성공')
            print('===============')
            food_money = food.select_one("span.calculate-price").get_text(strip=True)
            food_moneys = food_money.replace(",", "")
            print(food_moneys)
            print('금액 성공')
            print('===============')
            
            Food.objects.create(
            category=food_category,
            name=food_menu,
            price=food_moneys,
            food_info=food_info,
            )

        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:83: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 강남구 역삼동 831-23 1층
# 주소 뽑기 성공
# =========================================
#
# 정통 나폴리 화덕피자를 간편하고 가볍게 즐길 수 있는 이탈리안 익스프레스 핏제리아 입니다.
#
# (배달 시 매장에서 나가는 영수증으로 해피포인트 2% 적립이 가능합니다.)
#
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# 홈스타일초리조 피자 : 돼지고기_스페인산버섯 페퍼로니 피자 : 돼지고기_국내산,외국산 소고기_호주산불고기 피자 : 소고기_호주산에그 베이컨 피자 : 돼지고기_미국산시금치 베이컨 피자 : 돼지고기_미국산베이컨 포테이토 피자 : 돼지고기_미국산마르게리따 피자&홈스타일 초리조 피자 : 돼지고기_스페인산버섯 페퍼로니 피자&불고기 피자 : 돼지고기_국내산,외국산 소고기_호주산이탈리안 그라탕 : 소고기_호주산살라미 피자 : 돼지고기_스페인산스파이시 베이크윙 : 닭고기_태국산훈제치킨 & 칠리소스 : 닭고기_국내산
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [푸드플라이 세트]
# 음식 카테고리 성공
# =========================================
# [피자]
# 음식 카테고리 성공
# =========================================
# [그라탕]
# 음식 카테고리 성공
# =========================================
# [샐러드]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [푸드플라이 세트]
# 음식 카테고리 성공
# =========================================
# 마르게리따피자 & 그라탕 세트
# 음식메뉴 성공
# ===============
# 마르게리따 피자(L) + 이탈리안 그라탕 + 에그&넛츠 그린 샐러드로 구성된 세트입니다.마르게리따 피자 - 신선한 모짜렐라 치즈, 진한 토마토 소스, 향긋하 바질이 맛의 조화를 이루는 이탈리아 대표 피자이탈리안 그라탕 - 베사멜 소스와 모짜렐라 치즈, 고르곤졸라 치즈가 듬뿍 올라가 진한 크림 소스의 맛을 느낄 수 있는 이탈리안 가정식 그라탕에그&넛츠 그린 샐러드 - 계란, 아몬드, 피칸, 호두와 그린 채소를 함께 담아 리코타 치즈, 화이트 드레싱으로 맛을 더한 샐러드
# 음식정보 성공
# ===============
# 30400
# 금액 성공
# ===============
# 4가지치즈피자 & 베이크윙 세트
# 음식메뉴 성공
# ===============
# 4가지 치즈 피자(L)+스파이시 베이크윙+에그&넛츠 그린 샐러드로 구성된 세트입니다.4가지 치즈 피자 - 리코타, 모짜렐라, 고르곤졸라, 파르미지아노의 네 가지 치즈를 듬뿍 올려 치즈의 깊은 풍미를 느낄 수 있고 달콤한 꿀이 함께 제공되는 피자스파이시 베이크윙 - 칠리소스로 양념하여 화덕에서 구워낸 속살이 촉촉하고 부드러운 베이크윙에그&넛츠 그린 샐러드 - 계란, 아몬드, 피칸, 호두와 그린 채소를 함께 담아 리코타 치즈, 화이트 드레싱으로 맛을 더한 샐러드
# 음식정보 성공
# ===============
# 31900
# 금액 성공
# ===============
# 에그베이컨피자 & 훈제치킨 세트
# 음식메뉴 성공
# ===============
# 에그 베이컨 피자(L)+훈제치킨+에그&넛츠 그린 샐러드로 구성된 세트입니다.에그 베이컨 피자 - 삶은 계란과 베이컨을 토핑하고 화이트 소스로 고소한 맛을 더한 피자훈제치킨&칠리소스- 화덕에서 구워 참나무 향이 깊게 베인 부드러운 치킨, 칠리소스 제공에그&넛츠 그린 샐러드 - 계란, 아몬드, 피칸, 호두와 그린 채소를 함께 담아 리코타 치즈, 화이트 드레싱으로 맛을 더한 샐러드
# 음식정보 성공
# ===============
# 32900
# 금액 성공
# ===============
# [피자]
# 음식 카테고리 성공
# =========================================
# 마르게리따 피자
# 음식메뉴 성공
# ===============
# 밀가루에 효모, 물, 소금을 더해 피자이올로가 직접 반죽한 피자 도우에 올리브 오일과 토마토소스, 신선한 프리미엄 치즈를 사용하여 구워낸 마르게리따 피자
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 버섯 페퍼로니 피자
# 음식메뉴 성공
# ===============
# 짭짤한 페퍼로니와 양송이 버섯, 아삭한 적양파가 어우러진 피자
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 불고기 피자
# 음식메뉴 성공
# ===============
# 달콤 짭짤한 한국식 불고기 위에 모짜렐라 치즈와 그라나파다노 치즈가 올라간 불고기 피자
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 에그 베이컨 피자
# 음식메뉴 성공
# ===============
# 삶은 계란과 베이컨을 토핑하고 화이트 소스로 고소한 맛을 더한 피자
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 시금치 베이컨 피자
# 음식메뉴 성공
# ===============
# 중앙의 계란을 섞어 먹으면 부드러운 식감과 담백한 맛이 배가 되는 시금치 베이컨 피자
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 4가지 치즈 피자
# 음식메뉴 성공
# ===============
# 꿀과 함께 먹는 리코타, 모짜렐라, 고르곤졸라, 파르미지아노 레지아노의 네가지 치즈 맛 피자
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 3가지 버섯 피자
# 음식메뉴 성공
# ===============
# 느타리 버섯, 새송이 버섯, 양송이 버섯과 송로 버섯 오일이 어우러진 피자
# 음식정보 성공
# ===============
# 11800
# 금액 성공
# ===============
# 베지테리언 피자
# 음식메뉴 성공
# ===============
# 호박, 가지, 파프리카, 양파 등 채소만으로 토핑이 이루어진 베지테리언을 위한 담백한 피자
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 베이컨 포테이토 피자
# 음식메뉴 성공
# ===============
# 부드럽고 담백한 감자에 고소한 베이컨, 새콤달콤 파인애플이 곁들여진 베이컨 포테이토 피자
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# 마르게리따 피자 & 홀스타일 초리조 피자 (Large, 12inch)
# 음식메뉴 성공
# ===============
# 하프 & 하프로 즐기는 마르게리따 피자 & 홀스타일 초리조 피자
# 음식정보 성공
# ===============
# 17500
# 금액 성공
# ===============
# 4가지 치즈 피자 & 3가지 버섯 피자  (Large, 12inch)
# 음식메뉴 성공
# ===============
# 하프 & 하프로 즐기는 4가지 치즈 피자 & 3가지 버섯 피자
# 음식정보 성공
# ===============
# 18500
# 금액 성공
# ===============
# 버섯 페퍼로니 피자 & 불고기 피자  (Large, 12inch)
# 음식메뉴 성공
# ===============
# 하프 & 하프로 즐기는 버섯 페퍼로니 피자 & 불고기 피자
# 음식정보 성공
# ===============
# 19500
# 금액 성공
# ===============
# 살라미 피자
# 음식메뉴 성공
# ===============
# 짭쪼롬하고 풍미가 깊은 살라미를 듬뿍 올린 진한 맛의 피자
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# 아티초크 레지아노 피자
# 음식메뉴 성공
# ===============
# 씹을수록 고소한 아티초크와 진한 맛의 레지아노 치즈를 듬뿍 올린 피자
# 음식정보 성공
# ===============
# 10800
# 금액 성공
# ===============
# [그라탕]
# 음식 카테고리 성공
# =========================================
# 이탈리안 그라탕
# 음식메뉴 성공
# ===============
# 베사멜 소스와 모짜렐라 치즈, 고르곤졸라 치즈가 듬뿍 올라가 진한 크림 소스의 맛을 느낄 수 있는 이탈리안 가정식 그라탕
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# [샐러드]
# 음식 카테고리 성공
# =========================================
# 에그 & 넛츠 그린 샐러드
# 음식메뉴 성공
# ===============
# 계란, 아몬드, 피칸, 호두와 그린 채소를 함께 담아 리코타 치즈, 화이트 드레싱으로 맛을 더한 샐러드
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 스파이시 베이크윙
# 음식메뉴 성공
# ===============
# 칠리소스로 양념하여 화덕에서 구워낸 속살이 촉촉하고 부드러운 베이크윙
# 음식정보 성공
# ===============
# 9000
# 금액 성공
# ===============
# 훈제치킨 & 칠리소스
# 음식메뉴 성공
# ===============
# 화덕에서 구워 참나무 향이 깊게 베인 부드러운 치킨, 칠리소스 제공
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 사이다 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:217: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 강남구 역삼동 810-13 지하1층
# 주소 뽑기 성공
# =========================================
#
# 피자로 해장(=위 세탁)을 한다는 미국 젊은이들의 문화에 착안해
# 미국 로컬 세탁소를 인테리어 컨셉으로 재현한 수제 피자&펍 전문점입니다.
# 방문 고객들 사이에서 ‘분위기 깡패’라는 애칭을 얻을 정도로 특색있는 공간에서
# 이국적인 분위기를 만끽하며 조각 피자와 맥주를 즐길 수 있습니다.
# 다양한 토핑이 올려진 조각 피자를 입맛에 따라 골라 먹는 즐거움을 선사합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 돼지고기(돼지고기, 페퍼로니) : 미국산
# 돼지고기(베이컨) : 뉴질랜드산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [조각피자]
# 음식 카테고리 성공
# =========================================
# [한판피자 (20인치)]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [조각피자]
# 음식 카테고리 성공
# =========================================
# 런드리 피자 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 포테이토 피자 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 페퍼로니 피자 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 맥앤치즈 피자 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 스피니치 베이컨 피자 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 치즈 피자 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# [한판피자 (20인치)]
# 음식 카테고리 성공
# =========================================
# 런드리 피자 (20inch)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 36000
# 금액 성공
# ===============
# 포테이토 피자 (20inch)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 페퍼로니 피자 (20inch)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 31000
# 금액 성공
# ===============
# 맥앤치즈 피자 (20inch)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 39000
# 금액 성공
# ===============
# 스피니치 베이컨 피자 (20inch)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 40000
# 금액 성공
# ===============
# 치즈 피자 (20inch)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 콘샐러드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 코카콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 닥터페퍼 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 제로콜라 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 페리에 (330ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 강남구 대치동 932-11
# 주소 뽑기 성공
# =========================================
#
# ‘피자리아 시오’는 100% 참나무장작을 사용하는 나폴리 화덕피자 레스토랑입니다.이탈리아산 ‘카푸토’ 밀가루로 반죽한 도우를 6일간 초저온 숙성한 후 나폴리에서 직수입한‘마리오아쿤토’ 화덕에 485도 이상의 고온으로 짧은 시간에 구워내 쫄깃하고 바삭하며동시에 부드러운 피자를 선보이고 있습니다.이제 건강한 먹거리 이탈리안 피자, 파스타, 샐러드를 합리적인 가격으로 집에서 편안하게 즐기세요!!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 밀가루,치즈,프로슈트 : 이탈리아산쵸리소 : 스페인산베이컨 : 유럽산새우 : 베트남산연어 : 칠레산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 18000
# 최소 금액 성공
# =========================================
# [피자 (Pizza)]
# 음식 카테고리 성공
# =========================================
# [프리티 (Fritti)]
# 음식 카테고리 성공
# =========================================
# [샐러드 (Salad)]
# 음식 카테고리 성공
# =========================================
# [파스타 (Pasta)]
# 음식 카테고리 성공
# =========================================
# [음료 (Drinks)]
# 음식 카테고리 성공
# =========================================
# [피자 (Pizza)]
# 음식 카테고리 성공
# =========================================
# 마르게리타 (11인치)
# 음식메뉴 성공
# ===============
# 이탈리아산 생모짜렐라. 이탈리아산 토마소소스. 생바질. 최고급엑스트라올리브오일.심플하지만 질리지않는 피자. 바질. 토마토소스. 올리브오일이 어우러져 오렌지향을 느낄수있다면 당신은 절대미각.
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 로마나 피자 (11인치)
# 음식메뉴 성공
# ===============
# 로마 지역에서 많이 먹던 핏짜.수제 리코타치즈와 베이컨이 조화로운 한층 부드러운 맛
# 음식정보 성공
# ===============
# 14900
# 금액 성공
# ===============
# 디아볼라 피자 (11인치)
# 음식메뉴 성공
# ===============
# 스페인산 흑돼지로 만든 쵸리소가 들어간 매콤한 핏짜
# 음식정보 성공
# ===============
# 14900
# 금액 성공
# ===============
# 시오콤비네이션 피자 (11인치)
# 음식메뉴 성공
# ===============
# 그날의 신선한 재료만을 사용한 최다 토핑핏짜
# 음식정보 성공
# ===============
# 16900
# 금액 성공
# ===============
# 루꼴라피자 (11인치)
# 음식메뉴 성공
# ===============
# 루꼴라가 듬뿍 올라간 피자리아시오 대표메뉴
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 프로슈트 루꼴라 피자 (11인치)
# 음식메뉴 성공
# ===============
# 염장한 파르마 생햄(프로슈트)와 루꼴라의 조화
# 음식정보 성공
# ===============
# 19900
# 금액 성공
# ===============
# 고르곤졸라 피자 (11인치)
# 음식메뉴 성공
# ===============
# 꿀 찍어 먹는 국민피자. 고르곤졸라의 본고장인 치레사사의 최고급 치즈 사용
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# 콰트로포르마쥬 피자 (11인치)
# 음식메뉴 성공
# ===============
# 모짜렐라, 고르곤졸라, 리코타, 까망베르!4가지 치즈맛을 한번에 느끼 실 수 있는 치즈 덕후를 위한!
# 음식정보 성공
# ===============
# 17900
# 금액 성공
# ===============
# 소고기버섯 피자 (11인치)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15900
# 금액 성공
# ===============
# CMP피자 (11인치)
# 음식메뉴 성공
# ===============
# 강력추천!!!토마토소스 우민찌 감자 모짜렐라 거추 루꼴라 방울토마토가 들어간 매콤한 맛!!!
# 음식정보 성공
# ===============
# 14900
# 금액 성공
# ===============
# 나폴리타나 (11인치)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 14900
# 금액 성공
# ===============
# 루꼴라와 차돌박이 피자 (11인치)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 19900
# 금액 성공
# ===============
# [프리티 (Fritti)]
# 음식 카테고리 성공
# =========================================
# 감베리 프리티 (새우튀김, 12pcs)
# 음식메뉴 성공
# ===============
# 세몰리나 가루를 입혀 바삭한 이탈리아식 새우튀김
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 파타띠네 프리티 (감자튀김)
# 음식메뉴 성공
# ===============
# 이탈리아식 감자튀김과 시오스페셜 소스
# 음식정보 성공
# ===============
# 6900
# 금액 성공
# ===============
# 버팔로윙 (9pcs)
# 음식메뉴 성공
# ===============
# 버팔로윙 (9pcs)
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# [샐러드 (Salad)]
# 음식 카테고리 성공
# =========================================
# 청포도 리코타 샐러드
# 음식메뉴 성공
# ===============
# 5가지채소. 유자드레싱. 발사믹드레싱.  청포도. 리코타치즈  방울토마토. 파마산치즈. 화덕에 구운 빵
# 음식정보 성공
# ===============
# 13900
# 금액 성공
# ===============
# [파스타 (Pasta)]
# 음식 카테고리 성공
# =========================================
# 감베리크레마 파스타
# 음식메뉴 성공
# ===============
# 추천!!!매콤한 로제소스에 새우가 들어간 숏파스타
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 치즈치즈 파스타
# 음식메뉴 성공
# ===============
# 4가지 치즈가 들어간 수제 토마토베이스 스파게티면
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 까르보나라 파스타
# 음식메뉴 성공
# ===============
# 생파마산치즈로 간을 한 두툼한 베이컨과 양송이가 들어간 스파게티면
# 음식정보 성공
# ===============
# 9900
# 금액 성공
# ===============
# 볼로네제
# 음식메뉴 성공
# ===============
# 우육100%토마토 미트소스 스파게티
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 고르곤날치알크림 파스타
# 음식메뉴 성공
# ===============
# 고르곤졸라 크림베이스에 날치알이 입안에서 톡톡
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 봉골레 파스타
# 음식메뉴 성공
# ===============
# 모시조개로 우려낸 해장파스타. 살짝매콤
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 루꼴라와 새우 파스타
# 음식메뉴 성공
# ===============
# 알리오올리오에 루꼴라와 새우향이 가득
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 베노베제 파스타
# 음식메뉴 성공
# ===============
# 바질의 신선한 맛과 향을 그대로 옮긴 파스타
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 해산물토마토 파스타
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# [음료 (Drinks)]
# 음식 카테고리 성공
# =========================================
# 코카콜라 (350ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 아메리카노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 카페라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 카푸치노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 유기농에이드 레몬
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 유기농에이드 석류
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 유기농에이드 블루베리
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 강남구 논현동 243-7 지하1층
# 주소 뽑기 성공
# =========================================
#
# pizza me는 이태리나폴리스타일의 피자입니다
# 신선한 최상급의 식재료와 함께 모든 소스와 퓨레를 정성스레 직접 만들고,
# 100%자연산 뉴질랜드치즈를 고집하며, 건강하고 맛있는 피자를 만들기 위해 노력하고 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# * 소고기: 미국산 초이스*후레쉬모짜렐라: 이탈리아,스위스*모짜렐라치즈:미국산 뉴질랜드*도우: 미국,캐나다
#
# 가게 원산지 뽑기 성공
# =========================================
# 18000
# 최소 금액 성공
# =========================================
# [Pizza]
# 음식 카테고리 성공
# =========================================
# [Salad&Side]
# 음식 카테고리 성공
# =========================================
# [Drink]
# 음식 카테고리 성공
# =========================================
# [Pizza]
# 음식 카테고리 성공
# =========================================
# 마르게리타 피자 (Margherita pizza)
# 음식메뉴 성공
# ===============
# 홈메이드 토마토소스, 생모짜렐라치즈, 바질
# 음식정보 성공
# ===============
# 17000
# 금액 성공
# ===============
# 비스마르크 피자 (Bismarck pizza)
# 음식메뉴 성공
# ===============
# 트러플 향의 홈메이드 버섯퓨레, 그라나파다노치즈, 버섯, 베이컨, 반숙달걀
# 음식정보 성공
# ===============
# 21000
# 금액 성공
# ===============
# 페퍼로니 피자 (Pepperoni pizza)
# 음식메뉴 성공
# ===============
# 홈메이드 토마토소스, 모짜렐라&고다치즈, 그라나파다노치즈, 페퍼로니
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 루꼴라 &시금치 피자 (Rocket & spinach pizza)
# 음식메뉴 성공
# ===============
# 화이트소스, 그라나파다노치즈, 루꼴라, 시금치, 리코타치즈, 상큼한 요거트드레싱
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 필리치즈 피자 (Philly cheese pizza)
# 음식메뉴 성공
# ===============
# 화이트소스, 소불고기, 파프리카, 할라피뇨, 양파, 모짜렐라&고다치즈, 체다치즈, 그라나파다노치즈
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 반미피자 (Vietnamese Bahn Mi Pizza)
# 음식메뉴 성공
# ===============
# 스리랏차마요소스, 홈메이드피클, 베트남식제육볶음, 고수잎, 모짜렐라&고다치즈, 그라나파다노치즈
# 음식정보 성공
# ===============
# 22000
# 금액 성공
# ===============
# 소시지&콘 피자 (JohnsonVille Sausage & Sweet Corn Pizza)
# 음식메뉴 성공
# ===============
# 홈메이드토마토소스, 모짜렐라&고다치즈, 그라나파다노치즈, 소시지와 스위트콘
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [Salad&Side]
# 음식 카테고리 성공
# =========================================
# 카프레제 (Caprese)
# 음식메뉴 성공
# ===============
# 후레쉬 모짜렐라 치즈, 토마토, 바질, 올리브오일로 맛을 낸 샐러드
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# 가든 샐러드 (Garden Salad)
# 음식메뉴 성공
# ===============
# 청정고장 양양에서 무농약으로 재배한 신선하고  맛있는 유럽채소 샐러드(클리우드 그린,로싸, 롤로, 오크, 크리스피 그린, 클라우드 레드, 코스, 버터그린)
# 음식정보 성공
# ===============
# 8000
# 금액 성공
# ===============
# 토마토 오븐 스파게티 (Oven spaghetti)
# 음식메뉴 성공
# ===============
# 토마토미트소스, 모짜렐라&고다치즈, 체다치즈
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 버섯크림펜네파스타 (Oven spaghetti)
# 음식메뉴 성공
# ===============
# 홈메이드 머쉬룸 퓨레, 머쉬룸, 베이컨, 모짜렐라&고다치즈, 체다치즈
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 오븐 떡볶이 (Oven tteokbokki)
# 음식메뉴 성공
# ===============
# 매콤한 떡볶이에 치즈를 올린 매콤치즈 떡볶이
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 프렌치프라이 (Truffle French fries)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 버팔로윙 & 프라이 (Buffalo wing & fries)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10000
# 금액 성공
# ===============
# [Drink]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 페리에 라임 (Perrier Lime)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 강남구 대치동 623
# 주소 뽑기 성공
# =========================================
#
# 비오는날 피자 주문시 음료수 1개 서비스로 드려요~
# 콜라, 사이다 랜덤으로 발송해드리니 참고부탁드립니다^^
# (비가 내리는 날 이벤트는 배달주문시에만 적용되며, 배달주문시 저희매장 앞에 비가내리면 저희가 알아서 넣어 보내드린답니다.) 앞으로도 더 좋은 혜택 진행할테니 많은주문 부탁드려요~
# ———————————————————————
# 19인치 괴물크기에 피자를 조각으로 맛볼수 있는 Mr.Slice입니다. 한판이 부담스럽고 한,두조각이면 든든하고 맛있게 먹을수 있는 수제 조각피자!
# 항상 맛있는 피자를 드리기위해 매일매일 도우도 직접 만들어 48시간 저온숙성 시켜 쫀득하고 감칠맛이 있어 도우끝까지 맛있게 드실수 있으실겁니다.
# 재료를 아끼지않고 최상급의 재료로만 직접 만들어 더 맛있습니다!
# 수제 조각피자 한번 맛보세요!
#
#
# 감사합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 버섯 : 국내산소고기,페퍼로니 : 미국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 7000
# 최소 금액 성공
# =========================================
# [메뉴소개]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [메뉴소개]
# 음식 카테고리 성공
# =========================================
# 샤프 체다치즈피자(1pcs)
# 음식메뉴 성공
# ===============
# -도우를 펴서 토마토 소스를 펴바르고 모짜렐라 치즈 위로 샤프체다 치즈를 올려서 구워낸 피자입니다.-모짜렐라치즈의 고소함과 샤프체다치즈의 짭쪼롭한 맛의 조화가 일품!
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 페퍼로니&하와이안피자(1pcs)
# 음식메뉴 성공
# ===============
# -도우를 펴서 토마토소스를 바르고 모짜렐라 치즈 위로 미국산 페퍼로니와 파인애플을 올려 구워낸 피자입니다.-단짠의 조화로 이뤄진 저희매장 대표메뉴!!
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 스파이시 라구피자(1pcs)
# 음식메뉴 성공
# ===============
# -쇠고기와 각종 야채를 갈아서 매콤하게 저희가 직접 끓여낸 라구소스에 모짜렐라치즈를 올려 구워낸 피자입니다.-살짝 매콤한 느낌과 메이플시럽의 약간 달달함이 있는 피자!!
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 화이트 트러플 머쉬룸피자(1pcs)
# 음식메뉴 성공
# ===============
# -도우 위로 직접 끓여만든 화이트소스 위로 모짜렐라치즈 그리고 양송이&팽이버섯을 올려 구워낸 피자입니다.-전혀 자극적이지 않고 단백함의 끝판왕!!
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (225ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# 사이다 (225ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# ===========끝===========
# ---6번 식당파싱 시작 ---
# 서울 강남구 신사동 515-6 2층
# 주소 뽑기 성공
# =========================================
#
# 두툼하고 속이 꽉 찬Real 시카고피자!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 소고기 : 호주산
# 돼지고기 : 미국산
# 치즈 : 미국산,독일산
# 쌀 : 국내산
# 고축루 : 중국산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 19000
# 최소 금액 성공
# =========================================
# [클래식 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [스페셜 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [크림 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [클래식 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 클래식 시카고피자
# 음식메뉴 성공
# ===============
# 토마토 기본토핑
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [스페셜 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 헤리콤비네이션 시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 스위트 고구마 시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 불닭시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 불고기 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 베이컨 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 쉬림프 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 반반피자
# 음식메뉴 성공
# ===============
# 불고기, 베이컨, 쉬림프 중 택2
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# [크림 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 불고기크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 베이컨크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# 쉬림프크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 게살크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 반반 크림 피자
# 음식메뉴 성공
# ===============
# 불고기, 베이컨, 쉬림프, 게살 중 택2
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 웰치스 포도(355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 7번 오류
# 서울 강남구 신사동 515-6 2층
# 주소 뽑기 성공
# =========================================
#
# 두툼하고 속이 꽉 찬Real 시카고피자!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 소고기 : 호주산
# 돼지고기 : 미국산
# 치즈 : 미국산,독일산
# 쌀 : 국내산
# 고축루 : 중국산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 19000
# 최소 금액 성공
# =========================================
# [클래식 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [스페셜 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [크림 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [클래식 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 클래식 시카고피자
# 음식메뉴 성공
# ===============
# 토마토 기본토핑
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [스페셜 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 헤리콤비네이션 시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 스위트 고구마 시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 불닭시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 불고기 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 베이컨 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 쉬림프 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 반반피자
# 음식메뉴 성공
# ===============
# 불고기, 베이컨, 쉬림프 중 택2
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# [크림 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 불고기크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 베이컨크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# 쉬림프크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 게살크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 반반 크림 피자
# 음식메뉴 성공
# ===============
# 불고기, 베이컨, 쉬림프, 게살 중 택2
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 웰치스 포도(355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 7번 오류
# 서울 강남구 신사동 515-6 2층
# 주소 뽑기 성공
# =========================================
#
# 두툼하고 속이 꽉 찬Real 시카고피자!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 소고기 : 호주산
# 돼지고기 : 미국산
# 치즈 : 미국산,독일산
# 쌀 : 국내산
# 고축루 : 중국산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 19000
# 최소 금액 성공
# =========================================
# [클래식 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [스페셜 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [크림 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [클래식 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 클래식 시카고피자
# 음식메뉴 성공
# ===============
# 토마토 기본토핑
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [스페셜 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 헤리콤비네이션 시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 스위트 고구마 시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 불닭시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 불고기 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 베이컨 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 쉬림프 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 반반피자
# 음식메뉴 성공
# ===============
# 불고기, 베이컨, 쉬림프 중 택2
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# [크림 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 불고기크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 베이컨크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# 쉬림프크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 게살크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 반반 크림 피자
# 음식메뉴 성공
# ===============
# 불고기, 베이컨, 쉬림프, 게살 중 택2
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 웰치스 포도(355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 7번 오류
# 서울 강남구 신사동 515-6 2층
# 주소 뽑기 성공
# =========================================
#
# 두툼하고 속이 꽉 찬Real 시카고피자!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 소고기 : 호주산
# 돼지고기 : 미국산
# 치즈 : 미국산,독일산
# 쌀 : 국내산
# 고축루 : 중국산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 19000
# 최소 금액 성공
# =========================================
# [클래식 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [스페셜 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [크림 시카고 피자]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [클래식 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 클래식 시카고피자
# 음식메뉴 성공
# ===============
# 토마토 기본토핑
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# [스페셜 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 헤리콤비네이션 시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 20000
# 금액 성공
# ===============
# 스위트 고구마 시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 불닭시카고 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 불고기 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 베이컨 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 25000
# 금액 성공
# ===============
# 쉬림프 시카고 피자
# 음식메뉴 성공
# ===============
# 메인 토핑을 아낌없이~ 듬뿍듬뿍! 넣은 메뉴
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# 반반피자
# 음식메뉴 성공
# ===============
# 불고기, 베이컨, 쉬림프 중 택2
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# [크림 시카고 피자]
# 음식 카테고리 성공
# =========================================
# 불고기크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# 베이컨크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# 쉬림프크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 게살크림 시카고 피자
# 음식메뉴 성공
# ===============
# 크림소스와 스페셜 시카고 피자와의 만남~
# 음식정보 성공
# ===============
# 28000
# 금액 성공
# ===============
# 반반 크림 피자
# 음식메뉴 성공
# ===============
# 불고기, 베이컨, 쉬림프, 게살 중 택2
# 음식정보 성공
# ===============
# 27000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 환타 오렌지 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 웰치스 포도(355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
