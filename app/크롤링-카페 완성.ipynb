# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 카페[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[4]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 30:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 카페 데이터(이미지) 수집
soup = BeautifulSoup(html, 'lxml')
img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
count = 1
for i in img:
    img_url = i.get_text("url", strip=True)
    img_url_parse = img_url[4:-1]
    try:
        urllib.request.urlretrieve(img_url_parse, f'{count}.cafe_food_img.jpg')
    except:
        pass
    count += 1

# 일식 데이터(식당명) 수집
japan_store_list = []
japan_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in japan_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(japan_store_list):
    print(i, name)


    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 60:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='카페',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=1),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
        print('음식 카테고리 성공')
        print('=========================================')
        
        store_category_foods = menu.select(".row-menu")

        for food in store_category_foods:
            food_menu = food.select_one(".col-menu > strong").get_text(strip=True)
            print(food_menu)
            print('음식메뉴 성공')
            print('===============')
            food_info = food.select_one(".col-menu > span").get_text(strip=True)
            print(food_info)
            print('음식정보 성공')
            print('===============')
            food_money = food.select_one("span.calculate-price").get_text(strip=True)
            food_moneys = food_money.replace(",", "")
            print(food_moneys)
            print('금액 성공')
            print('===============')
            
            Food.objects.create(
            category=food_category,
            name=food_menu,
            price=food_moneys,
            food_info=food_info,
            )

        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:83: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 강남구 역삼동 828
# 주소 뽑기 성공
# =========================================
#
# coffeesmith는 장인을 일컫는 영어의 접미사인 "-smith"에서 유래하여 커피의 장인이 되겠다는 신념으로 탄생하였습니다.
# 커피를 진정으로 사랑하는 당신을 위해 최고의 솜씨와 최상의 아라비카 원두가 만들어 낸 작품입니다.
# 진한 커피의 즐거움을 커피스미스와 함께 하세요!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 16000
# 최소 금액 성공
# =========================================
# [커피 (Coffee)]
# 음식 카테고리 성공
# =========================================
# [라떼 (Latte special)]
# 음식 카테고리 성공
# =========================================
# [차 (Tea)]
# 음식 카테고리 성공
# =========================================
# [커피 (Coffee)]
# 음식 카테고리 성공
# =========================================
# 카페 아메리카노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 카페 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 바닐라 라떼
# 음식메뉴 성공
# ===============
# 바닐라 파우더와 커피가 만나 달고 부드러운 맛이 나는 커피 음료
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 카라멜 마끼아또
# 음식메뉴 성공
# ===============
# 달고 진한 캬라멜 소스와 커피가 조화를 이루는 커피음료
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 카페 모카
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# [라떼 (Latte special)]
# 음식 카테고리 성공
# =========================================
# 아쌈 밀크티
# 음식메뉴 성공
# ===============
# 매장에서 직접 우린 아쌈과 우유 그리고 꿀이 만나 아쌈의 진한 맛을 그대로 살린 밀크티
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 카라멜 밀크티
# 음식메뉴 성공
# ===============
# 캬라멜 소스와 직접 우린 아쌈베이스가 달달하게 어울리는 밀크티
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 녹차 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 핫 초코
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# [차 (Tea)]
# 음식 카테고리 성공
# =========================================
# 얼그레이 티 (Regular)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 다즐링 티 (Regular)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 그린티 (Regular)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 스미스 허브티 (Regular)
# 음식메뉴 성공
# ===============
# 히비스커스 외 여러가지 과일이 블랜딩되어 달콤하고 부드러움이 특징인 과일차
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 스미스 블랜드티 (Regular)
# 음식메뉴 성공
# ===============
# 부드러운 크림향과 달콤한 캬라멜향이 풍부한 홍차
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 유자차
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 허니레몬티
# 음식메뉴 성공
# ===============
# 달콤하고 상큼한 레몬맛이 일품인 티
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 자몽티
# 음식메뉴 성공
# ===============
# 진한 자몽의 맛이 달콤하고 쌉싸름하게 어우러지는 티
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:217: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 강남구 역삼동 826-20 1층
# 주소 뽑기 성공
# =========================================
# 나만의 즐거움을 만날 수 있는 프리미엄 디저트 카페.섬세하게 정성껏 내린 커피와 어울리는 프리미엄 디저트의 조화.투썸플레이스를 이제 푸드플라이에서 만나보세요~기타,제휴카드 할인 및 적립 불가합니다.
#
# 가게 소개 뽑기 성공
# =========================================
#
# 토마토,닭가슴살,계란,우유 :  국내산
# 모짜렐라: 스위스산
# 밀가루: 미국산,캐나다산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [2018 투썸 추석 선물세트 (9/3~9/30)]
# 음식 카테고리 성공
# =========================================
# [조각 케이크]
# 음식 카테고리 성공
# =========================================
# [홀케이크]
# 음식 카테고리 성공
# =========================================
# [커피]
# 음식 카테고리 성공
# =========================================
# [스폐셜 티커피]
# 음식 카테고리 성공
# =========================================
# [샌드위치]
# 음식 카테고리 성공
# =========================================
# [에이드 & 쉐이크]
# 음식 카테고리 성공
# =========================================
# [티 & 라떼]
# 음식 카테고리 성공
# =========================================
# [음료류]
# 음식 카테고리 성공
# =========================================
# [숫자초]
# 음식 카테고리 성공
# =========================================
# [2018 투썸 추석 선물세트 (9/3~9/30)]
# 음식 카테고리 성공
# =========================================
# 투썸 추석 기프트세트 18 1호
# 음식메뉴 성공
# ===============
# 최고의 커피에는 역시 디저트- 핸드드립커피_스페셜 1 PAC- 핸드드립커피_오리지널 1 PAC- 화이트버터 쿠키 1EA
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 투썸 추석 기프트세트 18 2호
# 음식메뉴 성공
# ===============
# 콜드브루를 가장 트렌디하게 마시는 방법-콜드브루 RTD 1EA (500ml)-투썸글라스머그 550ML 1EA
# 음식정보 성공
# ===============
# 19000
# 금액 성공
# ===============
# 투썸 추석 기프트세트 18 3호
# 음식메뉴 성공
# ===============
# 프리미엄 커피를 어디서나 즐기고 싶은 당신을 위해-투썸 스틱커피 2 PAC-투썸 슬림 텀블러(골드) 1EA (320ml)
# 음식정보 성공
# ===============
# 23000
# 금액 성공
# ===============
# 투썸 추석 기프트세트 18 4호
# 음식메뉴 성공
# ===============
# 다양한 커피 Flavor를 핸디형 텀블러에 가볍게 즐길 줄 아는 당신!-핸드드립커피_스페셜 1PAC-핸드드립커피_오리지널 1PAC-핸드드립커피_콜롬비아 후일라 아릴리오 1PAC-투썸 플랙펄 텀블러 1EA (400ml)
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 투썸 추석 기프트세트 18 5호
# 음식메뉴 성공
# ===============
# 우리집 바리스타인 당신에게-핸드드립커피_오리지널 1PAC-핸드드립커피_콜롬비아 후일라 아릴리오 1PAC-투썸 핸드드립 동주전자 1EA (용량 240ml)
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 투썸 추석 기프트세트 18 7호
# 음식메뉴 성공
# ===============
# 커피를 잘 아는 센스있는 당신에게-투썸 콜롬비아 후일라 아릴리오 원두 200g 1EA-킨토프레스 머그 1EA (용량 260ml)
# 음식정보 성공
# ===============
# 38000
# 금액 성공
# ===============
# 투썸 추석 기프트세트 18 8호
# 음식메뉴 성공
# ===============
# 합리적인 알찬 구성으로 만나볼 수 있는-투썸 스틱커피 10PAC
# 음식정보 성공
# ===============
# 34000
# 금액 성공
# ===============
# [조각 케이크]
# 음식 카테고리 성공
# =========================================
# 뉴욕치즈케이크 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 티라미스 플레이팅 (1pc)
# 음식메뉴 성공
# ===============
# 마스카포네 치즈와 진한 에스프레소 시럽으로 샌드 된 촉촉한 시트의 이탈리안 무스케이
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 클래식가토피스 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 딸기레어치즈케익 (1pc)
# 음식메뉴 성공
# ===============
# 상큼한 딸기퓨레와 부드러운 크림치즈, 고소한 크럼블, 라즈베리가 함께 어울려 봄을 닮은 맛의 떠먹는 케익
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 벨지안 멜팅 가나슈 (1pc)
# 음식메뉴 성공
# ===============
# 벨기에산 다크 초콜릿 가나슈와 시트 사이사이 초코 크런치, 크럼블로 바삭한 식감을 더한 케이크
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# 레드벨벳 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# 트리플초콜릿무스 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 더치솔티드카라멜 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# 생크림소프트쉬폰 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 떠먹는아이스박스 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 그뤼에르 치즈무스 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 크렘슈 (바닐라)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 크렘슈 (초콜릿)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# [홀케이크]
# 음식 카테고리 성공
# =========================================
# 클래식 가토 케이크 1호
# 음식메뉴 성공
# ===============
# 부드러운 초코시트에 초콜릿 가나슈를 샌드하여 초콜릿의 진한 맛을 느낄 수 있는 케익
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 스트로베리 초콜릿 생크림 케이크 1호
# 음식메뉴 성공
# ===============
# 한 가득 올린 상큼한 딸기, 크런치 초코볼이 초콜릿 생크림 시트와 조화를 이루는 투썸의 베스트 생크림 케이크
# 음식정보 성공
# ===============
# 31000
# 금액 성공
# ===============
# 마스카포네 생크림 케이크 (믹스드베리) 1호
# 음식메뉴 성공
# ===============
# 상큼한 세 가지 베리와 부드러운 마스카포네 생크림이 어우러져 새콤달콤하게 즐길 수 있는 케이크
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 그뤼에르치즈 케이크 1호
# 음식메뉴 성공
# ===============
# 초코 크런치를 토핑한 바삭이는 식감과 그뤼에르 치즈의 풍부하고 고소한 맛이 일품인 투썸 베스트 무스 케이크
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 레드벨벳 케이크 1호
# 음식메뉴 성공
# ===============
# 매력적인 벨벳느낌의 붉은 컬러가 인상적인 케이크. 고소한 버터 크림치즈로 아이싱되어 더욱 풍부하고 깊은맛을 즐길수 있는 제품.
# 음식정보 성공
# ===============
# 32000
# 금액 성공
# ===============
# 마스카포네티라미수 케이크 2호
# 음식메뉴 성공
# ===============
# 마스카포네 치즈크림과 진한 에스프레소 커피 시럽을 올린 시트, 순도 높은 카카오 파우더를 뿌려 마무리 한 정통 이탈리안 무스케이크.
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 벨지안 멜팅 가나슈 1호
# 음식메뉴 성공
# ===============
# 벨기에산 다크 초콜릿 가나슈와 시트 사이사이 초코 크런치, 크럼블로 바삭한 식감을 더한 케이크
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 뉴욕치즈케이크 2호
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 33000
# 금액 성공
# ===============
# 트리플 초콜릿 무스 케이크
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 29000
# 금액 성공
# ===============
# 까망베르치즈케이크
# 음식메뉴 성공
# ===============
# 진한 까망베르치즈의 풍미가 가득하고 커피와 잘 어우러지는 간식용 케이크
# 음식정보 성공
# ===============
# 26000
# 금액 성공
# ===============
# 블랙포레스트 1호
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 기프트박스 1호
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 바닐라크렘브륄레 1호
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 31000
# 금액 성공
# ===============
# 더치솔티드카라멜 1호
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 30000
# 금액 성공
# ===============
# 체리 초콜릿 생크림
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 31000
# 금액 성공
# ===============
# [커피]
# 음식 카테고리 성공
# =========================================
# 아메리카노 (Hot)
# 음식메뉴 성공
# ===============
# 진하게 로스팅된 원두에서 에스프레소를 추출하여 뜨거운 물과 결합하여 연한 맛을 좋아하는 커피 매니아에게 딱인 정통 아메리칸 스타일 커피.
# 음식정보 성공
# ===============
# 4100
# 금액 성공
# ===============
# 아메리카노 (Ice)
# 음식메뉴 성공
# ===============
# 진하게 로스팅된 커피 원두에서 진한 에스프레소를 추출하여, 시원한 얼음을 담아 여름에 산뜻하게 즐길 수 있는 깔끔한 스타일의 아이스 아메리카노~
# 음식정보 성공
# ===============
# 4100
# 금액 성공
# ===============
# 카페라떼 (Hot)
# 음식메뉴 성공
# ===============
# 풍부하고 진한 농도의 에스프레소와 따뜻한 우유가 어우러진 부드러운 에스프레소 음료.
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 카페라떼 (Ice)
# 음식메뉴 성공
# ===============
# 풍부하고 진한 농도의 에스프레소와 차가운 우유가 어우러진 부드러운 에스프레소 음료.
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 카푸치노 (Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 카페모카 (Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 카페모카 (Ice)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 카라멜 마키아또 (Hot)
# 음식메뉴 성공
# ===============
# 바닐라 향과 우유 에스프레소의 어울림에 얼음위에 뿌려진 카라멜 소스의 달콤함, 따뜻하면서도 달콤한 아이스 음료.
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 카라멜 마키아또 (Ice)
# 음식메뉴 성공
# ===============
# 바닐라 향과 우유 에스프레소의 어울림에 얼음위에 뿌려진 카라멜 소스의 달콤함, 시원하면서도 달콤한 아이스 음료.
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 바닐라 라떼 (Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 바닐라라떼 (Ice)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 콜드브루 (500ml)
# 음식메뉴 성공
# ===============
# 가정에서 즐기는 깊고 진한 투썸 콜드브루 커피 원액물과 희석하여 기호에 맞게 비율을 조정하여 드셔야합니다.
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# 콜드브루토닉
# 음식메뉴 성공
# ===============
# 콜드브루를 그대로 얼린 큐브얼음과 상큼한 토닉워터가 어우러진 커피
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [스폐셜 티커피]
# 음식 카테고리 성공
# =========================================
# 콜드브루 (에티오피아, only Ice)
# 음식메뉴 성공
# ===============
# 192시간 저온추출과 저온숙성과정을 과정을 거쳐 탄생한 스페셜티커피(얼음없음)
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 콜드브루 (콜롬비아, only Ice)
# 음식메뉴 성공
# ===============
# 192시간 저온추출과 저온숙성과정을 과정을 거쳐 탄생한 스페셜티커피(얼음없음)
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 콜드브루라떼 (only ice)
# 음식메뉴 성공
# ===============
# 192시간 저온추출과 저온숙성과정을 과정을 거쳐 탄생한 스페셜티커피 (콜드브루라떼-콜드브루커피+우유)
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [샌드위치]
# 음식 카테고리 성공
# =========================================
# BELT 샌드위치
# 음식메뉴 성공
# ===============
# 부드러운 우유식빵에 달걀,로메인, 레터스.토마토를 넣은 기본 샌드위치
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 레몬치킨클럽샌드위치
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 올리브 치킨 파니니
# 음식메뉴 성공
# ===============
# 올리브 타페나드를 듬뿍 바른 빵에 선드라이 토마토와 담백한 치킨으로 맛을 낸 파니니
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 페스토햄치즈 파니니
# 음식메뉴 성공
# ===============
# 터키햄, 스위스치즈, 후레쉬 모짜렐라치즈에 바질페스토가 어우러진 치아바타 HOT 샌드위치
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 바베큐 파니니
# 음식메뉴 성공
# ===============
# 바비큐 소스를 곁을인 치킨을 넣은 치아바타 HOT 샌드위치
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 멕시칸 파니니
# 음식메뉴 성공
# ===============
# 데리야끼 치킨, 볶은 파프리카, 후레쉬 모짜렐라치즈를 넣은 치아바타 HOT샌드위치
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 토마토모짜렐라 샌드위치
# 음식메뉴 성공
# ===============
# 신선한 토마토와 쫀득한 모짜렐라치즈가 어우러진 담백한 이탈리안 HOT 샌드위치
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [에이드 & 쉐이크]
# 음식 카테고리 성공
# =========================================
# 자몽에이드
# 음식메뉴 성공
# ===============
# 자몽의 상큼함과 청량함이 입안 가득 느껴지는 자몽에이드
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 바닐라쉐이크
# 음식메뉴 성공
# ===============
# 바닐라 아이스크림과 우유가 블렌딩 된 부드럽고 달콤한 쉐이크.
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 초코쉐이크
# 음식메뉴 성공
# ===============
# 바닐라아이스크림과 발로나 초콜렛의 진한 풍미를 즐길 수 있는 초코 쉐이크.
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 커피쉐이크
# 음식메뉴 성공
# ===============
# 에스프레소의 쌉싸름함과 아이스크림의 달콤함을 동시에 즐길 수 있는 쉐이크.
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 스트로베리 피치 프라페
# 음식메뉴 성공
# ===============
# 딸기와 복숭아의 상큼함이 조화롭게 어우러진 스무디 타입 음료
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 로얄밀크티쉐이크
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6300
# 금액 성공
# ===============
# 레몬 셔벗 에이드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 샹그리아 에이드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [티 & 라떼]
# 음식 카테고리 성공
# =========================================
# 캐모마일 허브티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 유자레몬티
# 음식메뉴 성공
# ===============
# 달콤 쌉싸름한 유자청과 레몬즙이 어우러진 상큼한 시트러스티.
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 로얄밀크티 (Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 로얄밀크티 (Ice)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 그린티 라떼
# 음식메뉴 성공
# ===============
# 달콤한 녹차의 향과 우유와의 조화로움이 입안 가득 부드러움을 느끼게 해주는 티 라떼.
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 아이스 그린티 라떼
# 음식메뉴 성공
# ===============
# 달콤한 녹차의 향과 우유와의 조화로움이 입안 가득 부드러움을 느끼게 해주는 티 라떼.
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 화이트크림 티라미수라떼
# 음식메뉴 성공
# ===============
# 눈처럼 부드럽고 달콤한 화이트크림과 진한 마스카포네 치즈가 조화로운 라떼
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 1837블랙티
# 음식메뉴 성공
# ===============
# 버뮤다 삼각지대의 과일이 블린댕 되어 홍차의 은은한 맛과 스트로베리의 뒷맛이 좋은 티
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 프렌치 얼그레이
# 음식메뉴 성공
# ===============
# 클래식하면서 우아한 시트러스 과일향과 수레국화의 향극한 향이 특징인 티
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 크림 카라멜
# 음식메뉴 성공
# ===============
# 루이보스차에 달콤한 카라멜을 블랜딩하여 매력적이고 섬세함을 지닌 티
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 잉글리쉬 블랙퍼스트 (Only Ice)
# 음식메뉴 성공
# ===============
# 강하고 풍부한 Broken-Leaf에 은은한 꽃향기가 더해진 오리지널 싱글 블랙티
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 라즈베리 아이스티
# 음식메뉴 성공
# ===============
# 달콤한 딸기향이 감도는 홍차베이스에 라즈베리로 상큼함을 더한 아이스티
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 허니레몬 아이스티
# 음식메뉴 성공
# ===============
# 진한 얼그레이 베이스에 달콤한 꿀과 상큼한 레몬이 더해진 아이스티
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 루이보스 크림티 (Only Ice)
# 음식메뉴 성공
# ===============
# 차갑게 우린 은은한 루이보스티 위에 루이보스 티크림을 풍성하게 올려 시원하게 즐기는 아이스티
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 오렌지자몽티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# [음료류]
# 음식 카테고리 성공
# =========================================
# 아이스 초콜릿
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 핫초코
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 플레인 요거 드링크
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 블루베리 요거 드링크
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 키위바나나주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 오렌지자몽주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 망고프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 플레인요거프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 그린티프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 모카칩프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 카라멜프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 고구마라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 아이스고구마라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# [숫자초]
# 음식 카테고리 성공
# =========================================
# 숫자 초 0
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# 숫자초 1
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# 숫자초 2
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# 숫자초 3
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# 숫자초 4
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# 숫자초 5
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# 숫자초 6
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# 숫자초 7
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# 숫자초 8
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# 숫자초 9
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 700
# 금액 성공
# ===============
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 강남구 역삼동 736-17 동궁빌딩 지상1층 101호
# 주소 뽑기 성공
# =========================================
#
# 매일매일(Tous Les Jours),
# 매장에서 직접 굽는신선한 베이커리
#
# 뚜레쥬르는(Tous Les Jours - 프랑스어로 ‘매일매일’이라는 뜻)" 그 이름의 의미처럼
# 매일매일 매장에서 직접 굽는 신선함을 가장 큰 가치로 하는 베이커리 입니다.
# 1997년 구리교문에 처음 매장을 연 뚜레쥬르는,
# 그 시절 공장에서 양산빵을 납품 받던 다른 베이커리들과 달리,
# 하루 3번 매장에서 갓 구운 신선한 빵을 제공하며
# 국내 베이커리 업계에 새로운 변화의 바람을 일으켰습니다.
# 뚜레쥬르 매장에 들어서는 순간 감도는 갓 구워낸 빵의 고소하고 달큰한 향은
# 대량 생산에 급급했던 여타의 베이커리 브랜드와는 분명히 다른 차별점이 되었습니다
#
#
# 갓 구운 신선함이
# 매장을 가득 채웁니다.
#
# 오븐에서 방금 꺼낸 빵이 가장 맛있다는 것을 알기에, 뚜레쥬르는 지금도
# 더욱 따뜻하고 촉촉한 갓 구운 빵을 제공하기 위해 끊임없이 노력합니다.
# 매장에서 직접 굽는 것에 그치지 않고, 언제라도 따끈한 빵을 만날 수 있게
# 더욱 자주 굽고, 고객들이 필요한 시간에 맞춰 굽는 등
# 세심하고 배려가 담긴 서비스도 준비하고 있습니다.
# 갓 구워낸 빵은 고소한 향기와 따스한 온기로 매장을 가득 채우고,
# 고객들에게는 가장 맛있는 빵을 맛보는 행복을 선물합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 스테이크 아보카도 볼샐러드 : 쇠고기(호주산)오리엔탈 그릴치킨 볼샐러드 : 닭고기(국내산)그릴포크 누들 분짜 볼샐러드 : 돼지고기(미국산)멕시칸볼 샐러드 : 분쇄 가공육제품[쇠고기(호주산), 돼지고기(국내산)]
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [이벤트메뉴]
# 음식 카테고리 성공
# =========================================
# [샌드위치밀박스]
# 음식 카테고리 성공
# =========================================
# [샌드위치]
# 음식 카테고리 성공
# =========================================
# [프리미엄샐러드]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [빵]
# 음식 카테고리 성공
# =========================================
# [디저트]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [스프레드]
# 음식 카테고리 성공
# =========================================
# [이벤트메뉴]
# 음식 카테고리 성공
# =========================================
# 스파이시 불고기 파니니&에그팟&음료
# 음식메뉴 성공
# ===============
# Spicy Bulgogi Panini & Egg Pot & Beverage 그릴 불고기에 몬테레이 잭 치즈와 구운 양파가 칠리소스에 어우러진 매콤한 파니니 + 루꼴라,  수란, 파마산 치즈 사이드
# 음식정보 성공
# ===============
# 11100
# 금액 성공
# ===============
# 쉬림프 페스토 파니니&에그포테이토팟&음료
# 음식메뉴 성공
# ===============
# Shrimp pesto Panini & Egg Potato Pot & Beverage 그릴드 쉬림프에 모짜렐라 치즈와 썬드라이 토마토가 페스토 소스에 어우러진 이탈리안 곡물 파니니 + 에그포테이토 샐러드, 구운 베이컨 사이드
# 음식정보 성공
# ===============
# 11700
# 금액 성공
# ===============
# B.E.L.T.A 샌드위치&블루베리요거트팟&음료
# 음식메뉴 성공
# ===============
# B.E.L.T.A  Sandwich & Blueberry Yogurt Pot & Beverage 베이컨, 에그, 래터스, 토마토에 아보카도와 뚜레쥬르만의 홀그레인드레싱의 조합 + 블루베리 요거트
# 음식정보 성공
# ===============
# 11100
# 금액 성공
# ===============
# [샌드위치밀박스]
# 음식 카테고리 성공
# =========================================
# 채끝 아보카도 바게트&토마토바질팟&음료
# 음식메뉴 성공
# ===============
# Beef Avocado Baguette & Tomato Basil Pot & Beverage 부드러운 채끝에 아보카도, 모짜렐라 치즈, 구운 야채가 홀그레인 머스타드 소스와 어우러진 핫 바게트 + 여러가지 토마토, 바질 사이드
# 음식정보 성공
# ===============
# 11700
# 금액 성공
# ===============
# 크래미 와사비마요&토마토바질팟&음료
# 음식메뉴 성공
# ===============
# Crammy Wasabi Mayo & Tomato Basil Pot & Beverage 톡 쏘는 와사비 마요 소스에 아보카도와 부드러운 크래미가 어우러진 콜드 샌드위치 + 여러가지 토마토, 바질 사이드
# 음식정보 성공
# ===============
# 10700
# 금액 성공
# ===============
# 크랜베리치킨 아보카도&곡물렌틸팟&음료
# 음식메뉴 성공
# ===============
# Cranberry Chicken Avocado & Mushroom Lentils Pot & Beverage 새콤달콤한 크랜베리에 부드러운 아보카도와 구운 닭가슴살이 어우러진 콜드 샌드위치 + 렌틸콩, 구운 버섯, 파슬리 사이드
# 음식정보 성공
# ===============
# 10700
# 금액 성공
# ===============
# [샌드위치]
# 음식 카테고리 성공
# =========================================
# 스파이시 불고기 파니니
# 음식메뉴 성공
# ===============
# Spicy Bulgogi Panini 그릴 불고기에 몬테레이 잭 치즈와 구운 양파가 칠리소스에 어우러진 매콤한 파니니
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 쉬림프 페스토 파니니
# 음식메뉴 성공
# ===============
# Shrimp Pesto Grain Panini 그릴드 쉬림프에 모짜렐라 치즈와 썬드라이 토마토가 페스토 소스에 어우러진 이탈리안 곡물 파니니
# 음식정보 성공
# ===============
# 7400
# 금액 성공
# ===============
# 채끝 아보카도 바게트
# 음식메뉴 성공
# ===============
# Beef Avocado Baguette 부드러운 채끝에 아보카도, 모짜렐라 치즈, 구운 야채가 홀그레인 머스타드 소스와 어우러진 핫 바게트
# 음식정보 성공
# ===============
# 7400
# 금액 성공
# ===============
# 트러플오일 베지 바게트
# 음식메뉴 성공
# ===============
# Tryffle-oil Veggie Baguette 구운 야채(브로콜리, 파프리카, 버섯, 양파, 쥬키니호박)에 트러플 오일향이 가득 더해진 부드러운 바게트 샌드위치
# 음식정보 성공
# ===============
# 6400
# 금액 성공
# ===============
# B.E.L.T.A 샌드위치
# 음식메뉴 성공
# ===============
# B.E.L.T.A Sandwich 베이컨, 에그, 래터스, 토마토에 아보카도와 뚜레쥬르만의 홀그레인드레싱드레싱의 조합
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 햄&치즈 에그샐러드 샌드위치
# 음식메뉴 성공
# ===============
# Ham&Cheese Egg Salad Sandwich 홈메이드스타일의 에그쉬림프 샐러드, 햄과 치즈로 맛을 더한 식빵 샌드위치
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 크래미 와사비마요
# 음식메뉴 성공
# ===============
# Crammy Wasabi Mayo 톡 쏘는 와사비 마요 소스에 아보카도와 부드러운 크래미가 어우러진 콜드 샌드위치
# 음식정보 성공
# ===============
# 6400
# 금액 성공
# ===============
# 크렌베리치킨 아보카도
# 음식메뉴 성공
# ===============
# Cranberry Chicken Avocado 새콤달콤한 크랜베리에 부드러운 아보카도와 구운 닭가슴살이 어우러진 콜드 샌드위치
# 음식정보 성공
# ===============
# 6400
# 금액 성공
# ===============
# 무화과 리코타 샌드위치
# 음식메뉴 성공
# ===============
# Fig Ricotta Sandwich 달콤한 무화과와 리코타가 샌드된 디저트 타입의 콜드 샌드위치
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# [프리미엄샐러드]
# 음식 카테고리 성공
# =========================================
# 채끝 아보카도 샐러드
# 음식메뉴 성공
# ===============
# Beef Avocado Salad 부드러운 채끝과 아보카도, 구운 야채가 발사믹 소스와 어우러진 한끼식사 샐러드 + 데일리브레드 제공
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 그릴치킨 곡물 샐러드
# 음식메뉴 성공
# ===============
# Grill Chicken Grain Salad 그릴드 치킨에 곡물, 브로콜리, 양파튀김이 고소한 참깨 소스와 어우러진 한끼식사 샐러드 + 데일리브레드 제공
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 쉬림프 에그포테이토 샐러드
# 음식메뉴 성공
# ===============
# Shrimp Egg Potato Salad 그릴드 쉬림프에 부드러운 에그포테이토 샐러드와 렌틸콩이 화이트 크림소스와 어우러진 한끼식사 샐러드 + 데일리브레드 제공
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 콥샐러드
# 음식메뉴 성공
# ===============
# Cobb Salad 구운 닭가슴살, 아보카도, 토마토, 베이컨이 요거트 드레싱과 어우러진 한끼식사 샐러드 + 데일리브레드 제공
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 에그팟
# 음식메뉴 성공
# ===============
# Egg POT 루꼴라,  수란, 파마산 치즈
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 에그포테이토팟
# 음식메뉴 성공
# ===============
# Egg Potato POT 에그포테이토 샐러드, 구운 베이컨
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 머쉬룸렌틸팟
# 음식메뉴 성공
# ===============
# Mushroom Lentils POT 렌틸콩, 구운 버섯, 파슬리
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 토마토바질팟
# 음식메뉴 성공
# ===============
# Tomato Basil POT 여러가지 토마토, 바질
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 블루베리요거트팟
# 음식메뉴 성공
# ===============
# Blueberry Yogurt POT 블루베리 요거트
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 요거트팟
# 음식메뉴 성공
# ===============
# Yogurt POT 요거트
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# [빵]
# 음식 카테고리 성공
# =========================================
# 단팥빵
# 음식메뉴 성공
# ===============
# Red Bean Bread 통팥앙금을 사용하여 누구나 좋아하는 빵
# 음식정보 성공
# ===============
# 1700
# 금액 성공
# ===============
# 슈크림빵
# 음식메뉴 성공
# ===============
# Cream Puff Bread 달콤하고 고소한 커스터드 크림이 듬뿍 *크림 속 검은 반점은 바닐라씨드임으로 안심하고 드시기 바랍니다
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 오리지널프렌치크라상
# 음식메뉴 성공
# ===============
# Croissant 버터가 듬뿍 들어가 고소한 풍미가 뛰어나고 한겹 한겹 정성으로 접어 만들어 패스트리의 결이 살아있는 오리지널 크라상 (프랑스산 버터, 유지방 82%)
# 음식정보 성공
# ===============
# 1900
# 금액 성공
# ===============
# 아몬드크라상
# 음식메뉴 성공
# ===============
# Almond Croissant 고소한 아몬드크림이 들어간 크라상
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 애플파이
# 음식메뉴 성공
# ===============
# Apple Pie 새콤달콤 사과 과육이 가득한 애플필링을 듬뿍 넣은 바삭한 파이
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 새콤달콤유자파이
# 음식메뉴 성공
# ===============
# Citron Pie 바삭바삭한 파이 안에 유자크림이 들어가 더욱 상큼한 패스트리
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 뺑오쇼콜라
# 음식메뉴 성공
# ===============
# Plain au Chocolat 초코스틱을 돌돌 말아 넣은 바삭한 패스트리
# 음식정보 성공
# ===============
# 2400
# 금액 성공
# ===============
# 에그타르트
# 음식메뉴 성공
# ===============
# Egg Tart 바삭하게 구워낸 패스트리 쉘 속에 담긴 풍부한 계란 맛을 입안 가득 느낄 수 있는 바삭하고 부드러운 에그타르트
# 음식정보 성공
# ===============
# 1600
# 금액 성공
# ===============
# 크림치즈타르트
# 음식메뉴 성공
# ===============
# Cream Cheese Tart 입안가득 부드럽고 진한 치즈의 맛을 느낄 수 있는 미니타르트
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 고소한 후랑크소시지
# 음식메뉴 성공
# ===============
# Frank Sausage 촉촉한 빵에 소시지를 넣은 조리빵
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 플레인베이글
# 음식메뉴 성공
# ===============
# Plain Bagel 쫄깃하고 담백한 맛의 플레인 베이글
# 음식정보 성공
# ===============
# 1600
# 금액 성공
# ===============
# 블루베리베이글
# 음식메뉴 성공
# ===============
# Blueberry Bagel 새콤달콤한 블루베리가 콕콕 박혀있는 상큼한 블루베리베이글
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 겉은바삭속은촉촉한플레인스콘
# 음식메뉴 성공
# ===============
# Plain Scorn 커피와 잘 어울리는 바삭한 비스킷 타입의 스콘
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 겉은바삭속은촉촉한쇼콜라스콘
# 음식메뉴 성공
# ===============
# Chocolat Scorn 초코칩이 쏙쏙 박힌 비스킷 타입의 초코 스콘
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# [디저트]
# 음식 카테고리 성공
# =========================================
# 마들렌
# 음식메뉴 성공
# ===============
# Madeleine 바닐라, 초코, 레드벨벳 마들렌으로 구성된 조개모양의 달콤한 디저트용 구움과자세트
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 마카롱
# 음식메뉴 성공
# ===============
# Macaron 작고 동그란 모양의 머량 크러스트 사이에 다양항 잼 필링을 채운 쿠키
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 아메리카노
# 음식메뉴 성공
# ===============
# Americano 뚜레쥬르만의 스페셜 고급원두를 적절한 비율로 블렌드하여 커피 본연의 맛과 향을 살린 따뜻한 아메리카노 음료
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 카페라떼
# 음식메뉴 성공
# ===============
# Café Latte 뚜레쥬르만의 스페셜 고급원두로 추출한 풍부한 풍미의 에스프레소와 스팀우유가 어우러진 따뜻한 라떼 음료
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 카푸치노
# 음식메뉴 성공
# ===============
# Cappuccino 뚜레쥬르만의 스페셜 고급원두로 추출한 풍부한 풍미의 에스프레소와 우유거품이 어우러진 부드러운 카푸치노 음료
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 카라멜마끼아또
# 음식메뉴 성공
# ===============
# Caramel Macchiato 뚜레쥬르만의 스페셜 고급원두로 추출한 풍부한 풍미의 에스프레소에 스팀우유, 향긋한 바닐라, 그리고 달콤한 카라멜이 어우러진 달달한 커피 음료
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 카페모카
# 음식메뉴 성공
# ===============
# Café Mocha 뚜레쥬르만의 스페셜 고급원두로 추출한 풍부한 풍미의 에스프레소, 부드러운 스팀우유와 진한 초콜릿이 어우러진 달콤한 모카 음료
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 바닐라라떼
# 음식메뉴 성공
# ===============
# Vanilla Latte 뚜레쥬르만의 스페셜 고급원두로 추출한 풍부한 풍미의 에스프레소와 부드러운 스팀우유, 그리고 향긋한 바닐라 시럽이 어우러진 달달한 음료
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 오가닉 카모마일
# 음식메뉴 성공
# ===============
# Chamomile Tea 사과향을 닮은 은은하고 부드러운 티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 잉글리쉬블랙퍼스트
# 음식메뉴 성공
# ===============
# English Breakfast Tea 홍차 본연의 풍부하고 진한 티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 페퍼민트
# 음식메뉴 성공
# ===============
# Pepermint 상쾌하고 청량감이 넘치는티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 그린티라떼
# 음식메뉴 성공
# ===============
# Geen Tea Latte 차광녹차가 들어 있어 더욱더 맛있는 녹차라떼
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 로얄밀크티 라떼
# 음식메뉴 성공
# ===============
# Royal Milk Tea Latte 잉글리쉬 블랙퍼스트 티로 만들어 홍차풍미와 부드러움이 가득한 로얄 밀크티
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 핫유자레몬티
# 음식메뉴 성공
# ===============
# Hot Citron Lemon Tea 꿀유자차에 새콤한 레몬즙을 넣어 더욱 맛있는 유자차
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 자몽에이드
# 음식메뉴 성공
# ===============
# Grapefruit Ade 자몽과육과 탄산수를 넣고 톡 쏘는 맛이 일품인 자몽에이드
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 레몬에이드
# 음식메뉴 성공
# ===============
# Lemon Ade 레몬농축액과 탄산수를 넣고 톡 쏘는 맛이 일품인 레몽에이드
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 뚜레쥬르 흰우유 (200ml)
# 음식메뉴 성공
# ===============
# Tous Les Jours Milk 맑은 물, 깨끗한 공기를 마시며 자란 젖소에서 생산된 1등급 원유를 사용하여 고소하고 깔끔한 맛의 뚜레쥬르가 만든 신선한 우유[비타민A, D3함유]
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# 뚜레쥬르 초코우유 (200ml)
# 음식메뉴 성공
# ===============
# Tous Les Jours Choco Milk 카카오폴리페놀이 함유된 진하고 부드러운 맛의 뚜레쥬르가 만든 신선한 초코우유
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# 뚜레쥬르 딸기우유 (200ml)
# 음식메뉴 성공
# ===============
# Tous Les Jours Strawberry Milk 국내산 딸기과즙을 넣은 달콤하고 부드러운 맛의 뚜레쥬르가 만든 신선한 딸기우유
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# [스프레드]
# 음식 카테고리 성공
# =========================================
# 폴리크림치즈포션
# 음식메뉴 성공
# ===============
# Pauly Cream Cheese
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# 본마망 딸기잼30G
# 음식메뉴 성공
# ===============
# Bonne Maman Strawberry Jam
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 서초구 서초동 1337-3
# 주소 뽑기 성공
# =========================================
#
# 롤링핀 이야기
# 다변화 된 식문화 발전과 함께 고객의 니즈 또한 빠르게 변하고 있습니다.
# 수많은 브랜드들이 생겨났다가 사라지고 또 다른 브랜드들이 유행처럼 번졌다가 없어지곤 합니다.
# 롤링핀은 건강한 먹거리와 일상생활에 가장 밀접하면서도 맛있는 식사 빵을 만들고자 시작되었습니다.
#
# 식사를 대체하면서 몸에 해가 되지 않는 것 중에 빵이면서도 천연발효로 만든 빵이면 더욱 좋지 않을까?
# 생각해서 내놓은 상품이 발효식빵 종류와 각 나라별 빵들입니다.
#
# 독일, 이태리, 프랑스 등 전통 베이커리를 한자리에서 즐길 수 있고 호두, 무화과, 블루베리, 밤, 단호박 등...
# 몸에 좋은 슈퍼푸드를 부재료로 사용하여 쫄깃하면서 부드러운 롤링핀만의 베이커리를 생산하고 있습니다.
#
# 단순 유행에 그치지 않고 식문화의 트렌트로 자리매김 하고자 (주)롤링핀 컴퍼니를 설립하였습니다.
# 아이들이 먹거리를 맘껏 즐길 수 있고, 롤링핀 공간에서 고객들이 감동하는 날까지 저희 임직원들은 최선을 다하여 전진하겠습니다.
# 감사합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 밀가루 : 캐나다산,미국산
# 크림치즈 : 수입산
# 생크림 : 국내산,수입산
# 계란,마늘,고구마,사과,토마토 : 국내산
# 롤치즈 : 뉴질랜드산,호주산
# 초콜릿 : 벨기에산,미국산
# 버터 : 프랑스산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [브런치]
# 음식 카테고리 성공
# =========================================
# [브런치]
# 음식 카테고리 성공
# =========================================
# 햄 & 모짜렐라 샌드위치
# 음식메뉴 성공
# ===============
# 재료소진시 조기품절 될 수 있습니다.(기본 20분정도 소요되는 메뉴입니다.)
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 스파이시 쉬림프 샌드위치
# 음식메뉴 성공
# ===============
# 잘 구워진 새우와 신선한 야채와의 조화재료소진시 조기품절 될 수 있습니다.(기본 20분정도 소요되는 메뉴입니다.)
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 크로크 엔젤
# 음식메뉴 성공
# ===============
# 부드러운 속결의 천사의 식빵에 진한 치즈향이 느껴지는 콜비잭치즈가 바삭하게 구워진 크로크무슈 스타일의 메뉴로 볶은 야채와 발사믹글레이즈가 속에 들어가 풍미가 더해진 제품재료소진시 조기품절 될 수 있습니다.(기본 20분정도 소요되는 메뉴입니다.)
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 오늘은 카프레제!
# 음식메뉴 성공
# ===============
# 시즌야채가 곁들여진 신선한 카프레제 샐러드와 담백한 빵들을 즐길 수 있는 클래식 샐러드 메뉴재료소진시 조기품절 될 수 있습니다.(기본 20분정도 소요되는 메뉴입니다.)
# 음식정보 성공
# ===============
# 10500
# 금액 성공
# ===============
# 굿모닝 크로와상
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 치아바타 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 굿모닝 크로와상+아메리카노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 강남구 역삼동 644-17
# 주소 뽑기 성공
# =========================================
#
# 맛있는'버라이어Tea'GONG CHA가 여러분을 찾아 갑니다.
#
# '대만 차장인'의 노하우로 만든
#
# '진짜 잎차'의 진수를 만끽하시기 바랍니다!
#
# 신속하고 정확하게 여러분이 계신 곳까지
#
# 신선한 공차를 배달해 드릴것을 약속드립니다.^*^
#
#
# 날씨가 더워 얼음이 조금 녹아서 배송될 수도 있으니 양해부탁드립니다~!
#
#
# 가게 소개 뽑기 성공
# =========================================
# ★음료 원산지 정보★그린티(대만산), 우롱티(대만산), 원터멜론티(대만산), 얼그레이티(대만산), 블랙티(대만산), 딸기시럽(대만산), 레드그레이프푸르트시럽(대만산), 레드그레이프푸르트시럽_자몽과즙베이스[적자몽농축액(이스라엘산)],홍자몽펄프믹스[홍자몽(미국산)], 레몬농축액(대만산), 레몬시럽_레몬과즙베이스[레몬(미국산)],레몬주스[레몬(이탈리아산)], 꿀레몬청_레몬[외국산(남아공,미국,이스라엘등)],벌꿀(국산), 꿀자몽청_자몽[외국산(남아공, 미국,이스라엘산 등)],벌꿀(국내산), 롱건시럽(대만산), 애플시럽(대만산) or 애플시럽[사과(국산), 사과농축액(칠레산)], 자몽청(남아공산), 카라멜시럽(대만산), 포도시럽(대만산), 농축청포도주스(아르헨티나산), 알로에(태국산), 펄(대만산), 홍자몽펄프(미국산), 코코넛(대만산), 화이트펄(대만산), 포도펄(대만산), 녹차파우더(국내산), 스무디파우더(대만산), 차이파우더{식물성크림[유청분말(칠레산,핀란드산,미국산),식물성유지(말레이시아산)]}, 초코파우더[코코아분말(네덜란드산), 식물성경화유(코코넛오일_인도네시아산, 필리핀산)], 초콜렛파우더(대만산), 타로파우더(대만산), 플랜트파우더(대만산), 플랜트파우더_식물성경화유지(인도네시아산,필리핀산), 레몬(이탈리아산), 레몬과즙베이스(미국산), 로즈마리(국내산), 망고퓌레(대만산), 밀가루(미국산), 밀크폼(대만산), 분당[설탕(호주산), 설탕(국내산), 식물성유지(말레이시아산), 식물성크림(칠레산), 쌀베이스(국내산), 야자경화유지(인도네시아산), 연유[원유(국내산), 유당(독일산)], 옥수수전분(러시아산), 우격(대만산), 우유(국내산), 자몽과즙(미국산), 자몽농축액(이스라엘산), 청포도베이스(칠레산), 커피(콜롬비아프레도니아, 코스타리카,브라질), 코코아(네덜란드산), 피코딸기(대만산), 휘피(캐나다산)★베이커리 원산지 정보★* 요구르트슈스틱: 식물성크림[팜핵경화유(인도네시아), 정제소금(미국산)], 기타가공품(네덜란드산), 전란액(국내산), 요구르트파우더 2.7%[요구르트분말0.46%(국내산)]* 초코슈스틱: 우유(원유100% 국내산), 전란액(국내산), 식물성크림[팜핵경화유(인도네시아), 정제소금(미국산)], 준초콜렛(1) 7.3% [다크컴파운드버튼(싱가포르산)], 준초콜렛(2) 7.3% {식물성유지[대두유(외국산:아르헨티나, 미국, 베트남 등)], 코코아분말(네덜란드산)}* 소시지패스츄리: 빵류{밀가루(밀:미국산,캐나다산),마아가린[식물성유지(대두유:외국산)]}, 소시지47.55%[돼지고기(국내산),닭고기(국내산)], 당류가공품(네덜란드산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# [2018년 가을-겨울 신메뉴]
# 음식 카테고리 성공
# =========================================
# [2018년 봄-여름 시즌 신메뉴]
# 음식 카테고리 성공
# =========================================
# [베스트 콤비네이션]
# 음식 카테고리 성공
# =========================================
# [밀크티]
# 음식 카테고리 성공
# =========================================
# [스무디]
# 음식 카테고리 성공
# =========================================
# [그린티 에이드]
# 음식 카테고리 성공
# =========================================
# [커피]
# 음식 카테고리 성공
# =========================================
# [공차 스페셜]
# 음식 카테고리 성공
# =========================================
# [오리지널 티]
# 음식 카테고리 성공
# =========================================
# [주스]
# 음식 카테고리 성공
# =========================================
# [디저트]
# 음식 카테고리 성공
# =========================================
# [후르츠 티]
# 음식 카테고리 성공
# =========================================
# [2018년 가을-겨울 신메뉴]
# 음식 카테고리 성공
# =========================================
# 치즈폼 커피 밀크티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 진한 커피 베이스 위에 부드럽고 달콤 짭쪼름한 치즈폼을 올린 음료(얼음량이 고정이며, 추천당도 70%입니다.)
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 치즈폼 커피 밀크티 (Hot, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 진한 커피 베이스 위에 부드럽고 달콤 짭쪼름한 치즈폼을 올린 음료(추천당도 70%입니다.)
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 치즈폼 딥바닐라 밀크티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 마다가스카르산 바닐라빈이 들어간 베이스 위에 부드럽고, 달콤 짭쪼름한 치즈폼을 올린 음료(얼음량이 고정이며, 추천당도 30%입니다.)
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 치즈폼 딥바닐라 밀크티 (Hot, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 마다가스카르산 바닐라빈이 들어간 베이스 위에 부드럽고, 달콤 짭쪼름한 치즈폼을 올린 음료(추천당도 30%입니다.)
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 치즈폼 딥초코 밀크티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 초콜렛, 스카치 풍미의 베이스 위에 부드럽고 달콤 짭쪼름한 치즈폼을 올린 음료(얼음량이 고정이며, 추천당도 50%입니다.)
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 치즈폼 딥초코 밀크티 (Hot, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 초콜렛, 스카치 풍미의 베이스 위에 부드럽고 달콤 짭쪼름한 치즈폼을 올린 음료(추천당도 50%입니다.)
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 치즈폼 딥초코 스무디 (Iced, Large)
# 음식메뉴 성공
# ===============
# 블랙티를 넣은 초콜렛 스무디에 스카치 풍미를 더해 진한 초콜렛 맛을 강조한 스무디로, 부드럽고 달콤 짭쪼름한 치즈폼과 조화를 이루는 음료(얼음량과 당도가 고정입니다.)
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 딥바닐라 카페라떼 (Iced, Large)
# 음식메뉴 성공
# ===============
# 진한 커피에 마다가스카르산 바닐라빈이 더해져 달콤하고 깊은 풍미를 느낄수 있는 공차만의 커피 음료 (얼음량이 고정이며, 추천당도 50%입니다.)
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 딥바닐라 카페라떼 (Hot, Large)
# 음식메뉴 성공
# ===============
# 진한 커피에 마다가스카르산 바닐라빈이 더해져 달콤하고 깊은 풍미를 느낄수 있는 공차만의 커피 음료 (추천당도 50%입니다.)
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 딥모카 카페라떼 (Iced, Large)
# 음식메뉴 성공
# ===============
# 카카오 함량이 높은 초콜렛 파우더를 사용하여 진한 풍미와 커피가 더해진 모카로 공차만의 밀크폼을 올려 달콤하게 즐기는 커피 음료 (얼음량이 고정이며, 추천당도 70%입니다.)
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 딥모카 카페라떼 (Hot, Large)
# 음식메뉴 성공
# ===============
# 카카오 함량이 높은 초콜렛 파우더를 사용하여 진한 풍미와 커피가 더해진 모카로 공차만의 밀크폼을 올려 달콤하게 즐기는 커피 음료 (추천당도 70%입니다.)
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [2018년 봄-여름 시즌 신메뉴]
# 음식 카테고리 성공
# =========================================
# 망고 쥬얼리 밀크티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 자스민 그린티로 만든 망고 밀크티와 쫀듯한 망고 쥬얼리가 어우러진 시즌 한정 밀크티 (ONLY ICED), 음료에 망고쥬얼리 (망고맛이 나는 펄)가 들어 있습니다. 얼음량 고정인 음료이고, 토핑은 최대2개까지 가능합니다.
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 망고 말차 티포카토 스무디 (Iced, Large)
# 음식메뉴 성공
# ===============
# 달콤한 망고가 더해진 부드러운 밀크 스무디에 쌉싸름한 우롱티를 함께 즐길 수 있는 시즌 한정 티포카토 스무디 (ONLY ICED). 얼음량과 당도가 고정인 음료이고, 토핑은 최대1개까지 가능합니다.
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 망고 밀크 요거티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 상큼한 요거트 우유에 과육이 살아있는 망고를 더한 시즌 한정 요거티(Yogurt-Tea) 음료 (ONLY ICED). 얼음량과 당도가 고정인 음료이고, 토핑은 최대2개까지 가능합니다.
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 커피 밀크티 크러쉬 + 펄 (Iced, Large)
# 음식메뉴 성공
# ===============
# 향긋한 블랙 밀크 티에 진한 커피를 더해 한여름 얼음과 함께 갈아 더욱 시원하게 즐기는 시즌 한정 음료 (ONLY ICED).  얼음량과 당도가 고정인 음료입니다.
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 포도 쥬얼리 밀크티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 향긋한 자스민 그린티로 만든 포도 밀크티와 상큼한 과즙의 포도 쥬얼리가 어우러진 시즌 한정 음료 (ONLY ICED), 음료에 포도쥬얼리(포도맛이 나는 펄)가 들어있습니다. 얼음량 고정인 음료이고, 토핑은 최대2개까지 가능합니다.
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 커피 밀크티 크러쉬 + 밀크폼 (Iced, Large)
# 음식메뉴 성공
# ===============
# 향긋한 블랙 밀크 티에 진한 커피를 더해 한여름 얼음과 함께 갈아 더욱 시원하게 즐기는 시즌 한정 음료 (ONLY ICED).  얼음량과 당도가 고정인 음료입니다.
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 포도 요거티 크러쉬 (Iced, Large)
# 음식메뉴 성공
# ===============
# 향긋한 자스민 그린티로 만든 요거티 크러쉬와 상큼한 과즙의 포도 쥬얼리가 어우러진 시즌 한정 음료 (ONLY ICED). 음료에 포도쥬얼리(포도맛이 나는 펄)가 들어 있습니다. 얼음량과 당도가 고정인 음료이고, 토핑은 최대2개까지 가능합니다.
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# [베스트 콤비네이션]
# 음식 카테고리 성공
# =========================================
# 블랙 밀크티 + 펄 (Large,Ice)
# 음식메뉴 성공
# ===============
# 공차 대표 메뉴 블랙밀크티와 쫄깃쫄깃한 펄의 콤비네이션
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 블랙 밀크티 + 펄 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 공차 대표 메뉴 블랙밀크티와 쫄깃쫄깃한 펄의 콤비네이션
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 블랙 밀크티 + 펄 (Large,Hot)
# 음식메뉴 성공
# ===============
# 공차 대표 메뉴 블랙밀크티와 쫄깃쫄깃한 펄의 콤비네이션
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 블랙 밀크티 + 펄 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 공차 대표 메뉴 블랙밀크티와 쫄깃쫄깃한 펄의 콤비네이션
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 타로 밀크티 + 펄 (Large,Ice)
# 음식메뉴 성공
# ===============
# 고소한 타로밀크티와 쫀득한 펄이 만난 공차의 베스트 셀러
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 타로 밀크티 + 펄 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 고소한 타로밀크티와 쫀득한 펄이 만난 공차의 베스트 셀러
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 타로 밀크티 + 펄 (Large,Hot)
# 음식메뉴 성공
# ===============
# 고소한 타로밀크티와 쫀득한 펄이 만난 공차의 베스트 셀러
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 타로 밀크티 + 펄 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 고소한 타로밀크티와 쫀득한 펄이 만난 공차의 베스트 셀러
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 초콜렛밀크티+밀크폼 (Large,Ice)
# 음식메뉴 성공
# ===============
# 공차만의 깊고 풍부한 초콜렛 밀크티에 부드러운 밀크폼을 더한 최고의 조합
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 초콜렛밀크티+밀크폼 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 공차만의 깊고 풍부한 초콜렛 밀크티에 부드러운 밀크폼을 더한 최고의 조합
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 밀크폼 얼그레이티+코코넛 (Large,Ice)
# 음식메뉴 성공
# ===============
# 베르가모트 향의 얼그레이티와 밀크폼의 조합에 숨겨진 베스트 콤비 쫄깃한 코코넛 토핑
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 밀크폼 얼그레이티+코코넛 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 베르가모트 향의 얼그레이티와 밀크폼의 조합에 숨겨진 베스트 콤비 쫄깃한 코코넛 토핑
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 자몽 그린티 에이드+알로에 (Large,Ice)
# 음식메뉴 성공
# ===============
# 청량하고 쌉싸름한 자몽 그린티 에이드에 달콤함을 더해주는 알로에 토핑
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 자몽 그린티 에이드+알로에 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 청량하고 쌉싸름한 자몽 그린티 에이드에 달콤함을 더해주는 알로에 토핑
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 망고요구르트+화이트펄 (Large,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 망고 과육과 요구르트에 화이트펄의 꼬들꼬들함이 느껴지는 주스
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 망고요구르트+화이트펄 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 망고 과육과 요구르트에 화이트펄의 꼬들꼬들함이 느껴지는 주스
# 음식정보 성공
# ===============
# 6400
# 금액 성공
# ===============
# [밀크티]
# 음식 카테고리 성공
# =========================================
# 그린 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 밀크의 조화
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 그린 밀크티 (Jumbo, Ice)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 밀크의 조화
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 그린 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 밀크의 조화
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 그린 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 밀크의 조화
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 우롱 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차에 밀크가 더해진 우롱밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 우롱 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차에 밀크가 더해진 우롱밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 우롱 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차에 밀크가 더해진 우롱밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 우롱 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차에 밀크가 더해진 우롱밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 블랙 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티(홍차)와 밀크의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 블랙 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티(홍차)와 밀크의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 블랙 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티(홍차)와 밀크의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 블랙 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티(홍차)와 밀크의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 얼그레이 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 베르가못 향의 얼그레이티(홍차)와 밀크가 부드러운 조화를 이루는 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 얼그레이 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 베르가못 향의 얼그레이티(홍차)와 밀크가 부드러운 조화를 이루는 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 얼그레이 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 베르가못 향의 얼그레이티(홍차)와 밀크가 부드러운 조화를 이루는 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 얼그레이 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 베르가못 향의 얼그레이티(홍차)와 밀크가 부드러운 조화를 이루는 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 윈터멜론 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론티와 부드러운 밀크가 더해진 윈터멜론 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 윈터멜론 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론티와 부드러운 밀크가 더해진 윈터멜론 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 윈터멜론 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론티와 부드러운 밀크가 더해진 윈터멜론 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 윈터멜론 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론티와 부드러운 밀크가 더해진 윈터멜론 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 타로 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 타로의 고소함과 밀크의 조합
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 타로 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 타로의 고소함과 밀크의 조합
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 타로 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 타로의 고소함과 밀크의 조합
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 타로 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 타로의 고소함과 밀크의 조합
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 카라멜 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티에 향기로운 카라멜향을 더한 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 카라멜 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티에 향기로운 카라멜향을 더한 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 카라멜 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티에 향기로운 카라멜향을 더한 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 카라멜 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티에 향기로운 카라멜향을 더한 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 초콜렛 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 부드러운 밀크에 녹아든 진한 초콜렛을 느낄 수 있는 초콜렛 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 초콜렛 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 부드러운 밀크에 녹아든 진한 초콜렛을 느낄 수 있는 초콜렛 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 초콜렛 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 부드러운 밀크에 녹아든 진한 초콜렛을 느낄 수 있는 초콜렛 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 초콜렛 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 부드러운 밀크에 녹아든 진한 초콜렛을 느낄 수 있는 초콜렛 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 차이 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 프리미엄 잎차만 골라, 블랙티 최적의 온도 95℃로 우려 스파이시한 풍미를 더하다 잎차로 직접 우려 낸 블랙티에 차이 파우더를 넣어 스파이시한 계피 향을 부드럽게 즐길 수 있는 밀크티
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 차이 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 프리미엄 잎차만 골라, 블랙티 최적의 온도 95℃로 우려 스파이시한 풍미를 더하다 잎차로 직접 우려 낸 블랙티에 차이 파우더를 넣어 스파이시한 계피 향을 부드럽게 즐길 수 있는 밀크티
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 차이 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 프리미엄 잎차만 골라, 블랙티 최적의 온도 95℃로 우려 스파이시한 풍미를 더하다 잎차로 직접 우려 낸 블랙티에 차이 파우더를 넣어 스파이시한 계피 향을 부드럽게 즐길 수 있는 밀크티
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 차이 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 프리미엄 잎차만 골라, 블랙티 최적의 온도 95℃로 우려 스파이시한 풍미를 더하다 잎차로 직접 우려 낸 블랙티에 차이 파우더를 넣어 스파이시한 계피 향을 부드럽게 즐길 수 있는 밀크티
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# [스무디]
# 음식 카테고리 성공
# =========================================
# 밀크 쿠앤크 스무디
# 음식메뉴 성공
# ===============
# 달콤한 쿠키앤크림과 밀크를 얼음과 함께 갈아만든 스무디
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 초코 쿠앤크 스무디
# 음식메뉴 성공
# ===============
# 진한 초콜렛과 달콤한쿠키앤크림을 밀크와 함께 갈아만든 오레오 초콜렛 스무디
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 타로 스무디
# 음식메뉴 성공
# ===============
# 고소한 타로를 밀크와 함께 갈아만든 달콤한 타로 스무디
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 망고 스무디
# 음식메뉴 성공
# ===============
# 농축된 달콤한 망고와 밀크를 함께 갈아만든 망고 스무디
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 레몬 요구르트 스무디
# 음식메뉴 성공
# ===============
# 새콤 달콤한 레몬 과즙과 요구르트를 얼음과 함께 갈아만든 스무디
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 청포도 스무디
# 음식메뉴 성공
# ===============
# 시원달콤한 청포도과즙과 알로에 알갱이가 쏙쏙 들어오는 재미가 일품인 청포도 스무디
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 제주그린티 스무디
# 음식메뉴 성공
# ===============
# 제주 유기농 그린티의 풍성한 향과 맛이 입안 가득 느껴지는 제주 유기농 그린티 스무디
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 블랙 밀크티 크러쉬 (iced, Large)
# 음식메뉴 성공
# ===============
# 공차 No.1 메뉴인 블랙밀크티와 얼음을 함께 갈아 만든 크러쉬의 청량함과 쫀득쫀득한 펄의 식감을 즐길 수 있는 시그니처 음료
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# [그린티 에이드]
# 음식 카테고리 성공
# =========================================
# 자몽 그린티 에이드 (Large)
# 음식메뉴 성공
# ===============
# 달콤하고 쌉싸름한 자몽과 로즈마리가 만드는 새로운 하모니의 그린티에이드
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 자몽 그린티 에이드 (Jumbo)
# 음식메뉴 성공
# ===============
# 달콤하고 쌉싸름한 자몽과 로즈마리가 만드는 새로운 하모니의 그린티에이드
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 망고 그린티 에이드 (Large)
# 음식메뉴 성공
# ===============
# 시원하고 청량한 그린티 에이드와 달콤한 망고가 조화로운 망고 그린티 에이드
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 망고 그린티 에이드 (Jumbo)
# 음식메뉴 성공
# ===============
# 시원하고 청량한 그린티 에이드와 달콤한 망고가 조화로운 망고 그린티 에이드
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 청포도 그린티 에이드 (Large)
# 음식메뉴 성공
# ===============
# 쌉싸름한 그린티에 청포도와 라임청을 넣어 청량하고 달콤한 그린티 에이드
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 청포도 그린티 에이드 (Jumbo)
# 음식메뉴 성공
# ===============
# 쌉싸름한 그린티에 청포도와 라임청을 넣어 청량하고 달콤한 그린티 에이드
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 레몬 그린티 에이드 (Large)
# 음식메뉴 성공
# ===============
# 쌉싸름한 그린티에 레몬과 라임청을 넣어 청량하고 상큼한 그린티 에이드
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 레몬 그린티 에이드 (Jumbo)
# 음식메뉴 성공
# ===============
# 쌉싸름한 그린티에 레몬과 라임청을 넣어 청량하고 상큼한 그린티 에이드
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# [커피]
# 음식 카테고리 성공
# =========================================
# 아메리카노 (Ice)
# 음식메뉴 성공
# ===============
# 100% 아라비카 원두의 드립커피
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 아메리카노 (Hot)
# 음식메뉴 성공
# ===============
# 100% 아라비카 원두의 드립커피
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 얼그레이 아메리카노 (Ice)
# 음식메뉴 성공
# ===============
# 100% 아라비카 커피와 향긋한 얼그레이티가 만나 이뤄내는 Only공차 커피메뉴
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 얼그레이 아메리카노 (Hot)
# 음식메뉴 성공
# ===============
# 100% 아라비카 커피와 향긋한 얼그레이티가 만나 이뤄내는 Only공차 커피메뉴
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 더블 그린 카페 라떼 (Iced, Large)
# 음식메뉴 성공
# ===============
# 제주산 녹차로 만든 말차 라떼에 커피와 밀크폼을 더한 더블 그린 카페 라떼
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 더블 그린 카페 라떼 (Hot, Large)
# 음식메뉴 성공
# ===============
# 제주산 녹차로 만든 말차 라떼에 커피와 밀크폼을 더한 더블 그린 카페 라떼
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# [공차 스페셜]
# 음식 카테고리 성공
# =========================================
# 밀크폼 그린티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 그린티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 그린티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 그린티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 우롱티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 우롱티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 우롱티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 우롱티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 윈터멜론티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론과 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 윈터멜론티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론과 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 윈터멜론티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론과 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 윈터멜론티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론과 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 블랙티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 맛의 블랙티(홍차)와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 블랙티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 맛의 블랙티(홍차)와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 블랙티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 맛의 블랙티(홍차)와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 블랙티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 맛의 블랙티(홍차)와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 얼그레이티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 베르가못향의 얼그레이티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 얼그레이티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# ...
# 음식정보 성공
# ===============
# 1400
# 금액 성공
# ===============
# 소시지 패스츄리
# 음식메뉴 성공
# ===============
# 달콤하고 바삭한 패스츄리안의 짭짤한 소시지의 조화가 좋은 핫 소시지 패스츄리
# 음식정보 성공
# ===============
# 3300
# 금액 성공
# ===============
# ===========끝===========
# ---28번 식당파싱 시작 ---
# 서울 강남구 논현동 181-9
# 주소 뽑기 성공
# =========================================
#
# 현재 커피스미스에서는주문금액 30000원 이상,배달받으시는 곳에서 매장간의 거리가 1km이내일 경우 배달료무료 이벤트를 진행하고 있습니다.
#
# coffeesmith는 장인을 일컫는 영어의 접미사인 "-smith"에서 유래하여
# 커피의 장인이 되겠다는 신념으로 탄생하였습니다.
# 커피를 진정으로 사랑하는 당신을 위해 최고의 솜씨와 최상의 아라비카 원두가 만들어 낸 작품입니다.
# 진한 커피의 즐거움을 커피스미스와 함께 하세요!
#
#
# ★★★ 리뷰Event 진행중- ★★★- 요청사항 란에 리뷰이벤트 참여여부 기재해 주시면 모든 음료 무료 Size Up !!
# ※ 항상 안전하고 맛있는 음식을 제공하기 위해 최선을 다하겠습니다. 이용해 주셔서 감사합니다.!!
#
#
#
# 가게 소개 뽑기 성공
# =========================================
# 원두 :브라질산,콜롬비아산,과테말라산,멕시코산,만델링산
#
# 가게 원산지 뽑기 성공
# =========================================
# 9000
# 최소 금액 성공
# =========================================
# [신메뉴 (NEW)]
# 음식 카테고리 성공
# =========================================
# [ICE아메리카노5+5EVENT]
# 음식 카테고리 성공
# =========================================
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# [커피 (Coffee)]
# 음식 카테고리 성공
# =========================================
# [논-커피 (Non-Coffee)]
# 음식 카테고리 성공
# =========================================
# [차 (Tea)]
# 음식 카테고리 성공
# =========================================
# [주스 & 에이드 (Juice & Ade)]
# 음식 카테고리 성공
# =========================================
# [프라페 (Frappe)]
# 음식 카테고리 성공
# =========================================
# [빙수]
# 음식 카테고리 성공
# =========================================
# [스무디 & 젤라또 (Smoothie & Gelato)]
# 음식 카테고리 성공
# =========================================
# [디저트 (Dessert)]
# 음식 카테고리 성공
# =========================================
# [기타 (etc)]
# 음식 카테고리 성공
# =========================================
# [신메뉴 (NEW)]
# 음식 카테고리 성공
# =========================================
# 콜드브루 (Only Ice)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 콜드브루 라떼 (Only Ice)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 크루아상 와플 (2조각)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 크루아상 와플 Set
# 음식메뉴 성공
# ===============
# 크루아상 와플 2조각 + Hot 아메리카노 1잔
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 뱅쇼 (Only hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# [ICE아메리카노5+5EVENT]
# 음식 카테고리 성공
# =========================================
# ICE 아메리카노 5+5 EVENT
# 음식메뉴 성공
# ===============
# +5잔 음료에 대해서는 옵션선택 및 적용 불가
# 음식정보 성공
# ===============
# 24000
# 금액 성공
# ===============
# [세트메뉴]
# 음식 카테고리 성공
# =========================================
# Set 1
# 음식메뉴 성공
# ===============
# 크로크무슈 + 아메리카노 2잔 (음료 변경 불가)
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# Set 2
# 음식메뉴 성공
# ===============
# 스미스 허니 바게트 + 아메리카노 2잔 (음료 변경 불가)
# 음식정보 성공
# ===============
# 14000
# 금액 성공
# ===============
# Set 3
# 음식메뉴 성공
# ===============
# 스미스 와플 + 아메리카노 2잔 (음료 변경 불가)
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# [커피 (Coffee)]
# 음식 카테고리 성공
# =========================================
# 카라멜비엔나
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 카페 모카
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 바닐라 라떼
# 음식메뉴 성공
# ===============
# 바닐라 파우더와 커피가 만나 달고 부드러운 맛이 나는 커피 음료
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 카라멜 마끼아또
# 음식메뉴 성공
# ===============
# 달고 진한 캬라멜 소스와 커피가 조화를 이루는 커피음료
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 카라멜카푸치노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 카페비엔나
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 카페 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 카푸치노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 카페 아메리카노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 시리얼 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# [논-커피 (Non-Coffee)]
# 음식 카테고리 성공
# =========================================
# 블랙빈 라떼
# 음식메뉴 성공
# ===============
# 커피가 들어가지 않은 검은콩 라떼
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# 카라멜 밀크티
# 음식메뉴 성공
# ===============
# 아씸밀크티에 캬리멜 시럽을 더한 향긋한 밀크티
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 아쌈 밀크티
# 음식메뉴 성공
# ===============
# 홍차 아쌈을 우유에 직접 끊여 우려낸 향이 진한 밀크티
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 녹차 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 아이스초코
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 핫초코
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 우유
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 고구마 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 미숫가루 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# ICE 버블그린티라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# ICE 버블로얄밀크티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 복숭아 아이스티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [차 (Tea)]
# 음식 카테고리 성공
# =========================================
# 자몽티 (Regular)
# 음식메뉴 성공
# ===============
# 진한 자몽의 맛이 달콤하고 쌉싸름하게 어우러지는 티
# 음식정보 성공
# ===============
# 6100
# 금액 성공
# ===============
# 유자차
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 한라봉차
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 오미자차
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 대추차
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 카모마일 티 (Regular)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 스미스 블랜드티 (Regular)
# 음식메뉴 성공
# ===============
# 부드러운 크림향과 달콤한 캬라멜향이 풍부한 홍차
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 스미스 허브티 (Regular)
# 음식메뉴 성공
# ===============
# 히비스커스 외 여러가지 과일이 블랜딩되어 달콤하고 부드러움이 특징인 과일차
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 민트티 (Regular)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 다즐링 티 (Regular)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 루이보스티 (Regular)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 얼그레이 티 (Regular)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 그린티 (Regular)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 뱅쇼 (Only hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# [주스 & 에이드 (Juice & Ade)]
# 음식 카테고리 성공
# =========================================
# 키위주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 토마토주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 딸기바나나주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 오렌지주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 바나나주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 청포도주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 딸기주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 스미스에이드 (유자) (Regular)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6100
# 금액 성공
# ===============
# 스미스에이드 (자몽) (Regular)
# 음식메뉴 성공
# ===============
# 자몽특유의 달고 쌉싸름한 맛과 톡쏘는 탄산수가 어우러진 에이드
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 스미스에이드 (레몬) (Regular)
# 음식메뉴 성공
# ===============
# 레몬즙의 상큼하고 톡쏘는 맛이 일품인 에이드
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 스미스에이드 (블루) (Regular)
# 음식메뉴 성공
# ===============
# 블루베리 맛의 톡쏘는 탄산수가 어우러진 에이드
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 스미스에이드 (레드) (Regular)
# 음식메뉴 성공
# ===============
# 라즈베리 맛의 톡쏘는 탄산수가 어우러진 에이드
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 사과주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 사과케일주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 청포도 케일 주스
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# [프라페 (Frappe)]
# 음식 카테고리 성공
# =========================================
# 커피 프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# 카라멜 프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# 그린티 프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# 초콜릿 프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 플레인 요거트 프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6200
# 금액 성공
# ===============
# 딸기 프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 모카 프라페
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6400
# 금액 성공
# ===============
# [빙수]
# 음식 카테고리 성공
# =========================================
# 눈꽃 팥빙수
# 음식메뉴 성공
# ===============
# * 눈꽃빙수는 3~4인용으로 양이 넉넉합니다.
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 눈꽃 초코빙수
# 음식메뉴 성공
# ===============
# * 눈꽃빙수는 3~4인용으로 양이 넉넉합니다.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 눈꽃 요거트빙수
# 음식메뉴 성공
# ===============
# * 눈꽃빙수는 3~4인용으로 양이 넉넉합니다.
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 눈꽃 망고빙수
# 음식메뉴 성공
# ===============
# * 눈꽃빙수는 3~4인용으로 양이 넉넉합니다.
# 음식정보 성공
# ===============
# 18000
# 금액 성공
# ===============
# 눈꽃 말차빙수
# 음식메뉴 성공
# ===============
# * 눈꽃빙수는 3~4인용으로 양이 넉넉합니다.
# 음식정보 성공
# ===============
# 16000
# 금액 성공
# ===============
# 팥빙수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 요거트 빙수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 초코 빙수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 커피 빙수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 밀크티 빙수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 녹차 빙수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# [스무디 & 젤라또 (Smoothie & Gelato)]
# 음식 카테고리 성공
# =========================================
# 블루베리 요거트 스무디
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6200
# 금액 성공
# ===============
# 라즈베리 요거트 스무디
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6200
# 금액 성공
# ===============
# 유자 요거트 스무디
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6200
# 금액 성공
# ===============
# 바닐라젤라또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 커피젤라또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 녹차젤라또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 베리요거트젤라또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 티라미수젤라또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 다크초코젤라또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 스트로베리젤라또
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [디저트 (Dessert)]
# 음식 카테고리 성공
# =========================================
# 카푸치노와플 (4pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 스미스 와플 (4pcs)
# 음식메뉴 성공
# ===============
# 바삭한 와플과 곁덜여먹는 부드러운 생크림이 매력적인 디저트
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 스미스 허니 바게트
# 음식메뉴 성공
# ===============
# 겉은 바삭하고 속은 촉촉하며 버터와 꿀이 달고 부드럽게 녹아들어있는 디저트
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 주니어 와플 (2pcs)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 브라우니 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 티라미수 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 뉴욕치즈케익 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 다크쇼콜라 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 블루베리 머핀
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 초코 머핀
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 블루베리 베이글
# 음식메뉴 성공
# ===============
# 크림치즈 1개 포함
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 어니언 베이글
# 음식메뉴 성공
# ===============
# 크림치즈 1개 포함
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 플레인 베이글
# 음식메뉴 성공
# ===============
# 크림치즈 1개 포함
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 아몬드쇼콜라 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 초콜릿쿠키 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 사브레쿠키 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 크로크무슈 (햄치즈 토스트)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 호미아 쿠키
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 호두 아몬드 머핀
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 레인보우 크레이프 (1pc)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# [기타 (etc)]
# 음식 카테고리 성공
# =========================================
# 아이스컵
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# ===========끝===========
# ---29번 식당파싱 시작 ---
# 서울 강남구 역삼동 810-13 1층
# 주소 뽑기 성공
# =========================================
#
# 더블 트러블은 '프레쉬 패스트푸드'를 표방하는 한국식 아메리칸 패스트푸드 전문점 입니다.
# 고소한 빵 사이에 묵직한 패티와 녹진한 치즈가 흘러내리는 10여 종의 '그릴드치즈’와
# ‘필라델피아 샌드위치’ , ‘치킨와플’ 등 특색 있는 메뉴를 시원한 맥주와 함께 즐겨보세요!
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 돼지고기,페퍼로니 : 미국산
# 베이컨 : 뉴질랜드산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [그릴드치즈]
# 음식 카테고리 성공
# =========================================
# [샌드위치]
# 음식 카테고리 성공
# =========================================
# [치킨]
# 음식 카테고리 성공
# =========================================
# [프라이즈]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [그릴드치즈]
# 음식 카테고리 성공
# =========================================
# 더블트러블 그릴드치즈
# 음식메뉴 성공
# ===============
# 두툼한 순쇠고기 수제 패티, 푸짐한 베이컨과 치즈가 들어간 더블트러블의 대표적인 그릴드치즈샌드위치
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 치킨코울슬로 그릴드치즈
# 음식메뉴 성공
# ===============
# 바삭한 치킨과 새콤달콤한 코울슬로샐러드가 어우러진 그릴드치즈샌드위치
# 음식정보 성공
# ===============
# 9700
# 금액 성공
# ===============
# 할라피뇨베이컨 그릴드치즈
# 음식메뉴 성공
# ===============
# 매콤한 할라피뇨와 베이컨이 어우러진 그릴드치즈샌드위치
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 풀&맥 그릴드치즈
# 음식메뉴 성공
# ===============
# 12시간 정도 양념에 푹 익힌 풀드 포크와 쫀득한 식감의 맥앤치즈가 어우러진 그릴드치즈샌드위치
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 블루베리치즈 그릴드치즈
# 음식메뉴 성공
# ===============
# 달콤한 블루베리 콤포트와 짭조름한 믹스치즈가 어우러져 달콤짭조름 그 자체의 그릴드치즈샌드위치
# 음식정보 성공
# ===============
# 7300
# 금액 성공
# ===============
# 페페로니 그릴드치즈
# 음식메뉴 성공
# ===============
# 오리지날 토마토 소스로 만들어진 페퍼로니피자를 연상케 하는 맛의 그릴드치즈샌드위치
# 음식정보 성공
# ===============
# 7300
# 금액 성공
# ===============
# 과카몰레베이컨 그릴드치즈
# 음식메뉴 성공
# ===============
# 아보카도로 만든 신선한 과카몰레와 베이컨이 어우러진 그릴드치즈샌드위치
# 음식정보 성공
# ===============
# 8100
# 금액 성공
# ===============
# 오리지날 그릴드치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6200
# 금액 성공
# ===============
# 아보카도트러블 그릴드치즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 11900
# 금액 성공
# ===============
# [샌드위치]
# 음식 카테고리 성공
# =========================================
# 서울치즈스테이크 샌드위치
# 음식메뉴 성공
# ===============
# 치즈를 베이스로 불판에 구운 쇠고기, 그릴드 어니언, 피망이 들어간 필라델피아식 샌드위치
# 음식정보 성공
# ===============
# 8800
# 금액 성공
# ===============
# 쉬림프롤 샌드위치
# 음식메뉴 성공
# ===============
# 마리네이드 하여 구운 새우, 토마토, 더블트러블의 오리지널 소스가 어우러진 샌드위치
# 음식정보 성공
# ===============
# 9800
# 금액 성공
# ===============
# [치킨]
# 음식 카테고리 성공
# =========================================
# W.M.C
# 음식메뉴 성공
# ===============
# 벨기에식 와플위에 올려진 바삭한 치킨과 치즈, 메이플 시럽이 한데 어우러진 메뉴
# 음식정보 성공
# ===============
# 9200
# 금액 성공
# ===============
# [프라이즈]
# 음식 카테고리 성공
# =========================================
# 더티 프라이즈
# 음식메뉴 성공
# ===============
# 베이컨슬라이스, 그릴드 어니언, 더블트러블만의 더티소스가 한데 어우러진 대표 프라이즈
# 음식정보 성공
# ===============
# 7500
# 금액 성공
# ===============
# 풀드포크 프라이즈
# 음식메뉴 성공
# ===============
# 12시간 정도 양념에 푹 익힌 풀드 포크와 신선한 아보카도, 사워크림과 절인채소, 고수를 곁들인 대표 프라이즈
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 맥앤치즈프라이즈
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# 피자 프라이즈
# 음식메뉴 성공
# ===============
# 오리지널 페퍼로니피자를 프라이즈위에 그대로 얹은 프라이즈
# 음식정보 성공
# ===============
# 7900
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 닥터페퍼 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# 제로콜라 (250ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3000
# 금액 성공
# ===============
# ===========끝===========
