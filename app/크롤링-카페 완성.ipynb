# %%
import time
import re

#  load library (url 이미지 다운로드)
import urllib.request
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/usr/sbin/chromedriver')

driver.implicitly_wait(3)
driver.get('https://www.foodfly.co.kr/restaurants')

# 카페[선택]
driver.find_element_by_xpath("/html/body/header/div[3]/form/div/div[4]").click()

# 웹 스크롤 다운 구현
elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 1
while no_of_pagedowns < 30:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.4)
    no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: use driver.switch_to.alert instead

# %%
# 웹 스크롤 다운 구현
# elem = driver.find_element_by_tag_name("body")
# no_of_pagedowns = 1
# while no_of_pagedowns < 40:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.8)
#     no_of_pagedowns += 1

# 팝업창 나올 시 해결
try:
    alert = driver.switch_to_alert()
    alert.accept()
    pass
except:
    pass

html = driver.page_source

soup = BeautifulSoup(html, 'lxml')

# 카페 데이터(이미지) 수집
# soup = BeautifulSoup(html, 'lxml')
# img = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_box_bg')
# count = 1
# for i in img:
#     img_url = i.get_text("url", strip=True)
#     img_url_parse = img_url[4:-1]
#     try:
#         urllib.request.urlretrieve(img_url_parse, f'{count}.cafe_food_img.jpg')
#     except:
#         pass
#     count += 1

# 일식 데이터(식당명) 수집
japan_store_list = []
japan_store_name = soup.select('#restaurants > .restaurant-list .restaurant_box .restaurant_info .restaurant_name')
for name in japan_store_name:
    store_name = f'{name.string}'
    
#     korea_store_list.append(store_name)

for i, name in enumerate(japan_store_list):
    print(i, name)


    
html = driver.page_source # 현재 페이지 주소를 반환    
ele_id = driver.find_element_by_id("restaurants")
html_content = ele_id.find_element_by_css_selector('div.restaurant-list').get_attribute('innerHTML')

soup = BeautifulSoup(html_content, 'lxml')

store_href = []
for url in soup:
    url_page = url.select('a')
    for url_href in url_page:
        a_href = url_href['href']
        store_href.append(a_href)


# 각 가게 링크에 접속 후 파싱
# 가게주소
store_addresss=[]
# 가게 소개
store_info_list = []
# 가게 원산지 정보
store_origin_infos = []
# 가게 최소금액
store_moneyss = []
# 가게 음식 카테고리
store_menu_category = []
# 가게 음식 메뉴
store_menus = []
# 음식 가격
store_prices = []
# 음식 정보
store_descriptions = []

num = 1
for p in store_href:
    # 팝업나올시 해결
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass
    
    try:
        driver.get(p)
        print(f'---{num}번 식당파싱 시작 ---')
        html2 = driver.page_source
        soup = BeautifulSoup(html2, 'lxml')
        num += 1
    except:
        print(f'{num}번 오류')
        pass
    # 가게명 뽑기
    store_name = soup.select_one('#restaurant-show > .clearfix > .left-section > .main-info').find_next('h1').get_text(strip=True)
    
    
    # 주소뽑기
    store_address = soup.select('#restaurant-show > .clearfix > .left-section .pull-left p .info-header + span')[1]
    store_address_str = store_address.contents[0]
    store_address_str_parse = store_address_str.replace(': ', '')
#     store_addresss.append(store_address_str_parse)
    print(store_address_str_parse)    
    print('주소 뽑기 성공')
    print('=========================================')
    
    
    # 가게소개 뽑기
    store_info = soup.select('#restaurant-show > .restaurant-info > p')    
    description = ''
    for x in store_info:
        store_info_str = x.get_text(strip=True)
        content = store_info_str + '\n'
        description += content
#     store_info_list.append(description)
    print(description)
    print('가게 소개 뽑기 성공')
    print('=========================================')
    
#     # 가게 원산지 정보 뽑기
    store_origin = soup.select_one('div.restaurant-info').find_next_sibling('div')
    origin_content = store_origin.select('p')
    
    description2 = ''
    for w in origin_content:
        store_origin_info = w.get_text(strip=True)
        content2 = store_origin_info + '\n'
        description2 += content2
#     store_origin_infos.append(description2)
    print(description2)
    print('가게 원산지 뽑기 성공')
    print('=========================================')    
    
    # 가게최소금액 뽑기
    store_least_money_list = soup.select('.main-info-sub > p > span.info-header + span')
    for a in store_least_money_list:
        store_least_money = store_least_money_list[3]
        store_least_money_result = store_least_money.get_text(":", strip=True)[2:8]
        store_split = re.split(',', store_least_money_result)
        store_money = ''
        for i in store_split:
            store_money += i
    store_moneys=int(store_money)
#     store_moneyss.append(store_moneys)
    print(store_moneys)
    print('최소 금액 성공')
    print('=========================================')
    
    if num == 11:
        break

    store_details_menu = soup.select('.left-section > .menu-category')
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
#         store_menu_category.append(store_category)
        print(store_category)
        print('음식 카테고리 성공')
        print('=========================================')
        
    store_category, _ = StoreCategory.objects.get_or_create(
        name='카페',
    )
    
    store = Store.objects.create(
        category=store_category,
        name=store_name,
        store_info=description,
        origin_info=description2,
        owner=User.objects.get(pk=1),
        least_cost=store_moneys,
    )
    
    for menu in store_details_menu:
        # 음식 카테고리
        store_category = menu.select_one(".row-category").find_next('strong').get_text(strip=True)
    #         store_menu_category.append(store_category)
        print(store_category)
        food_category, _ = FoodCategory.objects.get_or_create(
            name=store_category,
            store=store,
        )
        print('음식 카테고리 성공')
        print('=========================================')
        
        store_category_foods = menu.select(".row-menu")

        for food in store_category_foods:
            food_menu = food.select_one(".col-menu > strong").get_text(strip=True)
            print(food_menu)
            print('음식메뉴 성공')
            print('===============')
            food_info = food.select_one(".col-menu > span").get_text(strip=True)
            print(food_info)
            print('음식정보 성공')
            print('===============')
            food_money = food.select_one("span.calculate-price").get_text(strip=True)
            food_moneys = food_money.replace(",", "")
            print(food_moneys)
            print('금액 성공')
            print('===============')
            
            Food.objects.create(
            category=food_category,
            name=food_menu,
            price=food_moneys,
            food_info=food_info,
            )

        
    try:
        alert = driver.switch_to_alert()
        alert.accept()
        pass
    except:
        pass


    print('===========끝===========')



    driver.back()
    driver.implicitly_wait(12)
# Out:
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: use driver.switch_to.alert instead
#   # This is added back by InteractiveShellApp.init_path()
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:83: DeprecationWarning: use driver.switch_to.alert instead
# ---1번 식당파싱 시작 ---
# 서울 강남구 역삼동 736-17 동궁빌딩 지상1층 101호
# 주소 뽑기 성공
# =========================================
#
# 매일매일(Tous Les Jours),
# 매장에서 직접 굽는신선한 베이커리
#
# 뚜레쥬르는(Tous Les Jours - 프랑스어로 ‘매일매일’이라는 뜻)" 그 이름의 의미처럼
# 매일매일 매장에서 직접 굽는 신선함을 가장 큰 가치로 하는 베이커리 입니다.
# 1997년 구리교문에 처음 매장을 연 뚜레쥬르는,
# 그 시절 공장에서 양산빵을 납품 받던 다른 베이커리들과 달리,
# 하루 3번 매장에서 갓 구운 신선한 빵을 제공하며
# 국내 베이커리 업계에 새로운 변화의 바람을 일으켰습니다.
# 뚜레쥬르 매장에 들어서는 순간 감도는 갓 구워낸 빵의 고소하고 달큰한 향은
# 대량 생산에 급급했던 여타의 베이커리 브랜드와는 분명히 다른 차별점이 되었습니다
#
#
# 갓 구운 신선함이
# 매장을 가득 채웁니다.
#
# 오븐에서 방금 꺼낸 빵이 가장 맛있다는 것을 알기에, 뚜레쥬르는 지금도
# 더욱 따뜻하고 촉촉한 갓 구운 빵을 제공하기 위해 끊임없이 노력합니다.
# 매장에서 직접 굽는 것에 그치지 않고, 언제라도 따끈한 빵을 만날 수 있게
# 더욱 자주 굽고, 고객들이 필요한 시간에 맞춰 굽는 등
# 세심하고 배려가 담긴 서비스도 준비하고 있습니다.
# 갓 구워낸 빵은 고소한 향기와 따스한 온기로 매장을 가득 채우고,
# 고객들에게는 가장 맛있는 빵을 맛보는 행복을 선물합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 스테이크 아보카도 볼샐러드 : 쇠고기(호주산)오리엔탈 그릴치킨 볼샐러드 : 닭고기(국내산)그릴포크 누들 분짜 볼샐러드 : 돼지고기(미국산)멕시칸볼 샐러드 : 분쇄 가공육제품[쇠고기(호주산), 돼지고기(국내산)]
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [이벤트메뉴]
# 음식 카테고리 성공
# =========================================
# [샌드위치밀박스]
# 음식 카테고리 성공
# =========================================
# [샌드위치]
# 음식 카테고리 성공
# =========================================
# [프리미엄샐러드]
# 음식 카테고리 성공
# =========================================
# [사이드]
# 음식 카테고리 성공
# =========================================
# [빵]
# 음식 카테고리 성공
# =========================================
# [디저트]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [스프레드]
# 음식 카테고리 성공
# =========================================
# [이벤트메뉴]
# 음식 카테고리 성공
# =========================================
# 스파이시 불고기 파니니&에그팟&음료
# 음식메뉴 성공
# ===============
# Spicy Bulgogi Panini & Egg Pot & Beverage 그릴 불고기에 몬테레이 잭 치즈와 구운 양파가 칠리소스에 어우러진 매콤한 파니니 + 루꼴라,  수란, 파마산 치즈 사이드
# 음식정보 성공
# ===============
# 11100
# 금액 성공
# ===============
# 쉬림프 페스토 파니니&에그포테이토팟&음료
# 음식메뉴 성공
# ===============
# Shrimp pesto Panini & Egg Potato Pot & Beverage 그릴드 쉬림프에 모짜렐라 치즈와 썬드라이 토마토가 페스토 소스에 어우러진 이탈리안 곡물 파니니 + 에그포테이토 샐러드, 구운 베이컨 사이드
# 음식정보 성공
# ===============
# 11700
# 금액 성공
# ===============
# B.E.L.T.A 샌드위치&블루베리요거트팟&음료
# 음식메뉴 성공
# ===============
# B.E.L.T.A  Sandwich & Blueberry Yogurt Pot & Beverage 베이컨, 에그, 래터스, 토마토에 아보카도와 뚜레쥬르만의 홀그레인드레싱의 조합 + 블루베리 요거트
# 음식정보 성공
# ===============
# 11100
# 금액 성공
# ===============
# [샌드위치밀박스]
# 음식 카테고리 성공
# =========================================
# 채끝 아보카도 바게트&토마토바질팟&음료
# 음식메뉴 성공
# ===============
# Beef Avocado Baguette & Tomato Basil Pot & Beverage 부드러운 채끝에 아보카도, 모짜렐라 치즈, 구운 야채가 홀그레인 머스타드 소스와 어우러진 핫 바게트 + 여러가지 토마토, 바질 사이드
# 음식정보 성공
# ===============
# 11700
# 금액 성공
# ===============
# 크래미 와사비마요&토마토바질팟&음료
# 음식메뉴 성공
# ===============
# Crammy Wasabi Mayo & Tomato Basil Pot & Beverage 톡 쏘는 와사비 마요 소스에 아보카도와 부드러운 크래미가 어우러진 콜드 샌드위치 + 여러가지 토마토, 바질 사이드
# 음식정보 성공
# ===============
# 10700
# 금액 성공
# ===============
# 크랜베리치킨 아보카도&곡물렌틸팟&음료
# 음식메뉴 성공
# ===============
# Cranberry Chicken Avocado & Mushroom Lentils Pot & Beverage 새콤달콤한 크랜베리에 부드러운 아보카도와 구운 닭가슴살이 어우러진 콜드 샌드위치 + 렌틸콩, 구운 버섯, 파슬리 사이드
# 음식정보 성공
# ===============
# 10700
# 금액 성공
# ===============
# [샌드위치]
# 음식 카테고리 성공
# =========================================
# 스파이시 불고기 파니니
# 음식메뉴 성공
# ===============
# Spicy Bulgogi Panini 그릴 불고기에 몬테레이 잭 치즈와 구운 양파가 칠리소스에 어우러진 매콤한 파니니
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 쉬림프 페스토 파니니
# 음식메뉴 성공
# ===============
# Shrimp Pesto Grain Panini 그릴드 쉬림프에 모짜렐라 치즈와 썬드라이 토마토가 페스토 소스에 어우러진 이탈리안 곡물 파니니
# 음식정보 성공
# ===============
# 7400
# 금액 성공
# ===============
# 채끝 아보카도 바게트
# 음식메뉴 성공
# ===============
# Beef Avocado Baguette 부드러운 채끝에 아보카도, 모짜렐라 치즈, 구운 야채가 홀그레인 머스타드 소스와 어우러진 핫 바게트
# 음식정보 성공
# ===============
# 7400
# 금액 성공
# ===============
# 트러플오일 베지 바게트
# 음식메뉴 성공
# ===============
# Tryffle-oil Veggie Baguette 구운 야채(브로콜리, 파프리카, 버섯, 양파, 쥬키니호박)에 트러플 오일향이 가득 더해진 부드러운 바게트 샌드위치
# 음식정보 성공
# ===============
# 6400
# 금액 성공
# ===============
# B.E.L.T.A 샌드위치
# 음식메뉴 성공
# ===============
# B.E.L.T.A Sandwich 베이컨, 에그, 래터스, 토마토에 아보카도와 뚜레쥬르만의 홀그레인드레싱드레싱의 조합
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 햄&치즈 에그샐러드 샌드위치
# 음식메뉴 성공
# ===============
# Ham&Cheese Egg Salad Sandwich 홈메이드스타일의 에그쉬림프 샐러드, 햄과 치즈로 맛을 더한 식빵 샌드위치
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 크래미 와사비마요
# 음식메뉴 성공
# ===============
# Crammy Wasabi Mayo 톡 쏘는 와사비 마요 소스에 아보카도와 부드러운 크래미가 어우러진 콜드 샌드위치
# 음식정보 성공
# ===============
# 6400
# 금액 성공
# ===============
# 크렌베리치킨 아보카도
# 음식메뉴 성공
# ===============
# Cranberry Chicken Avocado 새콤달콤한 크랜베리에 부드러운 아보카도와 구운 닭가슴살이 어우러진 콜드 샌드위치
# 음식정보 성공
# ===============
# 6400
# 금액 성공
# ===============
# 무화과 리코타 샌드위치
# 음식메뉴 성공
# ===============
# Fig Ricotta Sandwich 달콤한 무화과와 리코타가 샌드된 디저트 타입의 콜드 샌드위치
# 음식정보 성공
# ===============
# 5800
# 금액 성공
# ===============
# [프리미엄샐러드]
# 음식 카테고리 성공
# =========================================
# 채끝 아보카도 샐러드
# 음식메뉴 성공
# ===============
# Beef Avocado Salad 부드러운 채끝과 아보카도, 구운 야채가 발사믹 소스와 어우러진 한끼식사 샐러드 + 데일리브레드 제공
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 그릴치킨 곡물 샐러드
# 음식메뉴 성공
# ===============
# Grill Chicken Grain Salad 그릴드 치킨에 곡물, 브로콜리, 양파튀김이 고소한 참깨 소스와 어우러진 한끼식사 샐러드 + 데일리브레드 제공
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# 쉬림프 에그포테이토 샐러드
# 음식메뉴 성공
# ===============
# Shrimp Egg Potato Salad 그릴드 쉬림프에 부드러운 에그포테이토 샐러드와 렌틸콩이 화이트 크림소스와 어우러진 한끼식사 샐러드 + 데일리브레드 제공
# 음식정보 성공
# ===============
# 9500
# 금액 성공
# ===============
# 콥샐러드
# 음식메뉴 성공
# ===============
# Cobb Salad 구운 닭가슴살, 아보카도, 토마토, 베이컨이 요거트 드레싱과 어우러진 한끼식사 샐러드 + 데일리브레드 제공
# 음식정보 성공
# ===============
# 8900
# 금액 성공
# ===============
# [사이드]
# 음식 카테고리 성공
# =========================================
# 에그팟
# 음식메뉴 성공
# ===============
# Egg POT 루꼴라,  수란, 파마산 치즈
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 에그포테이토팟
# 음식메뉴 성공
# ===============
# Egg Potato POT 에그포테이토 샐러드, 구운 베이컨
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 머쉬룸렌틸팟
# 음식메뉴 성공
# ===============
# Mushroom Lentils POT 렌틸콩, 구운 버섯, 파슬리
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 토마토바질팟
# 음식메뉴 성공
# ===============
# Tomato Basil POT 여러가지 토마토, 바질
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 블루베리요거트팟
# 음식메뉴 성공
# ===============
# Blueberry Yogurt POT 블루베리 요거트
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# 요거트팟
# 음식메뉴 성공
# ===============
# Yogurt POT 요거트
# 음식정보 성공
# ===============
# 2800
# 금액 성공
# ===============
# [빵]
# 음식 카테고리 성공
# =========================================
# 단팥빵
# 음식메뉴 성공
# ===============
# Red Bean Bread 통팥앙금을 사용하여 누구나 좋아하는 빵
# 음식정보 성공
# ===============
# 1700
# 금액 성공
# ===============
# 슈크림빵
# 음식메뉴 성공
# ===============
# Cream Puff Bread 달콤하고 고소한 커스터드 크림이 듬뿍 *크림 속 검은 반점은 바닐라씨드임으로 안심하고 드시기 바랍니다
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 오리지널프렌치크라상
# 음식메뉴 성공
# ===============
# Croissant 버터가 듬뿍 들어가 고소한 풍미가 뛰어나고 한겹 한겹 정성으로 접어 만들어 패스트리의 결이 살아있는 오리지널 크라상 (프랑스산 버터, 유지방 82%)
# 음식정보 성공
# ===============
# 1900
# 금액 성공
# ===============
# 아몬드크라상
# 음식메뉴 성공
# ===============
# Almond Croissant 고소한 아몬드크림이 들어간 크라상
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 애플파이
# 음식메뉴 성공
# ===============
# Apple Pie 새콤달콤 사과 과육이 가득한 애플필링을 듬뿍 넣은 바삭한 파이
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 새콤달콤유자파이
# 음식메뉴 성공
# ===============
# Citron Pie 바삭바삭한 파이 안에 유자크림이 들어가 더욱 상큼한 패스트리
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 뺑오쇼콜라
# 음식메뉴 성공
# ===============
# Plain au Chocolat 초코스틱을 돌돌 말아 넣은 바삭한 패스트리
# 음식정보 성공
# ===============
# 2400
# 금액 성공
# ===============
# 에그타르트
# 음식메뉴 성공
# ===============
# Egg Tart 바삭하게 구워낸 패스트리 쉘 속에 담긴 풍부한 계란 맛을 입안 가득 느낄 수 있는 바삭하고 부드러운 에그타르트
# 음식정보 성공
# ===============
# 1600
# 금액 성공
# ===============
# 크림치즈타르트
# 음식메뉴 성공
# ===============
# Cream Cheese Tart 입안가득 부드럽고 진한 치즈의 맛을 느낄 수 있는 미니타르트
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 고소한 후랑크소시지
# 음식메뉴 성공
# ===============
# Frank Sausage 촉촉한 빵에 소시지를 넣은 조리빵
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 플레인베이글
# 음식메뉴 성공
# ===============
# Plain Bagel 쫄깃하고 담백한 맛의 플레인 베이글
# 음식정보 성공
# ===============
# 1600
# 금액 성공
# ===============
# 블루베리베이글
# 음식메뉴 성공
# ===============
# Blueberry Bagel 새콤달콤한 블루베리가 콕콕 박혀있는 상큼한 블루베리베이글
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 겉은바삭속은촉촉한플레인스콘
# 음식메뉴 성공
# ===============
# Plain Scorn 커피와 잘 어울리는 바삭한 비스킷 타입의 스콘
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# 겉은바삭속은촉촉한쇼콜라스콘
# 음식메뉴 성공
# ===============
# Chocolat Scorn 초코칩이 쏙쏙 박힌 비스킷 타입의 초코 스콘
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# [디저트]
# 음식 카테고리 성공
# =========================================
# 마들렌
# 음식메뉴 성공
# ===============
# Madeleine 바닐라, 초코, 레드벨벳 마들렌으로 구성된 조개모양의 달콤한 디저트용 구움과자세트
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 마카롱
# 음식메뉴 성공
# ===============
# Macaron 작고 동그란 모양의 머량 크러스트 사이에 다양항 잼 필링을 채운 쿠키
# 음식정보 성공
# ===============
# 1500
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 아메리카노
# 음식메뉴 성공
# ===============
# Americano 뚜레쥬르만의 스페셜 고급원두를 적절한 비율로 블렌드하여 커피 본연의 맛과 향을 살린 따뜻한 아메리카노 음료
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 카페라떼
# 음식메뉴 성공
# ===============
# Café Latte 뚜레쥬르만의 스페셜 고급원두로 추출한 풍부한 풍미의 에스프레소와 스팀우유가 어우러진 따뜻한 라떼 음료
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 카푸치노
# 음식메뉴 성공
# ===============
# Cappuccino 뚜레쥬르만의 스페셜 고급원두로 추출한 풍부한 풍미의 에스프레소와 우유거품이 어우러진 부드러운 카푸치노 음료
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 카라멜마끼아또
# 음식메뉴 성공
# ===============
# Caramel Macchiato 뚜레쥬르만의 스페셜 고급원두로 추출한 풍부한 풍미의 에스프레소에 스팀우유, 향긋한 바닐라, 그리고 달콤한 카라멜이 어우러진 달달한 커피 음료
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 카페모카
# 음식메뉴 성공
# ===============
# Café Mocha 뚜레쥬르만의 스페셜 고급원두로 추출한 풍부한 풍미의 에스프레소, 부드러운 스팀우유와 진한 초콜릿이 어우러진 달콤한 모카 음료
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 바닐라라떼
# 음식메뉴 성공
# ===============
# Vanilla Latte 뚜레쥬르만의 스페셜 고급원두로 추출한 풍부한 풍미의 에스프레소와 부드러운 스팀우유, 그리고 향긋한 바닐라 시럽이 어우러진 달달한 음료
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 오가닉 카모마일
# 음식메뉴 성공
# ===============
# Chamomile Tea 사과향을 닮은 은은하고 부드러운 티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 잉글리쉬블랙퍼스트
# 음식메뉴 성공
# ===============
# English Breakfast Tea 홍차 본연의 풍부하고 진한 티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 페퍼민트
# 음식메뉴 성공
# ===============
# Pepermint 상쾌하고 청량감이 넘치는티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 그린티라떼
# 음식메뉴 성공
# ===============
# Geen Tea Latte 차광녹차가 들어 있어 더욱더 맛있는 녹차라떼
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 로얄밀크티 라떼
# 음식메뉴 성공
# ===============
# Royal Milk Tea Latte 잉글리쉬 블랙퍼스트 티로 만들어 홍차풍미와 부드러움이 가득한 로얄 밀크티
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 핫유자레몬티
# 음식메뉴 성공
# ===============
# Hot Citron Lemon Tea 꿀유자차에 새콤한 레몬즙을 넣어 더욱 맛있는 유자차
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 자몽에이드
# 음식메뉴 성공
# ===============
# Grapefruit Ade 자몽과육과 탄산수를 넣고 톡 쏘는 맛이 일품인 자몽에이드
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 레몬에이드
# 음식메뉴 성공
# ===============
# Lemon Ade 레몬농축액과 탄산수를 넣고 톡 쏘는 맛이 일품인 레몽에이드
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 뚜레쥬르 흰우유 (200ml)
# 음식메뉴 성공
# ===============
# Tous Les Jours Milk 맑은 물, 깨끗한 공기를 마시며 자란 젖소에서 생산된 1등급 원유를 사용하여 고소하고 깔끔한 맛의 뚜레쥬르가 만든 신선한 우유[비타민A, D3함유]
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# 뚜레쥬르 초코우유 (200ml)
# 음식메뉴 성공
# ===============
# Tous Les Jours Choco Milk 카카오폴리페놀이 함유된 진하고 부드러운 맛의 뚜레쥬르가 만든 신선한 초코우유
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# 뚜레쥬르 딸기우유 (200ml)
# 음식메뉴 성공
# ===============
# Tous Les Jours Strawberry Milk 국내산 딸기과즙을 넣은 달콤하고 부드러운 맛의 뚜레쥬르가 만든 신선한 딸기우유
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# [스프레드]
# 음식 카테고리 성공
# =========================================
# 폴리크림치즈포션
# 음식메뉴 성공
# ===============
# Pauly Cream Cheese
# 음식정보 성공
# ===============
# 900
# 금액 성공
# ===============
# 본마망 딸기잼30G
# 음식메뉴 성공
# ===============
# Bonne Maman Strawberry Jam
# 음식정보 성공
# ===============
# 1000
# 금액 성공
# ===============
# ===========끝===========
# /home/hanyonghee/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/ipykernel_launcher.py:217: DeprecationWarning: use driver.switch_to.alert instead
# ---2번 식당파싱 시작 ---
# 서울 서초구 서초동 1337-3
# 주소 뽑기 성공
# =========================================
#
# 롤링핀 이야기
# 다변화 된 식문화 발전과 함께 고객의 니즈 또한 빠르게 변하고 있습니다.
# 수많은 브랜드들이 생겨났다가 사라지고 또 다른 브랜드들이 유행처럼 번졌다가 없어지곤 합니다.
# 롤링핀은 건강한 먹거리와 일상생활에 가장 밀접하면서도 맛있는 식사 빵을 만들고자 시작되었습니다.
#
# 식사를 대체하면서 몸에 해가 되지 않는 것 중에 빵이면서도 천연발효로 만든 빵이면 더욱 좋지 않을까?
# 생각해서 내놓은 상품이 발효식빵 종류와 각 나라별 빵들입니다.
#
# 독일, 이태리, 프랑스 등 전통 베이커리를 한자리에서 즐길 수 있고 호두, 무화과, 블루베리, 밤, 단호박 등...
# 몸에 좋은 슈퍼푸드를 부재료로 사용하여 쫄깃하면서 부드러운 롤링핀만의 베이커리를 생산하고 있습니다.
#
# 단순 유행에 그치지 않고 식문화의 트렌트로 자리매김 하고자 (주)롤링핀 컴퍼니를 설립하였습니다.
# 아이들이 먹거리를 맘껏 즐길 수 있고, 롤링핀 공간에서 고객들이 감동하는 날까지 저희 임직원들은 최선을 다하여 전진하겠습니다.
# 감사합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 밀가루 : 캐나다산,미국산
# 크림치즈 : 수입산
# 생크림 : 국내산,수입산
# 계란,마늘,고구마,사과,토마토 : 국내산
# 롤치즈 : 뉴질랜드산,호주산
# 초콜릿 : 벨기에산,미국산
# 버터 : 프랑스산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 15000
# 최소 금액 성공
# =========================================
# [브런치]
# 음식 카테고리 성공
# =========================================
# [브런치]
# 음식 카테고리 성공
# =========================================
# 햄 & 모짜렐라 샌드위치
# 음식메뉴 성공
# ===============
# 재료소진시 조기품절 될 수 있습니다.(기본 20분정도 소요되는 메뉴입니다.)
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 스파이시 쉬림프 샌드위치
# 음식메뉴 성공
# ===============
# 잘 구워진 새우와 신선한 야채와의 조화재료소진시 조기품절 될 수 있습니다.(기본 20분정도 소요되는 메뉴입니다.)
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 크로크 엔젤
# 음식메뉴 성공
# ===============
# 부드러운 속결의 천사의 식빵에 진한 치즈향이 느껴지는 콜비잭치즈가 바삭하게 구워진 크로크무슈 스타일의 메뉴로 볶은 야채와 발사믹글레이즈가 속에 들어가 풍미가 더해진 제품재료소진시 조기품절 될 수 있습니다.(기본 20분정도 소요되는 메뉴입니다.)
# 음식정보 성공
# ===============
# 11500
# 금액 성공
# ===============
# 오늘은 카프레제!
# 음식메뉴 성공
# ===============
# 시즌야채가 곁들여진 신선한 카프레제 샐러드와 담백한 빵들을 즐길 수 있는 클래식 샐러드 메뉴재료소진시 조기품절 될 수 있습니다.(기본 20분정도 소요되는 메뉴입니다.)
# 음식정보 성공
# ===============
# 10500
# 금액 성공
# ===============
# 굿모닝 크로와상
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 치아바타 피자
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 10900
# 금액 성공
# ===============
# 굿모닝 크로와상+아메리카노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# ===========끝===========
# ---3번 식당파싱 시작 ---
# 서울 강남구 역삼동 644-17
# 주소 뽑기 성공
# =========================================
#
# 맛있는'버라이어Tea'GONG CHA가 여러분을 찾아 갑니다.
#
# '대만 차장인'의 노하우로 만든
#
# '진짜 잎차'의 진수를 만끽하시기 바랍니다!
#
# 신속하고 정확하게 여러분이 계신 곳까지
#
# 신선한 공차를 배달해 드릴것을 약속드립니다.^*^
#
#
# 날씨가 더워 얼음이 조금 녹아서 배송될 수도 있으니 양해부탁드립니다~!
#
#
# 가게 소개 뽑기 성공
# =========================================
# ★음료 원산지 정보★그린티(대만산), 우롱티(대만산), 원터멜론티(대만산), 얼그레이티(대만산), 블랙티(대만산), 딸기시럽(대만산), 레드그레이프푸르트시럽(대만산), 레드그레이프푸르트시럽_자몽과즙베이스[적자몽농축액(이스라엘산)],홍자몽펄프믹스[홍자몽(미국산)], 레몬농축액(대만산), 레몬시럽_레몬과즙베이스[레몬(미국산)],레몬주스[레몬(이탈리아산)], 꿀레몬청_레몬[외국산(남아공,미국,이스라엘등)],벌꿀(국산), 꿀자몽청_자몽[외국산(남아공, 미국,이스라엘산 등)],벌꿀(국내산), 롱건시럽(대만산), 애플시럽(대만산) or 애플시럽[사과(국산), 사과농축액(칠레산)], 자몽청(남아공산), 카라멜시럽(대만산), 포도시럽(대만산), 농축청포도주스(아르헨티나산), 알로에(태국산), 펄(대만산), 홍자몽펄프(미국산), 코코넛(대만산), 화이트펄(대만산), 포도펄(대만산), 녹차파우더(국내산), 스무디파우더(대만산), 차이파우더{식물성크림[유청분말(칠레산,핀란드산,미국산),식물성유지(말레이시아산)]}, 초코파우더[코코아분말(네덜란드산), 식물성경화유(코코넛오일_인도네시아산, 필리핀산)], 초콜렛파우더(대만산), 타로파우더(대만산), 플랜트파우더(대만산), 플랜트파우더_식물성경화유지(인도네시아산,필리핀산), 레몬(이탈리아산), 레몬과즙베이스(미국산), 로즈마리(국내산), 망고퓌레(대만산), 밀가루(미국산), 밀크폼(대만산), 분당[설탕(호주산), 설탕(국내산), 식물성유지(말레이시아산), 식물성크림(칠레산), 쌀베이스(국내산), 야자경화유지(인도네시아산), 연유[원유(국내산), 유당(독일산)], 옥수수전분(러시아산), 우격(대만산), 우유(국내산), 자몽과즙(미국산), 자몽농축액(이스라엘산), 청포도베이스(칠레산), 커피(콜롬비아프레도니아, 코스타리카,브라질), 코코아(네덜란드산), 피코딸기(대만산), 휘피(캐나다산)★베이커리 원산지 정보★* 요구르트슈스틱: 식물성크림[팜핵경화유(인도네시아), 정제소금(미국산)], 기타가공품(네덜란드산), 전란액(국내산), 요구르트파우더 2.7%[요구르트분말0.46%(국내산)]* 초코슈스틱: 우유(원유100% 국내산), 전란액(국내산), 식물성크림[팜핵경화유(인도네시아), 정제소금(미국산)], 준초콜렛(1) 7.3% [다크컴파운드버튼(싱가포르산)], 준초콜렛(2) 7.3% {식물성유지[대두유(외국산:아르헨티나, 미국, 베트남 등)], 코코아분말(네덜란드산)}* 소시지패스츄리: 빵류{밀가루(밀:미국산,캐나다산),마아가린[식물성유지(대두유:외국산)]}, 소시지47.55%[돼지고기(국내산),닭고기(국내산)], 당류가공품(네덜란드산)
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# [2018년 가을-겨울 신메뉴]
# 음식 카테고리 성공
# =========================================
# [2018년 봄-여름 시즌 신메뉴]
# 음식 카테고리 성공
# =========================================
# [베스트 콤비네이션]
# 음식 카테고리 성공
# =========================================
# [밀크티]
# 음식 카테고리 성공
# =========================================
# [스무디]
# 음식 카테고리 성공
# =========================================
# [그린티 에이드]
# 음식 카테고리 성공
# =========================================
# [커피]
# 음식 카테고리 성공
# =========================================
# [공차 스페셜]
# 음식 카테고리 성공
# =========================================
# [오리지널 티]
# 음식 카테고리 성공
# =========================================
# [주스]
# 음식 카테고리 성공
# =========================================
# [디저트]
# 음식 카테고리 성공
# =========================================
# [후르츠 티]
# 음식 카테고리 성공
# =========================================
# [2018년 가을-겨울 신메뉴]
# 음식 카테고리 성공
# =========================================
# 치즈폼 커피 밀크티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 진한 커피 베이스 위에 부드럽고 달콤 짭쪼름한 치즈폼을 올린 음료(얼음량이 고정이며, 추천당도 70%입니다.)
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 치즈폼 커피 밀크티 (Hot, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 진한 커피 베이스 위에 부드럽고 달콤 짭쪼름한 치즈폼을 올린 음료(추천당도 70%입니다.)
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 치즈폼 딥바닐라 밀크티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 마다가스카르산 바닐라빈이 들어간 베이스 위에 부드럽고, 달콤 짭쪼름한 치즈폼을 올린 음료(얼음량이 고정이며, 추천당도 30%입니다.)
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 치즈폼 딥바닐라 밀크티 (Hot, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 마다가스카르산 바닐라빈이 들어간 베이스 위에 부드럽고, 달콤 짭쪼름한 치즈폼을 올린 음료(추천당도 30%입니다.)
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 치즈폼 딥초코 밀크티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 초콜렛, 스카치 풍미의 베이스 위에 부드럽고 달콤 짭쪼름한 치즈폼을 올린 음료(얼음량이 고정이며, 추천당도 50%입니다.)
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 치즈폼 딥초코 밀크티 (Hot, Large)
# 음식메뉴 성공
# ===============
# 블랙티와 초콜렛, 스카치 풍미의 베이스 위에 부드럽고 달콤 짭쪼름한 치즈폼을 올린 음료(추천당도 50%입니다.)
# 음식정보 성공
# ===============
# 4900
# 금액 성공
# ===============
# 치즈폼 딥초코 스무디 (Iced, Large)
# 음식메뉴 성공
# ===============
# 블랙티를 넣은 초콜렛 스무디에 스카치 풍미를 더해 진한 초콜렛 맛을 강조한 스무디로, 부드럽고 달콤 짭쪼름한 치즈폼과 조화를 이루는 음료(얼음량과 당도가 고정입니다.)
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 딥바닐라 카페라떼 (Iced, Large)
# 음식메뉴 성공
# ===============
# 진한 커피에 마다가스카르산 바닐라빈이 더해져 달콤하고 깊은 풍미를 느낄수 있는 공차만의 커피 음료 (얼음량이 고정이며, 추천당도 50%입니다.)
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 딥바닐라 카페라떼 (Hot, Large)
# 음식메뉴 성공
# ===============
# 진한 커피에 마다가스카르산 바닐라빈이 더해져 달콤하고 깊은 풍미를 느낄수 있는 공차만의 커피 음료 (추천당도 50%입니다.)
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 딥모카 카페라떼 (Iced, Large)
# 음식메뉴 성공
# ===============
# 카카오 함량이 높은 초콜렛 파우더를 사용하여 진한 풍미와 커피가 더해진 모카로 공차만의 밀크폼을 올려 달콤하게 즐기는 커피 음료 (얼음량이 고정이며, 추천당도 70%입니다.)
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 딥모카 카페라떼 (Hot, Large)
# 음식메뉴 성공
# ===============
# 카카오 함량이 높은 초콜렛 파우더를 사용하여 진한 풍미와 커피가 더해진 모카로 공차만의 밀크폼을 올려 달콤하게 즐기는 커피 음료 (추천당도 70%입니다.)
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# [2018년 봄-여름 시즌 신메뉴]
# 음식 카테고리 성공
# =========================================
# 망고 쥬얼리 밀크티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 자스민 그린티로 만든 망고 밀크티와 쫀듯한 망고 쥬얼리가 어우러진 시즌 한정 밀크티 (ONLY ICED), 음료에 망고쥬얼리 (망고맛이 나는 펄)가 들어 있습니다. 얼음량 고정인 음료이고, 토핑은 최대2개까지 가능합니다.
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 망고 말차 티포카토 스무디 (Iced, Large)
# 음식메뉴 성공
# ===============
# 달콤한 망고가 더해진 부드러운 밀크 스무디에 쌉싸름한 우롱티를 함께 즐길 수 있는 시즌 한정 티포카토 스무디 (ONLY ICED). 얼음량과 당도가 고정인 음료이고, 토핑은 최대1개까지 가능합니다.
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 망고 밀크 요거티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 상큼한 요거트 우유에 과육이 살아있는 망고를 더한 시즌 한정 요거티(Yogurt-Tea) 음료 (ONLY ICED). 얼음량과 당도가 고정인 음료이고, 토핑은 최대2개까지 가능합니다.
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 커피 밀크티 크러쉬 + 펄 (Iced, Large)
# 음식메뉴 성공
# ===============
# 향긋한 블랙 밀크 티에 진한 커피를 더해 한여름 얼음과 함께 갈아 더욱 시원하게 즐기는 시즌 한정 음료 (ONLY ICED).  얼음량과 당도가 고정인 음료입니다.
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 포도 쥬얼리 밀크티 (Iced, Large)
# 음식메뉴 성공
# ===============
# 향긋한 자스민 그린티로 만든 포도 밀크티와 상큼한 과즙의 포도 쥬얼리가 어우러진 시즌 한정 음료 (ONLY ICED), 음료에 포도쥬얼리(포도맛이 나는 펄)가 들어있습니다. 얼음량 고정인 음료이고, 토핑은 최대2개까지 가능합니다.
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 커피 밀크티 크러쉬 + 밀크폼 (Iced, Large)
# 음식메뉴 성공
# ===============
# 향긋한 블랙 밀크 티에 진한 커피를 더해 한여름 얼음과 함께 갈아 더욱 시원하게 즐기는 시즌 한정 음료 (ONLY ICED).  얼음량과 당도가 고정인 음료입니다.
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 포도 요거티 크러쉬 (Iced, Large)
# 음식메뉴 성공
# ===============
# 향긋한 자스민 그린티로 만든 요거티 크러쉬와 상큼한 과즙의 포도 쥬얼리가 어우러진 시즌 한정 음료 (ONLY ICED). 음료에 포도쥬얼리(포도맛이 나는 펄)가 들어 있습니다. 얼음량과 당도가 고정인 음료이고, 토핑은 최대2개까지 가능합니다.
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# [베스트 콤비네이션]
# 음식 카테고리 성공
# =========================================
# 블랙 밀크티 + 펄 (Large,Ice)
# 음식메뉴 성공
# ===============
# 공차 대표 메뉴 블랙밀크티와 쫄깃쫄깃한 펄의 콤비네이션
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 블랙 밀크티 + 펄 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 공차 대표 메뉴 블랙밀크티와 쫄깃쫄깃한 펄의 콤비네이션
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 블랙 밀크티 + 펄 (Large,Hot)
# 음식메뉴 성공
# ===============
# 공차 대표 메뉴 블랙밀크티와 쫄깃쫄깃한 펄의 콤비네이션
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 블랙 밀크티 + 펄 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 공차 대표 메뉴 블랙밀크티와 쫄깃쫄깃한 펄의 콤비네이션
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 타로 밀크티 + 펄 (Large,Ice)
# 음식메뉴 성공
# ===============
# 고소한 타로밀크티와 쫀득한 펄이 만난 공차의 베스트 셀러
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 타로 밀크티 + 펄 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 고소한 타로밀크티와 쫀득한 펄이 만난 공차의 베스트 셀러
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 타로 밀크티 + 펄 (Large,Hot)
# 음식메뉴 성공
# ===============
# 고소한 타로밀크티와 쫀득한 펄이 만난 공차의 베스트 셀러
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 타로 밀크티 + 펄 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 고소한 타로밀크티와 쫀득한 펄이 만난 공차의 베스트 셀러
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 초콜렛밀크티+밀크폼 (Large,Ice)
# 음식메뉴 성공
# ===============
# 공차만의 깊고 풍부한 초콜렛 밀크티에 부드러운 밀크폼을 더한 최고의 조합
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 초콜렛밀크티+밀크폼 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 공차만의 깊고 풍부한 초콜렛 밀크티에 부드러운 밀크폼을 더한 최고의 조합
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 밀크폼 얼그레이티+코코넛 (Large,Ice)
# 음식메뉴 성공
# ===============
# 베르가모트 향의 얼그레이티와 밀크폼의 조합에 숨겨진 베스트 콤비 쫄깃한 코코넛 토핑
# 음식정보 성공
# ===============
# 4200
# 금액 성공
# ===============
# 밀크폼 얼그레이티+코코넛 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 베르가모트 향의 얼그레이티와 밀크폼의 조합에 숨겨진 베스트 콤비 쫄깃한 코코넛 토핑
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 자몽 그린티 에이드+알로에 (Large,Ice)
# 음식메뉴 성공
# ===============
# 청량하고 쌉싸름한 자몽 그린티 에이드에 달콤함을 더해주는 알로에 토핑
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 자몽 그린티 에이드+알로에 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 청량하고 쌉싸름한 자몽 그린티 에이드에 달콤함을 더해주는 알로에 토핑
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 망고요구르트+화이트펄 (Large,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 망고 과육과 요구르트에 화이트펄의 꼬들꼬들함이 느껴지는 주스
# 음식정보 성공
# ===============
# 5200
# 금액 성공
# ===============
# 망고요구르트+화이트펄 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 망고 과육과 요구르트에 화이트펄의 꼬들꼬들함이 느껴지는 주스
# 음식정보 성공
# ===============
# 6400
# 금액 성공
# ===============
# [밀크티]
# 음식 카테고리 성공
# =========================================
# 그린 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 밀크의 조화
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 그린 밀크티 (Jumbo, Ice)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 밀크의 조화
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 그린 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 밀크의 조화
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 그린 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 밀크의 조화
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 우롱 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차에 밀크가 더해진 우롱밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 우롱 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차에 밀크가 더해진 우롱밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 우롱 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차에 밀크가 더해진 우롱밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 우롱 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차에 밀크가 더해진 우롱밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 블랙 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티(홍차)와 밀크의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 블랙 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티(홍차)와 밀크의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 블랙 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티(홍차)와 밀크의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 블랙 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티(홍차)와 밀크의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 얼그레이 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 베르가못 향의 얼그레이티(홍차)와 밀크가 부드러운 조화를 이루는 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 얼그레이 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 베르가못 향의 얼그레이티(홍차)와 밀크가 부드러운 조화를 이루는 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 얼그레이 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 베르가못 향의 얼그레이티(홍차)와 밀크가 부드러운 조화를 이루는 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 얼그레이 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 베르가못 향의 얼그레이티(홍차)와 밀크가 부드러운 조화를 이루는 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 윈터멜론 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론티와 부드러운 밀크가 더해진 윈터멜론 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 윈터멜론 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론티와 부드러운 밀크가 더해진 윈터멜론 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 윈터멜론 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론티와 부드러운 밀크가 더해진 윈터멜론 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 윈터멜론 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론티와 부드러운 밀크가 더해진 윈터멜론 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 타로 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 타로의 고소함과 밀크의 조합
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 타로 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 타로의 고소함과 밀크의 조합
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 타로 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 타로의 고소함과 밀크의 조합
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 타로 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 타로의 고소함과 밀크의 조합
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 카라멜 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티에 향기로운 카라멜향을 더한 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 카라멜 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티에 향기로운 카라멜향을 더한 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 카라멜 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티에 향기로운 카라멜향을 더한 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 카라멜 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 블랙티에 향기로운 카라멜향을 더한 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 초콜렛 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 부드러운 밀크에 녹아든 진한 초콜렛을 느낄 수 있는 초콜렛 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 초콜렛 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 부드러운 밀크에 녹아든 진한 초콜렛을 느낄 수 있는 초콜렛 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 초콜렛 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 부드러운 밀크에 녹아든 진한 초콜렛을 느낄 수 있는 초콜렛 밀크티
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 초콜렛 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 부드러운 밀크에 녹아든 진한 초콜렛을 느낄 수 있는 초콜렛 밀크티
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 차이 밀크티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 프리미엄 잎차만 골라, 블랙티 최적의 온도 95℃로 우려 스파이시한 풍미를 더하다 잎차로 직접 우려 낸 블랙티에 차이 파우더를 넣어 스파이시한 계피 향을 부드럽게 즐길 수 있는 밀크티
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 차이 밀크티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 프리미엄 잎차만 골라, 블랙티 최적의 온도 95℃로 우려 스파이시한 풍미를 더하다 잎차로 직접 우려 낸 블랙티에 차이 파우더를 넣어 스파이시한 계피 향을 부드럽게 즐길 수 있는 밀크티
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 차이 밀크티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 프리미엄 잎차만 골라, 블랙티 최적의 온도 95℃로 우려 스파이시한 풍미를 더하다 잎차로 직접 우려 낸 블랙티에 차이 파우더를 넣어 스파이시한 계피 향을 부드럽게 즐길 수 있는 밀크티
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 차이 밀크티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 프리미엄 잎차만 골라, 블랙티 최적의 온도 95℃로 우려 스파이시한 풍미를 더하다 잎차로 직접 우려 낸 블랙티에 차이 파우더를 넣어 스파이시한 계피 향을 부드럽게 즐길 수 있는 밀크티
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# [스무디]
# 음식 카테고리 성공
# =========================================
# 밀크 쿠앤크 스무디
# 음식메뉴 성공
# ===============
# 달콤한 쿠키앤크림과 밀크를 얼음과 함께 갈아만든 스무디
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 초코 쿠앤크 스무디
# 음식메뉴 성공
# ===============
# 진한 초콜렛과 달콤한쿠키앤크림을 밀크와 함께 갈아만든 오레오 초콜렛 스무디
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 타로 스무디
# 음식메뉴 성공
# ===============
# 고소한 타로를 밀크와 함께 갈아만든 달콤한 타로 스무디
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 망고 스무디
# 음식메뉴 성공
# ===============
# 농축된 달콤한 망고와 밀크를 함께 갈아만든 망고 스무디
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 레몬 요구르트 스무디
# 음식메뉴 성공
# ===============
# 새콤 달콤한 레몬 과즙과 요구르트를 얼음과 함께 갈아만든 스무디
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 청포도 스무디
# 음식메뉴 성공
# ===============
# 시원달콤한 청포도과즙과 알로에 알갱이가 쏙쏙 들어오는 재미가 일품인 청포도 스무디
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 제주그린티 스무디
# 음식메뉴 성공
# ===============
# 제주 유기농 그린티의 풍성한 향과 맛이 입안 가득 느껴지는 제주 유기농 그린티 스무디
# 음식정보 성공
# ===============
# 5300
# 금액 성공
# ===============
# 블랙 밀크티 크러쉬 (iced, Large)
# 음식메뉴 성공
# ===============
# 공차 No.1 메뉴인 블랙밀크티와 얼음을 함께 갈아 만든 크러쉬의 청량함과 쫀득쫀득한 펄의 식감을 즐길 수 있는 시그니처 음료
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# [그린티 에이드]
# 음식 카테고리 성공
# =========================================
# 자몽 그린티 에이드 (Large)
# 음식메뉴 성공
# ===============
# 달콤하고 쌉싸름한 자몽과 로즈마리가 만드는 새로운 하모니의 그린티에이드
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 자몽 그린티 에이드 (Jumbo)
# 음식메뉴 성공
# ===============
# 달콤하고 쌉싸름한 자몽과 로즈마리가 만드는 새로운 하모니의 그린티에이드
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 망고 그린티 에이드 (Large)
# 음식메뉴 성공
# ===============
# 시원하고 청량한 그린티 에이드와 달콤한 망고가 조화로운 망고 그린티 에이드
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 망고 그린티 에이드 (Jumbo)
# 음식메뉴 성공
# ===============
# 시원하고 청량한 그린티 에이드와 달콤한 망고가 조화로운 망고 그린티 에이드
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 청포도 그린티 에이드 (Large)
# 음식메뉴 성공
# ===============
# 쌉싸름한 그린티에 청포도와 라임청을 넣어 청량하고 달콤한 그린티 에이드
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 청포도 그린티 에이드 (Jumbo)
# 음식메뉴 성공
# ===============
# 쌉싸름한 그린티에 청포도와 라임청을 넣어 청량하고 달콤한 그린티 에이드
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 레몬 그린티 에이드 (Large)
# 음식메뉴 성공
# ===============
# 쌉싸름한 그린티에 레몬과 라임청을 넣어 청량하고 상큼한 그린티 에이드
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 레몬 그린티 에이드 (Jumbo)
# 음식메뉴 성공
# ===============
# 쌉싸름한 그린티에 레몬과 라임청을 넣어 청량하고 상큼한 그린티 에이드
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# [커피]
# 음식 카테고리 성공
# =========================================
# 아메리카노 (Ice)
# 음식메뉴 성공
# ===============
# 100% 아라비카 원두의 드립커피
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 아메리카노 (Hot)
# 음식메뉴 성공
# ===============
# 100% 아라비카 원두의 드립커피
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 얼그레이 아메리카노 (Ice)
# 음식메뉴 성공
# ===============
# 100% 아라비카 커피와 향긋한 얼그레이티가 만나 이뤄내는 Only공차 커피메뉴
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 얼그레이 아메리카노 (Hot)
# 음식메뉴 성공
# ===============
# 100% 아라비카 커피와 향긋한 얼그레이티가 만나 이뤄내는 Only공차 커피메뉴
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 더블 그린 카페 라떼 (Iced, Large)
# 음식메뉴 성공
# ===============
# 제주산 녹차로 만든 말차 라떼에 커피와 밀크폼을 더한 더블 그린 카페 라떼
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 더블 그린 카페 라떼 (Hot, Large)
# 음식메뉴 성공
# ===============
# 제주산 녹차로 만든 말차 라떼에 커피와 밀크폼을 더한 더블 그린 카페 라떼
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# [공차 스페셜]
# 음식 카테고리 성공
# =========================================
# 밀크폼 그린티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 그린티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 그린티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 그린티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 자스민 꽃잎을 함께 우려낸 그린티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 우롱티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 우롱티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 우롱티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 우롱티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향의 우롱차와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 윈터멜론티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론과 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 윈터멜론티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론과 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 윈터멜론티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론과 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 윈터멜론티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 달콤한 윈터멜론과 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 블랙티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 맛의 블랙티(홍차)와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 블랙티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 맛의 블랙티(홍차)와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 블랙티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 맛의 블랙티(홍차)와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 블랙티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 맛을 느낄 수 있는 맛의 블랙티(홍차)와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 얼그레이티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 베르가못향의 얼그레이티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 얼그레이티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 베르가못향의 얼그레이티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# 밀크폼 얼그레이티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 베르가못향의 얼그레이티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 밀크폼 얼그레이티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 베르가못향의 얼그레이티와 부드러운 밀크폼의 만남
# 음식정보 성공
# ===============
# 5100
# 금액 성공
# ===============
# [오리지널 티]
# 음식 카테고리 성공
# =========================================
# 자스민그린티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 향긋한 자스민 꽃잎을 함께 우려내는 그린티
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 자스민그린티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 향긋한 자스민 꽃잎을 함께 우려내는 그린티
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 자스민그린티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 향긋한 자스민 꽃잎을 함께 우려내는 그린티
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 자스민그린티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 향긋한 자스민 꽃잎을 함께 우려내는 그린티
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 우롱티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향을 간직한 고소한 우롱차
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 우롱티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향을 간직한 고소한 우롱차
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 우롱티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향을 간직한 고소한 우롱차
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 우롱티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 묵직하고 깊은 향을 간직한 고소한 우롱차
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 블랙티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 감미로운 맛을 느낄 수있는 대표적인 홍차, 블랙티
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 블랙티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 감미로운 맛을 느낄 수있는 대표적인 홍차, 블랙티
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 블랙티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 진한 향과 감미로운 맛을 느낄 수있는 대표적인 홍차, 블랙티
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 블랙티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 진한 향과 감미로운 맛을 느낄 수있는 대표적인 홍차, 블랙티
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 얼그레이티 (Large,Ice)
# 음식메뉴 성공
# ===============
# 향긋한 베르가못향이 가미된 얼그레이티
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 얼그레이티 (Large,Hot)
# 음식메뉴 성공
# ===============
# 향긋한 베르가못향이 가미된 얼그레이티
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 얼그레이티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
# 향긋한 베르가못향이 가미된 얼그레이티
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 얼그레이티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
# 향긋한 베르가못향이 가미된 얼그레이티
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# [주스]
# 음식 카테고리 성공
# =========================================
# 망고 주스  (Large)
# 음식메뉴 성공
# ===============
# 농축된 달콤한 망고의 입자가 느껴지는 달콤한 망고 주스
# 음식정보 성공
# ===============
# 4600
# 금액 성공
# ===============
# 망고 주스 (Jumbo)
# 음식메뉴 성공
# ===============
# 농축된 달콤한 망고의 입자가 느껴지는 달콤한 망고 주스
# 음식정보 성공
# ===============
# 5700
# 금액 성공
# ===============
# 레몬 요구르트 (Large)
# 음식메뉴 성공
# ===============
# 레몬 과육과 요구르트 농축액을 믹스한 새콤달콤한 레몬 요구르트
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 레몬 요구르트 (Jumbo)
# 음식메뉴 성공
# ===============
# 레몬 과육과 요구르트 농축액을 믹스한 새콤달콤한 레몬 요구르트
# 음식정보 성공
# ===============
# 5600
# 금액 성공
# ===============
# 망고 요구르트 (Large)
# 음식메뉴 성공
# ===============
# 농축된 달콤한 망고의 입자와 새콤한 요구르트의 조합, 망고 요구르트
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 망고 요구르트 (Jumbo)
# 음식메뉴 성공
# ===============
# 농축된 달콤한 망고의 입자와 새콤한 요구르트의 조합, 망고 요구르트
# 음식정보 성공
# ===============
# 6100
# 금액 성공
# ===============
# [디저트]
# 음식 카테고리 성공
# =========================================
# 요구르트 슈스틱
# 음식메뉴 성공
# ===============
# 기다란 슈안에 상큼한 요구르트슈크림을 듬뿍 넣어 만든 시원하게 즐기는 아이스 슈스틱
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 초코 슈스틱
# 음식메뉴 성공
# ===============
# 기다란 슈안에 달콤한 초코슈크림을 듬뿍 넣어 만든 시원하게 즐기는 아이스 슈스틱
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 소시지 패스츄리
# 음식메뉴 성공
# ===============
# 달콤하고 바삭한 패스츄리안의 짭짤한 소시지의 조화가 좋은 핫 소시지 패스츄리
# 음식정보 성공
# ===============
# 3300
# 금액 성공
# ===============
# [후르츠 티]
# 음식 카테고리 성공
# =========================================
# 허니 레몬 티 (Large, Ice)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 허니 레몬 티 (Jumbo, Ice)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 허니 레몬 티 (Large, Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 허니 레몬 티 (Jumbo, Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 허니 자몽 티 (Large,Ice)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 허니 자몽 티 (Jumbo,Ice)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# 허니 자몽 티 (Large,Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4300
# 금액 성공
# ===============
# 허니 자몽 티 (Jumbo,Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5400
# 금액 성공
# ===============
# ===========끝===========
# ---4번 식당파싱 시작 ---
# 서울 강남구 역삼동 668-9 지하1층
# 주소 뽑기 성공
# =========================================
#
# 서울포케‘서퍼스 밀(Surfer’s meal)'이라고도 하는 건강하고 균형잡힌 하와이안 음식 '포케(Poke)'를 이제 저희 서울포케와 함께 편하게 배달로 즐기세요!
# 포케는 높은 칼로리의 식사가 부담스러운 분에겐 가벼움을, 샐러드만으로 식사를 대체하기엔 허전한 분에겐 든든함을 선사합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 쌀 (국내산), 콩 (수입산 캐나다, 중국, 미얀마), 연어 (노르웨이산), 참치 (남태평양,인도양), 새우 (베트남)
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [포케]
# 음식 카테고리 성공
# =========================================
# [샐러드]
# 음식 카테고리 성공
# =========================================
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [포케]
# 음식 카테고리 성공
# =========================================
# 아히 포케_참치
# 음식메뉴 성공
# ===============
# 참치,현미보리밥,믹스그린,적채,당근,방울토마토,초생강,해초무침,날치알,적환무,풋콩,후리카케
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 살몬 포케_연어
# 음식메뉴 성공
# ===============
# 연어,현미보리밥,믹스그린,적채,당근,양파,망고,초생강,해초무침,날치알,적환무,풋콩,후리카케
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 서울 포케 (연어+참치)
# 음식메뉴 성공
# ===============
# 참치,연어,현미보리밥,믹스그린,적채,당근,양파,망고,초생강,해초무침,날치알,적환무,풋콩,후리카케
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 쉬림프 포케_새우
# 음식메뉴 성공
# ===============
# 새우,현미보리밥,믹스그린,적채,당근,파인애플,초생강,해초무침,날치알,적환무,풋콩
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# [샐러드]
# 음식 카테고리 성공
# =========================================
# 두부샐러드
# 음식메뉴 성공
# ===============
# 두부,믹스그린,양파,아몬드,멸치,연근
# 음식정보 성공
# ===============
# 11000
# 금액 성공
# ===============
# 버섯 샐러드
# 음식메뉴 성공
# ===============
# 버섯,믹스그린,양파,아몬드,연근
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# 리코타 치즈 샐러드
# 음식메뉴 성공
# ===============
# 리코타치즈, 믹스그린, 방울토마토, 아몬드, 크랜베리
# 음식정보 성공
# ===============
# 12500
# 금액 성공
# ===============
# 그린 샐러드
# 음식메뉴 성공
# ===============
# 오늘의 신선한 야채
# 음식정보 성공
# ===============
# 5900
# 금액 성공
# ===============
# [사이드메뉴]
# 음식 카테고리 성공
# =========================================
# 코코넛 쉬림프
# 음식메뉴 성공
# ===============
# 새우,코코넛롱,프렌치 프라이,파슬리,스윗 칠리소스
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 갈릭프렌치프라이
# 음식메뉴 성공
# ===============
# 프렌치 프라이,올리브,마늘오일,파슬리
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 크랩랑군
# 음식메뉴 성공
# ===============
# 게살,새우,리코타 치즈,믹스 그린, 스윗 칠리 소스
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# [음료]
# 음식 카테고리 성공
# =========================================
# 콜라 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 스프라이트 (355ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 씨그램 라임 (350ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 1800
# 금액 성공
# ===============
# 디톡스 워터 (450ml)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# ===========끝===========
# ---5번 식당파싱 시작 ---
# 서울 강남구 역삼동 814-6 스타플렉스 4층
# 주소 뽑기 성공
# =========================================
#
# No. 1 Cultureplex CGV!
# 고객에게 색다른 즐거움을 선사하기 위해 항상 노력하는 CGV 입니다.
# 이제 CGV에서만 먹을 수 있는 팝콘을 푸드플라이를 통해 언제 어디서든 즐기세요.
# 기타 제휴카드 할인 및 적립은 불가합니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
# 팝콘-옥수수 :  미국산핫도그- 소시지(돼지고기) :  국내산나쵸 : 미국산
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [콤보]
# 음식 카테고리 성공
# =========================================
# [단품]
# 음식 카테고리 성공
# =========================================
# [콤보]
# 음식 카테고리 성공
# =========================================
# CGV 콤보
# 음식메뉴 성공
# ===============
# 고소팝콘(L) 1 + 탄산(M) 2+ + 스낵추가
# 음식정보 성공
# ===============
# 8500
# 금액 성공
# ===============
# 스몰세트
# 음식메뉴 성공
# ===============
# 고소팝콘(L) 1 + 탄산(M) 1 + 스낵추가
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 라지콤보
# 음식메뉴 성공
# ===============
# 즉석 버터구이 오징어는 배달이 불가합니다.고소팝콘(L) 2 + 탄산(L) 2 + 스낵추가
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# [단품]
# 음식 카테고리 성공
# =========================================
# 팝콘 (L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 탄산 (M)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 탄산 (L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2500
# 금액 성공
# ===============
# 복숭아 아이스티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 에이드 (M)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 에이드 (L)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 나초
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 오징어
# 음식메뉴 성공
# ===============
# 팩오징어 (완제품)
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# ===========끝===========
# ---6번 식당파싱 시작 ---
# 서울 강남구 역삼동 812-8
# 주소 뽑기 성공
# =========================================
#
# 다양한 디저트와 천연발효종으로 만든 건강한 빵들을 맛볼 수 있는 곳입니다.
# 신사동 가로수길에 교육청 인가받은 베이킹전문 아카데미를 운영하고 있는 브랜드라 더욱 믿고 먹을 수 있습니다.
# 마망갸또의 빵은 10일간 숙성시킨 천연발효종을 이용하며 최고급 프랑스산 버터와 밀가루등 최상의 재료로 당일 만들어 당일에만 판매하고 있습니다.
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 밀가루 : 캐나다산,미국산,프랑스산
# 우유,달걀 : 국내산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 10000
# 최소 금액 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# [구움과자]
# 음식 카테고리 성공
# =========================================
# [기타]
# 음식 카테고리 성공
# =========================================
# [빙수]
# 음식 카테고리 성공
# =========================================
# [디저트]
# 음식 카테고리 성공
# =========================================
# [생카라멜]
# 음식 카테고리 성공
# =========================================
# [음료]
# 음식 카테고리 성공
# =========================================
# 에스프레소
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 롱블랙 (Only Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 아메리카노
# 음식메뉴 성공
# ===============
# 연간생산량이 컨테이너 5개 정도의 양 밖에 되지 않는 Ethiopia Yirgacheffe Chelba 가 30%이상 들어간 100% 아라비카 커피로만 블렌딩되어 있습니다.
# 음식정보 성공
# ===============
# 4000
# 금액 성공
# ===============
# 플랫 화이트 (Only Hot)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 카페 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 카푸치노
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 카페모카
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 바닐라라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 솔티드 카라멜 라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 카라멜 아인슈페너
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 카라멜 밀크티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 말차라떼
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5500
# 금액 성공
# ===============
# 오랜지 카라멜 에이드 (Only Iced)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 얼그레이 피치 에이드 (Only Iced)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 아쿠아 오렌지 에이드 (Only Iced)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 얼그레이 티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 블루베리 히비스커스 티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 페퍼민트루이보스 티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 바닐라 블랙티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 차이나 블랙퍼스트
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 겐마이 녹차
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# 카모마일메들리 티
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 5000
# 금액 성공
# ===============
# [구움과자]
# 음식 카테고리 성공
# =========================================
# 라즈베리 피낭시에
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 오렌지피낭시에
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 얼그레이 마들렌
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 바닐라허니 마들렌
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 바닐라 마들렌
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2000
# 금액 성공
# ===============
# 말차 마들렌
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2200
# 금액 성공
# ===============
# 초코칩피칸쿠키
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 더블쇼콜라쿠키
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 말차화이트쿠키
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 오트밀크랜베리쿠키
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2300
# 금액 성공
# ===============
# 쇼콜라머핀
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2700
# 금액 성공
# ===============
# 크림치즈머핀
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 2700
# 금액 성공
# ===============
# 쇼콜라스콘
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3200
# 금액 성공
# ===============
# 말차넛츠 브라우니
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 코코넛 브라우니
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 더블버터 스콘
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3200
# 금액 성공
# ===============
# 카라멜 스콘
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3200
# 금액 성공
# ===============
# 리얼당근 파운드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 카라멜 헤이즐넛 파운드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 머드쇼콜라 파운드
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3800
# 금액 성공
# ===============
# [기타]
# 음식 카테고리 성공
# =========================================
# 홈베이킹스쿨 서적
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 디저트마케팅 서적
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 13500
# 금액 성공
# ===============
# 아이스 팩
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 500
# 금액 성공
# ===============
# [빙수]
# 음식 카테고리 성공
# =========================================
# 카라멜 눈꽃빙수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# 말차카라멜 눈꽃빙수
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 15000
# 금액 성공
# ===============
# [디저트]
# 음식 카테고리 성공
# =========================================
# 카라멜 롤케이크(조각)
# 음식메뉴 성공
# ===============
# 마망갸또의 시그니쳐 케익 순 우유생크림으로 만든 폭신한 크림과 촉촉한 비스퀴의 만남
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 카라멜 티라미수 타르트(조각)
# 음식메뉴 성공
# ===============
# 고메버터로 만든 정교한 타르트 쉘과 아라비카 원두와 마스카르포네 치즈로만든 티라미수를 동시에!
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 말차카라멜 롤케익 (조각)
# 음식메뉴 성공
# ===============
# 담백한 말차 생카라멜 크림과 부드러운 수플레 롤의 만남
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 당근케이크 (조각)
# 음식메뉴 성공
# ===============
# 피칸과 당근으로 만든 시트마다 당근& 사과잼과 치즈프로스팅이 듬뿍
# 음식정보 성공
# ===============
# 6000
# 금액 성공
# ===============
# 카라멜 치즈케이크 (조각)
# 음식메뉴 성공
# ===============
# 수제 생 가라멜의 진한 매력을 맛 볼 수 있는 묵직하고 진한 치즈케이크
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 카라멜 쇼콜라 무스 (조각)
# 음식메뉴 성공
# ===============
# 쇼콜라 조콩드에 바삭한 로쉐가 들어가 다양한 식감이 특징인 쇼콜라 무스
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 카라멜 롤케이크 (홀사이즈 / 냉동)
# 음식메뉴 성공
# ===============
# 제품의 질을 위해서 냉동상태로 배송되오니 한시간~두시간 정도 해동 후 드시면 더욱 맛있게 즐기실 수 있습니다.마망갸또의 시그니쳐 케익 순 우유생크림으로 만든 폭신한 크림과 촉촉한 비스퀴의 만남
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 말차 카라멜 롤케이크 (홀사이즈 / 냉동)
# 음식메뉴 성공
# ===============
# 제품의 질을 위해서 냉동상태로 배송되오니 한시간~두시간 정도 해동 후 드시면 더욱 맛있게 즐기실 수 있습니다.
# 음식정보 성공
# ===============
# 35000
# 금액 성공
# ===============
# 티라미수 롤케익 (조각)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 7000
# 금액 성공
# ===============
# 뉴욕치즈케이크 (조각)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6500
# 금액 성공
# ===============
# 트리플쇼콜라 롤 (조각)
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 카라멜롤 토르테
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 6800
# 금액 성공
# ===============
# 카라멜 바나나 푸딩
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4500
# 금액 성공
# ===============
# 카라멜 에끌레어
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 바닐라 에끌레어
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# 쇼콜라 에끌레어
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 4800
# 금액 성공
# ===============
# [생카라멜]
# 음식 카테고리 성공
# =========================================
# 라즈베리 생카라멜
# 음식메뉴 성공
# ===============
# 생크림과 유기농설탕 등으로 오랜시간 동냄비로 끓여낸 수제 생 카라멜
# 음식정보 성공
# ===============
# 1200
# 금액 성공
# ===============
# 얼그레이 생카라멜
# 음식메뉴 성공
# ===============
# 생크림과 유기농설탕 등으로 오랜시간 동냄비로 끓여낸 수제 생 카라멜
# 음식정보 성공
# ===============
# 1200
# 금액 성공
# ===============
# 헤이즐넛 생카라멜
# 음식메뉴 성공
# ===============
# 생크림과 유기농설탕 등으로 오랜시간 동냄비로 끓여낸 수제 생 카라멜
# 음식정보 성공
# ===============
# 1200
# 금액 성공
# ===============
# 키나코 생카라멜
# 음식메뉴 성공
# ===============
# 생크림과 유기농설탕 등으로 오랜시간 동냄비로 끓여낸 수제 생 카라멜
# 음식정보 성공
# ===============
# 1200
# 금액 성공
# ===============
# 바닐라 생카라멜
# 음식메뉴 성공
# ===============
# 생크림과 유기농설탕 등으로 오랜시간 동냄비로 끓여낸 수제 생 카라멜
# 음식정보 성공
# ===============
# 1200
# 금액 성공
# ===============
# 시오 생카라멜
# 음식메뉴 성공
# ===============
# 생크림과 유기농설탕 등으로 오랜시간 동냄비로 끓여낸 수제 생 카라멜
# 음식정보 성공
# ===============
# 1200
# 금액 성공
# ===============
# 생카라멜 10개 선물세트
# 음식메뉴 성공
# ===============
# 생크림과 유기농설탕 등으로 오랜시간 동냄비로 끓여낸 수제 생 카라멜
# 음식정보 성공
# ===============
# 12000
# 금액 성공
# ===============
# ===========끝===========
# ---7번 식당파싱 시작 ---
# 서울 강남구 역삼동 730-4
# 주소 뽑기 성공
# =========================================
#
# 좋은  품질의 커피는, 만드는 사람의 진실된 마음으로부터 시작됩니다.
# 우리는 원료에 터무니 없는 이윤을 더하지 않고 비싼 인테리어 비용을 가격에 더하지 않았습니다.
# 우리는 오로지 커피와 손님을 위하여 커피가격의 거품을 제거하고 최상의 원두로 맛있는 커피를 내립니다.
#
# 언제 어디서나, 누구나 즐길 수 있는 맛있는 커피.
# 더블유 카페가대한민국 커피의 새로운 기준을 제시합니다.
# 우리동네 원더한 커피숍.
#
# 9카페
#
#
# 가게 소개 뽑기 성공
# =========================================
#
# 닭고기,게살 : 국내산
# 소고기 : 호주산
#
#
# 가게 원산지 뽑기 성공
# =========================================
# 8000
# 최소 금액 성공
# =========================================
# [핫도그 (Hotdog)]
# 음식 카테고리 성공
# =========================================
# [샌드위치 (Sandwich)]
# 음식 카테고리 성공
# =========================================
# [샐러드 (Salad)]
# 음식 카테고리 성공
# =========================================
# [마카롱(Macaron)]
# 음식 카테고리 성공
# =========================================
# [커피 (Coffee)]
# 음식 카테고리 성공
# =========================================
# [라떼 (Latte)]
# 음식 카테고리 성공
# =========================================
# [수제과일차]
# 음식 카테고리 성공
# =========================================
# [에이드 (Ade)]
# 음식 카테고리 성공
# =========================================
# [요거트 (Yogurt)]
# 음식 카테고리 성공
# =========================================
# [생과일주스 (Juice)]
# 음식 카테고리 성공
# =========================================
# [티 (Tea)]
# 음식 카테고리 성공
# =========================================
# [핫도그 (Hotdog)]
# 음식 카테고리 성공
# =========================================
# 베이직 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3100
# 금액 성공
# ===============
# 비프치즈 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 크림어니언 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# 렐리쉬 핫도그
# 음식메뉴 성공
# ===============
#
# 음식정보 성공
# ===============
# 3500
# 금액 성공
# ===============
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4db945f9cef3> in <module>
#     210             name=food_menu,
#     211             price=food_moneys,
# --> 212             food_info=food_info,
#     213             )
#     214
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      80         def create_method(name, method):
#      81             def manager_method(self, *args, **kwargs):
# ---> 82                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      83             manager_method.__name__ = method.__name__
#      84             manager_method.__doc__ = method.__doc__
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/django/db/models/query.py in create(self, **kwargs)
#     411         obj = self.model(**kwargs)
#     412         self._for_write = True
# --> 413         obj.save(force_insert=True, using=self.db)
#     414         return obj
#     415
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/django/db/models/base.py in save(self, force_insert, force_update, using, update_fields)
#     716
#     717         self.save_base(using=using, force_insert=force_insert,
# --> 718                        force_update=force_update, update_fields=update_fields)
#     719     save.alters_data = True
#     720
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/django/db/models/base.py in save_base(self, raw, force_insert, force_update, using, update_fields)
#     746             if not raw:
#     747                 self._save_parents(cls, using, update_fields)
# --> 748             updated = self._save_table(raw, cls, force_insert, force_update, using, update_fields)
#     749         # Store the database on which the object was saved
#     750         self._state.db = using
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/django/db/transaction.py in __exit__(self, exc_type, exc_value, traceback)
#     210                     # Commit transaction
#     211                     try:
# --> 212                         connection.commit()
#     213                     except DatabaseError:
#     214                         try:
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/django/db/backends/base/base.py in commit(self)
#     259         self.validate_thread_sharing()
#     260         self.validate_no_atomic_block()
# --> 261         self._commit()
#     262         # A successful commit means that the database connection works.
#     263         self.errors_occurred = False
#
# ~/.local/share/virtualenvs/foodfly-av6wuyWs/lib/python3.6/site-packages/django/db/backends/base/base.py in _commit(self)
#     237         if self.connection is not None:
#     238             with self.wrap_database_errors:
# --> 239                 return self.connection.commit()
#     240
#     241     def _rollback(self):
#
# KeyboardInterrupt:
